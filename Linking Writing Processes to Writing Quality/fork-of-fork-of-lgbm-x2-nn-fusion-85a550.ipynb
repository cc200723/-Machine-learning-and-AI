# %% [markdown]
# This notebook ensembles the following models
# - https://www.kaggle.com/code/yunsuxiaozi/writing-quality-fusion-notebook
# - https://www.kaggle.com/code/cody11null/lgbm-x2-nn
#
# If you find it useful, please consider appreciating the above works.

# %% [markdown]
# # LightAutoML installation

# %%
# !pip install --no-index -U --find-links=/kaggle/input/lightautoml-038-dependecies lightautoml==0.3.8
# !pip install --no-index -U --find-links=/kaggle/input/lightautoml-038-dependecies pandas==2.0.3
# Out:
# Looking in links: /kaggle/input/lightautoml-038-dependecies
# Processing /kaggle/input/lightautoml-038-dependecies/lightautoml-0.3.8-py3-none-any.whl
# Processing /kaggle/input/lightautoml-038-dependecies/AutoWoE-1.3.2-py3-none-any.whl (from lightautoml==0.3.8)
# Requirement already satisfied: catboost>=0.26.1 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (1.2.2)
# Processing /kaggle/input/lightautoml-038-dependecies/cmaes-0.10.0-py3-none-any.whl (from lightautoml==0.3.8)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (0.24)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (3.1.2)
# Processing /kaggle/input/lightautoml-038-dependecies/joblib-1.2.0-py3-none-any.whl (from lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/json2html-1.3.0.tar.gz (from lightautoml==0.3.8)
# done
# Processing /kaggle/input/lightautoml-038-dependecies/lightgbm-3.2.1-py3-none-manylinux1_x86_64.whl (from lightautoml==0.3.8)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (3.1)
# Requirement already satisfied: numpy>=1.22 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (1.24.3)
# Requirement already satisfied: optuna in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (3.4.0)
# Processing /kaggle/input/lightautoml-038-dependecies/pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/poetry_core-1.8.1-py3-none-any.whl (from lightautoml==0.3.8)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (6.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (1.2.2)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (0.12.2)
# Requirement already satisfied: statsmodels<=0.14.0 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (0.14.0)
# Requirement already satisfied: torch<=2.0.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (2.0.0+cpu)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lightautoml==0.3.8) (4.66.1)
# Processing /kaggle/input/lightautoml-038-dependecies/StrEnum-0.4.15-py3-none-any.whl (from autowoe>=1.2->lightautoml==0.3.8)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from autowoe>=1.2->lightautoml==0.3.8) (3.7.3)
# Requirement already satisfied: pytest in /opt/conda/lib/python3.10/site-packages (from autowoe>=1.2->lightautoml==0.3.8) (7.4.3)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.10/site-packages (from autowoe>=1.2->lightautoml==0.3.8) (2023.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from autowoe>=1.2->lightautoml==0.3.8) (1.11.3)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinx-7.2.6-py3-none-any.whl (from autowoe>=1.2->lightautoml==0.3.8)
# Requirement already satisfied: sphinx-rtd-theme in /opt/conda/lib/python3.10/site-packages (from autowoe>=1.2->lightautoml==0.3.8) (0.2.4)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from catboost>=0.26.1->lightautoml==0.3.8) (0.20.1)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from catboost>=0.26.1->lightautoml==0.3.8) (5.16.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from catboost>=0.26.1->lightautoml==0.3.8) (1.16.0)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm<=3.2.1,>=2.3->lightautoml==0.3.8) (0.41.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas<2.0.0->lightautoml==0.3.8) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22->lightautoml==0.3.8) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.10/site-packages (from statsmodels<=0.14.0->lightautoml==0.3.8) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /opt/conda/lib/python3.10/site-packages (from statsmodels<=0.14.0->lightautoml==0.3.8) (21.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<=2.0.0,>=1.9.0->lightautoml==0.3.8) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch<=2.0.0,>=1.9.0->lightautoml==0.3.8) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<=2.0.0,>=1.9.0->lightautoml==0.3.8) (1.12)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.10/site-packages (from holidays->lightautoml==0.3.8) (2.3.1)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.10/site-packages (from holidays->lightautoml==0.3.8) (0.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->lightautoml==0.3.8) (2.1.3)
# Requirement already satisfied: alembic>=1.5.0 in /opt/conda/lib/python3.10/site-packages (from optuna->lightautoml==0.3.8) (1.12.1)
# Requirement already satisfied: colorlog in /opt/conda/lib/python3.10/site-packages (from optuna->lightautoml==0.3.8) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from optuna->lightautoml==0.3.8) (2.0.20)
# Requirement already satisfied: Mako in /opt/conda/lib/python3.10/site-packages (from alembic>=1.5.0->optuna->lightautoml==0.3.8) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->autowoe>=1.2->lightautoml==0.3.8) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna->lightautoml==0.3.8) (2.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->catboost>=0.26.1->lightautoml==0.3.8) (8.2.3)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.10/site-packages (from pytest->autowoe>=1.2->lightautoml==0.3.8) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/lib/python3.10/site-packages (from pytest->autowoe>=1.2->lightautoml==0.3.8) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/conda/lib/python3.10/site-packages (from pytest->autowoe>=1.2->lightautoml==0.3.8) (1.1.3)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pytest->autowoe>=1.2->lightautoml==0.3.8) (2.0.1)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_applehelp-1.0.7-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_devhelp-1.0.5-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_htmlhelp-2.0.4-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_serializinghtml-1.1.9-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/sphinxcontrib_qthelp-1.0.6-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Requirement already satisfied: Pygments>=2.14 in /opt/conda/lib/python3.10/site-packages (from sphinx->autowoe>=1.2->lightautoml==0.3.8) (2.16.1)
# Requirement already satisfied: docutils<0.21,>=0.18.1 in /opt/conda/lib/python3.10/site-packages (from sphinx->autowoe>=1.2->lightautoml==0.3.8) (0.20.1)
# Requirement already satisfied: snowballstemmer>=2.0 in /opt/conda/lib/python3.10/site-packages (from sphinx->autowoe>=1.2->lightautoml==0.3.8) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /opt/conda/lib/python3.10/site-packages (from sphinx->autowoe>=1.2->lightautoml==0.3.8) (2.12.1)
# Processing /kaggle/input/lightautoml-038-dependecies/alabaster-0.7.13-py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Processing /kaggle/input/lightautoml-038-dependecies/imagesize-1.4.1-py2.py3-none-any.whl (from sphinx->autowoe>=1.2->lightautoml==0.3.8)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.10/site-packages (from sphinx->autowoe>=1.2->lightautoml==0.3.8) (2.31.0)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<=2.0.0,>=1.9.0->lightautoml==0.3.8) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx->autowoe>=1.2->lightautoml==0.3.8) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx->autowoe>=1.2->lightautoml==0.3.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx->autowoe>=1.2->lightautoml==0.3.8) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.25.0->sphinx->autowoe>=1.2->lightautoml==0.3.8) (2023.7.22)
# Building wheels for collected packages: json2html
# done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7591 sha256=acb8420a06ce8f7d92fd54db1fe110018fa51fc404c0fda0cfb6861e343fbd7d
#   Stored in directory: /root/.cache/pip/wheels/03/04/0d/34912ecabd9128a537a032c0fc15c6c46e734fb5fe3a14536c
# Successfully built json2html
# Installing collected packages: StrEnum, json2html, sphinxcontrib-jsmath, poetry-core, joblib, imagesize, cmaes, alabaster, pandas, lightgbm, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, sphinx, autowoe, lightautoml
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.3.2
#     Uninstalling joblib-1.3.2:
#       Successfully uninstalled joblib-1.3.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 3.3.2
#     Uninstalling lightgbm-3.3.2:
#       Successfully uninstalled lightgbm-3.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beatrix-jupyterlab 2023.814.150030 requires jupyter-server~=1.16, but you have jupyter-server 2.10.0 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyterlab~=3.4, but you have jupyterlab 4.0.5 which is incompatible.
# fitter 1.6.0 requires joblib<2.0.0,>=1.3.1, but you have joblib 1.2.0 which is incompatible.
# fitter 1.6.0 requires pandas<3.0.0,>=2.0.3, but you have pandas 1.5.3 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.3 which is incompatible.
# tensorflowjs 4.13.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed StrEnum-0.4.15 alabaster-0.7.13 autowoe-1.3.2 cmaes-0.10.0 imagesize-1.4.1 joblib-1.2.0 json2html-1.3.0 lightautoml-0.3.8 lightgbm-3.2.1 pandas-1.5.3 poetry-core-1.8.1 sphinx-7.2.6 sphinxcontrib-applehelp-1.0.7 sphinxcontrib-devhelp-1.0.5 sphinxcontrib-htmlhelp-2.0.4 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.6 sphinxcontrib-serializinghtml-1.1.9
# Looking in links: /kaggle/input/lightautoml-038-dependecies
# Processing /kaggle/input/lightautoml-038-dependecies/pandas-2.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from pandas==2.0.3) (1.24.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.0.3) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beatrix-jupyterlab 2023.814.150030 requires jupyter-server~=1.16, but you have jupyter-server 2.10.0 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyterlab~=3.4, but you have jupyterlab 4.0.5 which is incompatible.
# fitter 1.6.0 requires joblib<2.0.0,>=1.3.1, but you have joblib 1.2.0 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# lightautoml 0.3.8 requires pandas<2.0.0, but you have pandas 2.0.3 which is incompatible.
# momepy 0.6.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.24.3 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.3 which is incompatible.
# tensorflowjs 4.13.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.24.3 which is incompatible.
# Successfully installed pandas-2.0.3

# %%
# %matplotlib inline
import gc
import os
import itertools
import pickle
import re
import time
from random import choice, choices
from functools import reduce
from tqdm import tqdm
from itertools import cycle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from functools import reduce
from itertools import cycle
from scipy import stats
from scipy.stats import skew, kurtosis
from sklearn import metrics, model_selection, preprocessing, linear_model, ensemble, decomposition, tree
import lightgbm as lgb
import torch

# %% [markdown]
# ## Load Data

# %%
INPUT_DIR = '../input/linking-writing-processes-to-writing-quality'
train_logs = pd.read_csv(f'{INPUT_DIR}/train_logs.csv')
train_scores = pd.read_csv(f'{INPUT_DIR}/train_scores.csv')
test_logs = pd.read_csv(f'{INPUT_DIR}/test_logs.csv')
ss_df = pd.read_csv(f'{INPUT_DIR}/sample_submission.csv')

# %%
train_essays = pd.read_csv('../input/writing-quality-challenge-constructed-essays/train_essays_02.csv')
train_essays.index = train_essays["Unnamed: 0"]
train_essays.index.name = None
train_essays.drop(columns=["Unnamed: 0"], inplace=True)
train_essays.head()
# Out:
#                                                       essay
# 001519c8  qqqqqqqqq qq qqqqq qq qqqq qqqq.  qqqqqq qqq q...
# 0022f953  qqqq qq qqqqqqqqqqq ? qq qq qqq qqq qqq, qqqqq...
# 0042269b  qqqqqqqqqqq qq qqqqq qqqqqqqqq qq qqqqqqqqqqq ...
# 0059420b  qq qqqqqqq qqqqqq qqqqqqqqqqqqq qqqq q qqqq qq...
# 0075873a  qqqqqqqqqqq qq qqq qqqqq qq qqqqqqqqqq, qqq qq...

# %% [markdown]
# ## Feature Engineering

# %%
# Function to construct essays copied from here (small adjustments): https://www.kaggle.com/code/kawaiicoderuwu/essay-contructor

def getEssays(df):
    textInputDf = df[['id', 'activity', 'cursor_position', 'text_change']]
    textInputDf = textInputDf[textInputDf.activity != 'Nonproduction']
    valCountsArr = textInputDf['id'].value_counts(sort=False).values
    lastIndex = 0
    essaySeries = pd.Series()
    for index, valCount in enumerate(valCountsArr):
        currTextInput = textInputDf[['activity', 'cursor_position', 'text_change']].iloc[lastIndex : lastIndex + valCount]
        lastIndex += valCount
        essayText = ""
        for Input in currTextInput.values:
            if Input[0] == 'Replace':
                replaceTxt = Input[2].split(' => ')
                essayText = essayText[:Input[1] - len(replaceTxt[1])] + replaceTxt[1] +\
                essayText[Input[1] - len(replaceTxt[1]) + len(replaceTxt[0]):]
                continue
            if Input[0] == 'Paste':
                essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
                continue
            if Input[0] == 'Remove/Cut':
                essayText = essayText[:Input[1]] + essayText[Input[1] + len(Input[2]):]
                continue
            if "M" in Input[0]:
                croppedTxt = Input[0][10:]
                splitTxt = croppedTxt.split(' To ')
                valueArr = [item.split(', ') for item in splitTxt]
                moveData = (int(valueArr[0][0][1:]), 
                            int(valueArr[0][1][:-1]), 
                            int(valueArr[1][0][1:]), 
                            int(valueArr[1][1][:-1]))
                if moveData[0] != moveData[2]:
                    if moveData[0] < moveData[2]:
                        essayText = essayText[:moveData[0]] + essayText[moveData[1]:moveData[3]] +\
                        essayText[moveData[0]:moveData[1]] + essayText[moveData[3]:]
                    else:
                        essayText = essayText[:moveData[2]] + essayText[moveData[0]:moveData[1]] +\
                        essayText[moveData[2]:moveData[0]] + essayText[moveData[1]:]
                continue
            essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
        essaySeries[index] = essayText
    essaySeries.index =  textInputDf['id'].unique()
    return pd.DataFrame(essaySeries, columns=['essay'])

# %%
# Helper functions

def q1(x):
    return x.quantile(0.25)
def q3(x):
    return x.quantile(0.75)

# %%
AGGREGATIONS = ['count', 'mean', 'std', 'min', 'max', 'first', 'last', 'sem', q1, 'median', q3, 'skew', pd.DataFrame.kurt, 'sum']

def split_essays_into_sentences(df):
    essay_df = df
    essay_df['id'] = essay_df.index
    essay_df['sent'] = essay_df['essay'].apply(lambda x: re.split('\\.|\\?|\\!',x))
    essay_df = essay_df.explode('sent')
    essay_df['sent'] = essay_df['sent'].apply(lambda x: x.replace('\n','').strip())
    # Number of characters in sentences
    essay_df['sent_len'] = essay_df['sent'].apply(lambda x: len(x))
    # Number of words in sentences
    essay_df['sent_word_count'] = essay_df['sent'].apply(lambda x: len(x.split(' ')))
    essay_df = essay_df[essay_df.sent_len!=0].reset_index(drop=True)
    return essay_df

def compute_sentence_aggregations(df):
    sent_agg_df = pd.concat(
        [df[['id','sent_len']].groupby(['id']).agg(AGGREGATIONS), df[['id','sent_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1
    )
    sent_agg_df.columns = ['_'.join(x) for x in sent_agg_df.columns]
    sent_agg_df['id'] = sent_agg_df.index
    sent_agg_df = sent_agg_df.reset_index(drop=True)
    sent_agg_df.drop(columns=["sent_word_count_count"], inplace=True)
    sent_agg_df = sent_agg_df.rename(columns={"sent_len_count":"sent_count"})
    return sent_agg_df

def split_essays_into_paragraphs(df):
    essay_df = df
    essay_df['id'] = essay_df.index
    essay_df['paragraph'] = essay_df['essay'].apply(lambda x: x.split('\n'))
    essay_df = essay_df.explode('paragraph')
    # Number of characters in paragraphs
    essay_df['paragraph_len'] = essay_df['paragraph'].apply(lambda x: len(x)) 
    # Number of words in paragraphs
    essay_df['paragraph_word_count'] = essay_df['paragraph'].apply(lambda x: len(x.split(' ')))
    essay_df = essay_df[essay_df.paragraph_len!=0].reset_index(drop=True)
    return essay_df

def compute_paragraph_aggregations(df):
    paragraph_agg_df = pd.concat(
        [df[['id','paragraph_len']].groupby(['id']).agg(AGGREGATIONS), df[['id','paragraph_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1
    ) 
    paragraph_agg_df.columns = ['_'.join(x) for x in paragraph_agg_df.columns]
    paragraph_agg_df['id'] = paragraph_agg_df.index
    paragraph_agg_df = paragraph_agg_df.reset_index(drop=True)
    paragraph_agg_df.drop(columns=["paragraph_word_count_count"], inplace=True)
    paragraph_agg_df = paragraph_agg_df.rename(columns={"paragraph_len_count":"paragraph_count"})
    return paragraph_agg_df

# %%
# Sentence features for train dataset
train_sent_df = split_essays_into_sentences(train_essays)
train_sent_agg_df = compute_sentence_aggregations(train_sent_df)
# plt.figure(figsize=(15, 1.5))
# plt.boxplot(x=train_sent_df.sent_len, vert=False, labels=['Sentence length'])
# plt.show()

# %%
# Paragraph features for train dataset
train_paragraph_df = split_essays_into_paragraphs(train_essays)
train_paragraph_agg_df = compute_paragraph_aggregations(train_paragraph_df)
# plt.figure(figsize=(15, 1.5))
# plt.boxplot(x=train_paragraph_df.paragraph_len, vert=False, labels=['Paragraph length'])
# plt.show()

# %%
# Features for test dataset
test_essays = getEssays(test_logs)
test_sent_agg_df = compute_sentence_aggregations(split_essays_into_sentences(test_essays))
test_paragraph_agg_df = compute_paragraph_aggregations(split_essays_into_paragraphs(test_essays))

# %%
# The following code comes almost Abdullah's notebook: https://www.kaggle.com/code/abdullahmeda/enter-ing-the-timeseries-space-sec-3-new-aggs
# Abdullah's code is based on work shared in previous notebooks (e.g., https://www.kaggle.com/code/hengzheng/link-writing-simple-lgbm-baseline)

from collections import defaultdict

class Preprocessor:
    
    def __init__(self, seed):
        self.seed = seed
        
        self.activities = ['Input', 'Remove/Cut', 'Nonproduction', 'Replace', 'Paste']
        self.events = ['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick', 'ArrowLeft', '.', ',', 
              'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock', "'", 'Delete', 'Unidentified']
        self.text_changes = ['q', ' ', 'NoChange', '.', ',', '\n', "'", '"', '-', '?', ';', '=', '/', '\\', ':']
        self.punctuations = ['"', '.', ',', "'", '-', ';', ':', '?', '!', '<', '>', '/',
                        '@', '#', '$', '%', '^', '&', '*', '(', ')', '_', '+']
        self.gaps = [1, 2, 3, 5, 10, 20, 50, 100]
        
        self.idf = defaultdict(float)
    
    def activity_counts(self, df):
        tmp_df = df.groupby('id').agg({'activity': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['activity'].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.activities:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'activity_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf

            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf

        return ret

    def event_counts(self, df, colname):
        tmp_df = df.groupby('id').agg({colname: list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df[colname].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.events:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'{colname}_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf
            
            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf

        return ret

    def text_change_counts(self, df):
        tmp_df = df.groupby('id').agg({'text_change': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['text_change'].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.text_changes:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'text_change_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf
            
            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf
            
        return ret

    def match_punctuations(self, df):
        tmp_df = df.groupby('id').agg({'down_event': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['down_event'].values):
            cnt = 0
            items = list(Counter(li).items())
            for item in items:
                k, v = item[0], item[1]
                if k in self.punctuations:
                    cnt += v
            ret.append(cnt)
        ret = pd.DataFrame({'punct_cnt': ret})
        return ret

    def get_input_words(self, df):
        tmp_df = df[(~df['text_change'].str.contains('=>'))&(df['text_change'] != 'NoChange')].reset_index(drop=True)
        tmp_df = tmp_df.groupby('id').agg({'text_change': list}).reset_index()
        tmp_df['text_change'] = tmp_df['text_change'].apply(lambda x: ''.join(x))
        tmp_df['text_change'] = tmp_df['text_change'].apply(lambda x: re.findall(r'q+', x))
        tmp_df['input_word_count'] = tmp_df['text_change'].apply(len)
        tmp_df['input_word_length_mean'] = tmp_df['text_change'].apply(lambda x: np.mean([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df['input_word_length_max'] = tmp_df['text_change'].apply(lambda x: np.max([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df['input_word_length_std'] = tmp_df['text_change'].apply(lambda x: np.std([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df.drop(['text_change'], axis=1, inplace=True)
        return tmp_df
    
    def make_feats(self, df):
        
        feats = pd.DataFrame({'id': df['id'].unique().tolist()})
        
        print("Engineering time data")
        for gap in self.gaps:
            df[f'up_time_shift{gap}'] = df.groupby('id')['up_time'].shift(gap)
            df[f'action_time_gap{gap}'] = df['down_time'] - df[f'up_time_shift{gap}']
        df.drop(columns=[f'up_time_shift{gap}' for gap in self.gaps], inplace=True)

        print("Engineering cursor position data")
        for gap in self.gaps:
            df[f'cursor_position_shift{gap}'] = df.groupby('id')['cursor_position'].shift(gap)
            df[f'cursor_position_change{gap}'] = df['cursor_position'] - df[f'cursor_position_shift{gap}']
            df[f'cursor_position_abs_change{gap}'] = np.abs(df[f'cursor_position_change{gap}'])
        df.drop(columns=[f'cursor_position_shift{gap}' for gap in self.gaps], inplace=True)

        print("Engineering word count data")
        for gap in self.gaps:
            df[f'word_count_shift{gap}'] = df.groupby('id')['word_count'].shift(gap)
            df[f'word_count_change{gap}'] = df['word_count'] - df[f'word_count_shift{gap}']
            df[f'word_count_abs_change{gap}'] = np.abs(df[f'word_count_change{gap}'])
        df.drop(columns=[f'word_count_shift{gap}' for gap in self.gaps], inplace=True)
        
        print("Engineering statistical summaries for features")
        feats_stat = [
            ('event_id', ['max']),
            ('up_time', ['max']),
            ('action_time', ['max', 'min', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew', pd.DataFrame.kurt]),
            ('activity', ['nunique']),
            ('down_event', ['nunique']),
            ('up_event', ['nunique']),
            ('text_change', ['nunique']),
            ('cursor_position', ['nunique', 'max', 'quantile', 'sem', 'mean']),
            ('word_count', ['nunique', 'max', 'quantile', 'sem', 'mean'])]
        for gap in self.gaps:
            feats_stat.extend([
                (f'action_time_gap{gap}', ['max', 'min', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew', pd.DataFrame.kurt]),
                (f'cursor_position_change{gap}', ['max', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew', pd.DataFrame.kurt]),
                (f'word_count_change{gap}', ['max', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew', pd.DataFrame.kurt])
            ])
        
        pbar = tqdm(feats_stat)
        for item in pbar:
            colname, methods = item[0], item[1]
            for method in methods:
                pbar.set_postfix()
                if isinstance(method, str):
                    method_name = method
                else:
                    method_name = method.__name__
                pbar.set_postfix(column=colname, method=method_name)
                tmp_df = df.groupby(['id']).agg({colname: method}).reset_index().rename(columns={colname: f'{colname}_{method_name}'})
                feats = feats.merge(tmp_df, on='id', how='left')

        print("Engineering activity counts data")
        tmp_df = self.activity_counts(df)
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering event counts data")
        tmp_df = self.event_counts(df, 'down_event')
        feats = pd.concat([feats, tmp_df], axis=1)
        tmp_df = self.event_counts(df, 'up_event')
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering text change counts data")
        tmp_df = self.text_change_counts(df)
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering punctuation counts data")
        tmp_df = self.match_punctuations(df)
        feats = pd.concat([feats, tmp_df], axis=1)

        print("Engineering input words data")
        tmp_df = self.get_input_words(df)
        feats = pd.merge(feats, tmp_df, on='id', how='left')

        print("Engineering ratios data")
        feats['word_time_ratio'] = feats['word_count_max'] / feats['up_time_max']
        feats['word_event_ratio'] = feats['word_count_max'] / feats['event_id_max']
        feats['event_time_ratio'] = feats['event_id_max']  / feats['up_time_max']
        feats['idle_time_ratio'] = feats['action_time_gap1_sum'] / feats['up_time_max']

        return feats

# %%
preprocessor = Preprocessor(seed=42)
train_feats = preprocessor.make_feats(train_logs)
test_feats = preprocessor.make_feats(test_logs)
nan_cols = train_feats.columns[train_feats.isna().any()].tolist()
train_feats = train_feats.drop(columns=nan_cols)
test_feats = test_feats.drop(columns=nan_cols)
# Out:
# Engineering time data
# Engineering cursor position data
# Engineering word count data
# Engineering statistical summaries for features
# 100%|██████████| 33/33 [05:06<00:00,  9.28s/it, column=word_count_change100, method=kurt]
# Engineering activity counts data
# 100%|██████████| 2471/2471 [00:00<00:00, 4929.28it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering event counts data
# 100%|██████████| 2471/2471 [00:00<00:00, 4433.56it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|██████████| 2471/2471 [00:00<00:00, 4768.07it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering text change counts data
# 100%|██████████| 2471/2471 [00:00<00:00, 4766.42it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering punctuation counts data
# 100%|██████████| 2471/2471 [00:00<00:00, 4645.29it/s]
# Engineering input words data
# /tmp/ipykernel_19/3946551957.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['word_time_ratio'] = feats['word_count_max'] / feats['up_time_max']
# /tmp/ipykernel_19/3946551957.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['word_event_ratio'] = feats['word_count_max'] / feats['event_id_max']
# /tmp/ipykernel_19/3946551957.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['event_time_ratio'] = feats['event_id_max']  / feats['up_time_max']
# /tmp/ipykernel_19/3946551957.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['idle_time_ratio'] = feats['action_time_gap1_sum'] / feats['up_time_max']
# Engineering ratios data
# Engineering time data
# Engineering cursor position data
# Engineering word count data
# Engineering statistical summaries for features
# 100%|██████████| 33/33 [00:02<00:00, 13.65it/s, column=word_count_change100, method=kurt]
# Engineering activity counts data
# 100%|██████████| 3/3 [00:00<00:00, 18531.53it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering event counts data
# 100%|██████████| 3/3 [00:00<00:00, 16111.28it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 100%|██████████| 3/3 [00:00<00:00, 19298.94it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering text change counts data
# 100%|██████████| 3/3 [00:00<00:00, 16777.22it/s]
# /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Engineering punctuation counts data
# 100%|██████████| 3/3 [00:00<00:00, 19753.39it/s]
# /tmp/ipykernel_19/3946551957.py:221: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['word_time_ratio'] = feats['word_count_max'] / feats['up_time_max']
# /tmp/ipykernel_19/3946551957.py:222: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['word_event_ratio'] = feats['word_count_max'] / feats['event_id_max']
# /tmp/ipykernel_19/3946551957.py:223: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['event_time_ratio'] = feats['event_id_max']  / feats['up_time_max']
# /tmp/ipykernel_19/3946551957.py:224: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   feats['idle_time_ratio'] = feats['action_time_gap1_sum'] / feats['up_time_max']
# Engineering input words data
# Engineering ratios data

# %%
# Code for additional aggregations comes from here: https://www.kaggle.com/code/abdullahmeda/enter-ing-the-timeseries-space-sec-3-new-aggs

train_agg_fe_df = train_logs.groupby("id")[['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']].agg(
    ['mean', 'std', 'min', 'max', 'last', 'first', 'sem', 'median', 'sum'])
train_agg_fe_df.columns = ['_'.join(x) for x in train_agg_fe_df.columns]
train_agg_fe_df = train_agg_fe_df.add_prefix("tmp_")
train_agg_fe_df.reset_index(inplace=True)

test_agg_fe_df = test_logs.groupby("id")[['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']].agg(
    ['mean', 'std', 'min', 'max', 'last', 'first', 'sem', 'median', 'sum'])
test_agg_fe_df.columns = ['_'.join(x) for x in test_agg_fe_df.columns]
test_agg_fe_df = test_agg_fe_df.add_prefix("tmp_")
test_agg_fe_df.reset_index(inplace=True)

train_feats = train_feats.merge(train_agg_fe_df, on='id', how='left')
test_feats = test_feats.merge(test_agg_fe_df, on='id', how='left')

# %%
# Code for creating these features comes from here: https://www.kaggle.com/code/abdullahmeda/enter-ing-the-timeseries-space-sec-3-new-aggs
# Idea is based on features introduced in Section 3 of this research paper: https://files.eric.ed.gov/fulltext/ED592674.pdf

data = []

for logs in [train_logs, test_logs]:
    logs['up_time_lagged'] = logs.groupby('id')['up_time'].shift(1).fillna(logs['down_time'])
    logs['time_diff'] = abs(logs['down_time'] - logs['up_time_lagged']) / 1000

    group = logs.groupby('id')['time_diff']
    largest_lantency = group.max()
    smallest_lantency = group.min()
    median_lantency = group.median()
    initial_pause = logs.groupby('id')['down_time'].first() / 1000
    pauses_half_sec = group.apply(lambda x: ((x > 0.5) & (x < 1)).sum())
    pauses_1_sec = group.apply(lambda x: ((x > 1) & (x < 1.5)).sum())
    pauses_1_half_sec = group.apply(lambda x: ((x > 1.5) & (x < 2)).sum())
    pauses_2_sec = group.apply(lambda x: ((x > 2) & (x < 3)).sum())
    pauses_3_sec = group.apply(lambda x: (x > 3).sum())

    data.append(pd.DataFrame({
        'id': logs['id'].unique(),
        'largest_lantency': largest_lantency,
        'smallest_lantency': smallest_lantency,
        'median_lantency': median_lantency,
        'initial_pause': initial_pause,
        'pauses_half_sec': pauses_half_sec,
        'pauses_1_sec': pauses_1_sec,
        'pauses_1_half_sec': pauses_1_half_sec,
        'pauses_2_sec': pauses_2_sec,
        'pauses_3_sec': pauses_3_sec,
    }).reset_index(drop=True))

train_eD592674, test_eD592674 = data

train_feats = train_feats.merge(train_eD592674, on='id', how='left')
test_feats = test_feats.merge(test_eD592674, on='id', how='left')
train_feats = train_feats.merge(train_scores, on='id', how='left')

# %%
# Adding the additional features to the original feature set

train_feats = train_feats.merge(train_sent_agg_df, on='id', how='left')
train_feats = train_feats.merge(train_paragraph_agg_df, on='id', how='left')
test_feats = test_feats.merge(test_sent_agg_df, on='id', how='left')
test_feats = test_feats.merge(test_paragraph_agg_df, on='id', how='left')

# %%
target_col = ['score']
drop_cols = ['id']
train_cols = [col for col in train_feats.columns if col not in target_col + drop_cols]

# %%
len(test_feats)
# Out:
# 3

# %% [markdown]
# # LightGBM train and predict

# %%
OOF_PREDS = np.zeros((len(train_feats), 2))
TEST_PREDS = np.zeros((len(test_feats), 2))

# %%
# Code comes from here: https://www.kaggle.com/code/abdullahmeda/enter-ing-the-timeseries-space-sec-3-new-aggs

models_dict = {}
scores = []

test_predict_list = []
best_params = {'reg_alpha': 0.007678095440286993, 
               'reg_lambda': 0.34230534302168353, 
               'colsample_bytree': 0.627061253588415, 
               'subsample': 0.854942238828458, 
               'learning_rate': 0.04,   #0.038697981947473245, 
               'num_leaves': 22, 
               'max_depth': 37, 
               'min_child_samples': 18,
               'n_jobs':4
              }

for i in range(5): 
    kf = model_selection.KFold(n_splits=10, random_state=42 + i, shuffle=True)
    oof_valid_preds = np.zeros(train_feats.shape[0])
    X_test = test_feats[train_cols]
    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_feats)):
        
        X_train, y_train = train_feats.iloc[train_idx][train_cols], train_feats.iloc[train_idx][target_col]
        X_valid, y_valid = train_feats.iloc[valid_idx][train_cols], train_feats.iloc[valid_idx][target_col]
        params = {
            "objective": "regression",
            "metric": "rmse",
            'random_state': 42,
            "n_estimators" : 12001,
            "verbosity": -1,
            **best_params
        }
        model = lgb.LGBMRegressor(**params)
        early_stopping_callback = lgb.early_stopping(100, first_metric_only=True, verbose=False)
        
        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],  
                  callbacks=[early_stopping_callback],
        )
        valid_predict = model.predict(X_valid)
        oof_valid_preds[valid_idx] = valid_predict
        OOF_PREDS[valid_idx, 0] += valid_predict / 5
        test_predict = model.predict(X_test)
        TEST_PREDS[:, 0] += test_predict / 5 / 10
        test_predict_list.append(test_predict)
        score = metrics.mean_squared_error(y_valid, valid_predict, squared=False)
        models_dict[f'{fold}_{i}'] = model

    oof_score = metrics.mean_squared_error(train_feats[target_col], oof_valid_preds, squared=False)
    scores.append(oof_score)
# Out:
# [1]	valid_0's rmse: 0.994979
# [2]	valid_0's rmse: 0.971753
# [3]	valid_0's rmse: 0.95105
# [4]	valid_0's rmse: 0.931631
# [5]	valid_0's rmse: 0.912679
# [6]	valid_0's rmse: 0.895416
# [7]	valid_0's rmse: 0.878517
# [8]	valid_0's rmse: 0.862567
# [9]	valid_0's rmse: 0.846738
# [10]	valid_0's rmse: 0.833044
# [11]	valid_0's rmse: 0.819773
# [12]	valid_0's rmse: 0.806434
# [13]	valid_0's rmse: 0.794328
# [14]	valid_0's rmse: 0.782885
# [15]	valid_0's rmse: 0.772237
# [16]	valid_0's rmse: 0.76151
# [17]	valid_0's rmse: 0.752921
# [18]	valid_0's rmse: 0.745096
# [19]	valid_0's rmse: 0.735623
# [20]	valid_0's rmse: 0.727965
# [21]	valid_0's rmse: 0.721605
# [22]	valid_0's rmse: 0.713883
# [23]	valid_0's rmse: 0.708105
# [24]	valid_0's rmse: 0.702485
# [25]	valid_0's rmse: 0.696428
# [26]	valid_0's rmse: 0.690825
# [27]	valid_0's rmse: 0.685159
# [28]	valid_0's rmse: 0.680592
# [29]	valid_0's rmse: 0.675816
# [30]	valid_0's rmse: 0.671763
# [31]	valid_0's rmse: 0.667913
# [32]	valid_0's rmse: 0.663912
# [33]	valid_0's rmse: 0.66007
# [34]	valid_0's rmse: 0.656155
# [35]	valid_0's rmse: 0.652419
# [36]	valid_0's rmse: 0.64872
# [37]	valid_0's rmse: 0.646141
# [38]	valid_0's rmse: 0.64343
# [39]	valid_0's rmse: 0.641571
# [40]	valid_0's rmse: 0.639043
# [41]	valid_0's rmse: 0.637638
# [42]	valid_0's rmse: 0.635489
# [43]	valid_0's rmse: 0.632786
# [44]	valid_0's rmse: 0.63004
# [45]	valid_0's rmse: 0.627496
# [46]	valid_0's rmse: 0.625745
# [47]	valid_0's rmse: 0.624746
# [48]	valid_0's rmse: 0.622522
# [49]	valid_0's rmse: 0.620671
# [50]	valid_0's rmse: 0.619347
# [51]	valid_0's rmse: 0.618004
# [52]	valid_0's rmse: 0.616203
# [53]	valid_0's rmse: 0.614677
# [54]	valid_0's rmse: 0.613634
# [55]	valid_0's rmse: 0.612642
# [56]	valid_0's rmse: 0.61214
# [57]	valid_0's rmse: 0.611158
# [58]	valid_0's rmse: 0.610444
# [59]	valid_0's rmse: 0.609111
# [60]	valid_0's rmse: 0.608945
# [61]	valid_0's rmse: 0.609079
# [62]	valid_0's rmse: 0.607514
# [63]	valid_0's rmse: 0.607219
# [64]	valid_0's rmse: 0.606384
# [65]	valid_0's rmse: 0.606405
# [66]	valid_0's rmse: 0.606171
# [67]	valid_0's rmse: 0.605885
# [68]	valid_0's rmse: 0.605479
# [69]	valid_0's rmse: 0.605111
# [70]	valid_0's rmse: 0.605333
# [71]	valid_0's rmse: 0.604507
# [72]	valid_0's rmse: 0.604747
# [73]	valid_0's rmse: 0.60492
# [74]	valid_0's rmse: 0.605017
# [75]	valid_0's rmse: 0.604529
# [76]	valid_0's rmse: 0.604181
# [77]	valid_0's rmse: 0.603487
# [78]	valid_0's rmse: 0.603231
# [79]	valid_0's rmse: 0.603076
# [80]	valid_0's rmse: 0.603014
# [81]	valid_0's rmse: 0.602486
# [82]	valid_0's rmse: 0.602486
# [83]	valid_0's rmse: 0.603186
# [84]	valid_0's rmse: 0.602566
# [85]	valid_0's rmse: 0.602199
# [86]	valid_0's rmse: 0.601969
# [87]	valid_0's rmse: 0.602195
# [88]	valid_0's rmse: 0.601733
# [89]	valid_0's rmse: 0.601758
# [90]	valid_0's rmse: 0.601161
# [91]	valid_0's rmse: 0.601328
# [92]	valid_0's rmse: 0.601207
# [93]	valid_0's rmse: 0.601734
# [94]	valid_0's rmse: 0.601508
# [95]	valid_0's rmse: 0.601407
# [96]	valid_0's rmse: 0.601772
# [97]	valid_0's rmse: 0.602201
# [98]	valid_0's rmse: 0.601624
# [99]	valid_0's rmse: 0.600998
# [100]	valid_0's rmse: 0.600958
# [101]	valid_0's rmse: 0.601125
# [102]	valid_0's rmse: 0.601303
# [103]	valid_0's rmse: 0.601049
# [104]	valid_0's rmse: 0.600247
# [105]	valid_0's rmse: 0.600153
# [106]	valid_0's rmse: 0.600039
# [107]	valid_0's rmse: 0.599923
# [108]	valid_0's rmse: 0.599977
# [109]	valid_0's rmse: 0.599369
# [110]	valid_0's rmse: 0.599319
# [111]	valid_0's rmse: 0.599152
# [112]	valid_0's rmse: 0.599612
# [113]	valid_0's rmse: 0.60024
# [114]	valid_0's rmse: 0.600562
# [115]	valid_0's rmse: 0.600136
# [116]	valid_0's rmse: 0.60029
# [117]	valid_0's rmse: 0.600455
# [118]	valid_0's rmse: 0.600766
# [119]	valid_0's rmse: 0.600538
# [120]	valid_0's rmse: 0.600201
# [121]	valid_0's rmse: 0.600533
# [122]	valid_0's rmse: 0.599725
# [123]	valid_0's rmse: 0.599999
# [124]	valid_0's rmse: 0.600076
# [125]	valid_0's rmse: 0.600165
# [126]	valid_0's rmse: 0.599948
# [127]	valid_0's rmse: 0.600196
# [128]	valid_0's rmse: 0.600644
# [129]	valid_0's rmse: 0.600757
# [130]	valid_0's rmse: 0.600639
# [131]	valid_0's rmse: 0.600785
# [132]	valid_0's rmse: 0.601108
# [133]	valid_0's rmse: 0.601177
# [134]	valid_0's rmse: 0.600681
# [135]	valid_0's rmse: 0.600557
# [136]	valid_0's rmse: 0.600729
# [137]	valid_0's rmse: 0.600663
# [138]	valid_0's rmse: 0.600654
# [139]	valid_0's rmse: 0.600897
# [140]	valid_0's rmse: 0.600789
# [141]	valid_0's rmse: 0.60082
# [142]	valid_0's rmse: 0.600531
# [143]	valid_0's rmse: 0.600697
# [144]	valid_0's rmse: 0.600833
# [145]	valid_0's rmse: 0.60132
# [146]	valid_0's rmse: 0.601349
# [147]	valid_0's rmse: 0.601686
# [148]	valid_0's rmse: 0.601128
# [149]	valid_0's rmse: 0.600647
# [150]	valid_0's rmse: 0.600886
# [151]	valid_0's rmse: 0.600983
# [152]	valid_0's rmse: 0.601334
# [153]	valid_0's rmse: 0.601407
# [154]	valid_0's rmse: 0.601256
# [155]	valid_0's rmse: 0.601499
# [156]	valid_0's rmse: 0.601641
# [157]	valid_0's rmse: 0.601405
# [158]	valid_0's rmse: 0.601637
# [159]	valid_0's rmse: 0.601539
# [160]	valid_0's rmse: 0.602043
# [161]	valid_0's rmse: 0.601694
# [162]	valid_0's rmse: 0.601697
# [163]	valid_0's rmse: 0.601181
# [164]	valid_0's rmse: 0.601211
# [165]	valid_0's rmse: 0.601193
# [166]	valid_0's rmse: 0.601011
# [167]	valid_0's rmse: 0.601258
# [168]	valid_0's rmse: 0.601256
# [169]	valid_0's rmse: 0.601327
# [170]	valid_0's rmse: 0.601213
# [171]	valid_0's rmse: 0.601453
# [172]	valid_0's rmse: 0.602062
# [173]	valid_0's rmse: 0.601924
# [174]	valid_0's rmse: 0.602086
# [175]	valid_0's rmse: 0.602179
# [176]	valid_0's rmse: 0.601927
# [177]	valid_0's rmse: 0.601882
# [178]	valid_0's rmse: 0.60172
# [179]	valid_0's rmse: 0.601477
# [180]	valid_0's rmse: 0.602184
# [181]	valid_0's rmse: 0.60262
# [182]	valid_0's rmse: 0.602492
# [183]	valid_0's rmse: 0.602691
# [184]	valid_0's rmse: 0.602673
# [185]	valid_0's rmse: 0.602906
# [186]	valid_0's rmse: 0.60285
# [187]	valid_0's rmse: 0.602696
# [188]	valid_0's rmse: 0.602621
# [189]	valid_0's rmse: 0.602574
# [190]	valid_0's rmse: 0.602537
# [191]	valid_0's rmse: 0.602538
# [192]	valid_0's rmse: 0.60264
# [193]	valid_0's rmse: 0.602837
# [194]	valid_0's rmse: 0.602981
# [195]	valid_0's rmse: 0.602916
# [196]	valid_0's rmse: 0.602954
# [197]	valid_0's rmse: 0.60311
# [198]	valid_0's rmse: 0.60281
# [199]	valid_0's rmse: 0.602947
# [200]	valid_0's rmse: 0.603079
# [201]	valid_0's rmse: 0.602908
# [202]	valid_0's rmse: 0.6029
# [203]	valid_0's rmse: 0.602936
# [204]	valid_0's rmse: 0.60305
# [205]	valid_0's rmse: 0.603212
# [206]	valid_0's rmse: 0.603073
# [207]	valid_0's rmse: 0.603294
# [208]	valid_0's rmse: 0.603506
# [209]	valid_0's rmse: 0.603304
# [210]	valid_0's rmse: 0.603228
# [211]	valid_0's rmse: 0.603621
# [1]	valid_0's rmse: 0.930544
# [2]	valid_0's rmse: 0.90804
# [3]	valid_0's rmse: 0.885117
# [4]	valid_0's rmse: 0.864212
# [5]	valid_0's rmse: 0.844111
# [6]	valid_0's rmse: 0.825106
# [7]	valid_0's rmse: 0.806384
# [8]	valid_0's rmse: 0.789191
# [9]	valid_0's rmse: 0.774018
# [10]	valid_0's rmse: 0.760204
# [11]	valid_0's rmse: 0.745776
# [12]	valid_0's rmse: 0.732634
# [13]	valid_0's rmse: 0.72076
# [14]	valid_0's rmse: 0.708473
# [15]	valid_0's rmse: 0.696233
# [16]	valid_0's rmse: 0.68549
# [17]	valid_0's rmse: 0.676558
# [18]	valid_0's rmse: 0.667114
# [19]	valid_0's rmse: 0.658347
# [20]	valid_0's rmse: 0.651108
# [21]	valid_0's rmse: 0.642469
# [22]	valid_0's rmse: 0.635478
# [23]	valid_0's rmse: 0.628595
# [24]	valid_0's rmse: 0.622272
# [25]	valid_0's rmse: 0.616087
# [26]	valid_0's rmse: 0.609526
# [27]	valid_0's rmse: 0.60426
# [28]	valid_0's rmse: 0.600079
# [29]	valid_0's rmse: 0.595661
# [30]	valid_0's rmse: 0.591511
# [31]	valid_0's rmse: 0.586648
# [32]	valid_0's rmse: 0.58279
# [33]	valid_0's rmse: 0.579584
# [34]	valid_0's rmse: 0.576023
# [35]	valid_0's rmse: 0.573398
# [36]	valid_0's rmse: 0.570788
# [37]	valid_0's rmse: 0.567556
# [38]	valid_0's rmse: 0.5647
# [39]	valid_0's rmse: 0.56191
# [40]	valid_0's rmse: 0.558163
# [41]	valid_0's rmse: 0.555705
# [42]	valid_0's rmse: 0.553663
# [43]	valid_0's rmse: 0.550581
# [44]	valid_0's rmse: 0.548248
# [45]	valid_0's rmse: 0.546338
# [46]	valid_0's rmse: 0.544912
# [47]	valid_0's rmse: 0.543389
# [48]	valid_0's rmse: 0.541217
# [49]	valid_0's rmse: 0.539703
# [50]	valid_0's rmse: 0.538578
# [51]	valid_0's rmse: 0.536873
# [52]	valid_0's rmse: 0.535488
# [53]	valid_0's rmse: 0.534349
# [54]	valid_0's rmse: 0.53308
# [55]	valid_0's rmse: 0.532297
# [56]	valid_0's rmse: 0.531662
# [57]	valid_0's rmse: 0.530876
# [58]	valid_0's rmse: 0.529683
# [59]	valid_0's rmse: 0.528508
# [60]	valid_0's rmse: 0.527826
# [61]	valid_0's rmse: 0.527866
# [62]	valid_0's rmse: 0.526972
# [63]	valid_0's rmse: 0.526265
# [64]	valid_0's rmse: 0.526744
# [65]	valid_0's rmse: 0.526442
# [66]	valid_0's rmse: 0.52606
# [67]	valid_0's rmse: 0.524826
# [68]	valid_0's rmse: 0.524889
# [69]	valid_0's rmse: 0.524498
# [70]	valid_0's rmse: 0.523345
# [71]	valid_0's rmse: 0.523073
# [72]	valid_0's rmse: 0.523129
# [73]	valid_0's rmse: 0.522427
# [74]	valid_0's rmse: 0.522217
# [75]	valid_0's rmse: 0.521546
# [76]	valid_0's rmse: 0.521133
# [77]	valid_0's rmse: 0.520607
# [78]	valid_0's rmse: 0.519727
# [79]	valid_0's rmse: 0.519649
# [80]	valid_0's rmse: 0.519569
# [81]	valid_0's rmse: 0.518784
# [82]	valid_0's rmse: 0.518219
# [83]	valid_0's rmse: 0.518305
# [84]	valid_0's rmse: 0.51776
# [85]	valid_0's rmse: 0.517438
# [86]	valid_0's rmse: 0.516893
# [87]	valid_0's rmse: 0.516705
# [88]	valid_0's rmse: 0.516191
# [89]	valid_0's rmse: 0.516146
# [90]	valid_0's rmse: 0.515468
# [91]	valid_0's rmse: 0.515639
# [92]	valid_0's rmse: 0.515386
# [93]	valid_0's rmse: 0.515377
# [94]	valid_0's rmse: 0.514669
# [95]	valid_0's rmse: 0.514844
# [96]	valid_0's rmse: 0.515158
# [97]	valid_0's rmse: 0.514595
# [98]	valid_0's rmse: 0.514881
# [99]	valid_0's rmse: 0.515002
# [100]	valid_0's rmse: 0.514982
# [101]	valid_0's rmse: 0.515108
# [102]	valid_0's rmse: 0.515502
# [103]	valid_0's rmse: 0.515183
# [104]	valid_0's rmse: 0.515721
# [105]	valid_0's rmse: 0.515965
# [106]	valid_0's rmse: 0.5157
# [107]	valid_0's rmse: 0.515696
# [108]	valid_0's rmse: 0.515501
# [109]	valid_0's rmse: 0.515071
# [110]	valid_0's rmse: 0.514658
# [111]	valid_0's rmse: 0.514438
# [112]	valid_0's rmse: 0.514864
# [113]	valid_0's rmse: 0.515154
# [114]	valid_0's rmse: 0.514695
# [115]	valid_0's rmse: 0.514623
# [116]	valid_0's rmse: 0.514926
# [117]	valid_0's rmse: 0.515041
# [118]	valid_0's rmse: 0.515266
# [119]	valid_0's rmse: 0.515212
# [120]	valid_0's rmse: 0.51559
# [121]	valid_0's rmse: 0.515321
# [122]	valid_0's rmse: 0.514879
# [123]	valid_0's rmse: 0.515087
# [124]	valid_0's rmse: 0.514797
# [125]	valid_0's rmse: 0.514841
# [126]	valid_0's rmse: 0.51502
# [127]	valid_0's rmse: 0.515005
# [128]	valid_0's rmse: 0.514722
# [129]	valid_0's rmse: 0.514693
# [130]	valid_0's rmse: 0.514335
# [131]	valid_0's rmse: 0.514589
# [132]	valid_0's rmse: 0.513954
# [133]	valid_0's rmse: 0.514071
# [134]	valid_0's rmse: 0.513872
# [135]	valid_0's rmse: 0.513384
# [136]	valid_0's rmse: 0.513705
# [137]	valid_0's rmse: 0.513947
# [138]	valid_0's rmse: 0.513762
# [139]	valid_0's rmse: 0.513839
# [140]	valid_0's rmse: 0.514083
# [141]	valid_0's rmse: 0.513844
# [142]	valid_0's rmse: 0.514012
# [143]	valid_0's rmse: 0.513976
# [144]	valid_0's rmse: 0.514019
# [145]	valid_0's rmse: 0.514005
# [146]	valid_0's rmse: 0.514084
# [147]	valid_0's rmse: 0.513975
# [148]	valid_0's rmse: 0.513975
# [149]	valid_0's rmse: 0.514197
# [150]	valid_0's rmse: 0.514101
# [151]	valid_0's rmse: 0.514314
# [152]	valid_0's rmse: 0.514122
# [153]	valid_0's rmse: 0.51421
# [154]	valid_0's rmse: 0.514059
# [155]	valid_0's rmse: 0.513791
# [156]	valid_0's rmse: 0.513948
# [157]	valid_0's rmse: 0.514119
# [158]	valid_0's rmse: 0.514026
# [159]	valid_0's rmse: 0.513845
# [160]	valid_0's rmse: 0.5136
# [161]	valid_0's rmse: 0.51346
# [162]	valid_0's rmse: 0.513429
# [163]	valid_0's rmse: 0.513897
# [164]	valid_0's rmse: 0.514184
# [165]	valid_0's rmse: 0.514292
# [166]	valid_0's rmse: 0.514134
# [167]	valid_0's rmse: 0.514489
# [168]	valid_0's rmse: 0.514482
# [169]	valid_0's rmse: 0.514481
# [170]	valid_0's rmse: 0.514328
# [171]	valid_0's rmse: 0.51408
# [172]	valid_0's rmse: 0.513837
# [173]	valid_0's rmse: 0.51403
# [174]	valid_0's rmse: 0.514377
# [175]	valid_0's rmse: 0.514775
# [176]	valid_0's rmse: 0.514855
# [177]	valid_0's rmse: 0.515134
# [178]	valid_0's rmse: 0.515404
# [179]	valid_0's rmse: 0.515247
# [180]	valid_0's rmse: 0.514768
# [181]	valid_0's rmse: 0.514692
# [182]	valid_0's rmse: 0.514559
# [183]	valid_0's rmse: 0.514467
# [184]	valid_0's rmse: 0.514397
# [185]	valid_0's rmse: 0.514435
# [186]	valid_0's rmse: 0.51438
# [187]	valid_0's rmse: 0.51433
# [188]	valid_0's rmse: 0.514806
# [189]	valid_0's rmse: 0.514632
# [190]	valid_0's rmse: 0.515109
# [191]	valid_0's rmse: 0.515031
# [192]	valid_0's rmse: 0.514951
# [193]	valid_0's rmse: 0.514753
# [194]	valid_0's rmse: 0.514555
# [195]	valid_0's rmse: 0.514478
# [196]	valid_0's rmse: 0.514704
# [197]	valid_0's rmse: 0.514659
# [198]	valid_0's rmse: 0.51475
# [199]	valid_0's rmse: 0.514608
# [200]	valid_0's rmse: 0.514659
# [201]	valid_0's rmse: 0.514483
# [202]	valid_0's rmse: 0.514314
# [203]	valid_0's rmse: 0.514544
# [204]	valid_0's rmse: 0.514587
# [205]	valid_0's rmse: 0.514281
# [206]	valid_0's rmse: 0.513997
# [207]	valid_0's rmse: 0.513863
# [208]	valid_0's rmse: 0.5138
# [209]	valid_0's rmse: 0.513981
# [210]	valid_0's rmse: 0.513856
# [211]	valid_0's rmse: 0.513612
# [212]	valid_0's rmse: 0.513374
# [213]	valid_0's rmse: 0.513186
# [214]	valid_0's rmse: 0.513335
# [215]	valid_0's rmse: 0.513416
# [216]	valid_0's rmse: 0.513471
# [217]	valid_0's rmse: 0.513266
# [218]	valid_0's rmse: 0.513311
# [219]	valid_0's rmse: 0.513
# [220]	valid_0's rmse: 0.512938
# [221]	valid_0's rmse: 0.513273
# [222]	valid_0's rmse: 0.513164
# [223]	valid_0's rmse: 0.513446
# [224]	valid_0's rmse: 0.513549
# [225]	valid_0's rmse: 0.51365
# [226]	valid_0's rmse: 0.513863
# [227]	valid_0's rmse: 0.513709
# [228]	valid_0's rmse: 0.513817
# [229]	valid_0's rmse: 0.51373
# [230]	valid_0's rmse: 0.513547
# [231]	valid_0's rmse: 0.513716
# [232]	valid_0's rmse: 0.513438
# [233]	valid_0's rmse: 0.513556
# [234]	valid_0's rmse: 0.513313
# [235]	valid_0's rmse: 0.513737
# [236]	valid_0's rmse: 0.513695
# [237]	valid_0's rmse: 0.513736
# [238]	valid_0's rmse: 0.513726
# [239]	valid_0's rmse: 0.513727
# [240]	valid_0's rmse: 0.513998
# [241]	valid_0's rmse: 0.513962
# [242]	valid_0's rmse: 0.513774
# [243]	valid_0's rmse: 0.513669
# [244]	valid_0's rmse: 0.513627
# [245]	valid_0's rmse: 0.513614
# [246]	valid_0's rmse: 0.513618
# [247]	valid_0's rmse: 0.513602
# [248]	valid_0's rmse: 0.513403
# [249]	valid_0's rmse: 0.513172
# [250]	valid_0's rmse: 0.513062
# [251]	valid_0's rmse: 0.512961
# [252]	valid_0's rmse: 0.512844
# [253]	valid_0's rmse: 0.51306
# [254]	valid_0's rmse: 0.513263
# [255]	valid_0's rmse: 0.513069
# [256]	valid_0's rmse: 0.512927
# [257]	valid_0's rmse: 0.512798
# [258]	valid_0's rmse: 0.512992
# [259]	valid_0's rmse: 0.513088
# [260]	valid_0's rmse: 0.513132
# [261]	valid_0's rmse: 0.512974
# [262]	valid_0's rmse: 0.512733
# [263]	valid_0's rmse: 0.512592
# [264]	valid_0's rmse: 0.512581
# [265]	valid_0's rmse: 0.512366
# [266]	valid_0's rmse: 0.512375
# [267]	valid_0's rmse: 0.512511
# [268]	valid_0's rmse: 0.512107
# [269]	valid_0's rmse: 0.51233
# [270]	valid_0's rmse: 0.512218
# [271]	valid_0's rmse: 0.51201
# [272]	valid_0's rmse: 0.512459
# [273]	valid_0's rmse: 0.51251
# [274]	valid_0's rmse: 0.512666
# [275]	valid_0's rmse: 0.512359
# [276]	valid_0's rmse: 0.512045
# [277]	valid_0's rmse: 0.511982
# [278]	valid_0's rmse: 0.512145
# [279]	valid_0's rmse: 0.512136
# [280]	valid_0's rmse: 0.512067
# [281]	valid_0's rmse: 0.511912
# [282]	valid_0's rmse: 0.51185
# [283]	valid_0's rmse: 0.511532
# [284]	valid_0's rmse: 0.511537
# [285]	valid_0's rmse: 0.511529
# [286]	valid_0's rmse: 0.511801
# [287]	valid_0's rmse: 0.511813
# [288]	valid_0's rmse: 0.511539
# [289]	valid_0's rmse: 0.511916
# [290]	valid_0's rmse: 0.511885
# [291]	valid_0's rmse: 0.51182
# [292]	valid_0's rmse: 0.511912
# [293]	valid_0's rmse: 0.511922
# [294]	valid_0's rmse: 0.51211
# [295]	valid_0's rmse: 0.512392
# [296]	valid_0's rmse: 0.51251
# [297]	valid_0's rmse: 0.512579
# [298]	valid_0's rmse: 0.512756
# [299]	valid_0's rmse: 0.512642
# [300]	valid_0's rmse: 0.512569
# [301]	valid_0's rmse: 0.512362
# [302]	valid_0's rmse: 0.512254
# [303]	valid_0's rmse: 0.511916
# [304]	valid_0's rmse: 0.511939
# [305]	valid_0's rmse: 0.512089
# [306]	valid_0's rmse: 0.512202
# [307]	valid_0's rmse: 0.512254
# [308]	valid_0's rmse: 0.51224
# [309]	valid_0's rmse: 0.511997
# [310]	valid_0's rmse: 0.512173
# [311]	valid_0's rmse: 0.512375
# [312]	valid_0's rmse: 0.512599
# [313]	valid_0's rmse: 0.512548
# [314]	valid_0's rmse: 0.512355
# [315]	valid_0's rmse: 0.512354
# [316]	valid_0's rmse: 0.512353
# [317]	valid_0's rmse: 0.512338
# [318]	valid_0's rmse: 0.512247
# [319]	valid_0's rmse: 0.512347
# [320]	valid_0's rmse: 0.512468
# [321]	valid_0's rmse: 0.51246
# [322]	valid_0's rmse: 0.512473
# [323]	valid_0's rmse: 0.51223
# [324]	valid_0's rmse: 0.512145
# [325]	valid_0's rmse: 0.512129
# [326]	valid_0's rmse: 0.511838
# [327]	valid_0's rmse: 0.511998
# [328]	valid_0's rmse: 0.51223
# [329]	valid_0's rmse: 0.512191
# [330]	valid_0's rmse: 0.512072
# [331]	valid_0's rmse: 0.512013
# [332]	valid_0's rmse: 0.512142
# [333]	valid_0's rmse: 0.511963
# [334]	valid_0's rmse: 0.511901
# [335]	valid_0's rmse: 0.511877
# [336]	valid_0's rmse: 0.511812
# [337]	valid_0's rmse: 0.511671
# [338]	valid_0's rmse: 0.511542
# [339]	valid_0's rmse: 0.511441
# [340]	valid_0's rmse: 0.511428
# [341]	valid_0's rmse: 0.511621
# [342]	valid_0's rmse: 0.511506
# [343]	valid_0's rmse: 0.511446
# [344]	valid_0's rmse: 0.511297
# [345]	valid_0's rmse: 0.511129
# [346]	valid_0's rmse: 0.510941
# [347]	valid_0's rmse: 0.51078
# [348]	valid_0's rmse: 0.510713
# [349]	valid_0's rmse: 0.510877
# [350]	valid_0's rmse: 0.510791
# [351]	valid_0's rmse: 0.510938
# [352]	valid_0's rmse: 0.511055
# [353]	valid_0's rmse: 0.511021
# [354]	valid_0's rmse: 0.511122
# [355]	valid_0's rmse: 0.510874
# [356]	valid_0's rmse: 0.51076
# [357]	valid_0's rmse: 0.510774
# [358]	valid_0's rmse: 0.510827
# [359]	valid_0's rmse: 0.510528
# [360]	valid_0's rmse: 0.510606
# [361]	valid_0's rmse: 0.510547
# [362]	valid_0's rmse: 0.510636
# [363]	valid_0's rmse: 0.51066
# [364]	valid_0's rmse: 0.510595
# [365]	valid_0's rmse: 0.510641
# [366]	valid_0's rmse: 0.510557
# [367]	valid_0's rmse: 0.510779
# [368]	valid_0's rmse: 0.510741
# [369]	valid_0's rmse: 0.510875
# [370]	valid_0's rmse: 0.511267
# [371]	valid_0's rmse: 0.511545
# [372]	valid_0's rmse: 0.511398
# [373]	valid_0's rmse: 0.51147
# [374]	valid_0's rmse: 0.511544
# [375]	valid_0's rmse: 0.511554
# [376]	valid_0's rmse: 0.511562
# [377]	valid_0's rmse: 0.511499
# [378]	valid_0's rmse: 0.511324
# [379]	valid_0's rmse: 0.511283
# [380]	valid_0's rmse: 0.511288
# [381]	valid_0's rmse: 0.511485
# [382]	valid_0's rmse: 0.511498
# [383]	valid_0's rmse: 0.511641
# [384]	valid_0's rmse: 0.511642
# [385]	valid_0's rmse: 0.511847
# [386]	valid_0's rmse: 0.511776
# [387]	valid_0's rmse: 0.511744
# [388]	valid_0's rmse: 0.511932
# [389]	valid_0's rmse: 0.512075
# [390]	valid_0's rmse: 0.511824
# [391]	valid_0's rmse: 0.511812
# [392]	valid_0's rmse: 0.511737
# [393]	valid_0's rmse: 0.511565
# [394]	valid_0's rmse: 0.511551
# [395]	valid_0's rmse: 0.511436
# [396]	valid_0's rmse: 0.511441
# [397]	valid_0's rmse: 0.511348
# [398]	valid_0's rmse: 0.511377
# [399]	valid_0's rmse: 0.511445
# [400]	valid_0's rmse: 0.511585
# [401]	valid_0's rmse: 0.511768
# [402]	valid_0's rmse: 0.51179
# [403]	valid_0's rmse: 0.511661
# [404]	valid_0's rmse: 0.511697
# [405]	valid_0's rmse: 0.511549
# [406]	valid_0's rmse: 0.511562
# [407]	valid_0's rmse: 0.511562
# [408]	valid_0's rmse: 0.5116
# [409]	valid_0's rmse: 0.511712
# [410]	valid_0's rmse: 0.511754
# [411]	valid_0's rmse: 0.511768
# [412]	valid_0's rmse: 0.511949
# [413]	valid_0's rmse: 0.511739
# [414]	valid_0's rmse: 0.511787
# [415]	valid_0's rmse: 0.511677
# [416]	valid_0's rmse: 0.511709
# [417]	valid_0's rmse: 0.511869
# [418]	valid_0's rmse: 0.512068
# [419]	valid_0's rmse: 0.51214
# [420]	valid_0's rmse: 0.512022
# [421]	valid_0's rmse: 0.512065
# [422]	valid_0's rmse: 0.512165
# [423]	valid_0's rmse: 0.512312
# [424]	valid_0's rmse: 0.512122
# [425]	valid_0's rmse: 0.51202
# [426]	valid_0's rmse: 0.511779
# [427]	valid_0's rmse: 0.511874
# [428]	valid_0's rmse: 0.511919
# [429]	valid_0's rmse: 0.512034
# [430]	valid_0's rmse: 0.512042
# [431]	valid_0's rmse: 0.511961
# [432]	valid_0's rmse: 0.512085
# [433]	valid_0's rmse: 0.511971
# [434]	valid_0's rmse: 0.51183
# [435]	valid_0's rmse: 0.511803
# [436]	valid_0's rmse: 0.511941
# [437]	valid_0's rmse: 0.511918
# [438]	valid_0's rmse: 0.511872
# [439]	valid_0's rmse: 0.511883
# [440]	valid_0's rmse: 0.511923
# [441]	valid_0's rmse: 0.511846
# [442]	valid_0's rmse: 0.511809
# [443]	valid_0's rmse: 0.511768
# [444]	valid_0's rmse: 0.511784
# [445]	valid_0's rmse: 0.511863
# [446]	valid_0's rmse: 0.511668
# [447]	valid_0's rmse: 0.511664
# [448]	valid_0's rmse: 0.511763
# [449]	valid_0's rmse: 0.511994
# [450]	valid_0's rmse: 0.512107
# [451]	valid_0's rmse: 0.512116
# [452]	valid_0's rmse: 0.511987
# [453]	valid_0's rmse: 0.511954
# [454]	valid_0's rmse: 0.511811
# [455]	valid_0's rmse: 0.511913
# [456]	valid_0's rmse: 0.51194
# [457]	valid_0's rmse: 0.512081
# [458]	valid_0's rmse: 0.511809
# [459]	valid_0's rmse: 0.511894
# [1]	valid_0's rmse: 1.01641
# [2]	valid_0's rmse: 0.99509
# [3]	valid_0's rmse: 0.974061
# [4]	valid_0's rmse: 0.954296
# [5]	valid_0's rmse: 0.93649
# [6]	valid_0's rmse: 0.920124
# [7]	valid_0's rmse: 0.903686
# [8]	valid_0's rmse: 0.888688
# [9]	valid_0's rmse: 0.875669
# [10]	valid_0's rmse: 0.862073
# [11]	valid_0's rmse: 0.84915
# [12]	valid_0's rmse: 0.837615
# [13]	valid_0's rmse: 0.826985
# [14]	valid_0's rmse: 0.817395
# [15]	valid_0's rmse: 0.808974
# [16]	valid_0's rmse: 0.80061
# [17]	valid_0's rmse: 0.792151
# [18]	valid_0's rmse: 0.784679
# [19]	valid_0's rmse: 0.777342
# [20]	valid_0's rmse: 0.770695
# [21]	valid_0's rmse: 0.764392
# [22]	valid_0's rmse: 0.75894
# [23]	valid_0's rmse: 0.75288
# [24]	valid_0's rmse: 0.748019
# [25]	valid_0's rmse: 0.744166
# [26]	valid_0's rmse: 0.740039
# [27]	valid_0's rmse: 0.736337
# [28]	valid_0's rmse: 0.733276
# [29]	valid_0's rmse: 0.729469
# [30]	valid_0's rmse: 0.726444
# [31]	valid_0's rmse: 0.723924
# [32]	valid_0's rmse: 0.720844
# [33]	valid_0's rmse: 0.718501
# [34]	valid_0's rmse: 0.716194
# [35]	valid_0's rmse: 0.714402
# [36]	valid_0's rmse: 0.711786
# [37]	valid_0's rmse: 0.709962
# [38]	valid_0's rmse: 0.708082
# [39]	valid_0's rmse: 0.706416
# [40]	valid_0's rmse: 0.705017
# [41]	valid_0's rmse: 0.704222
# [42]	valid_0's rmse: 0.703874
# [43]	valid_0's rmse: 0.703361
# [44]	valid_0's rmse: 0.702391
# [45]	valid_0's rmse: 0.70187
# [46]	valid_0's rmse: 0.701242
# [47]	valid_0's rmse: 0.700209
# [48]	valid_0's rmse: 0.69904
# [49]	valid_0's rmse: 0.69822
# [50]	valid_0's rmse: 0.697413
# [51]	valid_0's rmse: 0.697045
# [52]	valid_0's rmse: 0.696284
# [53]	valid_0's rmse: 0.695301
# [54]	valid_0's rmse: 0.694432
# [55]	valid_0's rmse: 0.693653
# [56]	valid_0's rmse: 0.693434
# [57]	valid_0's rmse: 0.693464
# [58]	valid_0's rmse: 0.692931
# [59]	valid_0's rmse: 0.692429
# [60]	valid_0's rmse: 0.692096
# [61]	valid_0's rmse: 0.691657
# [62]	valid_0's rmse: 0.692216
# [63]	valid_0's rmse: 0.692146
# [64]	valid_0's rmse: 0.692051
# [65]	valid_0's rmse: 0.691731
# [66]	valid_0's rmse: 0.691735
# [67]	valid_0's rmse: 0.691504
# [68]	valid_0's rmse: 0.691686
# [69]	valid_0's rmse: 0.692363
# [70]	valid_0's rmse: 0.692854
# [71]	valid_0's rmse: 0.692277
# [72]	valid_0's rmse: 0.691841
# [73]	valid_0's rmse: 0.691399
# [74]	valid_0's rmse: 0.690948
# [75]	valid_0's rmse: 0.690362
# [76]	valid_0's rmse: 0.690252
# [77]	valid_0's rmse: 0.690163
# [78]	valid_0's rmse: 0.690211
# [79]	valid_0's rmse: 0.690561
# [80]	valid_0's rmse: 0.690557
# [81]	valid_0's rmse: 0.691086
# [82]	valid_0's rmse: 0.691573
# [83]	valid_0's rmse: 0.691393
# [84]	valid_0's rmse: 0.691189
# [85]	valid_0's rmse: 0.690968
# [86]	valid_0's rmse: 0.691099
# [87]	valid_0's rmse: 0.690679
# [88]	valid_0's rmse: 0.690692
# [89]	valid_0's rmse: 0.690426
# [90]	valid_0's rmse: 0.690571
# [91]	valid_0's rmse: 0.690476
# [92]	valid_0's rmse: 0.690794
# [93]	valid_0's rmse: 0.690613
# [94]	valid_0's rmse: 0.690618
# [95]	valid_0's rmse: 0.690226
# [96]	valid_0's rmse: 0.689886
# [97]	valid_0's rmse: 0.690161
# [98]	valid_0's rmse: 0.689315
# [99]	valid_0's rmse: 0.688674
# [100]	valid_0's rmse: 0.688651
# [101]	valid_0's rmse: 0.688443
# [102]	valid_0's rmse: 0.688589
# [103]	valid_0's rmse: 0.688608
# [104]	valid_0's rmse: 0.688622
# [105]	valid_0's rmse: 0.689104
# [106]	valid_0's rmse: 0.689361
# [107]	valid_0's rmse: 0.6891
# [108]	valid_0's rmse: 0.689561
# [109]	valid_0's rmse: 0.689569
# [110]	valid_0's rmse: 0.689148
# [111]	valid_0's rmse: 0.689273
# [112]	valid_0's rmse: 0.689394
# [113]	valid_0's rmse: 0.688599
# [114]	valid_0's rmse: 0.688734
# [115]	valid_0's rmse: 0.688998
# [116]	valid_0's rmse: 0.688772
# [117]	valid_0's rmse: 0.689004
# [118]	valid_0's rmse: 0.689121
# [119]	valid_0's rmse: 0.688911
# [120]	valid_0's rmse: 0.688905
# [121]	valid_0's rmse: 0.688759
# [122]	valid_0's rmse: 0.68867
# [123]	valid_0's rmse: 0.688484
# [124]	valid_0's rmse: 0.688657
# [125]	valid_0's rmse: 0.688836
# [126]	valid_0's rmse: 0.688349
# [127]	valid_0's rmse: 0.688682
# [128]	valid_0's rmse: 0.68839
# [129]	valid_0's rmse: 0.688979
# [130]	valid_0's rmse: 0.689062
# [131]	valid_0's rmse: 0.689096
# [132]	valid_0's rmse: 0.689024
# [133]	valid_0's rmse: 0.689514
# [134]	valid_0's rmse: 0.689284
# [135]	valid_0's rmse: 0.689661
# [136]	valid_0's rmse: 0.68953
# [137]	valid_0's rmse: 0.689215
# [138]	valid_0's rmse: 0.689172
# [139]	valid_0's rmse: 0.688915
# [140]	valid_0's rmse: 0.6887
# [141]	valid_0's rmse: 0.688886
# [142]	valid_0's rmse: 0.688582
# [143]	valid_0's rmse: 0.688562
# [144]	valid_0's rmse: 0.688616
# [145]	valid_0's rmse: 0.688632
# [146]	valid_0's rmse: 0.688499
# [147]	valid_0's rmse: 0.688321
# [148]	valid_0's rmse: 0.688117
# [149]	valid_0's rmse: 0.688174
# [150]	valid_0's rmse: 0.688199
# [151]	valid_0's rmse: 0.688402
# [152]	valid_0's rmse: 0.688542
# [153]	valid_0's rmse: 0.688675
# [154]	valid_0's rmse: 0.688736
# [155]	valid_0's rmse: 0.688695
# [156]	valid_0's rmse: 0.688864
# [157]	valid_0's rmse: 0.688985
# [158]	valid_0's rmse: 0.688628
# [159]	valid_0's rmse: 0.688705
# [160]	valid_0's rmse: 0.688243
# [161]	valid_0's rmse: 0.688437
# [162]	valid_0's rmse: 0.688517
# [163]	valid_0's rmse: 0.688152
# [164]	valid_0's rmse: 0.687856
# [165]	valid_0's rmse: 0.687967
# [166]	valid_0's rmse: 0.687607
# [167]	valid_0's rmse: 0.687632
# [168]	valid_0's rmse: 0.68789
# [169]	valid_0's rmse: 0.687858
# [170]	valid_0's rmse: 0.687549
# [171]	valid_0's rmse: 0.687729
# [172]	valid_0's rmse: 0.687666
# [173]	valid_0's rmse: 0.687703
# [174]	valid_0's rmse: 0.687816
# [175]	valid_0's rmse: 0.687831
# [176]	valid_0's rmse: 0.687556
# [177]	valid_0's rmse: 0.687568
# [178]	valid_0's rmse: 0.687323
# [179]	valid_0's rmse: 0.687571
# [180]	valid_0's rmse: 0.688
# [181]	valid_0's rmse: 0.687801
# [182]	valid_0's rmse: 0.687669
# [183]	valid_0's rmse: 0.687782
# [184]	valid_0's rmse: 0.6879
# [185]	valid_0's rmse: 0.687855
# [186]	valid_0's rmse: 0.687755
# [187]	valid_0's rmse: 0.687984
# [188]	valid_0's rmse: 0.688221
# [189]	valid_0's rmse: 0.688453
# [190]	valid_0's rmse: 0.688439
# [191]	valid_0's rmse: 0.688832
# [192]	valid_0's rmse: 0.688928
# [193]	valid_0's rmse: 0.688601
# [194]	valid_0's rmse: 0.688839
# [195]	valid_0's rmse: 0.688604
# [196]	valid_0's rmse: 0.68901
# [197]	valid_0's rmse: 0.689235
# [198]	valid_0's rmse: 0.689354
# [199]	valid_0's rmse: 0.689049
# [200]	valid_0's rmse: 0.689094
# [201]	valid_0's rmse: 0.689258
# [202]	valid_0's rmse: 0.689037
# [203]	valid_0's rmse: 0.689056
# [204]	valid_0's rmse: 0.689067
# [205]	valid_0's rmse: 0.688793
# [206]	valid_0's rmse: 0.688717
# [207]	valid_0's rmse: 0.689004
# [208]	valid_0's rmse: 0.688732
# [209]	valid_0's rmse: 0.689136
# [210]	valid_0's rmse: 0.688942
# [211]	valid_0's rmse: 0.689166
# [212]	valid_0's rmse: 0.689308
# [213]	valid_0's rmse: 0.689432
# [214]	valid_0's rmse: 0.689484
# [215]	valid_0's rmse: 0.68941
# [216]	valid_0's rmse: 0.689621
# [217]	valid_0's rmse: 0.689493
# [218]	valid_0's rmse: 0.68968
# [219]	valid_0's rmse: 0.689403
# [220]	valid_0's rmse: 0.6893
# [221]	valid_0's rmse: 0.689686
# [222]	valid_0's rmse: 0.689751
# [223]	valid_0's rmse: 0.689658
# [224]	valid_0's rmse: 0.689539
# [225]	valid_0's rmse: 0.689554
# [226]	valid_0's rmse: 0.689878
# [227]	valid_0's rmse: 0.690109
# [228]	valid_0's rmse: 0.689922
# [229]	valid_0's rmse: 0.690148
# [230]	valid_0's rmse: 0.689949
# [231]	valid_0's rmse: 0.690166
# [232]	valid_0's rmse: 0.690291
# [233]	valid_0's rmse: 0.690243
# [234]	valid_0's rmse: 0.69035
# [235]	valid_0's rmse: 0.690623
# [236]	valid_0's rmse: 0.690837
# [237]	valid_0's rmse: 0.690825
# [238]	valid_0's rmse: 0.690938
# [239]	valid_0's rmse: 0.6912
# [240]	valid_0's rmse: 0.691208
# [241]	valid_0's rmse: 0.691265
# [242]	valid_0's rmse: 0.691373
# [243]	valid_0's rmse: 0.691502
# [244]	valid_0's rmse: 0.691329
# [245]	valid_0's rmse: 0.691312
# [246]	valid_0's rmse: 0.691361
# [247]	valid_0's rmse: 0.691435
# [248]	valid_0's rmse: 0.691681
# [249]	valid_0's rmse: 0.691586
# [250]	valid_0's rmse: 0.691644
# [251]	valid_0's rmse: 0.691934
# [252]	valid_0's rmse: 0.691795
# [253]	valid_0's rmse: 0.691806
# [254]	valid_0's rmse: 0.691892
# [255]	valid_0's rmse: 0.691933
# [256]	valid_0's rmse: 0.691868
# [257]	valid_0's rmse: 0.692052
# [258]	valid_0's rmse: 0.691854
# [259]	valid_0's rmse: 0.69188
# [260]	valid_0's rmse: 0.691991
# [261]	valid_0's rmse: 0.691968
# [262]	valid_0's rmse: 0.691862
# [263]	valid_0's rmse: 0.691984
# [264]	valid_0's rmse: 0.691788
# [265]	valid_0's rmse: 0.692079
# [266]	valid_0's rmse: 0.692162
# [267]	valid_0's rmse: 0.692187
# [268]	valid_0's rmse: 0.692271
# [269]	valid_0's rmse: 0.692699
# [270]	valid_0's rmse: 0.692837
# [271]	valid_0's rmse: 0.69265
# [272]	valid_0's rmse: 0.692647
# [273]	valid_0's rmse: 0.692934
# [274]	valid_0's rmse: 0.693219
# [275]	valid_0's rmse: 0.693213
# [276]	valid_0's rmse: 0.693109
# [277]	valid_0's rmse: 0.693092
# [278]	valid_0's rmse: 0.692899
# [1]	valid_0's rmse: 1.06147
# [2]	valid_0's rmse: 1.0373
# [3]	valid_0's rmse: 1.01633
# [4]	valid_0's rmse: 0.994757
# [5]	valid_0's rmse: 0.974616
# [6]	valid_0's rmse: 0.956497
# [7]	valid_0's rmse: 0.939457
# [8]	valid_0's rmse: 0.923087
# [9]	valid_0's rmse: 0.906802
# [10]	valid_0's rmse: 0.892505
# [11]	valid_0's rmse: 0.877694
# [12]	valid_0's rmse: 0.86466
# [13]	valid_0's rmse: 0.852407
# [14]	valid_0's rmse: 0.841021
# [15]	valid_0's rmse: 0.830377
# [16]	valid_0's rmse: 0.820181
# [17]	valid_0's rmse: 0.811004
# [18]	valid_0's rmse: 0.80188
# [19]	valid_0's rmse: 0.793159
# [20]	valid_0's rmse: 0.785371
# [21]	valid_0's rmse: 0.77724
# [22]	valid_0's rmse: 0.769219
# [23]	valid_0's rmse: 0.762105
# [24]	valid_0's rmse: 0.755937
# [25]	valid_0's rmse: 0.749909
# [26]	valid_0's rmse: 0.744515
# [27]	valid_0's rmse: 0.73902
# [28]	valid_0's rmse: 0.734365
# [29]	valid_0's rmse: 0.729475
# [30]	valid_0's rmse: 0.725146
# [31]	valid_0's rmse: 0.721495
# [32]	valid_0's rmse: 0.716553
# [33]	valid_0's rmse: 0.712762
# [34]	valid_0's rmse: 0.708207
# [35]	valid_0's rmse: 0.70444
# [36]	valid_0's rmse: 0.699848
# [37]	valid_0's rmse: 0.696822
# [38]	valid_0's rmse: 0.694443
# [39]	valid_0's rmse: 0.691713
# [40]	valid_0's rmse: 0.689847
# [41]	valid_0's rmse: 0.68795
# [42]	valid_0's rmse: 0.68633
# [43]	valid_0's rmse: 0.684185
# [44]	valid_0's rmse: 0.681832
# [45]	valid_0's rmse: 0.679625
# [46]	valid_0's rmse: 0.677953
# [47]	valid_0's rmse: 0.676535
# [48]	valid_0's rmse: 0.673753
# [49]	valid_0's rmse: 0.673129
# [50]	valid_0's rmse: 0.672
# [51]	valid_0's rmse: 0.670211
# [52]	valid_0's rmse: 0.669006
# [53]	valid_0's rmse: 0.667676
# [54]	valid_0's rmse: 0.665404
# [55]	valid_0's rmse: 0.664519
# [56]	valid_0's rmse: 0.663014
# [57]	valid_0's rmse: 0.660936
# [58]	valid_0's rmse: 0.659338
# [59]	valid_0's rmse: 0.659128
# [60]	valid_0's rmse: 0.65752
# [61]	valid_0's rmse: 0.656015
# [62]	valid_0's rmse: 0.655077
# [63]	valid_0's rmse: 0.653666
# [64]	valid_0's rmse: 0.652879
# [65]	valid_0's rmse: 0.652261
# [66]	valid_0's rmse: 0.651251
# [67]	valid_0's rmse: 0.650145
# [68]	valid_0's rmse: 0.649045
# [69]	valid_0's rmse: 0.648446
# [70]	valid_0's rmse: 0.647997
# [71]	valid_0's rmse: 0.647036
# [72]	valid_0's rmse: 0.645905
# [73]	valid_0's rmse: 0.645539
# [74]	valid_0's rmse: 0.644749
# [75]	valid_0's rmse: 0.644035
# [76]	valid_0's rmse: 0.643183
# [77]	valid_0's rmse: 0.642264
# [78]	valid_0's rmse: 0.642154
# [79]	valid_0's rmse: 0.642094
# [80]	valid_0's rmse: 0.641382
# [81]	valid_0's rmse: 0.641004
# [82]	valid_0's rmse: 0.640787
# [83]	valid_0's rmse: 0.640179
# [84]	valid_0's rmse: 0.639195
# [85]	valid_0's rmse: 0.638978
# [86]	valid_0's rmse: 0.638897
# [87]	valid_0's rmse: 0.639156
# [88]	valid_0's rmse: 0.639213
# [89]	valid_0's rmse: 0.639065
# [90]	valid_0's rmse: 0.638534
# [91]	valid_0's rmse: 0.639054
# [92]	valid_0's rmse: 0.638644
# [93]	valid_0's rmse: 0.638864
# [94]	valid_0's rmse: 0.638443
# [95]	valid_0's rmse: 0.638067
# [96]	valid_0's rmse: 0.638357
# [97]	valid_0's rmse: 0.637945
# [98]	valid_0's rmse: 0.63763
# [99]	valid_0's rmse: 0.637601
# [100]	valid_0's rmse: 0.6378
# [101]	valid_0's rmse: 0.637222
# [102]	valid_0's rmse: 0.637409
# [103]	valid_0's rmse: 0.637479
# [104]	valid_0's rmse: 0.63714
# [105]	valid_0's rmse: 0.637009
# [106]	valid_0's rmse: 0.636657
# [107]	valid_0's rmse: 0.636132
# [108]	valid_0's rmse: 0.635386
# [109]	valid_0's rmse: 0.634974
# [110]	valid_0's rmse: 0.635311
# [111]	valid_0's rmse: 0.635291
# [112]	valid_0's rmse: 0.634394
# [113]	valid_0's rmse: 0.634458
# [114]	valid_0's rmse: 0.633931
# [115]	valid_0's rmse: 0.633839
# [116]	valid_0's rmse: 0.633559
# [117]	valid_0's rmse: 0.633316
# [118]	valid_0's rmse: 0.63328
# [119]	valid_0's rmse: 0.633252
# [120]	valid_0's rmse: 0.632832
# [121]	valid_0's rmse: 0.632828
# [122]	valid_0's rmse: 0.632358
# [123]	valid_0's rmse: 0.63169
# [124]	valid_0's rmse: 0.631119
# [125]	valid_0's rmse: 0.630951
# [126]	valid_0's rmse: 0.631526
# [127]	valid_0's rmse: 0.6318
# [128]	valid_0's rmse: 0.631727
# [129]	valid_0's rmse: 0.631344
# [130]	valid_0's rmse: 0.631224
# [131]	valid_0's rmse: 0.631028
# [132]	valid_0's rmse: 0.631127
# [133]	valid_0's rmse: 0.630568
# [134]	valid_0's rmse: 0.630499
# [135]	valid_0's rmse: 0.630498
# [136]	valid_0's rmse: 0.63051
# [137]	valid_0's rmse: 0.630119
# [138]	valid_0's rmse: 0.6304
# [139]	valid_0's rmse: 0.630607
# [140]	valid_0's rmse: 0.630141
# [141]	valid_0's rmse: 0.63036
# [142]	valid_0's rmse: 0.630282
# [143]	valid_0's rmse: 0.629903
# [144]	valid_0's rmse: 0.630398
# [145]	valid_0's rmse: 0.630524
# [146]	valid_0's rmse: 0.630612
# [147]	valid_0's rmse: 0.630518
# [148]	valid_0's rmse: 0.630302
# [149]	valid_0's rmse: 0.630053
# [150]	valid_0's rmse: 0.629992
# [151]	valid_0's rmse: 0.630214
# [152]	valid_0's rmse: 0.630855
# [153]	valid_0's rmse: 0.630932
# [154]	valid_0's rmse: 0.6308
# [155]	valid_0's rmse: 0.630632
# [156]	valid_0's rmse: 0.630448
# [157]	valid_0's rmse: 0.630629
# [158]	valid_0's rmse: 0.630262
# [159]	valid_0's rmse: 0.630204
# [160]	valid_0's rmse: 0.629685
# [161]	valid_0's rmse: 0.629569
# [162]	valid_0's rmse: 0.629359
# [163]	valid_0's rmse: 0.628876
# [164]	valid_0's rmse: 0.629226
# [165]	valid_0's rmse: 0.629347
# [166]	valid_0's rmse: 0.629158
# [167]	valid_0's rmse: 0.628545
# [168]	valid_0's rmse: 0.628817
# [169]	valid_0's rmse: 0.628853
# [170]	valid_0's rmse: 0.629019
# [171]	valid_0's rmse: 0.629181
# [172]	valid_0's rmse: 0.629136
# [173]	valid_0's rmse: 0.629569
# [174]	valid_0's rmse: 0.629651
# [175]	valid_0's rmse: 0.629359
# [176]	valid_0's rmse: 0.629213
# [177]	valid_0's rmse: 0.629003
# [178]	valid_0's rmse: 0.62943
# [179]	valid_0's rmse: 0.629434
# [180]	valid_0's rmse: 0.629574
# [181]	valid_0's rmse: 0.629439
# [182]	valid_0's rmse: 0.62937
# [183]	valid_0's rmse: 0.629605
# [184]	valid_0's rmse: 0.629844
# [185]	valid_0's rmse: 0.629912
# [186]	valid_0's rmse: 0.63023
# [187]	valid_0's rmse: 0.630297
# [188]	valid_0's rmse: 0.630342
# [189]	valid_0's rmse: 0.629932
# [190]	valid_0's rmse: 0.629665
# [191]	valid_0's rmse: 0.629218
# [192]	valid_0's rmse: 0.629177
# [193]	valid_0's rmse: 0.629477
# [194]	valid_0's rmse: 0.629365
# [195]	valid_0's rmse: 0.629505
# [196]	valid_0's rmse: 0.629443
# [197]	valid_0's rmse: 0.62918
# [198]	valid_0's rmse: 0.629093
# [199]	valid_0's rmse: 0.628869
# [200]	valid_0's rmse: 0.628439
# [201]	valid_0's rmse: 0.628486
# [202]	valid_0's rmse: 0.628244
# [203]	valid_0's rmse: 0.627876
# [204]	valid_0's rmse: 0.627579
# [205]	valid_0's rmse: 0.627488
# [206]	valid_0's rmse: 0.627587
# [207]	valid_0's rmse: 0.627631
# [208]	valid_0's rmse: 0.627675
# [209]	valid_0's rmse: 0.62783
# [210]	valid_0's rmse: 0.627804
# [211]	valid_0's rmse: 0.6281
# [212]	valid_0's rmse: 0.627958
# [213]	valid_0's rmse: 0.628013
# [214]	valid_0's rmse: 0.628131
# [215]	valid_0's rmse: 0.627801
# [216]	valid_0's rmse: 0.627853
# [217]	valid_0's rmse: 0.627479
# [218]	valid_0's rmse: 0.627182
# [219]	valid_0's rmse: 0.6271
# [220]	valid_0's rmse: 0.62658
# [221]	valid_0's rmse: 0.626353
# [222]	valid_0's rmse: 0.626289
# [223]	valid_0's rmse: 0.626537
# [224]	valid_0's rmse: 0.626639
# [225]	valid_0's rmse: 0.626557
# [226]	valid_0's rmse: 0.626752
# [227]	valid_0's rmse: 0.627022
# [228]	valid_0's rmse: 0.627109
# [229]	valid_0's rmse: 0.627024
# [230]	valid_0's rmse: 0.626879
# [231]	valid_0's rmse: 0.62687
# [232]	valid_0's rmse: 0.627072
# [233]	valid_0's rmse: 0.627001
# [234]	valid_0's rmse: 0.626789
# [235]	valid_0's rmse: 0.62661
# [236]	valid_0's rmse: 0.626445
# [237]	valid_0's rmse: 0.626532
# [238]	valid_0's rmse: 0.626588
# [239]	valid_0's rmse: 0.626741
# [240]	valid_0's rmse: 0.62668
# [241]	valid_0's rmse: 0.626475
# [242]	valid_0's rmse: 0.626576
# [243]	valid_0's rmse: 0.626543
# [244]	valid_0's rmse: 0.626179
# [245]	valid_0's rmse: 0.625973
# [246]	valid_0's rmse: 0.626025
# [247]	valid_0's rmse: 0.626235
# [248]	valid_0's rmse: 0.626489
# [249]	valid_0's rmse: 0.626509
# [250]	valid_0's rmse: 0.626501
# [251]	valid_0's rmse: 0.626303
# [252]	valid_0's rmse: 0.626042
# [253]	valid_0's rmse: 0.626115
# [254]	valid_0's rmse: 0.62601
# [255]	valid_0's rmse: 0.625712
# [256]	valid_0's rmse: 0.625537
# [257]	valid_0's rmse: 0.625424
# [258]	valid_0's rmse: 0.625617
# [259]	valid_0's rmse: 0.625675
# [260]	valid_0's rmse: 0.625901
# [261]	valid_0's rmse: 0.626159
# [262]	valid_0's rmse: 0.626379
# [263]	valid_0's rmse: 0.626353
# [264]	valid_0's rmse: 0.625986
# [265]	valid_0's rmse: 0.626197
# [266]	valid_0's rmse: 0.625826
# [267]	valid_0's rmse: 0.625848
# [268]	valid_0's rmse: 0.625726
# [269]	valid_0's rmse: 0.625788
# [270]	valid_0's rmse: 0.625646
# [271]	valid_0's rmse: 0.625577
# [272]	valid_0's rmse: 0.625396
# [273]	valid_0's rmse: 0.625613
# [274]	valid_0's rmse: 0.625729
# [275]	valid_0's rmse: 0.625753
# [276]	valid_0's rmse: 0.62562
# [277]	valid_0's rmse: 0.625909
# [278]	valid_0's rmse: 0.625801
# [279]	valid_0's rmse: 0.625765
# [280]	valid_0's rmse: 0.625603
# [281]	valid_0's rmse: 0.625822
# [282]	valid_0's rmse: 0.625894
# [283]	valid_0's rmse: 0.625876
# [284]	valid_0's rmse: 0.626013
# [285]	valid_0's rmse: 0.625507
# [286]	valid_0's rmse: 0.625572
# [287]	valid_0's rmse: 0.625495
# [288]	valid_0's rmse: 0.625582
# [289]	valid_0's rmse: 0.625789
# [290]	valid_0's rmse: 0.625828
# [291]	valid_0's rmse: 0.625964
# [292]	valid_0's rmse: 0.625837
# [293]	valid_0's rmse: 0.625688
# [294]	valid_0's rmse: 0.625645
# [295]	valid_0's rmse: 0.625799
# [296]	valid_0's rmse: 0.626101
# [297]	valid_0's rmse: 0.625938
# [298]	valid_0's rmse: 0.626007
# [299]	valid_0's rmse: 0.626434
# [300]	valid_0's rmse: 0.626427
# [301]	valid_0's rmse: 0.626218
# [302]	valid_0's rmse: 0.626312
# [303]	valid_0's rmse: 0.626088
# [304]	valid_0's rmse: 0.626147
# [305]	valid_0's rmse: 0.626014
# [306]	valid_0's rmse: 0.625846
# [307]	valid_0's rmse: 0.625967
# [308]	valid_0's rmse: 0.626046
# [309]	valid_0's rmse: 0.626096
# [310]	valid_0's rmse: 0.62608
# [311]	valid_0's rmse: 0.62609
# [312]	valid_0's rmse: 0.625998
# [313]	valid_0's rmse: 0.625581
# [314]	valid_0's rmse: 0.625668
# [315]	valid_0's rmse: 0.625496
# [316]	valid_0's rmse: 0.625607
# [317]	valid_0's rmse: 0.62557
# [318]	valid_0's rmse: 0.625494
# [319]	valid_0's rmse: 0.625366
# [320]	valid_0's rmse: 0.625156
# [321]	valid_0's rmse: 0.625382
# [322]	valid_0's rmse: 0.625416
# [323]	valid_0's rmse: 0.625246
# [324]	valid_0's rmse: 0.625536
# [325]	valid_0's rmse: 0.625604
# [326]	valid_0's rmse: 0.625541
# [327]	valid_0's rmse: 0.625483
# [328]	valid_0's rmse: 0.625504
# [329]	valid_0's rmse: 0.62559
# [330]	valid_0's rmse: 0.625758
# [331]	valid_0's rmse: 0.625803
# [332]	valid_0's rmse: 0.626057
# [333]	valid_0's rmse: 0.626124
# [334]	valid_0's rmse: 0.625768
# [335]	valid_0's rmse: 0.625713
# [336]	valid_0's rmse: 0.625805
# [337]	valid_0's rmse: 0.625901
# [338]	valid_0's rmse: 0.625926
# [339]	valid_0's rmse: 0.62608
# [340]	valid_0's rmse: 0.625974
# [341]	valid_0's rmse: 0.626071
# [342]	valid_0's rmse: 0.626006
# [343]	valid_0's rmse: 0.625921
# [344]	valid_0's rmse: 0.625852
# [345]	valid_0's rmse: 0.626005
# [346]	valid_0's rmse: 0.626086
# [347]	valid_0's rmse: 0.626095
# [348]	valid_0's rmse: 0.626289
# [349]	valid_0's rmse: 0.62636
# [350]	valid_0's rmse: 0.626271
# [351]	valid_0's rmse: 0.626041
# [352]	valid_0's rmse: 0.626102
# [353]	valid_0's rmse: 0.625859
# [354]	valid_0's rmse: 0.625717
# [355]	valid_0's rmse: 0.625723
# [356]	valid_0's rmse: 0.625468
# [357]	valid_0's rmse: 0.625466
# [358]	valid_0's rmse: 0.625513
# [359]	valid_0's rmse: 0.625489
# [360]	valid_0's rmse: 0.625779
# [361]	valid_0's rmse: 0.625856
# [362]	valid_0's rmse: 0.625995
# [363]	valid_0's rmse: 0.626158
# [364]	valid_0's rmse: 0.625957
# [365]	valid_0's rmse: 0.625947
# [366]	valid_0's rmse: 0.626047
# [367]	valid_0's rmse: 0.626092
# [368]	valid_0's rmse: 0.626259
# [369]	valid_0's rmse: 0.62618
# [370]	valid_0's rmse: 0.626366
# [371]	valid_0's rmse: 0.626307
# [372]	valid_0's rmse: 0.626006
# [373]	valid_0's rmse: 0.626056
# [374]	valid_0's rmse: 0.625923
# [375]	valid_0's rmse: 0.626266
# [376]	valid_0's rmse: 0.626324
# [377]	valid_0's rmse: 0.626326
# [378]	valid_0's rmse: 0.626179
# [379]	valid_0's rmse: 0.62624
# [380]	valid_0's rmse: 0.626343
# [381]	valid_0's rmse: 0.626384
# [382]	valid_0's rmse: 0.62629
# [383]	valid_0's rmse: 0.6263
# [384]	valid_0's rmse: 0.626105
# [385]	valid_0's rmse: 0.62618
# [386]	valid_0's rmse: 0.626146
# [387]	valid_0's rmse: 0.626204
# [388]	valid_0's rmse: 0.626286
# [389]	valid_0's rmse: 0.625948
# [390]	valid_0's rmse: 0.625973
# [391]	valid_0's rmse: 0.625983
# [392]	valid_0's rmse: 0.625843
# [393]	valid_0's rmse: 0.62565
# [394]	valid_0's rmse: 0.625711
# [395]	valid_0's rmse: 0.625616
# [396]	valid_0's rmse: 0.625754
# [397]	valid_0's rmse: 0.625696
# [398]	valid_0's rmse: 0.625701
# [399]	valid_0's rmse: 0.625525
# [400]	valid_0's rmse: 0.625143
# [401]	valid_0's rmse: 0.624939
# [402]	valid_0's rmse: 0.625036
# [403]	valid_0's rmse: 0.624993
# [404]	valid_0's rmse: 0.625132
# [405]	valid_0's rmse: 0.625154
# [406]	valid_0's rmse: 0.624955
# [407]	valid_0's rmse: 0.624843
# [408]	valid_0's rmse: 0.624646
# [409]	valid_0's rmse: 0.624701
# [410]	valid_0's rmse: 0.624697
# [411]	valid_0's rmse: 0.624747
# [412]	valid_0's rmse: 0.624904
# [413]	valid_0's rmse: 0.624995
# [414]	valid_0's rmse: 0.624921
# [415]	valid_0's rmse: 0.624827
# [416]	valid_0's rmse: 0.6248
# [417]	valid_0's rmse: 0.624751
# [418]	valid_0's rmse: 0.624853
# [419]	valid_0's rmse: 0.624796
# [420]	valid_0's rmse: 0.6248
# [421]	valid_0's rmse: 0.624975
# [422]	valid_0's rmse: 0.624994
# [423]	valid_0's rmse: 0.624969
# [424]	valid_0's rmse: 0.625012
# [425]	valid_0's rmse: 0.625263
# [426]	valid_0's rmse: 0.625304
# [427]	valid_0's rmse: 0.625516
# [428]	valid_0's rmse: 0.625624
# [429]	valid_0's rmse: 0.625704
# [430]	valid_0's rmse: 0.625661
# [431]	valid_0's rmse: 0.625636
# [432]	valid_0's rmse: 0.625706
# [433]	valid_0's rmse: 0.625769
# [434]	valid_0's rmse: 0.625794
# [435]	valid_0's rmse: 0.625915
# [436]	valid_0's rmse: 0.625904
# [437]	valid_0's rmse: 0.625936
# [438]	valid_0's rmse: 0.62601
# [439]	valid_0's rmse: 0.626071
# [440]	valid_0's rmse: 0.626119
# [441]	valid_0's rmse: 0.626204
# [442]	valid_0's rmse: 0.62629
# [443]	valid_0's rmse: 0.626338
# [444]	valid_0's rmse: 0.62629
# [445]	valid_0's rmse: 0.626207
# [446]	valid_0's rmse: 0.626292
# [447]	valid_0's rmse: 0.626127
# [448]	valid_0's rmse: 0.626159
# [449]	valid_0's rmse: 0.626228
# [450]	valid_0's rmse: 0.626203
# [451]	valid_0's rmse: 0.626009
# [452]	valid_0's rmse: 0.62607
# [453]	valid_0's rmse: 0.626016
# [454]	valid_0's rmse: 0.626035
# [455]	valid_0's rmse: 0.625875
# [456]	valid_0's rmse: 0.625935
# [457]	valid_0's rmse: 0.625759
# [458]	valid_0's rmse: 0.62568
# [459]	valid_0's rmse: 0.625713
# [460]	valid_0's rmse: 0.625697
# [461]	valid_0's rmse: 0.62562
# [462]	valid_0's rmse: 0.625611
# [463]	valid_0's rmse: 0.625676
# [464]	valid_0's rmse: 0.625807
# [465]	valid_0's rmse: 0.625841
# [466]	valid_0's rmse: 0.625637
# [467]	valid_0's rmse: 0.625701
# [468]	valid_0's rmse: 0.625918
# [469]	valid_0's rmse: 0.625861
# [470]	valid_0's rmse: 0.625912
# [471]	valid_0's rmse: 0.626029
# [472]	valid_0's rmse: 0.625968
# [473]	valid_0's rmse: 0.626047
# [474]	valid_0's rmse: 0.626072
# [475]	valid_0's rmse: 0.62598
# [476]	valid_0's rmse: 0.62602
# [477]	valid_0's rmse: 0.626125
# [478]	valid_0's rmse: 0.626141
# [479]	valid_0's rmse: 0.626151
# [480]	valid_0's rmse: 0.626231
# [481]	valid_0's rmse: 0.626184
# [482]	valid_0's rmse: 0.62639
# [483]	valid_0's rmse: 0.626562
# [484]	valid_0's rmse: 0.626547
# [485]	valid_0's rmse: 0.626499
# [486]	valid_0's rmse: 0.626686
# [487]	valid_0's rmse: 0.626814
# [488]	valid_0's rmse: 0.626829
# [489]	valid_0's rmse: 0.626716
# [490]	valid_0's rmse: 0.626644
# [491]	valid_0's rmse: 0.626433
# [492]	valid_0's rmse: 0.626471
# [493]	valid_0's rmse: 0.626499
# [494]	valid_0's rmse: 0.626701
# [495]	valid_0's rmse: 0.626729
# [496]	valid_0's rmse: 0.626558
# [497]	valid_0's rmse: 0.626396
# [498]	valid_0's rmse: 0.626313
# [499]	valid_0's rmse: 0.626243
# [500]	valid_0's rmse: 0.626274
# [501]	valid_0's rmse: 0.626196
# [502]	valid_0's rmse: 0.626284
# [503]	valid_0's rmse: 0.626305
# [504]	valid_0's rmse: 0.626213
# [505]	valid_0's rmse: 0.626273
# [506]	valid_0's rmse: 0.626298
# [507]	valid_0's rmse: 0.626044
# [508]	valid_0's rmse: 0.626106
# [1]	valid_0's rmse: 0.950818
# [2]	valid_0's rmse: 0.928048
# [3]	valid_0's rmse: 0.907127
# [4]	valid_0's rmse: 0.887623
# [5]	valid_0's rmse: 0.868925
# [6]	valid_0's rmse: 0.852448
# [7]	valid_0's rmse: 0.836155
# [8]	valid_0's rmse: 0.82041
# [9]	valid_0's rmse: 0.806263
# [10]	valid_0's rmse: 0.792409
# [11]	valid_0's rmse: 0.780927
# [12]	valid_0's rmse: 0.769115
# [13]	valid_0's rmse: 0.758871
# [14]	valid_0's rmse: 0.747604
# [15]	valid_0's rmse: 0.738065
# [16]	valid_0's rmse: 0.729913
# [17]	valid_0's rmse: 0.722565
# [18]	valid_0's rmse: 0.715834
# [19]	valid_0's rmse: 0.708842
# [20]	valid_0's rmse: 0.702657
# [21]	valid_0's rmse: 0.696872
# [22]	valid_0's rmse: 0.691247
# [23]	valid_0's rmse: 0.68563
# [24]	valid_0's rmse: 0.68126
# [25]	valid_0's rmse: 0.676012
# [26]	valid_0's rmse: 0.672157
# [27]	valid_0's rmse: 0.669016
# [28]	valid_0's rmse: 0.665351
# [29]	valid_0's rmse: 0.662696
# [30]	valid_0's rmse: 0.659243
# [31]	valid_0's rmse: 0.656116
# [32]	valid_0's rmse: 0.652295
# [33]	valid_0's rmse: 0.650522
# [34]	valid_0's rmse: 0.647041
# [35]	valid_0's rmse: 0.644368
# [36]	valid_0's rmse: 0.641055
# [37]	valid_0's rmse: 0.638774
# [38]	valid_0's rmse: 0.636789
# [39]	valid_0's rmse: 0.635887
# [40]	valid_0's rmse: 0.634781
# [41]	valid_0's rmse: 0.63265
# [42]	valid_0's rmse: 0.631065
# [43]	valid_0's rmse: 0.629192
# [44]	valid_0's rmse: 0.627898
# [45]	valid_0's rmse: 0.626264
# [46]	valid_0's rmse: 0.624913
# [47]	valid_0's rmse: 0.623972
# [48]	valid_0's rmse: 0.622796
# [49]	valid_0's rmse: 0.622317
# [50]	valid_0's rmse: 0.622256
# [51]	valid_0's rmse: 0.62207
# [52]	valid_0's rmse: 0.620899
# [53]	valid_0's rmse: 0.619346
# [54]	valid_0's rmse: 0.618912
# [55]	valid_0's rmse: 0.617865
# [56]	valid_0's rmse: 0.617123
# [57]	valid_0's rmse: 0.616415
# [58]	valid_0's rmse: 0.615793
# [59]	valid_0's rmse: 0.615253
# [60]	valid_0's rmse: 0.61426
# [61]	valid_0's rmse: 0.612828
# [62]	valid_0's rmse: 0.612075
# [63]	valid_0's rmse: 0.611166
# [64]	valid_0's rmse: 0.611126
# [65]	valid_0's rmse: 0.610487
# [66]	valid_0's rmse: 0.610411
# [67]	valid_0's rmse: 0.610654
# [68]	valid_0's rmse: 0.610003
# [69]	valid_0's rmse: 0.60913
# [70]	valid_0's rmse: 0.60892
# [71]	valid_0's rmse: 0.608899
# [72]	valid_0's rmse: 0.608552
# [73]	valid_0's rmse: 0.608737
# [74]	valid_0's rmse: 0.607962
# [75]	valid_0's rmse: 0.60725
# [76]	valid_0's rmse: 0.607338
# [77]	valid_0's rmse: 0.607911
# [78]	valid_0's rmse: 0.608372
# [79]	valid_0's rmse: 0.608428
# [80]	valid_0's rmse: 0.608955
# [81]	valid_0's rmse: 0.608713
# [82]	valid_0's rmse: 0.607935
# [83]	valid_0's rmse: 0.608274
# [84]	valid_0's rmse: 0.607409
# [85]	valid_0's rmse: 0.607242
# [86]	valid_0's rmse: 0.606809
# [87]	valid_0's rmse: 0.606549
# [88]	valid_0's rmse: 0.605853
# [89]	valid_0's rmse: 0.605549
# [90]	valid_0's rmse: 0.605289
# [91]	valid_0's rmse: 0.605107
# [92]	valid_0's rmse: 0.605283
# [93]	valid_0's rmse: 0.605347
# [94]	valid_0's rmse: 0.605684
# [95]	valid_0's rmse: 0.60566
# [96]	valid_0's rmse: 0.604911
# [97]	valid_0's rmse: 0.604476
# [98]	valid_0's rmse: 0.604496
# [99]	valid_0's rmse: 0.604348
# [100]	valid_0's rmse: 0.604573
# [101]	valid_0's rmse: 0.604351
# [102]	valid_0's rmse: 0.60457
# [103]	valid_0's rmse: 0.604451
# [104]	valid_0's rmse: 0.604368
# [105]	valid_0's rmse: 0.604522
# [106]	valid_0's rmse: 0.604627
# [107]	valid_0's rmse: 0.60454
# [108]	valid_0's rmse: 0.6046
# [109]	valid_0's rmse: 0.60474
# [110]	valid_0's rmse: 0.604829
# [111]	valid_0's rmse: 0.604895
# [112]	valid_0's rmse: 0.605104
# [113]	valid_0's rmse: 0.605771
# [114]	valid_0's rmse: 0.605674
# [115]	valid_0's rmse: 0.606621
# [116]	valid_0's rmse: 0.607029
# ...
# [48]	valid_0's rmse: 0.664268
# [49]	valid_0's rmse: 0.663164
# [50]	valid_0's rmse: 0.661301
# [51]	valid_0's rmse: 0.659989
# [52]	valid_0's rmse: 0.659149
# [53]	valid_0's rmse: 0.658594
# [54]	valid_0's rmse: 0.657479
# [55]	valid_0's rmse: 0.656388
# [56]	valid_0's rmse: 0.655717
# [57]	valid_0's rmse: 0.654949
# [58]	valid_0's rmse: 0.653541
# [59]	valid_0's rmse: 0.652886
# [60]	valid_0's rmse: 0.652505
# [61]	valid_0's rmse: 0.651828
# [62]	valid_0's rmse: 0.651005
# [63]	valid_0's rmse: 0.649563
# [64]	valid_0's rmse: 0.64766
# [65]	valid_0's rmse: 0.647273
# [66]	valid_0's rmse: 0.646913
# [67]	valid_0's rmse: 0.64681
# [68]	valid_0's rmse: 0.646108
# [69]	valid_0's rmse: 0.645648
# [70]	valid_0's rmse: 0.645169
# [71]	valid_0's rmse: 0.644618
# [72]	valid_0's rmse: 0.644241
# [73]	valid_0's rmse: 0.643753
# [74]	valid_0's rmse: 0.643009
# [75]	valid_0's rmse: 0.642752
# [76]	valid_0's rmse: 0.642691
# [77]	valid_0's rmse: 0.642475
# [78]	valid_0's rmse: 0.641472
# [79]	valid_0's rmse: 0.641228
# [80]	valid_0's rmse: 0.639935
# [81]	valid_0's rmse: 0.639158
# [82]	valid_0's rmse: 0.63831
# [83]	valid_0's rmse: 0.637218
# [84]	valid_0's rmse: 0.637079
# [85]	valid_0's rmse: 0.636619
# [86]	valid_0's rmse: 0.636178
# [87]	valid_0's rmse: 0.636373
# [88]	valid_0's rmse: 0.636854
# [89]	valid_0's rmse: 0.63665
# [90]	valid_0's rmse: 0.636613
# [91]	valid_0's rmse: 0.636104
# [92]	valid_0's rmse: 0.63619
# [93]	valid_0's rmse: 0.636236
# [94]	valid_0's rmse: 0.636471
# [95]	valid_0's rmse: 0.636505
# [96]	valid_0's rmse: 0.636167
# [97]	valid_0's rmse: 0.635868
# [98]	valid_0's rmse: 0.635357
# [99]	valid_0's rmse: 0.634742
# [100]	valid_0's rmse: 0.634757
# [101]	valid_0's rmse: 0.633942
# [102]	valid_0's rmse: 0.633702
# [103]	valid_0's rmse: 0.633618
# [104]	valid_0's rmse: 0.633477
# [105]	valid_0's rmse: 0.63389
# [106]	valid_0's rmse: 0.633052
# [107]	valid_0's rmse: 0.632827
# [108]	valid_0's rmse: 0.633097
# [109]	valid_0's rmse: 0.633517
# [110]	valid_0's rmse: 0.633012
# [111]	valid_0's rmse: 0.632324
# [112]	valid_0's rmse: 0.632414
# [113]	valid_0's rmse: 0.632245
# [114]	valid_0's rmse: 0.632301
# [115]	valid_0's rmse: 0.631848
# [116]	valid_0's rmse: 0.631638
# [117]	valid_0's rmse: 0.631672
# [118]	valid_0's rmse: 0.631764
# [119]	valid_0's rmse: 0.631711
# [120]	valid_0's rmse: 0.631997
# [121]	valid_0's rmse: 0.632272
# [122]	valid_0's rmse: 0.63236
# [123]	valid_0's rmse: 0.632051
# [124]	valid_0's rmse: 0.632608
# [125]	valid_0's rmse: 0.632334
# [126]	valid_0's rmse: 0.63225
# [127]	valid_0's rmse: 0.632529
# [128]	valid_0's rmse: 0.632032
# [129]	valid_0's rmse: 0.631855
# [130]	valid_0's rmse: 0.631913
# [131]	valid_0's rmse: 0.632166
# [132]	valid_0's rmse: 0.632223
# [133]	valid_0's rmse: 0.632127
# [134]	valid_0's rmse: 0.631958
# [135]	valid_0's rmse: 0.631612
# [136]	valid_0's rmse: 0.631382
# [137]	valid_0's rmse: 0.631574
# [138]	valid_0's rmse: 0.631578
# [139]	valid_0's rmse: 0.631795
# [140]	valid_0's rmse: 0.631556
# [141]	valid_0's rmse: 0.631587
# [142]	valid_0's rmse: 0.631443
# [143]	valid_0's rmse: 0.631341
# [144]	valid_0's rmse: 0.631375
# [145]	valid_0's rmse: 0.631118
# [146]	valid_0's rmse: 0.630854
# [147]	valid_0's rmse: 0.630815
# [148]	valid_0's rmse: 0.630503
# [149]	valid_0's rmse: 0.630889
# [150]	valid_0's rmse: 0.630915
# [151]	valid_0's rmse: 0.631376
# [152]	valid_0's rmse: 0.631525
# [153]	valid_0's rmse: 0.631219
# [154]	valid_0's rmse: 0.631043
# [155]	valid_0's rmse: 0.631246
# [156]	valid_0's rmse: 0.631267
# [157]	valid_0's rmse: 0.631555
# [158]	valid_0's rmse: 0.631648
# [159]	valid_0's rmse: 0.632305
# [160]	valid_0's rmse: 0.632235
# [161]	valid_0's rmse: 0.632396
# [162]	valid_0's rmse: 0.63285
# [163]	valid_0's rmse: 0.633047
# [164]	valid_0's rmse: 0.632436
# [165]	valid_0's rmse: 0.632603
# [166]	valid_0's rmse: 0.632595
# [167]	valid_0's rmse: 0.632981
# [168]	valid_0's rmse: 0.632658
# [169]	valid_0's rmse: 0.632609
# [170]	valid_0's rmse: 0.632642
# [171]	valid_0's rmse: 0.632331
# [172]	valid_0's rmse: 0.632635
# [173]	valid_0's rmse: 0.632325
# [174]	valid_0's rmse: 0.63244
# [175]	valid_0's rmse: 0.632453
# [176]	valid_0's rmse: 0.632385
# [177]	valid_0's rmse: 0.632258
# [178]	valid_0's rmse: 0.632188
# [179]	valid_0's rmse: 0.632223
# [180]	valid_0's rmse: 0.632072
# [181]	valid_0's rmse: 0.632459
# [182]	valid_0's rmse: 0.632045
# [183]	valid_0's rmse: 0.63192
# [184]	valid_0's rmse: 0.631481
# [185]	valid_0's rmse: 0.631284
# [186]	valid_0's rmse: 0.63122
# [187]	valid_0's rmse: 0.631203
# [188]	valid_0's rmse: 0.631415
# [189]	valid_0's rmse: 0.631405
# [190]	valid_0's rmse: 0.631188
# [191]	valid_0's rmse: 0.631102
# [192]	valid_0's rmse: 0.63122
# [193]	valid_0's rmse: 0.631024
# [194]	valid_0's rmse: 0.630774
# [195]	valid_0's rmse: 0.630862
# [196]	valid_0's rmse: 0.630337
# [197]	valid_0's rmse: 0.630329
# [198]	valid_0's rmse: 0.630896
# [199]	valid_0's rmse: 0.630984
# [200]	valid_0's rmse: 0.63088
# [201]	valid_0's rmse: 0.630702
# [202]	valid_0's rmse: 0.630789
# [203]	valid_0's rmse: 0.630725
# [204]	valid_0's rmse: 0.630653
# [205]	valid_0's rmse: 0.630348
# [206]	valid_0's rmse: 0.629981
# [207]	valid_0's rmse: 0.629747
# [208]	valid_0's rmse: 0.630057
# [209]	valid_0's rmse: 0.630235
# [210]	valid_0's rmse: 0.630123
# [211]	valid_0's rmse: 0.630205
# [212]	valid_0's rmse: 0.630177
# [213]	valid_0's rmse: 0.629847
# [214]	valid_0's rmse: 0.629741
# [215]	valid_0's rmse: 0.629543
# [216]	valid_0's rmse: 0.629761
# [217]	valid_0's rmse: 0.62975
# [218]	valid_0's rmse: 0.629739
# [219]	valid_0's rmse: 0.629814
# [220]	valid_0's rmse: 0.629526
# [221]	valid_0's rmse: 0.6296
# [222]	valid_0's rmse: 0.629762
# [223]	valid_0's rmse: 0.630009
# [224]	valid_0's rmse: 0.630081
# [225]	valid_0's rmse: 0.629964
# [226]	valid_0's rmse: 0.630027
# [227]	valid_0's rmse: 0.629947
# [228]	valid_0's rmse: 0.630088
# [229]	valid_0's rmse: 0.629943
# [230]	valid_0's rmse: 0.629763
# [231]	valid_0's rmse: 0.629858
# [232]	valid_0's rmse: 0.629787
# [233]	valid_0's rmse: 0.629725
# [234]	valid_0's rmse: 0.629301
# [235]	valid_0's rmse: 0.629342
# [236]	valid_0's rmse: 0.629527
# [237]	valid_0's rmse: 0.629674
# [238]	valid_0's rmse: 0.629668
# [239]	valid_0's rmse: 0.62945
# [240]	valid_0's rmse: 0.629644
# [241]	valid_0's rmse: 0.629184
# [242]	valid_0's rmse: 0.629115
# [243]	valid_0's rmse: 0.628748
# [244]	valid_0's rmse: 0.628703
# [245]	valid_0's rmse: 0.628451
# [246]	valid_0's rmse: 0.628248
# [247]	valid_0's rmse: 0.628142
# [248]	valid_0's rmse: 0.628269
# [249]	valid_0's rmse: 0.628375
# [250]	valid_0's rmse: 0.628336
# [251]	valid_0's rmse: 0.628302
# [252]	valid_0's rmse: 0.628385
# [253]	valid_0's rmse: 0.628314
# [254]	valid_0's rmse: 0.628161
# [255]	valid_0's rmse: 0.628399
# [256]	valid_0's rmse: 0.628236
# [257]	valid_0's rmse: 0.628032
# [258]	valid_0's rmse: 0.627918
# [259]	valid_0's rmse: 0.62779
# [260]	valid_0's rmse: 0.627447
# [261]	valid_0's rmse: 0.627329
# [262]	valid_0's rmse: 0.627437
# [263]	valid_0's rmse: 0.627201
# [264]	valid_0's rmse: 0.627164
# [265]	valid_0's rmse: 0.627672
# [266]	valid_0's rmse: 0.627877
# [267]	valid_0's rmse: 0.62776
# [268]	valid_0's rmse: 0.627547
# [269]	valid_0's rmse: 0.627485
# [270]	valid_0's rmse: 0.62763
# [271]	valid_0's rmse: 0.627185
# [272]	valid_0's rmse: 0.627328
# [273]	valid_0's rmse: 0.62739
# [274]	valid_0's rmse: 0.627556
# [275]	valid_0's rmse: 0.627615
# [276]	valid_0's rmse: 0.627638
# [277]	valid_0's rmse: 0.627528
# [278]	valid_0's rmse: 0.627466
# [279]	valid_0's rmse: 0.627303
# [280]	valid_0's rmse: 0.627181
# [281]	valid_0's rmse: 0.627716
# [282]	valid_0's rmse: 0.627682
# [283]	valid_0's rmse: 0.627519
# [284]	valid_0's rmse: 0.627429
# [285]	valid_0's rmse: 0.627733
# [286]	valid_0's rmse: 0.627602
# [287]	valid_0's rmse: 0.627831
# [288]	valid_0's rmse: 0.627695
# [289]	valid_0's rmse: 0.627588
# [290]	valid_0's rmse: 0.627719
# [291]	valid_0's rmse: 0.627749
# [292]	valid_0's rmse: 0.627741
# [293]	valid_0's rmse: 0.627495
# [294]	valid_0's rmse: 0.627802
# [295]	valid_0's rmse: 0.628041
# [296]	valid_0's rmse: 0.628092
# [297]	valid_0's rmse: 0.627998
# [298]	valid_0's rmse: 0.628491
# [299]	valid_0's rmse: 0.62852
# [300]	valid_0's rmse: 0.628242
# [301]	valid_0's rmse: 0.628356
# [302]	valid_0's rmse: 0.628458
# [303]	valid_0's rmse: 0.628084
# [304]	valid_0's rmse: 0.628061
# [305]	valid_0's rmse: 0.627999
# [306]	valid_0's rmse: 0.627823
# [307]	valid_0's rmse: 0.627377
# [308]	valid_0's rmse: 0.627353
# [309]	valid_0's rmse: 0.627605
# [310]	valid_0's rmse: 0.627945
# [311]	valid_0's rmse: 0.627794
# [312]	valid_0's rmse: 0.627403
# [313]	valid_0's rmse: 0.627556
# [314]	valid_0's rmse: 0.627457
# [315]	valid_0's rmse: 0.627462
# [316]	valid_0's rmse: 0.627612
# [317]	valid_0's rmse: 0.62783
# [318]	valid_0's rmse: 0.62761
# [319]	valid_0's rmse: 0.627852
# [320]	valid_0's rmse: 0.627925
# [321]	valid_0's rmse: 0.628049
# [322]	valid_0's rmse: 0.627917
# [323]	valid_0's rmse: 0.628044
# [324]	valid_0's rmse: 0.627918
# [325]	valid_0's rmse: 0.62795
# [326]	valid_0's rmse: 0.62753
# [327]	valid_0's rmse: 0.627398
# [328]	valid_0's rmse: 0.62733
# [329]	valid_0's rmse: 0.627336
# [330]	valid_0's rmse: 0.627333
# [331]	valid_0's rmse: 0.627301
# [332]	valid_0's rmse: 0.627376
# [333]	valid_0's rmse: 0.627184
# [334]	valid_0's rmse: 0.627241
# [335]	valid_0's rmse: 0.627061
# [336]	valid_0's rmse: 0.627069
# [337]	valid_0's rmse: 0.627097
# [338]	valid_0's rmse: 0.626977
# [339]	valid_0's rmse: 0.626977
# [340]	valid_0's rmse: 0.627051
# [341]	valid_0's rmse: 0.627084
# [342]	valid_0's rmse: 0.627052
# [343]	valid_0's rmse: 0.627034
# [344]	valid_0's rmse: 0.626871
# [345]	valid_0's rmse: 0.626769
# [346]	valid_0's rmse: 0.626615
# [347]	valid_0's rmse: 0.626363
# [348]	valid_0's rmse: 0.626354
# [349]	valid_0's rmse: 0.626418
# [350]	valid_0's rmse: 0.626372
# [351]	valid_0's rmse: 0.626358
# [352]	valid_0's rmse: 0.626493
# [353]	valid_0's rmse: 0.626383
# [354]	valid_0's rmse: 0.626341
# [355]	valid_0's rmse: 0.626303
# [356]	valid_0's rmse: 0.626334
# [357]	valid_0's rmse: 0.62633
# [358]	valid_0's rmse: 0.626329
# [359]	valid_0's rmse: 0.626227
# [360]	valid_0's rmse: 0.626096
# [361]	valid_0's rmse: 0.625899
# [362]	valid_0's rmse: 0.625933
# [363]	valid_0's rmse: 0.626067
# [364]	valid_0's rmse: 0.625887
# [365]	valid_0's rmse: 0.62581
# [366]	valid_0's rmse: 0.625739
# [367]	valid_0's rmse: 0.625717
# [368]	valid_0's rmse: 0.625616
# [369]	valid_0's rmse: 0.625588
# [370]	valid_0's rmse: 0.625741
# [371]	valid_0's rmse: 0.625696
# [372]	valid_0's rmse: 0.625562
# [373]	valid_0's rmse: 0.625407
# [374]	valid_0's rmse: 0.625328
# [375]	valid_0's rmse: 0.625212
# [376]	valid_0's rmse: 0.625121
# [377]	valid_0's rmse: 0.624907
# [378]	valid_0's rmse: 0.624925
# [379]	valid_0's rmse: 0.624872
# [380]	valid_0's rmse: 0.624796
# [381]	valid_0's rmse: 0.624548
# [382]	valid_0's rmse: 0.624649
# [383]	valid_0's rmse: 0.624387
# [384]	valid_0's rmse: 0.62436
# [385]	valid_0's rmse: 0.624167
# [386]	valid_0's rmse: 0.624371
# [387]	valid_0's rmse: 0.624239
# [388]	valid_0's rmse: 0.624176
# [389]	valid_0's rmse: 0.624228
# [390]	valid_0's rmse: 0.624089
# [391]	valid_0's rmse: 0.624166
# [392]	valid_0's rmse: 0.62423
# [393]	valid_0's rmse: 0.624196
# [394]	valid_0's rmse: 0.624309
# [395]	valid_0's rmse: 0.624271
# [396]	valid_0's rmse: 0.624235
# [397]	valid_0's rmse: 0.624302
# [398]	valid_0's rmse: 0.624293
# [399]	valid_0's rmse: 0.624227
# [400]	valid_0's rmse: 0.624348
# [401]	valid_0's rmse: 0.624216
# [402]	valid_0's rmse: 0.62406
# [403]	valid_0's rmse: 0.624045
# [404]	valid_0's rmse: 0.623934
# [405]	valid_0's rmse: 0.623881
# [406]	valid_0's rmse: 0.623983
# [407]	valid_0's rmse: 0.623909
# [408]	valid_0's rmse: 0.623956
# [409]	valid_0's rmse: 0.62403
# [410]	valid_0's rmse: 0.623806
# [411]	valid_0's rmse: 0.623792
# [412]	valid_0's rmse: 0.623917
# [413]	valid_0's rmse: 0.623874
# [414]	valid_0's rmse: 0.623945
# [415]	valid_0's rmse: 0.624228
# [416]	valid_0's rmse: 0.624193
# [417]	valid_0's rmse: 0.62432
# [418]	valid_0's rmse: 0.624222
# [419]	valid_0's rmse: 0.624392
# [420]	valid_0's rmse: 0.624215
# [421]	valid_0's rmse: 0.624253
# [422]	valid_0's rmse: 0.624359
# [423]	valid_0's rmse: 0.624478
# [424]	valid_0's rmse: 0.62439
# [425]	valid_0's rmse: 0.624426
# [426]	valid_0's rmse: 0.6246
# [427]	valid_0's rmse: 0.62464
# [428]	valid_0's rmse: 0.62475
# [429]	valid_0's rmse: 0.624791
# [430]	valid_0's rmse: 0.624748
# [431]	valid_0's rmse: 0.624727
# [432]	valid_0's rmse: 0.624682
# [433]	valid_0's rmse: 0.624652
# [434]	valid_0's rmse: 0.62472
# [435]	valid_0's rmse: 0.624602
# [436]	valid_0's rmse: 0.624509
# [437]	valid_0's rmse: 0.624387
# [438]	valid_0's rmse: 0.624391
# [439]	valid_0's rmse: 0.62426
# [440]	valid_0's rmse: 0.624274
# [441]	valid_0's rmse: 0.624141
# [442]	valid_0's rmse: 0.624038
# [443]	valid_0's rmse: 0.624093
# [444]	valid_0's rmse: 0.62401
# [445]	valid_0's rmse: 0.624054
# [446]	valid_0's rmse: 0.624059
# [447]	valid_0's rmse: 0.62411
# [448]	valid_0's rmse: 0.624231
# [449]	valid_0's rmse: 0.624275
# [450]	valid_0's rmse: 0.624098
# [451]	valid_0's rmse: 0.624119
# [452]	valid_0's rmse: 0.624071
# [453]	valid_0's rmse: 0.624122
# [454]	valid_0's rmse: 0.62417
# [455]	valid_0's rmse: 0.624063
# [456]	valid_0's rmse: 0.623973
# [457]	valid_0's rmse: 0.624047
# [458]	valid_0's rmse: 0.623983
# [459]	valid_0's rmse: 0.62401
# [460]	valid_0's rmse: 0.62389
# [461]	valid_0's rmse: 0.623809
# [462]	valid_0's rmse: 0.62379
# [463]	valid_0's rmse: 0.623879
# [464]	valid_0's rmse: 0.623775
# [465]	valid_0's rmse: 0.62375
# [466]	valid_0's rmse: 0.62366
# [467]	valid_0's rmse: 0.623749
# [468]	valid_0's rmse: 0.623731
# [469]	valid_0's rmse: 0.623785
# [470]	valid_0's rmse: 0.623821
# [471]	valid_0's rmse: 0.623911
# [472]	valid_0's rmse: 0.623788
# [473]	valid_0's rmse: 0.623938
# [474]	valid_0's rmse: 0.624043
# [475]	valid_0's rmse: 0.623932
# [476]	valid_0's rmse: 0.623927
# [477]	valid_0's rmse: 0.624034
# [478]	valid_0's rmse: 0.624215
# [479]	valid_0's rmse: 0.624241
# [480]	valid_0's rmse: 0.624252
# [481]	valid_0's rmse: 0.624325
# [482]	valid_0's rmse: 0.624313
# [483]	valid_0's rmse: 0.624306
# [484]	valid_0's rmse: 0.62429
# [485]	valid_0's rmse: 0.624177
# [486]	valid_0's rmse: 0.624184
# [487]	valid_0's rmse: 0.624324
# [488]	valid_0's rmse: 0.624284
# [489]	valid_0's rmse: 0.624359
# [490]	valid_0's rmse: 0.624343
# [491]	valid_0's rmse: 0.624202
# [492]	valid_0's rmse: 0.624175
# [493]	valid_0's rmse: 0.624337
# [494]	valid_0's rmse: 0.624338
# [495]	valid_0's rmse: 0.624256
# [496]	valid_0's rmse: 0.624321
# [497]	valid_0's rmse: 0.624212
# [498]	valid_0's rmse: 0.6242
# [499]	valid_0's rmse: 0.624348
# [500]	valid_0's rmse: 0.624277
# [501]	valid_0's rmse: 0.624243
# [502]	valid_0's rmse: 0.624178
# [503]	valid_0's rmse: 0.62433
# [504]	valid_0's rmse: 0.624344
# [505]	valid_0's rmse: 0.624166
# [506]	valid_0's rmse: 0.624212
# [507]	valid_0's rmse: 0.62425
# [508]	valid_0's rmse: 0.624212
# [509]	valid_0's rmse: 0.624273
# [510]	valid_0's rmse: 0.624204
# [511]	valid_0's rmse: 0.624238
# [512]	valid_0's rmse: 0.624112
# [513]	valid_0's rmse: 0.624008
# [514]	valid_0's rmse: 0.624076
# [515]	valid_0's rmse: 0.624083
# [516]	valid_0's rmse: 0.624183
# [517]	valid_0's rmse: 0.624185
# [518]	valid_0's rmse: 0.62413
# [519]	valid_0's rmse: 0.623935
# [520]	valid_0's rmse: 0.623971
# [521]	valid_0's rmse: 0.624012
# [522]	valid_0's rmse: 0.624074
# [523]	valid_0's rmse: 0.624047
# [524]	valid_0's rmse: 0.624042
# [525]	valid_0's rmse: 0.62402
# [526]	valid_0's rmse: 0.623984
# [527]	valid_0's rmse: 0.623998
# [528]	valid_0's rmse: 0.624015
# [529]	valid_0's rmse: 0.62391
# [530]	valid_0's rmse: 0.623815
# [531]	valid_0's rmse: 0.623793
# [532]	valid_0's rmse: 0.623905
# [533]	valid_0's rmse: 0.623794
# [534]	valid_0's rmse: 0.623809
# [535]	valid_0's rmse: 0.623724
# [536]	valid_0's rmse: 0.623818
# [537]	valid_0's rmse: 0.62383
# [538]	valid_0's rmse: 0.623878
# [539]	valid_0's rmse: 0.623926
# [540]	valid_0's rmse: 0.623909
# [541]	valid_0's rmse: 0.623867
# [542]	valid_0's rmse: 0.623714
# [543]	valid_0's rmse: 0.623799
# [544]	valid_0's rmse: 0.62389
# [545]	valid_0's rmse: 0.623944
# [546]	valid_0's rmse: 0.623923
# [547]	valid_0's rmse: 0.623967
# [548]	valid_0's rmse: 0.623969
# [549]	valid_0's rmse: 0.623975
# [550]	valid_0's rmse: 0.623815
# [551]	valid_0's rmse: 0.62386
# [552]	valid_0's rmse: 0.623841
# [553]	valid_0's rmse: 0.623919
# [554]	valid_0's rmse: 0.623921
# [555]	valid_0's rmse: 0.623857
# [556]	valid_0's rmse: 0.623884
# [557]	valid_0's rmse: 0.624021
# [558]	valid_0's rmse: 0.623938
# [559]	valid_0's rmse: 0.62397
# [560]	valid_0's rmse: 0.623918
# [561]	valid_0's rmse: 0.62395
# [562]	valid_0's rmse: 0.624043
# [563]	valid_0's rmse: 0.624053
# [564]	valid_0's rmse: 0.623902
# [565]	valid_0's rmse: 0.623796
# [566]	valid_0's rmse: 0.623782

# %%
print('OOF metric LGBM = {:.5f}'.format(metrics.mean_squared_error(train_feats[target_col], 
                                                                   OOF_PREDS[:, 0], 
                                                                   squared=False)))
# Out:
# OOF metric LGBM = 0.61522

# %% [markdown]
# # LightAutoML NN (DenseLight) prediction

# %%
from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task
import joblib

# def use_plr(USE_PLR):
#     if USE_PLR:
#         return "plr"
#     else:
#         return "cont"

# %%
for i in range(3):
    oof_pred, automl = joblib.load('/kaggle/input/linkinglamamodels/oof_and_lama_denselight_{}.pkl'.format(i))
    OOF_PREDS[:, 1] += oof_pred / 3
    TEST_PREDS[:, 1] += automl.predict(test_feats[train_cols]).data[:, 0] / 3
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator QuantileTransformer from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator QuantileTransformer from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator QuantileTransformer from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
print('OOF metric LightAutoML_NN = {:.5f}'.format(metrics.mean_squared_error(train_feats[target_col], 
                                                                               OOF_PREDS[:, 1], 
                                                                               squared=False)))
# Out:
# OOF metric LightAutoML_NN = 0.61386

# %% [markdown]
# # Blending

# %%
best_sc = 1
for w in np.arange(0, 1.01, 0.001):
    sc = metrics.mean_squared_error(train_feats[target_col], 
                                    w * OOF_PREDS[:, 0] + (1-w) * OOF_PREDS[:, 1], 
                                    squared=False)
    if sc < best_sc:
        best_sc = sc
        best_w = w
        
print('Composition OOF score = {:.5f}'.format(best_sc))
print('Composition best W = {:.3f}'.format(best_w))
# Out:
# Composition OOF score = 0.60851
# Composition best W = 0.472

# %% [markdown]
# # Submission creation

# %%
W = [best_w, 1 - best_w]
print(W)
test_preds = TEST_PREDS[:, 0] * W[0] + TEST_PREDS[:, 1] * W[1]
test_preds
# Out:
# [0.47200000000000003, 0.528]
# array([1.66823226, 0.99674628, 0.95888981])

# %%
test_feats['score'] = test_preds
sub1 = test_feats[['id', 'score']]
#test_feats[['id', 'score']].to_csv("submission.csv", index=False)
# Out:
# /tmp/ipykernel_19/1024135510.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test_feats['score'] = test_preds

# %%
sub1
# Out:
#          id     score
# 0  0000aaaa  1.668232
# 1  2222bbbb  0.996746
# 2  4444cccc  0.958890

# %% [markdown]
# # Saving OOFs and test predictions

# %%
joblib.dump((OOF_PREDS, TEST_PREDS), 'OOF_and_TEST_preds.pkl')
# Out:
# ['OOF_and_TEST_preds.pkl']

# %% [markdown]
# # Writing Quality(fusion_notebook)

# %%
import re, random, torch, pickle, gc, os, sklearn
import optuna
import lightgbm as lgb
import polars as pl
import pandas as pd
import numpy as np
from pathlib import Path
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
## Sklearn package
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor 
from sklearn.preprocessing import RobustScaler, FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.ensemble import VotingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import mean_squared_error 
from scipy.stats import skew, kurtosis
import ctypes
libc = ctypes.CDLL("libc.so.6")  # clear the memory
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_rows = 999
pd.options.display.max_colwidth = 99

# %%
DEBUG = True
SEED = 42
N_FOLD = 5
# Seed the same seed to all 
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
seed_everything(SEED)

# %%
data_path = '/kaggle/input/linking-writing-processes-to-writing-quality/'
train_logs = pl.scan_csv(data_path + 'train_logs.csv') # Create a datafrom using polars for fast execution
display(train_logs.collect().head()) # collect() produce the actual df
# Train_logs dataset has 11 columns
# Out:
# shape: (5, 11)
# ┌──────────┬──────────┬───────────┬─────────┬───┬───────────┬────────────┬────────────┬────────────┐
# │ id       ┆ event_id ┆ down_time ┆ up_time ┆ … ┆ up_event  ┆ text_chang ┆ cursor_pos ┆ word_count │
# │ ---      ┆ ---      ┆ ---       ┆ ---     ┆   ┆ ---       ┆ e          ┆ ition      ┆ ---        │
# │ str      ┆ i64      ┆ i64       ┆ i64     ┆   ┆ str       ┆ ---        ┆ ---        ┆ i64        │
# │          ┆          ┆           ┆         ┆   ┆           ┆ str        ┆ i64        ┆            │
# ╞══════════╪══════════╪═══════════╪═════════╪═══╪═══════════╪════════════╪════════════╪════════════╡
# │ 001519c8 ┆ 1        ┆ 4526      ┆ 4557    ┆ … ┆ Leftclick ┆ NoChange   ┆ 0          ┆ 0          │
# │ 001519c8 ┆ 2        ┆ 4558      ┆ 4962    ┆ … ┆ Leftclick ┆ NoChange   ┆ 0          ┆ 0          │
# │ 001519c8 ┆ 3        ┆ 106571    ┆ 106571  ┆ … ┆ Shift     ┆ NoChange   ┆ 0          ┆ 0          │
# │ 001519c8 ┆ 4        ┆ 106686    ┆ 106777  ┆ … ┆ q         ┆ q          ┆ 1          ┆ 1          │
# │ 001519c8 ┆ 5        ┆ 107196    ┆ 107323  ┆ … ┆ q         ┆ q          ┆ 2          ┆ 1          │
# └──────────┴──────────┴───────────┴─────────┴───┴───────────┴────────────┴────────────┴────────────┘

# %%
class FeatureExtractor():
    def __init__(self, logs):
        self.logs = logs # Training logs
        
    def count_by_values(self, colname, used_cols):
        fts = self.logs.select(pl.col('id').unique(maintain_order=True))
        for i, col in enumerate(used_cols):
            tmp_logs = self.logs.group_by('id').agg(
                            pl.col(colname).is_in([col]).sum().alias(f'{colname}_{i}_cnt')
                                    )
            fts  = fts.join(tmp_logs, on='id', how='left') 
        return fts
    
    # Create the features from statistics of activities, text changes, events
    def create_count_by_values_feats(self):
        activities = ['Input', 'Remove/Cut', 'Nonproduction', 'Replace', 'Paste']
        events = ['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick', 'ArrowLeft', '.',
                       ',', 'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock', "'", 'Delete', 'Unidentified']
        text_changes = ['q', ' ', '.', ',', '\n', "'", '"', '-', '?', ';', '=', '/', '\\', ':']        
        #=== Create the feature columns using count by values ===
        df = self.count_by_values('activity', activities) # Create 'activity' column
        df = df.join(self.count_by_values('text_change', text_changes), on='id', how='left') 
        df = df.join(self.count_by_values('down_event', events), on='id', how='left') 
        df = df.join(self.count_by_values('up_event', events), on='id', how='left')
        # print(df.collect().head())
        return df
    
    # Create the features 
    def create_input_words_feats(self):
        # Filter no changes 
        df = self.logs.filter((~pl.col('text_change').str.contains('=>')) & (pl.col('text_change') != 'NoChange'))
        # Aggregate the text changes by id
        df = df.group_by('id').agg(pl.col('text_change').str.concat('').str.extract_all(r'q+'))
        # creates only two columns ('id' and 'text_change') 
        df = df.with_columns(input_word_count=pl.col('text_change').list.lengths(),
                             input_word_length_mean=pl.col('text_change').apply(lambda x: np.mean([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_max=pl.col('text_change').apply(lambda x: np.max([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_std=pl.col('text_change').apply(lambda x: np.std([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_median=pl.col('text_change').apply(lambda x: np.median([len(i) for i in x] if len(x) > 0 else 0)),
                             input_word_length_skew=pl.col('text_change').apply(lambda x: skew([len(i) for i in x] if len(x) > 0 else 0)))
        df = df.drop('text_change') # Remove 'text_change' to avoid including duplicated `text_change` column
        return df
    
    # Create the statistical numeric features (e.g. sum, median, mean min, 0.5_quantile)
    def create_numeric_feats(self):
        num_cols = ['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']
        df = self.logs.group_by("id").agg(pl.sum('action_time').suffix('_sum'),
                                                pl.mean(num_cols).suffix('_mean'),
                                                pl.std(num_cols).suffix('_std'),
                                                pl.median(num_cols).suffix('_median'), pl.min(num_cols).suffix('_min'), pl.max(num_cols).suffix('_max'),
                                                pl.quantile(num_cols, 0.5).suffix('_quantile'))
        return df
    
    def create_categorical_feats(self):
        df  = self.logs.group_by("id").agg(
                pl.n_unique(['activity', 'down_event', 'up_event', 'text_change']))
        return df
    
    # Create the idle time features 
    def create_idle_time_feats(self):
        df = self.logs.with_columns(pl.col('up_time').shift().over('id').alias('up_time_lagged'))
        df = df.with_columns((abs(pl.col('down_time') - pl.col('up_time_lagged')) / 1000).fill_null(0).alias('time_diff'))
        df = df.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
        df = df.group_by("id").agg(inter_key_largest_lantency = pl.max('time_diff'),
                                   inter_key_median_lantency = pl.median('time_diff'),
                                   mean_pause_time = pl.mean('time_diff'),
                                   std_pause_time = pl.std('time_diff'),
                                   total_pause_time = pl.sum('time_diff'),
                                   pauses_half_sec = pl.col('time_diff').filter((pl.col('time_diff') > 0.5) & (pl.col('time_diff') < 1)).count(),
                                   pauses_1_sec = pl.col('time_diff').filter((pl.col('time_diff') > 1) & (pl.col('time_diff') < 1.5)).count(),
                                   pauses_1_half_sec = pl.col('time_diff').filter((pl.col('time_diff') > 1.5) & (pl.col('time_diff') < 2)).count(),
                                   pauses_2_sec = pl.col('time_diff').filter((pl.col('time_diff') > 2) & (pl.col('time_diff') < 3)).count(),
                                   pauses_3_sec = pl.col('time_diff').filter(pl.col('time_diff') > 3).count(),)
        return df
    
    # Create p-bursts features using up and down time and activity
    def create_p_bursts_feats(self):
        df = self.logs.with_columns(pl.col('up_time').shift().over('id').alias('up_time_lagged'))
        df = df.with_columns((abs(pl.col('down_time') - pl.col('up_time_lagged')) / 1000).fill_null(0).alias('time_diff'))
        df = df.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
        df = df.with_columns(pl.col('time_diff')<2)
        df = df.with_columns(pl.when(pl.col("time_diff") & pl.col("time_diff").is_last()).then(pl.count()).over(pl.col("time_diff").rle_id()).alias('P-bursts'))
        df = df.drop_nulls()
        df = df.group_by("id").agg(pl.mean('P-bursts').suffix('_mean'),
                                   pl.std('P-bursts').suffix('_std'),
                                   pl.count('P-bursts').suffix('_count'),
                                   pl.median('P-bursts').suffix('_median'),
                                   pl.max('P-bursts').suffix('_max'),
                                   pl.first('P-bursts').suffix('_first'),
                                   pl.last('P-bursts').suffix('_last'))
        return df
    
    # Create r-burst features using activity 
    def create_r_bursts_feats(self):
        df = self.logs.filter(pl.col('activity').is_in(['Input', 'Remove/Cut']))
        df = df.with_columns(pl.col('activity').is_in(['Remove/Cut']))
        df = df.with_columns(pl.when(pl.col("activity") & pl.col("activity").is_last()).then(pl.count()).over(pl.col("activity").rle_id()).alias('R-bursts'))
        df = df.drop_nulls()
        df = df.group_by("id").agg(pl.mean('R-bursts').suffix('_mean'),
                                   pl.std('R-bursts').suffix('_std'), 
                                   pl.median('R-bursts').suffix('_median'),
                                   pl.max('R-bursts').suffix('_max'),
                                   pl.first('R-bursts').suffix('_first'),
                                   pl.last('R-bursts').suffix('_last'))
        return df

    # Main function creates all 122 features
    def create_feats(self):
        feats = self.create_count_by_values_feats()  # 52 columns in total
#         print(f"< Count by values features > {len(feats.columns)}")        
        feats = feats.join(self.create_input_words_feats(), on='id', how='left')  # 58 columns
#         print(f"< Input words stats features > {len(feats.columns)}")
        feats = feats.join(self.create_numeric_feats(), on='id', how='left') # 89 columns
#         print(f"< Numerical features > {len(feats.columns)}")
        feats = feats.join(self.create_categorical_feats(), on='id', how='left') # 93 columns      
#         print(f"< Categorical features > {len(feats.columns)}")
        feats = feats.join(self.create_idle_time_feats(), on='id', how='left') # 103 columns
#         print(f"< Idle time features > {len(feats.columns)}")
        feats = feats.join(self.create_p_bursts_feats(), on='id', how='left') # 110 columns
#         print(f"< P-bursts features > {len(feats.columns)}")
        feats = feats.join(self.create_r_bursts_feats() , on='id', how='left') # 116 columns
#         print(f"< R-bursts features > {len(feats.columns)}")        
        return feats # 116 features

# %%
fe = FeatureExtractor(train_logs)
train_feats = fe.create_feats() # Extract features from trainning logs (polars df)
train_feats = train_feats.collect().to_pandas() # Convert polars df to pandas df
train_feats.to_csv("train_feats_0.csv")
# print(train_feats.describe())
train_logs = train_logs.collect().to_pandas()  # Convert polars df to pandas df
del fe

# %%
def q1(x):
    return x.quantile(0.25)
def q3(x):
    return x.quantile(0.75)

class EssayConstructor():
    def __init__(self, logs):
        self.logs = logs
        self.train_essays = self.get_train_essays(self.logs)
        self.AGGREGATIONS = ['count', 'mean', 'min', 'max', 'first', 'last', q1, 'median', q3, 'sum']
    
    # Get the essay from train logs 
    def get_train_essays(self, logs):
        def reconstruct_essay(currTextInput):
            essayText = ""
            for Input in currTextInput.values:
                if Input[0] == 'Replace':
                    replaceTxt = Input[2].split(' => ')
                    essayText = essayText[:Input[1] - len(replaceTxt[1])] + replaceTxt[1] + essayText[Input[1] - len(replaceTxt[1]) + len(replaceTxt[0]):]
                    continue
                if Input[0] == 'Paste':
                    essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
                    continue
                if Input[0] == 'Remove/Cut':
                    essayText = essayText[:Input[1]] + essayText[Input[1] + len(Input[2]):]
                    continue
                if "M" in Input[0]:
                    croppedTxt = Input[0][10:]
                    splitTxt = croppedTxt.split(' To ')
                    valueArr = [item.split(', ') for item in splitTxt]
                    moveData = (int(valueArr[0][0][1:]), int(valueArr[0][1][:-1]), int(valueArr[1][0][1:]), int(valueArr[1][1][:-1]))
                    if moveData[0] != moveData[2]:
                        if moveData[0] < moveData[2]:
                            essayText = essayText[:moveData[0]] + essayText[moveData[1]:moveData[3]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[3]:]
                        else:
                            essayText = essayText[:moveData[2]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[2]:moveData[0]] + essayText[moveData[1]:]
                    continue
                essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
            return essayText
        
        # Filter logs 
        df = logs[logs.activity != 'Nonproduction']
        group_df = df.groupby('id').apply(lambda x: reconstruct_essay(x[['activity', 'cursor_position', 'text_change']]))
        essay_df = pd.DataFrame({'id': df['id'].unique().tolist()})
        essay_df = essay_df.merge(group_df.rename('essay'), on='id')
        return essay_df

    # Create word level features from train essay
    def create_word_feats(self):
        df = self.train_essays.copy()
        df['word'] = df['essay'].apply(lambda x: re.split(' |\\n|\\.|\\?|\\!',x))
        df = df.explode('word')
        df['word_len'] = df['word'].apply(lambda x: len(x))
        df = df[df['word_len'] != 0] # Remove all the no-word record
        # Aggregate word level features
        word_agg_df = df[['id','word_len']].groupby(['id']).agg(self.AGGREGATIONS)
        word_agg_df.columns = ['_'.join(x) for x in word_agg_df.columns]
        word_agg_df['id'] = word_agg_df.index
        word_agg_df = word_agg_df.reset_index(drop=True)
        return word_agg_df
    # Create sentence level features
    def create_sentence_feats(self):
        df = self.train_essays.copy()
        df['sent'] = df['essay'].apply(lambda x: re.split('\\.|\\?|\\!',x))
        df = df.explode('sent')
        df['sent'] = df['sent'].apply(lambda x: x.replace('\n','').strip())
        # Number of characters in sentences
        df['sent_len'] = df['sent'].apply(lambda x: len(x))
        # Number of words in sentences
        df['sent_word_count'] = df['sent'].apply(lambda x: len(x.split(' ')))
        df = df[df.sent_len!=0].reset_index(drop=True)
        # Aggregate sentence level features
        sent_agg_df = pd.concat([df[['id','sent_len']].groupby(['id']).agg(self.AGGREGATIONS), 
                                 df[['id','sent_word_count']].groupby(['id']).agg(self.AGGREGATIONS)], axis=1)
        sent_agg_df.columns = ['_'.join(x) for x in sent_agg_df.columns]
        sent_agg_df['id'] = sent_agg_df.index
        sent_agg_df = sent_agg_df.reset_index(drop=True)
        sent_agg_df.drop(columns=["sent_word_count_count"], inplace=True)
        sent_agg_df = sent_agg_df.rename(columns={"sent_len_count":"sent_count"})
        return sent_agg_df
    # Create paragraph level features
    def create_paragraph_feats(self):
        df = self.train_essays.copy()
        df['paragraph'] = df['essay'].apply(lambda x: x.split('\n'))
        df = df.explode('paragraph')
        # Number of characters in paragraphs
        df['paragraph_len'] = df['paragraph'].apply(lambda x: len(x)) 
        # Number of words in paragraphs
        df['paragraph_word_count'] = df['paragraph'].apply(lambda x: len(x.split(' ')))
        df = df[df.paragraph_len!=0].reset_index(drop=True)
        # Aggregate paragraph level features
        paragraph_agg_df = pd.concat([df[['id','paragraph_len']].groupby(['id']).agg(self.AGGREGATIONS), 
                                      df[['id','paragraph_word_count']].groupby(['id']).agg(self.AGGREGATIONS)], axis=1) 
        paragraph_agg_df.columns = ['_'.join(x) for x in paragraph_agg_df.columns]
        paragraph_agg_df['id'] = paragraph_agg_df.index
        paragraph_agg_df = paragraph_agg_df.reset_index(drop=True)
        paragraph_agg_df.drop(columns=["paragraph_word_count_count"], inplace=True)
        paragraph_agg_df = paragraph_agg_df.rename(columns={"paragraph_len_count":"paragraph_count"})
        return paragraph_agg_df

    
    # Create product to keys features
    def create_product_to_keys_feats(self):
        essays = self.train_essays.copy()
        logs = self.logs.copy()
        essays['product_len'] = essays['essay'].str.len()
        tmp_df = logs[logs['activity'].isin(['Input', 'Remove/Cut'])].groupby(['id']).agg({'activity': 'count'}).reset_index().rename(columns={'activity': 'keys_pressed'})
        essays = essays.merge(tmp_df, on='id', how='left')
        essays['product_to_keys'] = essays['product_len'] / essays['keys_pressed']
        return essays[['id', 'product_to_keys']]

    # Create key pressed features
    def create_keys_pressed_feats(self):
        logs = self.logs.copy()
        temp_df = logs[logs['activity'].isin(['Input', 'Remove/Cut'])].groupby(['id']).agg(keys_pressed=('event_id', 'count')).reset_index()
        temp_df_2 = logs.groupby(['id']).agg(min_down_time=('down_time', 'min'), max_up_time=('up_time', 'max')).reset_index()
        temp_df = temp_df.merge(temp_df_2, on='id', how='left')
        temp_df['keys_per_second'] = temp_df['keys_pressed'] / ((temp_df['max_up_time'] - temp_df['min_down_time']) / 1000)
        return temp_df[['id', 'keys_per_second']]
    
    def create_feats(self, feats):
        feats = feats.merge(self.create_word_feats(), on='id', how='left') # 126 columns in total
#         print(f"{len(feats.columns)}")
        feats = feats.merge(self.create_sentence_feats(), on='id', how='left') # 145 columns
#         print(f"{len(feats.columns)}")
        feats = feats.merge(self.create_paragraph_feats(), on='id', how='left') # 164 columns
#         print(f"{len(feats.columns)}")
        feats = feats.merge(self.create_keys_pressed_feats(), on='id', how='left') # 166 columns
#         print(f"{len(feats.columns)}")
        feats = feats.merge(self.create_product_to_keys_feats(), on='id', how='left') # 165 columns
#         print(f"{len(feats.columns)}")
        return feats

# %%
print('< Essay Reconstruction >')
ec = EssayConstructor(train_logs)
train_feats = ec.create_feats(train_feats)
# Writing to csg
train_feats.to_csv("train_feats.csv")
del ec
# Out:
# < Essay Reconstruction >

# %%
train_scores  = pd.read_csv(data_path + 'train_scores.csv')
# Merge train features and train scores as training data
train_data = train_feats.merge(train_scores, on='id', how='left')

# %%
print('< Testing Data >')  # Load test data
test_logs = pl.scan_csv(data_path + 'test_logs.csv')
# Extract statistical features
fe = FeatureExtractor(test_logs)
test_feats = fe.create_feats() 
test_feats = test_feats.collect().to_pandas()
test_logs = test_logs.collect().to_pandas()
# Extract essay features
ec = EssayConstructor(test_logs)
test_feats = ec.create_feats(test_feats)
print("Nan columns of test data", test_feats.columns[test_feats.isna().any()].tolist()) # Check if any na in the test data

test_ids = test_feats['id'].values
test_x = test_feats.drop(['id'], axis=1)
# Out:
# < Testing Data >
# Nan columns of test data ['input_word_length_skew', 'P-bursts_mean', 'P-bursts_std', 'P-bursts_count', 'P-bursts_median', 'P-bursts_max', 'P-bursts_first', 'P-bursts_last', 'R-bursts_mean', 'R-bursts_std', 'R-bursts_median', 'R-bursts_max', 'R-bursts_first', 'R-bursts_last', 'word_len_count', 'word_len_mean', 'word_len_min', 'word_len_max', 'word_len_first', 'word_len_last', 'word_len_q1', 'word_len_median', 'word_len_q3', 'word_len_sum', 'sent_count', 'sent_len_mean', 'sent_len_min', 'sent_len_max', 'sent_len_first', 'sent_len_last', 'sent_len_q1', 'sent_len_median', 'sent_len_q3', 'sent_len_sum', 'sent_word_count_mean', 'sent_word_count_min', 'sent_word_count_max', 'sent_word_count_first', 'sent_word_count_last', 'sent_word_count_q1', 'sent_word_count_median', 'sent_word_count_q3', 'sent_word_count_sum']

# %%
# Split train data into X and Y
data_X = train_data.drop(['id', 'score'], axis=1)
data_Y = train_data['score'].values

# %%
class ModelTrainer():
    def __init__(self, model_name, **params):
        # Model
        self.model_name = model_name
        self.params = params
        self.create_model()
        
        self.X = data_X
        self.Y = data_Y        
        print(f'Number of features: {len(self.X.columns)}')
        
    
    def make_pipeline(self, model):
        return Pipeline([
            ('remove_infs', FunctionTransformer(lambda x: np.nan_to_num(x, nan=np.nan, posinf=0, neginf=0))),
            ('imputer', SimpleImputer(strategy='mean')),
            ('normalizer', FunctionTransformer(lambda x: np.log1p(np.abs(x)))),
            ('scaler', RobustScaler()),
            ('model', model)
        ])
    
    # Create the model
    def create_model(self):
        match model_name:
            case "lgbm":
                self.model = LGBMRegressor(**self.params)
            case "xgb":
                self.model = XGBRegressor(**self.params)
            case "catboost":
                self.model = CatBoostRegressor(**self.params)
            case 'rfr':
                self.model = self.make_pipeline(RandomForestRegressor(**self.params))
            case "svr":
                self.model = self.make_pipeline(SVR(**self.params))
            case 'lasso':
                self.model = self.make_pipeline(Lasso(**self.params))
            case 'ridge':
                self.model = self.make_pipeline(Ridge(**self.params))
            case other:
                print("Not implemented")
                sys.exit(-1)
    
    # Get the trained model        
    def get_model(self):
        return self.model
        
    # Train the model with 5-fold CV
    def train_model(self):        
        early_stopping_callback = lgb.early_stopping(200, first_metric_only=True, verbose=False)
#         verbose_callback = lgb.callback.log_evaluation(100)        
        # Split the training data into 5 fold
        skf = StratifiedKFold(n_splits=N_FOLD, random_state=SEED, shuffle=True)
        fold_rmses = []
        for fold, (train_index, valid_index) in enumerate(skf.split(self.X, self.Y.astype(str))):
            train_x = self.X.iloc[train_index]
            train_y = self.Y[train_index]
            valid_x = self.X.iloc[valid_index]
            valid_y = self.Y[valid_index]
            if model_name == 'lgbm':
                # Train the model with early stop of 100 
                self.model.fit(train_x, train_y, eval_set=[(valid_x, valid_y)],
                          callbacks=[
                                lgb.callback.early_stopping(stopping_rounds=100)
                          ])  
            else:
                # Fit the model with train x and train y
                self.model.fit(train_x, train_y)            
            predictions = self.model.predict(valid_x)
            rmse = mean_squared_error(y_true=valid_y, y_pred=predictions, squared=False) # Return RMSE
            fold_rmses.append(rmse)
        avg_rmse = np.mean(fold_rmses)
        print(f"Average rmse: {avg_rmse}") 
        return avg_rmse
    
    # Evaluate the model with entire X data
    def evaluation(self):
        preds = self.predict(self.X)
        rmse = mean_squared_error(y_true=self.Y, y_pred=preds, squared=False)
        return rmse
        
    # Predict the test data. 
    def predict(self, test_x):
        # Prediction loop
        tests_y = np.zeros((len(test_x), N_FOLD))
        for fold in range(N_FOLD):
            preds = self.model.predict(test_x)
            tests_y[:, fold] = preds
            #print(f"Fold = {fold} Prediction = {preds[:5]}")
        test_y = np.mean(tests_y, axis=1)
        return test_y# Average the prediction of each fold model
    
    # Clear the memory
    def clear_memory(self):
        del self.model
        libc.malloc_trim(0)
        torch.cuda.empty_cache()
        gc.collect()

# %%
params_dict ={}
# CatBoostRegressor
params_dict['catboost'] =  {
    "iterations": 5000,
    "early_stopping_rounds": 50,
    "depth": 6,
    "loss_function": "RMSE",
    "random_seed": SEED,
    "silent": True
}

## Best parameters of LGBM
params_dict['lgbm'] = {
    'n_estimators': 1024,
    'learning_rate': 0.005,
    'metric': 'rmse',
    'random_state': SEED,
    'force_col_wise': True,
    'verbosity': 0,
}

# XGBRegressor
params_dict['xgb'] = {
    "max_depth": 4,
    "learning_rate": 0.1,
    "objective": "reg:squarederror",
    "num_estimators": 1000,
    "num_boost_round": 1000,
    "eval_metric": "rmse",
    "seed": SEED
}
# svr
params_dict['svr'] = {
    'kernel':'rbf',
    'C':1.0,
    'epsilon': 0.1
}
# rfr 
params_dict['rfr'] = {
    'max_depth': 6,
    'max_features': 'sqrt',
    'min_impurity_decrease': 0.0016295128631816343,
    'n_estimators': 200,
    'random_state': SEED,
    }
# Ridge
params_dict['ridge'] = {
    'alpha': 1,
    'random_state': SEED,
    'solver': 'auto'
    }
# Lasso
params_dict['lasso'] = {
    'alpha': 0.04198227921905038, 
    'max_iter': 2000, 
    'random_state': SEED,
    }

# %%
best_score = 1.0
# Find the optimal learning rate
def objective(trial, model_name):
    global params_dict
    # Parameters
    params = params_dict[model_name] # Load the default parameters
    # set the trial for tunable parameters
    if model_name == 'xgb':
        # Parameters for 'xgb' model
        params['learning_rate'] = trial.suggest_loguniform('learning_rate', 1e-4, 0.5)
        params['max_depth'] = trial.suggest_int('max_depth', 2, 64)
    elif model_name == 'catboost':
        params['depth'] = trial.suggest_int('depth', 2, 30)
    elif model_name == 'svr':
        params['epsilon'] = trial.suggest_float('epsilon', 0.01, 1)
    elif model_name == 'ridge':
        params['alpha'] = trial.suggest_loguniform('alpha', 1e-3, 10.0)
    elif model_name == 'lgbm':
        params['learning_rate'] = trial.suggest_loguniform('learning_rate', 1e-4, 0.5)
        params['reg_alpha'] = trial.suggest_loguniform('reg_alpha', 1e-3, 10.0)
        params['reg_lambda'] = trial.suggest_loguniform('reg_lambda', 1e-3, 10.0)
        params['colsample_bytree'] = trial.suggest_float('colsample_bytree', 0.5, 1)
        params['subsample'] = trial.suggest_float('subsample', 0.5, 1)
        params['num_leaves'] = trial.suggest_int('num_leaves', 8, 64)
        params['min_child_samples'] = trial.suggest_int('min_child_samples', 1, 100)
    # Experiment the parameters
    trainer = ModelTrainer(model_name, **params)
    avg_score = trainer.train_model()
    # Save the model is the avg score > current best score
    global best_score
    if avg_score < best_score:
        best_score = avg_score
    # Clean up
    trainer.clear_memory()
    del trainer    
    print(f"Average result {avg_score} and the best score {best_score}")
    return avg_score

def run_optuna(model_name):
    study_name = f"{model_name}_study"
    study_file_path = f"/kaggle/working/{study_name}.db"
    if os.path.exists(study_file_path):
        os.remove(study_file_path)
    # # Create a study to find the optimal hyper-parameters    
    study = optuna.create_study(direction="minimize", study_name=study_name,
                                storage="sqlite:///" + f"{study_file_path}", # Storage path of the database keeping the study results
                                load_if_exists=False)  # Resume the existing study
    # Set up the timeout to avoid runing out of quote
    # n_jobs =-1 is CPU bounded
    study.optimize(lambda trial: objective(trial, model_name), 
                   n_jobs=4, n_trials=1000,
                   show_progress_bar=True, gc_after_trial=True)
    ## Print the best parameters    
    best_trial = study.best_trial
    best_params = study.best_params
    # Print out the experiment results
    print(f"Best parameters: {best_params}\n\n"
          f"Number of finished trials: {len(study.trials)}\n\n"
          f"Best trial:{best_trial}")    
    return study

# %%
# Train the model and make the predictions
def train_model(model_name, is_loaded=True):
    best_params = params_dict[model_name]
    # If is_loaded is True, load the best parameters.
    # Otherwise, initiate an Optuna study to optimize parameters.
    if is_loaded:  # Loaded the best parameters that are found from previous experiments
        study_name = f"{model_name}_study"
        study_file_path = f"/kaggle/input/writing-quality-dataset/{study_name}.db"
        if os.path.isfile(study_file_path):
            loaded_study = optuna.load_study(study_name=study_name,
                                         storage="sqlite:///" + f"{study_file_path}")
            best_params.update(loaded_study.best_params)
            print(f"Best parameters: {best_params}\n\n")
    else:
        study = run_optuna(model_name)
        best_params.update(study.best_params)
        # Print out the experiment results
        print(f"Best parameters: {best_params}\n\n")
    ## Parameters for LGBMRegressor model
    trainer = ModelTrainer(model_name, **best_params)
    trainer.train_model()
    rmse = trainer.evaluation()
    model = trainer.get_model()
    print(f"Complete training {model_name} RMSE = {rmse}")
    return model

# Collect all the models
models = []
model_names = ['ridge', 'svr', 'catboost', 'lgbm', 'xgb'] # 5 models 
# model_names = ['lasso', 'ridge', 'rfr', 'svr', 'catboost', 'lgbm', 'xgb'] # 7 models
preds_y = []
tests_y = []
for model_name in model_names:
    is_loaded = True
#     if 'lgbm' == model_name: # Enable optuna
#         is_loaded = False
    model = train_model(model_name, is_loaded)
    models.append((model_name, model))
print(models)
# Out:
# Number of features: 165
# Average rmse: 0.6288597873858061
# Complete training ridge RMSE = 0.5918428650495949
# Number of features: 165
# Average rmse: 0.6443252066658391
# Complete training svr RMSE = 0.5196133177200885
# Number of features: 165
# Average rmse: 0.6211000678151847
# Complete training catboost RMSE = 0.3092264620227419
# Number of features: 165
# [1]	valid_0's rmse: 1.01962
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 1.0166
# [3]	valid_0's rmse: 1.01356
# [4]	valid_0's rmse: 1.01063
# [5]	valid_0's rmse: 1.00764
# [6]	valid_0's rmse: 1.00475
# [7]	valid_0's rmse: 1.00181
# [8]	valid_0's rmse: 0.99896
# [9]	valid_0's rmse: 0.996022
# [10]	valid_0's rmse: 0.993215
# [11]	valid_0's rmse: 0.990338
# [12]	valid_0's rmse: 0.987476
# [13]	valid_0's rmse: 0.984702
# [14]	valid_0's rmse: 0.981846
# [15]	valid_0's rmse: 0.979125
# [16]	valid_0's rmse: 0.976299
# [17]	valid_0's rmse: 0.97357
# [18]	valid_0's rmse: 0.970907
# [19]	valid_0's rmse: 0.968158
# [20]	valid_0's rmse: 0.96548
# [21]	valid_0's rmse: 0.962794
# [22]	valid_0's rmse: 0.960183
# [23]	valid_0's rmse: 0.957529
# [24]	valid_0's rmse: 0.954923
# [25]	valid_0's rmse: 0.952393
# [26]	valid_0's rmse: 0.949763
# [27]	valid_0's rmse: 0.947205
# [28]	valid_0's rmse: 0.944666
# [29]	valid_0's rmse: 0.942189
# [30]	valid_0's rmse: 0.939765
# [31]	valid_0's rmse: 0.937217
# [32]	valid_0's rmse: 0.934776
# [33]	valid_0's rmse: 0.932385
# [34]	valid_0's rmse: 0.930035
# [35]	valid_0's rmse: 0.927668
# [36]	valid_0's rmse: 0.925273
# [37]	valid_0's rmse: 0.922909
# [38]	valid_0's rmse: 0.9206
# [39]	valid_0's rmse: 0.918296
# [40]	valid_0's rmse: 0.915991
# [41]	valid_0's rmse: 0.913734
# [42]	valid_0's rmse: 0.91146
# [43]	valid_0's rmse: 0.909254
# [44]	valid_0's rmse: 0.907041
# [45]	valid_0's rmse: 0.904797
# [46]	valid_0's rmse: 0.902594
# [47]	valid_0's rmse: 0.900406
# [48]	valid_0's rmse: 0.898305
# [49]	valid_0's rmse: 0.89615
# [50]	valid_0's rmse: 0.894011
# [51]	valid_0's rmse: 0.891843
# [52]	valid_0's rmse: 0.889768
# [53]	valid_0's rmse: 0.887671
# [54]	valid_0's rmse: 0.885574
# [55]	valid_0's rmse: 0.883564
# [56]	valid_0's rmse: 0.881571
# [57]	valid_0's rmse: 0.879568
# [58]	valid_0's rmse: 0.877555
# [59]	valid_0's rmse: 0.875531
# [60]	valid_0's rmse: 0.87362
# [61]	valid_0's rmse: 0.871638
# [62]	valid_0's rmse: 0.86963
# [63]	valid_0's rmse: 0.867623
# [64]	valid_0's rmse: 0.865621
# [65]	valid_0's rmse: 0.863692
# [66]	valid_0's rmse: 0.861775
# [67]	valid_0's rmse: 0.859858
# [68]	valid_0's rmse: 0.857939
# [69]	valid_0's rmse: 0.85601
# [70]	valid_0's rmse: 0.854097
# [71]	valid_0's rmse: 0.852246
# [72]	valid_0's rmse: 0.850388
# [73]	valid_0's rmse: 0.848552
# [74]	valid_0's rmse: 0.846708
# [75]	valid_0's rmse: 0.84487
# [76]	valid_0's rmse: 0.842995
# [77]	valid_0's rmse: 0.841181
# [78]	valid_0's rmse: 0.839359
# [79]	valid_0's rmse: 0.837556
# [80]	valid_0's rmse: 0.835803
# [81]	valid_0's rmse: 0.834064
# [82]	valid_0's rmse: 0.832311
# [83]	valid_0's rmse: 0.830615
# [84]	valid_0's rmse: 0.828937
# [85]	valid_0's rmse: 0.827229
# [86]	valid_0's rmse: 0.82554
# [87]	valid_0's rmse: 0.82392
# [88]	valid_0's rmse: 0.822218
# [89]	valid_0's rmse: 0.820582
# [90]	valid_0's rmse: 0.819075
# [91]	valid_0's rmse: 0.817473
# [92]	valid_0's rmse: 0.815973
# [93]	valid_0's rmse: 0.814389
# [94]	valid_0's rmse: 0.812752
# [95]	valid_0's rmse: 0.811236
# [96]	valid_0's rmse: 0.809708
# [97]	valid_0's rmse: 0.808166
# [98]	valid_0's rmse: 0.806655
# [99]	valid_0's rmse: 0.80515
# [100]	valid_0's rmse: 0.803681
# [101]	valid_0's rmse: 0.802135
# [102]	valid_0's rmse: 0.800737
# [103]	valid_0's rmse: 0.799279
# [104]	valid_0's rmse: 0.797801
# [105]	valid_0's rmse: 0.796339
# [106]	valid_0's rmse: 0.794855
# [107]	valid_0's rmse: 0.793454
# [108]	valid_0's rmse: 0.792013
# [109]	valid_0's rmse: 0.790617
# [110]	valid_0's rmse: 0.789172
# [111]	valid_0's rmse: 0.787877
# [112]	valid_0's rmse: 0.786465
# [113]	valid_0's rmse: 0.785074
# [114]	valid_0's rmse: 0.783691
# [115]	valid_0's rmse: 0.782299
# [116]	valid_0's rmse: 0.781003
# [117]	valid_0's rmse: 0.779665
# [118]	valid_0's rmse: 0.77843
# [119]	valid_0's rmse: 0.777144
# [120]	valid_0's rmse: 0.775928
# [121]	valid_0's rmse: 0.774772
# [122]	valid_0's rmse: 0.773403
# [123]	valid_0's rmse: 0.772187
# [124]	valid_0's rmse: 0.770959
# [125]	valid_0's rmse: 0.769623
# [126]	valid_0's rmse: 0.768377
# [127]	valid_0's rmse: 0.767045
# [128]	valid_0's rmse: 0.765779
# [129]	valid_0's rmse: 0.764668
# [130]	valid_0's rmse: 0.763395
# [131]	valid_0's rmse: 0.7622
# [132]	valid_0's rmse: 0.761108
# [133]	valid_0's rmse: 0.760031
# [134]	valid_0's rmse: 0.758802
# [135]	valid_0's rmse: 0.757648
# [136]	valid_0's rmse: 0.756421
# [137]	valid_0's rmse: 0.755308
# [138]	valid_0's rmse: 0.754193
# [139]	valid_0's rmse: 0.752998
# [140]	valid_0's rmse: 0.751802
# [141]	valid_0's rmse: 0.750688
# [142]	valid_0's rmse: 0.749587
# [143]	valid_0's rmse: 0.748405
# [144]	valid_0's rmse: 0.747361
# [145]	valid_0's rmse: 0.746292
# [146]	valid_0's rmse: 0.74509
# [147]	valid_0's rmse: 0.744067
# [148]	valid_0's rmse: 0.743042
# [149]	valid_0's rmse: 0.741862
# [150]	valid_0's rmse: 0.740915
# [151]	valid_0's rmse: 0.739802
# [152]	valid_0's rmse: 0.738748
# [153]	valid_0's rmse: 0.737717
# [154]	valid_0's rmse: 0.73677
# [155]	valid_0's rmse: 0.735623
# [156]	valid_0's rmse: 0.734596
# [157]	valid_0's rmse: 0.733529
# [158]	valid_0's rmse: 0.732566
# [159]	valid_0's rmse: 0.731499
# [160]	valid_0's rmse: 0.730465
# [161]	valid_0's rmse: 0.729413
# [162]	valid_0's rmse: 0.728481
# [163]	valid_0's rmse: 0.72749
# [164]	valid_0's rmse: 0.726592
# [165]	valid_0's rmse: 0.725686
# [166]	valid_0's rmse: 0.724781
# [167]	valid_0's rmse: 0.723937
# [168]	valid_0's rmse: 0.722962
# [169]	valid_0's rmse: 0.722076
# [170]	valid_0's rmse: 0.721083
# [171]	valid_0's rmse: 0.720227
# [172]	valid_0's rmse: 0.719321
# [173]	valid_0's rmse: 0.718529
# [174]	valid_0's rmse: 0.717541
# [175]	valid_0's rmse: 0.716665
# [176]	valid_0's rmse: 0.715788
# [177]	valid_0's rmse: 0.714867
# [178]	valid_0's rmse: 0.714021
# [179]	valid_0's rmse: 0.713127
# [180]	valid_0's rmse: 0.712254
# [181]	valid_0's rmse: 0.711383
# [182]	valid_0's rmse: 0.710635
# [183]	valid_0's rmse: 0.709809
# [184]	valid_0's rmse: 0.709022
# [185]	valid_0's rmse: 0.708326
# [186]	valid_0's rmse: 0.707555
# [187]	valid_0's rmse: 0.706802
# [188]	valid_0's rmse: 0.705947
# [189]	valid_0's rmse: 0.705178
# [190]	valid_0's rmse: 0.70441
# [191]	valid_0's rmse: 0.703602
# [192]	valid_0's rmse: 0.70288
# [193]	valid_0's rmse: 0.702161
# [194]	valid_0's rmse: 0.701404
# [195]	valid_0's rmse: 0.700699
# [196]	valid_0's rmse: 0.699956
# [197]	valid_0's rmse: 0.699329
# [198]	valid_0's rmse: 0.698551
# [199]	valid_0's rmse: 0.697898
# [200]	valid_0's rmse: 0.69716
# [201]	valid_0's rmse: 0.696493
# [202]	valid_0's rmse: 0.695762
# [203]	valid_0's rmse: 0.695094
# [204]	valid_0's rmse: 0.694433
# [205]	valid_0's rmse: 0.693805
# [206]	valid_0's rmse: 0.69308
# [207]	valid_0's rmse: 0.692417
# [208]	valid_0's rmse: 0.691746
# [209]	valid_0's rmse: 0.69105
# [210]	valid_0's rmse: 0.690413
# [211]	valid_0's rmse: 0.689748
# [212]	valid_0's rmse: 0.68915
# [213]	valid_0's rmse: 0.688568
# [214]	valid_0's rmse: 0.687968
# [215]	valid_0's rmse: 0.687343
# [216]	valid_0's rmse: 0.686736
# [217]	valid_0's rmse: 0.68613
# [218]	valid_0's rmse: 0.685535
# [219]	valid_0's rmse: 0.684988
# [220]	valid_0's rmse: 0.684413
# [221]	valid_0's rmse: 0.683847
# [222]	valid_0's rmse: 0.683279
# [223]	valid_0's rmse: 0.682682
# [224]	valid_0's rmse: 0.682161
# [225]	valid_0's rmse: 0.681566
# [226]	valid_0's rmse: 0.680975
# [227]	valid_0's rmse: 0.680376
# [228]	valid_0's rmse: 0.679816
# [229]	valid_0's rmse: 0.679242
# [230]	valid_0's rmse: 0.678694
# [231]	valid_0's rmse: 0.678223
# [232]	valid_0's rmse: 0.677581
# [233]	valid_0's rmse: 0.677045
# [234]	valid_0's rmse: 0.676472
# [235]	valid_0's rmse: 0.675918
# [236]	valid_0's rmse: 0.675347
# [237]	valid_0's rmse: 0.674902
# [238]	valid_0's rmse: 0.674462
# [239]	valid_0's rmse: 0.673799
# [240]	valid_0's rmse: 0.67332
# [241]	valid_0's rmse: 0.67267
# [242]	valid_0's rmse: 0.67225
# [243]	valid_0's rmse: 0.671612
# [244]	valid_0's rmse: 0.671066
# [245]	valid_0's rmse: 0.670626
# [246]	valid_0's rmse: 0.670119
# [247]	valid_0's rmse: 0.669502
# [248]	valid_0's rmse: 0.66912
# [249]	valid_0's rmse: 0.668514
# [250]	valid_0's rmse: 0.668034
# [251]	valid_0's rmse: 0.667675
# [252]	valid_0's rmse: 0.667201
# [253]	valid_0's rmse: 0.66658
# [254]	valid_0's rmse: 0.666045
# [255]	valid_0's rmse: 0.66566
# [256]	valid_0's rmse: 0.665185
# [257]	valid_0's rmse: 0.664766
# [258]	valid_0's rmse: 0.664249
# [259]	valid_0's rmse: 0.663821
# [260]	valid_0's rmse: 0.663347
# [261]	valid_0's rmse: 0.662952
# [262]	valid_0's rmse: 0.662456
# [263]	valid_0's rmse: 0.662035
# [264]	valid_0's rmse: 0.661661
# [265]	valid_0's rmse: 0.661176
# [266]	valid_0's rmse: 0.660774
# [267]	valid_0's rmse: 0.660298
# [268]	valid_0's rmse: 0.659811
# [269]	valid_0's rmse: 0.659404
# [270]	valid_0's rmse: 0.658934
# [271]	valid_0's rmse: 0.658455
# [272]	valid_0's rmse: 0.658099
# [273]	valid_0's rmse: 0.657665
# [274]	valid_0's rmse: 0.657183
# [275]	valid_0's rmse: 0.656768
# [276]	valid_0's rmse: 0.656367
# [277]	valid_0's rmse: 0.655995
# [278]	valid_0's rmse: 0.655543
# [279]	valid_0's rmse: 0.655102
# [280]	valid_0's rmse: 0.654741
# [281]	valid_0's rmse: 0.654349
# [282]	valid_0's rmse: 0.653971
# [283]	valid_0's rmse: 0.653514
# [284]	valid_0's rmse: 0.653158
# [285]	valid_0's rmse: 0.652744
# [286]	valid_0's rmse: 0.652458
# [287]	valid_0's rmse: 0.652046
# [288]	valid_0's rmse: 0.651661
# [289]	valid_0's rmse: 0.651218
# [290]	valid_0's rmse: 0.650812
# [291]	valid_0's rmse: 0.650488
# [292]	valid_0's rmse: 0.650139
# [293]	valid_0's rmse: 0.649738
# [294]	valid_0's rmse: 0.649362
# [295]	valid_0's rmse: 0.648926
# [296]	valid_0's rmse: 0.648566
# [297]	valid_0's rmse: 0.648242
# [298]	valid_0's rmse: 0.647911
# [299]	valid_0's rmse: 0.647533
# [300]	valid_0's rmse: 0.647156
# [301]	valid_0's rmse: 0.646826
# [302]	valid_0's rmse: 0.646463
# [303]	valid_0's rmse: 0.646086
# [304]	valid_0's rmse: 0.645782
# [305]	valid_0's rmse: 0.645376
# [306]	valid_0's rmse: 0.644936
# [307]	valid_0's rmse: 0.644583
# [308]	valid_0's rmse: 0.644287
# [309]	valid_0's rmse: 0.644021
# [310]	valid_0's rmse: 0.64363
# [311]	valid_0's rmse: 0.643356
# [312]	valid_0's rmse: 0.642995
# [313]	valid_0's rmse: 0.642692
# [314]	valid_0's rmse: 0.642386
# [315]	valid_0's rmse: 0.642131
# [316]	valid_0's rmse: 0.641862
# [317]	valid_0's rmse: 0.641504
# [318]	valid_0's rmse: 0.641185
# [319]	valid_0's rmse: 0.64098
# [320]	valid_0's rmse: 0.640717
# [321]	valid_0's rmse: 0.640394
# [322]	valid_0's rmse: 0.640217
# [323]	valid_0's rmse: 0.639989
# [324]	valid_0's rmse: 0.639765
# [325]	valid_0's rmse: 0.639443
# [326]	valid_0's rmse: 0.63922
# [327]	valid_0's rmse: 0.638903
# [328]	valid_0's rmse: 0.638646
# [329]	valid_0's rmse: 0.638351
# [330]	valid_0's rmse: 0.638042
# [331]	valid_0's rmse: 0.637842
# [332]	valid_0's rmse: 0.637545
# [333]	valid_0's rmse: 0.637273
# [334]	valid_0's rmse: 0.637045
# [335]	valid_0's rmse: 0.636784
# [336]	valid_0's rmse: 0.636513
# [337]	valid_0's rmse: 0.636242
# [338]	valid_0's rmse: 0.635985
# [339]	valid_0's rmse: 0.635742
# [340]	valid_0's rmse: 0.6354
# [341]	valid_0's rmse: 0.635148
# [342]	valid_0's rmse: 0.634828
# [343]	valid_0's rmse: 0.634588
# [344]	valid_0's rmse: 0.634275
# [345]	valid_0's rmse: 0.634006
# [346]	valid_0's rmse: 0.633794
# [347]	valid_0's rmse: 0.63352
# [348]	valid_0's rmse: 0.633251
# [349]	valid_0's rmse: 0.633058
# [350]	valid_0's rmse: 0.632867
# [351]	valid_0's rmse: 0.63263
# [352]	valid_0's rmse: 0.632397
# [353]	valid_0's rmse: 0.632134
# [354]	valid_0's rmse: 0.631983
# [355]	valid_0's rmse: 0.631756
# [356]	valid_0's rmse: 0.631556
# [357]	valid_0's rmse: 0.631326
# [358]	valid_0's rmse: 0.631105
# [359]	valid_0's rmse: 0.630892
# [360]	valid_0's rmse: 0.630685
# [361]	valid_0's rmse: 0.630519
# [362]	valid_0's rmse: 0.630347
# [363]	valid_0's rmse: 0.630093
# [364]	valid_0's rmse: 0.62988
# [365]	valid_0's rmse: 0.629625
# [366]	valid_0's rmse: 0.629469
# [367]	valid_0's rmse: 0.629222
# [368]	valid_0's rmse: 0.628975
# [369]	valid_0's rmse: 0.628828
# [370]	valid_0's rmse: 0.628589
# [371]	valid_0's rmse: 0.628418
# [372]	valid_0's rmse: 0.628222
# [373]	valid_0's rmse: 0.627987
# [374]	valid_0's rmse: 0.627821
# [375]	valid_0's rmse: 0.627636
# [376]	valid_0's rmse: 0.627401
# [377]	valid_0's rmse: 0.627226
# [378]	valid_0's rmse: 0.627043
# [379]	valid_0's rmse: 0.626821
# [380]	valid_0's rmse: 0.626653
# [381]	valid_0's rmse: 0.626471
# [382]	valid_0's rmse: 0.626292
# [383]	valid_0's rmse: 0.626127
# [384]	valid_0's rmse: 0.625976
# [385]	valid_0's rmse: 0.625827
# [386]	valid_0's rmse: 0.625653
# [387]	valid_0's rmse: 0.625527
# [388]	valid_0's rmse: 0.625365
# [389]	valid_0's rmse: 0.625167
# [390]	valid_0's rmse: 0.624958
# [391]	valid_0's rmse: 0.624792
# [392]	valid_0's rmse: 0.624673
# [393]	valid_0's rmse: 0.624506
# [394]	valid_0's rmse: 0.624344
# [395]	valid_0's rmse: 0.624185
# [396]	valid_0's rmse: 0.624096
# [397]	valid_0's rmse: 0.623937
# [398]	valid_0's rmse: 0.62375
# [399]	valid_0's rmse: 0.623633
# [400]	valid_0's rmse: 0.623434
# [401]	valid_0's rmse: 0.623267
# [402]	valid_0's rmse: 0.623048
# [403]	valid_0's rmse: 0.622922
# [404]	valid_0's rmse: 0.622767
# [405]	valid_0's rmse: 0.622597
# [406]	valid_0's rmse: 0.622452
# [407]	valid_0's rmse: 0.622354
# [408]	valid_0's rmse: 0.62221
# [409]	valid_0's rmse: 0.622064
# [410]	valid_0's rmse: 0.621901
# [411]	valid_0's rmse: 0.621737
# [412]	valid_0's rmse: 0.621556
# [413]	valid_0's rmse: 0.621423
# [414]	valid_0's rmse: 0.621283
# [415]	valid_0's rmse: 0.621138
# [416]	valid_0's rmse: 0.621033
# [417]	valid_0's rmse: 0.620966
# [418]	valid_0's rmse: 0.620866
# [419]	valid_0's rmse: 0.620712
# [420]	valid_0's rmse: 0.620583
# [421]	valid_0's rmse: 0.620377
# [422]	valid_0's rmse: 0.620261
# [423]	valid_0's rmse: 0.620104
# [424]	valid_0's rmse: 0.620003
# [425]	valid_0's rmse: 0.61979
# [426]	valid_0's rmse: 0.619613
# [427]	valid_0's rmse: 0.619516
# [428]	valid_0's rmse: 0.619414
# [429]	valid_0's rmse: 0.619255
# [430]	valid_0's rmse: 0.619177
# [431]	valid_0's rmse: 0.619074
# [432]	valid_0's rmse: 0.618893
# [433]	valid_0's rmse: 0.618724
# [434]	valid_0's rmse: 0.618628
# [435]	valid_0's rmse: 0.61854
# [436]	valid_0's rmse: 0.618416
# [437]	valid_0's rmse: 0.618358
# [438]	valid_0's rmse: 0.618191
# [439]	valid_0's rmse: 0.618058
# [440]	valid_0's rmse: 0.617961
# [441]	valid_0's rmse: 0.61784
# [442]	valid_0's rmse: 0.617782
# [443]	valid_0's rmse: 0.617671
# [444]	valid_0's rmse: 0.617511
# [445]	valid_0's rmse: 0.617492
# [446]	valid_0's rmse: 0.617385
# [447]	valid_0's rmse: 0.617293
# [448]	valid_0's rmse: 0.617207
# [449]	valid_0's rmse: 0.617069
# [450]	valid_0's rmse: 0.616997
# [451]	valid_0's rmse: 0.616929
# [452]	valid_0's rmse: 0.616869
# [453]	valid_0's rmse: 0.616699
# [454]	valid_0's rmse: 0.616573
# [455]	valid_0's rmse: 0.616443
# [456]	valid_0's rmse: 0.616238
# [457]	valid_0's rmse: 0.616122
# [458]	valid_0's rmse: 0.615973
# [459]	valid_0's rmse: 0.615852
# [460]	valid_0's rmse: 0.615794
# [461]	valid_0's rmse: 0.615612
# [462]	valid_0's rmse: 0.615491
# [463]	valid_0's rmse: 0.615348
# [464]	valid_0's rmse: 0.615246
# [465]	valid_0's rmse: 0.6151
# [466]	valid_0's rmse: 0.615015
# [467]	valid_0's rmse: 0.614825
# [468]	valid_0's rmse: 0.614749
# [469]	valid_0's rmse: 0.614622
# [470]	valid_0's rmse: 0.614466
# [471]	valid_0's rmse: 0.614319
# [472]	valid_0's rmse: 0.614273
# [473]	valid_0's rmse: 0.614171
# [474]	valid_0's rmse: 0.614035
# [475]	valid_0's rmse: 0.613959
# [476]	valid_0's rmse: 0.613861
# [477]	valid_0's rmse: 0.613705
# [478]	valid_0's rmse: 0.613661
# [479]	valid_0's rmse: 0.613616
# [480]	valid_0's rmse: 0.613509
# [481]	valid_0's rmse: 0.613402
# [482]	valid_0's rmse: 0.613363
# [483]	valid_0's rmse: 0.613215
# [484]	valid_0's rmse: 0.613174
# [485]	valid_0's rmse: 0.613083
# [486]	valid_0's rmse: 0.613014
# [487]	valid_0's rmse: 0.612904
# [488]	valid_0's rmse: 0.612844
# [489]	valid_0's rmse: 0.612723
# [490]	valid_0's rmse: 0.612581
# [491]	valid_0's rmse: 0.612436
# [492]	valid_0's rmse: 0.612388
# [493]	valid_0's rmse: 0.612287
# [494]	valid_0's rmse: 0.612183
# [495]	valid_0's rmse: 0.612018
# [496]	valid_0's rmse: 0.61197
# [497]	valid_0's rmse: 0.611915
# [498]	valid_0's rmse: 0.611877
# [499]	valid_0's rmse: 0.611793
# [500]	valid_0's rmse: 0.611678
# [501]	valid_0's rmse: 0.611599
# [502]	valid_0's rmse: 0.611505
# [503]	valid_0's rmse: 0.611415
# [504]	valid_0's rmse: 0.611296
# [505]	valid_0's rmse: 0.611234
# [506]	valid_0's rmse: 0.611128
# [507]	valid_0's rmse: 0.611065
# [508]	valid_0's rmse: 0.610963
# [509]	valid_0's rmse: 0.610887
# [510]	valid_0's rmse: 0.610816
# [511]	valid_0's rmse: 0.610718
# [512]	valid_0's rmse: 0.610646
# [513]	valid_0's rmse: 0.610549
# [514]	valid_0's rmse: 0.610474
# [515]	valid_0's rmse: 0.610397
# [516]	valid_0's rmse: 0.610321
# [517]	valid_0's rmse: 0.610248
# [518]	valid_0's rmse: 0.610149
# [519]	valid_0's rmse: 0.610112
# [520]	valid_0's rmse: 0.610022
# [521]	valid_0's rmse: 0.60995
# [522]	valid_0's rmse: 0.609855
# [523]	valid_0's rmse: 0.609803
# [524]	valid_0's rmse: 0.609752
# [525]	valid_0's rmse: 0.6097
# [526]	valid_0's rmse: 0.609639
# [527]	valid_0's rmse: 0.609565
# [528]	valid_0's rmse: 0.609511
# [529]	valid_0's rmse: 0.609476
# [530]	valid_0's rmse: 0.609399
# [531]	valid_0's rmse: 0.609381
# [532]	valid_0's rmse: 0.609397
# [533]	valid_0's rmse: 0.609254
# [534]	valid_0's rmse: 0.609161
# [535]	valid_0's rmse: 0.60907
# [536]	valid_0's rmse: 0.609089
# [537]	valid_0's rmse: 0.609029
# [538]	valid_0's rmse: 0.608919
# [539]	valid_0's rmse: 0.608829
# [540]	valid_0's rmse: 0.608823
# [541]	valid_0's rmse: 0.608749
# [542]	valid_0's rmse: 0.608725
# [543]	valid_0's rmse: 0.608587
# [544]	valid_0's rmse: 0.608605
# [545]	valid_0's rmse: 0.608536
# [546]	valid_0's rmse: 0.60847
# [547]	valid_0's rmse: 0.608412
# [548]	valid_0's rmse: 0.6084
# [549]	valid_0's rmse: 0.6083
# [550]	valid_0's rmse: 0.60819
# [551]	valid_0's rmse: 0.60811
# [552]	valid_0's rmse: 0.608078
# [553]	valid_0's rmse: 0.608013
# [554]	valid_0's rmse: 0.607953
# [555]	valid_0's rmse: 0.607935
# [556]	valid_0's rmse: 0.607863
# [557]	valid_0's rmse: 0.607833
# [558]	valid_0's rmse: 0.607821
# [559]	valid_0's rmse: 0.607811
# [560]	valid_0's rmse: 0.607737
# [561]	valid_0's rmse: 0.607618
# [562]	valid_0's rmse: 0.607544
# [563]	valid_0's rmse: 0.60745
# [564]	valid_0's rmse: 0.607388
# [565]	valid_0's rmse: 0.607296
# [566]	valid_0's rmse: 0.60724
# [567]	valid_0's rmse: 0.60715
# [568]	valid_0's rmse: 0.607079
# [569]	valid_0's rmse: 0.607019
# [570]	valid_0's rmse: 0.606981
# [571]	valid_0's rmse: 0.60689
# [572]	valid_0's rmse: 0.606827
# [573]	valid_0's rmse: 0.606757
# [574]	valid_0's rmse: 0.606699
# [575]	valid_0's rmse: 0.606619
# [576]	valid_0's rmse: 0.606573
# [577]	valid_0's rmse: 0.606552
# [578]	valid_0's rmse: 0.606514
# [579]	valid_0's rmse: 0.606493
# [580]	valid_0's rmse: 0.60639
# [581]	valid_0's rmse: 0.606414
# [582]	valid_0's rmse: 0.606438
# [583]	valid_0's rmse: 0.606386
# [584]	valid_0's rmse: 0.606337
# [585]	valid_0's rmse: 0.606301
# [586]	valid_0's rmse: 0.606246
# [587]	valid_0's rmse: 0.606199
# [588]	valid_0's rmse: 0.606208
# [589]	valid_0's rmse: 0.606264
# [590]	valid_0's rmse: 0.606184
# [591]	valid_0's rmse: 0.606224
# [592]	valid_0's rmse: 0.60622
# [593]	valid_0's rmse: 0.606188
# [594]	valid_0's rmse: 0.606174
# [595]	valid_0's rmse: 0.606122
# [596]	valid_0's rmse: 0.606099
# [597]	valid_0's rmse: 0.606033
# [598]	valid_0's rmse: 0.605964
# [599]	valid_0's rmse: 0.605909
# [600]	valid_0's rmse: 0.605905
# [601]	valid_0's rmse: 0.605884
# [602]	valid_0's rmse: 0.605852
# [603]	valid_0's rmse: 0.605848
# [604]	valid_0's rmse: 0.605905
# [605]	valid_0's rmse: 0.605918
# [606]	valid_0's rmse: 0.605945
# [607]	valid_0's rmse: 0.605887
# [608]	valid_0's rmse: 0.605908
# [609]	valid_0's rmse: 0.605815
# [610]	valid_0's rmse: 0.605727
# [611]	valid_0's rmse: 0.605732
# [612]	valid_0's rmse: 0.605743
# [613]	valid_0's rmse: 0.605759
# [614]	valid_0's rmse: 0.605726
# [615]	valid_0's rmse: 0.605602
# [616]	valid_0's rmse: 0.60554
# [617]	valid_0's rmse: 0.605569
# [618]	valid_0's rmse: 0.605453
# [619]	valid_0's rmse: 0.605422
# [620]	valid_0's rmse: 0.605359
# [621]	valid_0's rmse: 0.605329
# [622]	valid_0's rmse: 0.605348
# [623]	valid_0's rmse: 0.605238
# [624]	valid_0's rmse: 0.605236
# [625]	valid_0's rmse: 0.60524
# [626]	valid_0's rmse: 0.605204
# [627]	valid_0's rmse: 0.605142
# [628]	valid_0's rmse: 0.605156
# [629]	valid_0's rmse: 0.605153
# [630]	valid_0's rmse: 0.60516
# [631]	valid_0's rmse: 0.605137
# [632]	valid_0's rmse: 0.605139
# [633]	valid_0's rmse: 0.605137
# [634]	valid_0's rmse: 0.605111
# [635]	valid_0's rmse: 0.605128
# [636]	valid_0's rmse: 0.605126
# [637]	valid_0's rmse: 0.605176
# [638]	valid_0's rmse: 0.605121
# [639]	valid_0's rmse: 0.605123
# [640]	valid_0's rmse: 0.605105
# [641]	valid_0's rmse: 0.605058
# [642]	valid_0's rmse: 0.604976
# [643]	valid_0's rmse: 0.604997
# [644]	valid_0's rmse: 0.604985
# [645]	valid_0's rmse: 0.604987
# [646]	valid_0's rmse: 0.604991
# [647]	valid_0's rmse: 0.604994
# [648]	valid_0's rmse: 0.605002
# [649]	valid_0's rmse: 0.60495
# [650]	valid_0's rmse: 0.604929
# [651]	valid_0's rmse: 0.604919
# [652]	valid_0's rmse: 0.604898
# [653]	valid_0's rmse: 0.604919
# [654]	valid_0's rmse: 0.604932
# [655]	valid_0's rmse: 0.6049
# [656]	valid_0's rmse: 0.604872
# [657]	valid_0's rmse: 0.604863
# [658]	valid_0's rmse: 0.604836
# [659]	valid_0's rmse: 0.6048
# [660]	valid_0's rmse: 0.604766
# [661]	valid_0's rmse: 0.604713
# [662]	valid_0's rmse: 0.604726
# [663]	valid_0's rmse: 0.604701
# [664]	valid_0's rmse: 0.60468
# [665]	valid_0's rmse: 0.604616
# [666]	valid_0's rmse: 0.604595
# [667]	valid_0's rmse: 0.604612
# [668]	valid_0's rmse: 0.60457
# [669]	valid_0's rmse: 0.604533
# [670]	valid_0's rmse: 0.60446
# [671]	valid_0's rmse: 0.604417
# [672]	valid_0's rmse: 0.60438
# [673]	valid_0's rmse: 0.604341
# [674]	valid_0's rmse: 0.604268
# [675]	valid_0's rmse: 0.604249
# [676]	valid_0's rmse: 0.604225
# [677]	valid_0's rmse: 0.604204
# [678]	valid_0's rmse: 0.604139
# [679]	valid_0's rmse: 0.604128
# [680]	valid_0's rmse: 0.604093
# [681]	valid_0's rmse: 0.604079
# [682]	valid_0's rmse: 0.604036
# [683]	valid_0's rmse: 0.604046
# [684]	valid_0's rmse: 0.604007
# [685]	valid_0's rmse: 0.603965
# [686]	valid_0's rmse: 0.60401
# [687]	valid_0's rmse: 0.603949
# [688]	valid_0's rmse: 0.603931
# [689]	valid_0's rmse: 0.603913
# [690]	valid_0's rmse: 0.603891
# [691]	valid_0's rmse: 0.603853
# [692]	valid_0's rmse: 0.60389
# [693]	valid_0's rmse: 0.603869
# [694]	valid_0's rmse: 0.603852
# [695]	valid_0's rmse: 0.603835
# [696]	valid_0's rmse: 0.603812
# [697]	valid_0's rmse: 0.603762
# [698]	valid_0's rmse: 0.603735
# [699]	valid_0's rmse: 0.603691
# [700]	valid_0's rmse: 0.603699
# [701]	valid_0's rmse: 0.603684
# [702]	valid_0's rmse: 0.603653
# [703]	valid_0's rmse: 0.603639
# [704]	valid_0's rmse: 0.60358
# [705]	valid_0's rmse: 0.603586
# [706]	valid_0's rmse: 0.603575
# [707]	valid_0's rmse: 0.603584
# [708]	valid_0's rmse: 0.603594
# [709]	valid_0's rmse: 0.603582
# [710]	valid_0's rmse: 0.603585
# [711]	valid_0's rmse: 0.603533
# [712]	valid_0's rmse: 0.603552
# [713]	valid_0's rmse: 0.603563
# [714]	valid_0's rmse: 0.603536
# [715]	valid_0's rmse: 0.60346
# [716]	valid_0's rmse: 0.603451
# [717]	valid_0's rmse: 0.603467
# [718]	valid_0's rmse: 0.603504
# [719]	valid_0's rmse: 0.603508
# [720]	valid_0's rmse: 0.603545
# [721]	valid_0's rmse: 0.603527
# [722]	valid_0's rmse: 0.60351
# [723]	valid_0's rmse: 0.603493
# [724]	valid_0's rmse: 0.603512
# [725]	valid_0's rmse: 0.60355
# [726]	valid_0's rmse: 0.603534
# [727]	valid_0's rmse: 0.603571
# [728]	valid_0's rmse: 0.603592
# [729]	valid_0's rmse: 0.603582
# [730]	valid_0's rmse: 0.603643
# [731]	valid_0's rmse: 0.603636
# [732]	valid_0's rmse: 0.603624
# [733]	valid_0's rmse: 0.603576
# [734]	valid_0's rmse: 0.603576
# [735]	valid_0's rmse: 0.60353
# [736]	valid_0's rmse: 0.603525
# [737]	valid_0's rmse: 0.603496
# [738]	valid_0's rmse: 0.603458
# [739]	valid_0's rmse: 0.603461
# [740]	valid_0's rmse: 0.603424
# [741]	valid_0's rmse: 0.603405
# [742]	valid_0's rmse: 0.603363
# [743]	valid_0's rmse: 0.603361
# [744]	valid_0's rmse: 0.603313
# [745]	valid_0's rmse: 0.603295
# [746]	valid_0's rmse: 0.603261
# [747]	valid_0's rmse: 0.603224
# [748]	valid_0's rmse: 0.603247
# [749]	valid_0's rmse: 0.603229
# [750]	valid_0's rmse: 0.603215
# [751]	valid_0's rmse: 0.603197
# [752]	valid_0's rmse: 0.603161
# [753]	valid_0's rmse: 0.603128
# [754]	valid_0's rmse: 0.603137
# [755]	valid_0's rmse: 0.603122
# [756]	valid_0's rmse: 0.60308
# [757]	valid_0's rmse: 0.603066
# [758]	valid_0's rmse: 0.603025
# [759]	valid_0's rmse: 0.602958
# [760]	valid_0's rmse: 0.602978
# [761]	valid_0's rmse: 0.602948
# [762]	valid_0's rmse: 0.602938
# [763]	valid_0's rmse: 0.602881
# [764]	valid_0's rmse: 0.602866
# [765]	valid_0's rmse: 0.602814
# [766]	valid_0's rmse: 0.602771
# [767]	valid_0's rmse: 0.602754
# [768]	valid_0's rmse: 0.602757
# [769]	valid_0's rmse: 0.602687
# [770]	valid_0's rmse: 0.602667
# [771]	valid_0's rmse: 0.602691
# [772]	valid_0's rmse: 0.602677
# [773]	valid_0's rmse: 0.60262
# [774]	valid_0's rmse: 0.60263
# [775]	valid_0's rmse: 0.602633
# [776]	valid_0's rmse: 0.602617
# [777]	valid_0's rmse: 0.602588
# [778]	valid_0's rmse: 0.602626
# [779]	valid_0's rmse: 0.602647
# [780]	valid_0's rmse: 0.602607
# [781]	valid_0's rmse: 0.602621
# [782]	valid_0's rmse: 0.602581
# [783]	valid_0's rmse: 0.602562
# [784]	valid_0's rmse: 0.602551
# [785]	valid_0's rmse: 0.602512
# [786]	valid_0's rmse: 0.602509
# [787]	valid_0's rmse: 0.602514
# [788]	valid_0's rmse: 0.602495
# [789]	valid_0's rmse: 0.602534
# [790]	valid_0's rmse: 0.602564
# [791]	valid_0's rmse: 0.602603
# [792]	valid_0's rmse: 0.602588
# [793]	valid_0's rmse: 0.60263
# [794]	valid_0's rmse: 0.602672
# [795]	valid_0's rmse: 0.602686
# [796]	valid_0's rmse: 0.602709
# [797]	valid_0's rmse: 0.602674
# [798]	valid_0's rmse: 0.602712
# [799]	valid_0's rmse: 0.602672
# [800]	valid_0's rmse: 0.602694
# [801]	valid_0's rmse: 0.602705
# [802]	valid_0's rmse: 0.602725
# [803]	valid_0's rmse: 0.602759
# [804]	valid_0's rmse: 0.602778
# [805]	valid_0's rmse: 0.602753
# [806]	valid_0's rmse: 0.602802
# [807]	valid_0's rmse: 0.602833
# [808]	valid_0's rmse: 0.602879
# [809]	valid_0's rmse: 0.602903
# [810]	valid_0's rmse: 0.602921
# [811]	valid_0's rmse: 0.602967
# [812]	valid_0's rmse: 0.602941
# [813]	valid_0's rmse: 0.602924
# [814]	valid_0's rmse: 0.602991
# [815]	valid_0's rmse: 0.603037
# [816]	valid_0's rmse: 0.603057
# [817]	valid_0's rmse: 0.603058
# [818]	valid_0's rmse: 0.603085
# [819]	valid_0's rmse: 0.603118
# [820]	valid_0's rmse: 0.603164
# [821]	valid_0's rmse: 0.603138
# [822]	valid_0's rmse: 0.603136
# [823]	valid_0's rmse: 0.603141
# [824]	valid_0's rmse: 0.603171
# [825]	valid_0's rmse: 0.603233
# [826]	valid_0's rmse: 0.603281
# [827]	valid_0's rmse: 0.603302
# [828]	valid_0's rmse: 0.603336
# [829]	valid_0's rmse: 0.603382
# [830]	valid_0's rmse: 0.603388
# [831]	valid_0's rmse: 0.603346
# [832]	valid_0's rmse: 0.603406
# [833]	valid_0's rmse: 0.603429
# [834]	valid_0's rmse: 0.603456
# [835]	valid_0's rmse: 0.603536
# [836]	valid_0's rmse: 0.60355
# [837]	valid_0's rmse: 0.603577
# [838]	valid_0's rmse: 0.603583
# [839]	valid_0's rmse: 0.603587
# [840]	valid_0's rmse: 0.603606
# [841]	valid_0's rmse: 0.603569
# [842]	valid_0's rmse: 0.603598
# [843]	valid_0's rmse: 0.60359
# [844]	valid_0's rmse: 0.60361
# [845]	valid_0's rmse: 0.603613
# [846]	valid_0's rmse: 0.603566
# [847]	valid_0's rmse: 0.603571
# [848]	valid_0's rmse: 0.603638
# [849]	valid_0's rmse: 0.603603
# [850]	valid_0's rmse: 0.603616
# [851]	valid_0's rmse: 0.603554
# [852]	valid_0's rmse: 0.603561
# [853]	valid_0's rmse: 0.603553
# [854]	valid_0's rmse: 0.60358
# [855]	valid_0's rmse: 0.60361
# [856]	valid_0's rmse: 0.603603
# [857]	valid_0's rmse: 0.603588
# [858]	valid_0's rmse: 0.603584
# [859]	valid_0's rmse: 0.603604
# [860]	valid_0's rmse: 0.603631
# [861]	valid_0's rmse: 0.603605
# [862]	valid_0's rmse: 0.603562
# [863]	valid_0's rmse: 0.603576
# [864]	valid_0's rmse: 0.603546
# [865]	valid_0's rmse: 0.603519
# [866]	valid_0's rmse: 0.603587
# [867]	valid_0's rmse: 0.60358
# [868]	valid_0's rmse: 0.603604
# [869]	valid_0's rmse: 0.60359
# [870]	valid_0's rmse: 0.603608
# [871]	valid_0's rmse: 0.603633
# [872]	valid_0's rmse: 0.60363
# [873]	valid_0's rmse: 0.60358
# [874]	valid_0's rmse: 0.603594
# [875]	valid_0's rmse: 0.603551
# [876]	valid_0's rmse: 0.603511
# [877]	valid_0's rmse: 0.603491
# [878]	valid_0's rmse: 0.603501
# [879]	valid_0's rmse: 0.603521
# [880]	valid_0's rmse: 0.603592
# [881]	valid_0's rmse: 0.603608
# [882]	valid_0's rmse: 0.603567
# [883]	valid_0's rmse: 0.603584
# [884]	valid_0's rmse: 0.6036
# [885]	valid_0's rmse: 0.603576
# [886]	valid_0's rmse: 0.603641
# [887]	valid_0's rmse: 0.603591
# [888]	valid_0's rmse: 0.603627
# Early stopping, best iteration is:
# [788]	valid_0's rmse: 0.602495
# [1]	valid_0's rmse: 1.02313
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's rmse: 1.02004
# [3]	valid_0's rmse: 1.01696
# [4]	valid_0's rmse: 1.01397
# [5]	valid_0's rmse: 1.01091
# [6]	valid_0's rmse: 1.00797
# [7]	valid_0's rmse: 1.00507
# [8]	valid_0's rmse: 1.0021
# [9]	valid_0's rmse: 0.999177
# [10]	valid_0's rmse: 0.996371
# [11]	valid_0's rmse: 0.993446
# [12]	valid_0's rmse: 0.990644
# [13]	valid_0's rmse: 0.987828
# [14]	valid_0's rmse: 0.985099
# [15]	valid_0's rmse: 0.982389
# [16]	valid_0's rmse: 0.979557
# [17]	valid_0's rmse: 0.976832
# [18]	valid_0's rmse: 0.973991
# [19]	valid_0's rmse: 0.971304
# [20]	valid_0's rmse: 0.96865
# [21]	valid_0's rmse: 0.966003
# [22]	valid_0's rmse: 0.963366
# [23]	valid_0's rmse: 0.9607
# [24]	valid_0's rmse: 0.9581
# [25]	valid_0's rmse: 0.955521
# [26]	valid_0's rmse: 0.95296
# [27]	valid_0's rmse: 0.950359
# [28]	valid_0's rmse: 0.947829
# [29]	valid_0's rmse: 0.945317
# [30]	valid_0's rmse: 0.942846
# [31]	valid_0's rmse: 0.9403
# [32]	valid_0's rmse: 0.937864
# [33]	valid_0's rmse: 0.93548
# [34]	valid_0's rmse: 0.933054
# [35]	valid_0's rmse: 0.930691
# [36]	valid_0's rmse: 0.928293
# [37]	valid_0's rmse: 0.925952
# [38]	valid_0's rmse: 0.923669
# [39]	valid_0's rmse: 0.921313
# [40]	valid_0's rmse: 0.918928
# [41]	valid_0's rmse: 0.916551
# [42]	valid_0's rmse: 0.914259
# [43]	valid_0's rmse: 0.91201
# [44]	valid_0's rmse: 0.909695
# [45]	valid_0's rmse: 0.907426
# [46]	valid_0's rmse: 0.905191
# [47]	valid_0's rmse: 0.902979
# [48]	valid_0's rmse: 0.90079
# [49]	valid_0's rmse: 0.89862
# [50]	valid_0's rmse: 0.896277
# [51]	valid_0's rmse: 0.894161
# [52]	valid_0's rmse: 0.892022
# [53]	valid_0's rmse: 0.889847
# [54]	valid_0's rmse: 0.887714
# [55]	valid_0's rmse: 0.885453
# [56]	valid_0's rmse: 0.883416
# [57]	valid_0's rmse: 0.881213
# [58]	valid_0's rmse: 0.879145
# [59]	valid_0's rmse: 0.8771
# [60]	valid_0's rmse: 0.875089
# [61]	valid_0's rmse: 0.872996
# [62]	valid_0's rmse: 0.871064
# [63]	valid_0's rmse: 0.869137
# [64]	valid_0's rmse: 0.867133
# [65]	valid_0's rmse: 0.865205
# [66]	valid_0's rmse: 0.863231
# [67]	valid_0's rmse: 0.861286
# [68]	valid_0's rmse: 0.859354
# [69]	valid_0's rmse: 0.857511
# [70]	valid_0's rmse: 0.855595
# [71]	valid_0's rmse: 0.85372
# [72]	valid_0's rmse: 0.851821
# [73]	valid_0's rmse: 0.85005
# [74]	valid_0's rmse: 0.848227
# [75]	valid_0's rmse: 0.846346
# [76]	valid_0's rmse: 0.844597
# [77]	valid_0's rmse: 0.842831
# [78]	valid_0's rmse: 0.840996
# [79]	valid_0's rmse: 0.839229
# [80]	valid_0's rmse: 0.83742
# [81]	valid_0's rmse: 0.835702
# [82]	valid_0's rmse: 0.833977
# [83]	valid_0's rmse: 0.832205
# [84]	valid_0's rmse: 0.830436
# [85]	valid_0's rmse: 0.828624
# [86]	valid_0's rmse: 0.826885
# [87]	valid_0's rmse: 0.825245
# [88]	valid_0's rmse: 0.823465
# [89]	valid_0's rmse: 0.821708
# [90]	valid_0's rmse: 0.820035
# [91]	valid_0's rmse: 0.818292
# [92]	valid_0's rmse: 0.816571
# [93]	valid_0's rmse: 0.815034
# [94]	valid_0's rmse: 0.813339
# [95]	valid_0's rmse: 0.811742
# [96]	valid_0's rmse: 0.810132
# [97]	valid_0's rmse: 0.808455
# [98]	valid_0's rmse: 0.806827
# [99]	valid_0's rmse: 0.805193
# [100]	valid_0's rmse: 0.803785
# [101]	valid_0's rmse: 0.802173
# [102]	valid_0's rmse: 0.800587
# [103]	valid_0's rmse: 0.799059
# [104]	valid_0's rmse: 0.797626
# [105]	valid_0's rmse: 0.796233
# [106]	valid_0's rmse: 0.794733
# [107]	valid_0's rmse: 0.793304
# [108]	valid_0's rmse: 0.791775
# [109]	valid_0's rmse: 0.790341
# [110]	valid_0's rmse: 0.788933
# [111]	valid_0's rmse: 0.787475
# [112]	valid_0's rmse: 0.786064
# [113]	valid_0's rmse: 0.784588
# [114]	valid_0's rmse: 0.78319
# [115]	valid_0's rmse: 0.78177
# [116]	valid_0's rmse: 0.780409
# [117]	valid_0's rmse: 0.778948
# [118]	valid_0's rmse: 0.777582
# [119]	valid_0's rmse: 0.776216
# [120]	valid_0's rmse: 0.774976
# [121]	valid_0's rmse: 0.773701
# [122]	valid_0's rmse: 0.77234
# [123]	valid_0's rmse: 0.770943
# [124]	valid_0's rmse: 0.769602
# [125]	valid_0's rmse: 0.768271
# [126]	valid_0's rmse: 0.766992
# [127]	valid_0's rmse: 0.765695
# [128]	valid_0's rmse: 0.764449
# [129]	valid_0's rmse: 0.763136
# [130]	valid_0's rmse: 0.761901
# [131]	valid_0's rmse: 0.760685
# [132]	valid_0's rmse: 0.759456
# [133]	valid_0's rmse: 0.758192
# [134]	valid_0's rmse: 0.756998
# [135]	valid_0's rmse: 0.755745
# [136]	valid_0's rmse: 0.754538
# [137]	valid_0's rmse: 0.75332
# [138]	valid_0's rmse: 0.752151
# [139]	valid_0's rmse: 0.751012
# [140]	valid_0's rmse: 0.749834
# [141]	valid_0's rmse: 0.748672
# [142]	valid_0's rmse: 0.747501
# [143]	valid_0's rmse: 0.746418
# [144]	valid_0's rmse: 0.745267
# [145]	valid_0's rmse: 0.744152
# [146]	valid_0's rmse: 0.743063
# [147]	valid_0's rmse: 0.741996
# [148]	valid_0's rmse: 0.74091
# [149]	valid_0's rmse: 0.739874
# [150]	valid_0's rmse: 0.738807
# [151]	valid_0's rmse: 0.737771
# [152]	valid_0's rmse: 0.736766
# [153]	valid_0's rmse: 0.735776
# [154]	valid_0's rmse: 0.734782
# [155]	valid_0's rmse: 0.733774
# [156]	valid_0's rmse: 0.732803
# [157]	valid_0's rmse: 0.731769
# [158]	valid_0's rmse: 0.730705
# [159]	valid_0's rmse: 0.729691
# [160]	valid_0's rmse: 0.728713
# [161]	valid_0's rmse: 0.727749
# [162]	valid_0's rmse: 0.726799
# [163]	valid_0's rmse: 0.725781
# [164]	valid_0's rmse: 0.724821
# [165]	valid_0's rmse: 0.723893
# [166]	valid_0's rmse: 0.722899
# [167]	valid_0's rmse: 0.721955
# [168]	valid_0's rmse: 0.720913
# [169]	valid_0's rmse: 0.72
# [170]	valid_0's rmse: 0.718978
# [171]	valid_0's rmse: 0.718009
# [172]	valid_0's rmse: 0.7171
# [173]	valid_0's rmse: 0.716111
# [174]	valid_0's rmse: 0.715167
# [175]	valid_0's rmse: 0.714203
# [176]	valid_0's rmse: 0.713389
# [177]	valid_0's rmse: 0.712449
# [178]	valid_0's rmse: 0.711491
# [179]	valid_0's rmse: 0.710716
# [180]	valid_0's rmse: 0.709774
# [181]	valid_0's rmse: 0.708952
# [182]	valid_0's rmse: 0.708145
# [183]	valid_0's rmse: 0.707235
# [184]	valid_0's rmse: 0.706351
# [185]	valid_0's rmse: 0.705505
# [186]	valid_0's rmse: 0.704709
# [187]	valid_0's rmse: 0.703832
# [188]	valid_0's rmse: 0.702987
# [189]	valid_0's rmse: 0.702176
# [190]	valid_0's rmse: 0.701449
# [191]	valid_0's rmse: 0.700705
# [192]	valid_0's rmse: 0.699854
# [193]	valid_0's rmse: 0.699042
# [194]	valid_0's rmse: 0.698229
# [195]	valid_0's rmse: 0.697392
# [196]	valid_0's rmse: 0.696585
# [197]	valid_0's rmse: 0.695852
# [198]	valid_0's rmse: 0.695058
# [199]	valid_0's rmse: 0.69437
# [200]	valid_0's rmse: 0.693624
# [201]	valid_0's rmse: 0.692881
# [202]	valid_0's rmse: 0.692035
# [203]	valid_0's rmse: 0.69134
# [204]	valid_0's rmse: 0.690521
# [205]	valid_0's rmse: 0.689858
# [206]	valid_0's rmse: 0.689148
# [207]	valid_0's rmse: 0.688439
# [208]	valid_0's rmse: 0.68769
# [209]	valid_0's rmse: 0.687051
# [210]	valid_0's rmse: 0.686388
# [211]	valid_0's rmse: 0.685772
# [212]	valid_0's rmse: 0.685127
# [213]	valid_0's rmse: 0.684549
# [214]	valid_0's rmse: 0.683927
# [215]	valid_0's rmse: 0.683293
# [216]	valid_0's rmse: 0.682646
# [217]	valid_0's rmse: 0.68206
# [218]	valid_0's rmse: 0.681458
# [219]	valid_0's rmse: 0.680812
# [220]	valid_0's rmse: 0.680195
# [221]	valid_0's rmse: 0.679626
# [222]	valid_0's rmse: 0.679033
# [223]	valid_0's rmse: 0.678378
# [224]	valid_0's rmse: 0.67778
# [225]	valid_0's rmse: 0.677109
# [226]	valid_0's rmse: 0.676576
# [227]	valid_0's rmse: 0.676022
# [228]	valid_0's rmse: 0.675441
# [229]	valid_0's rmse: 0.67489
# [230]	valid_0's rmse: 0.674341
# [231]	valid_0's rmse: 0.673802
# [232]	valid_0's rmse: 0.673245
# [233]	valid_0's rmse: 0.672726
# [234]	valid_0's rmse: 0.672175
# [235]	valid_0's rmse: 0.67169
# [236]	valid_0's rmse: 0.671218
# [237]	valid_0's rmse: 0.670692
# [238]	valid_0's rmse: 0.670205
# [239]	valid_0's rmse: 0.669694
# [240]	valid_0's rmse: 0.669107
# [241]	valid_0's rmse: 0.668618
# [242]	valid_0's rmse: 0.668123
# [243]	valid_0's rmse: 0.667634
# [244]	valid_0's rmse: 0.667134
# [245]	valid_0's rmse: 0.66663
# [246]	valid_0's rmse: 0.666148
# [247]	valid_0's rmse: 0.665687
# [248]	valid_0's rmse: 0.665129
# [249]	valid_0's rmse: 0.664661
# [250]	valid_0's rmse: 0.664199
# [251]	valid_0's rmse: 0.663738
# [252]	valid_0's rmse: 0.663303
# [253]	valid_0's rmse: 0.662814
# [254]	valid_0's rmse: 0.662358
# [255]	valid_0's rmse: 0.661973
# [256]	valid_0's rmse: 0.661447
# [257]	valid_0's rmse: 0.660938
# [258]	valid_0's rmse: 0.660475
# [259]	valid_0's rmse: 0.660086
# [260]	valid_0's rmse: 0.659576
# [261]	valid_0's rmse: 0.659145
# [262]	valid_0's rmse: 0.658663
# [263]	valid_0's rmse: 0.658273
# [264]	valid_0's rmse: 0.657811
# [265]	valid_0's rmse: 0.657454
# [266]	valid_0's rmse: 0.65705
# [267]	valid_0's rmse: 0.656566
# [268]	valid_0's rmse: 0.656105
# [269]	valid_0's rmse: 0.655711
# [270]	valid_0's rmse: 0.655334
# [271]	valid_0's rmse: 0.654932
# [272]	valid_0's rmse: 0.65448
# [273]	valid_0's rmse: 0.65408
# [274]	valid_0's rmse: 0.653653
# [275]	valid_0's rmse: 0.653262
# [276]	valid_0's rmse: 0.652863
# [277]	valid_0's rmse: 0.65243
# [278]	valid_0's rmse: 0.6521
# [279]	valid_0's rmse: 0.65173
# [280]	valid_0's rmse: 0.651333
# [281]	valid_0's rmse: 0.650949
# [282]	valid_0's rmse: 0.65054
# [283]	valid_0's rmse: 0.650159
# [284]	valid_0's rmse: 0.649729
# [285]	valid_0's rmse: 0.649287
# [286]	valid_0's rmse: 0.64884
# [287]	valid_0's rmse: 0.648449
# [288]	valid_0's rmse: 0.648114
# [289]	valid_0's rmse: 0.647781
# [290]	valid_0's rmse: 0.647458
# [291]	valid_0's rmse: 0.647156
# [292]	valid_0's rmse: 0.646759
# [293]	valid_0's rmse: 0.646427
# [294]	valid_0's rmse: 0.646133
# [295]	valid_0's rmse: 0.645794
# [296]	valid_0's rmse: 0.645469
# [297]	valid_0's rmse: 0.645184
# [298]	valid_0's rmse: 0.644914
# [299]	valid_0's rmse: 0.644577
# [300]	valid_0's rmse: 0.644339
# [301]	valid_0's rmse: 0.644001
# [302]	valid_0's rmse: 0.643682
# [303]	valid_0's rmse: 0.643374
# [304]	valid_0's rmse: 0.643061
# [305]	valid_0's rmse: 0.642725
# [306]	valid_0's rmse: 0.642403
# [307]	valid_0's rmse: 0.642017
# [308]	valid_0's rmse: 0.641659
# [309]	valid_0's rmse: 0.641383
# [310]	valid_0's rmse: 0.641076
# [311]	valid_0's rmse: 0.640737
# [312]	valid_0's rmse: 0.6405
# [313]	valid_0's rmse: 0.640224
# [314]	valid_0's rmse: 0.639928
# [315]	valid_0's rmse: 0.63963
# [316]	valid_0's rmse: 0.639297
# [317]	valid_0's rmse: 0.638965
# [318]	valid_0's rmse: 0.638673
# [319]	valid_0's rmse: 0.638348
# [320]	valid_0's rmse: 0.638081
# [321]	valid_0's rmse: 0.637909
# [322]	valid_0's rmse: 0.637575
# [323]	valid_0's rmse: 0.637233
# [324]	valid_0's rmse: 0.636911
# [325]	valid_0's rmse: 0.636608
# [326]	valid_0's rmse: 0.636285
# [327]	valid_0's rmse: 0.635982
# [328]	valid_0's rmse: 0.635665
# [329]	valid_0's rmse: 0.635355
# [330]	valid_0's rmse: 0.635059
# [331]	valid_0's rmse: 0.634748
# [332]	valid_0's rmse: 0.634523
# [333]	valid_0's rmse: 0.634235
# [334]	valid_0's rmse: 0.633987
# [335]	valid_0's rmse: 0.633668
# [336]	valid_0's rmse: 0.633426
# [337]	valid_0's rmse: 0.633142
# [338]	valid_0's rmse: 0.63286
# [339]	valid_0's rmse: 0.632621
# [340]	valid_0's rmse: 0.632363
# [341]	valid_0's rmse: 0.632132
# [342]	valid_0's rmse: 0.631941
# [343]	valid_0's rmse: 0.631711
# [344]	valid_0's rmse: 0.631583
# [345]	valid_0's rmse: 0.631357
# [346]	valid_0's rmse: 0.631124
# [347]	valid_0's rmse: 0.630993
# [348]	valid_0's rmse: 0.630803
# [349]	valid_0's rmse: 0.630595
# [350]	valid_0's rmse: 0.63037
# [351]	valid_0's rmse: 0.630105
# [352]	valid_0's rmse: 0.629854
# [353]	valid_0's rmse: 0.629688
# [354]	valid_0's rmse: 0.629457
# [355]	valid_0's rmse: 0.629248
# [356]	valid_0's rmse: 0.629035
# [357]	valid_0's rmse: 0.628855
# [358]	valid_0's rmse: 0.628621
# [359]	valid_0's rmse: 0.628396
# [360]	valid_0's rmse: 0.628272
# [361]	valid_0's rmse: 0.628006
# [362]	valid_0's rmse: 0.627774
# [363]	valid_0's rmse: 0.6275
# [364]	valid_0's rmse: 0.627309
# [365]	valid_0's rmse: 0.627055
# [366]	valid_0's rmse: 0.62682
# [367]	valid_0's rmse: 0.626605
# [368]	valid_0's rmse: 0.626375
# [369]	valid_0's rmse: 0.626176
# [370]	valid_0's rmse: 0.625941
# [371]	valid_0's rmse: 0.62576
# [372]	valid_0's rmse: 0.625485
# [373]	valid_0's rmse: 0.625298
# [374]	valid_0's rmse: 0.625114
# [375]	valid_0's rmse: 0.62491
# [376]	valid_0's rmse: 0.624658
# [377]	valid_0's rmse: 0.624453
# [378]	valid_0's rmse: 0.624229
# [379]	valid_0's rmse: 0.624031
# [380]	valid_0's rmse: 0.623796
# [381]	valid_0's rmse: 0.623644
# [382]	valid_0's rmse: 0.623458
# [383]	valid_0's rmse: 0.623228
# [384]	valid_0's rmse: 0.623063
# [385]	valid_0's rmse: 0.622918
# [386]	valid_0's rmse: 0.622728
# [387]	valid_0's rmse: 0.622595
# [388]	valid_0's rmse: 0.622363
# [389]	valid_0's rmse: 0.622138
# [390]	valid_0's rmse: 0.621994
# [391]	valid_0's rmse: 0.621828
# [392]	valid_0's rmse: 0.621728
# [393]	valid_0's rmse: 0.621537
# [394]	valid_0's rmse: 0.621349
# [395]	valid_0's rmse: 0.621194
# [396]	valid_0's rmse: 0.621073
# [397]	valid_0's rmse: 0.62097
# [398]	valid_0's rmse: 0.620782
# [399]	valid_0's rmse: 0.620665
# [400]	valid_0's rmse: 0.620483
# [401]	valid_0's rmse: 0.620319
# [402]	valid_0's rmse: 0.620172
# [403]	valid_0's rmse: 0.619978
# [404]	valid_0's rmse: 0.619872
# [405]	valid_0's rmse: 0.619674
# [406]	valid_0's rmse: 0.619528
# [407]	valid_0's rmse: 0.619366
# [408]	valid_0's rmse: 0.619168
# [409]	valid_0's rmse: 0.618965
# [410]	valid_0's rmse: 0.618832
# [411]	valid_0's rmse: 0.618692
# [412]	valid_0's rmse: 0.618517
# [413]	valid_0's rmse: 0.61832
# [414]	valid_0's rmse: 0.618201
# [415]	valid_0's rmse: 0.618064
# [416]	valid_0's rmse: 0.61793
# [417]	valid_0's rmse: 0.617813
# [418]	valid_0's rmse: 0.617624
# [419]	valid_0's rmse: 0.617463
# [420]	valid_0's rmse: 0.61735
# [421]	valid_0's rmse: 0.617212
# [422]	valid_0's rmse: 0.61704
# [423]	valid_0's rmse: 0.61689
# [424]	valid_0's rmse: 0.61675
# [425]	valid_0's rmse: 0.616643
# [426]	valid_0's rmse: 0.6165
# [427]	valid_0's rmse: 0.616361
# [428]	valid_0's rmse: 0.61625
# [429]	valid_0's rmse: 0.616104
# [430]	valid_0's rmse: 0.615992
# [431]	valid_0's rmse: 0.615868
# [432]	valid_0's rmse: 0.615765
# [433]	valid_0's rmse: 0.615614
# [434]	valid_0's rmse: 0.615494
# [435]	valid_0's rmse: 0.615395
# [436]	valid_0's rmse: 0.615266
# [437]	valid_0's rmse: 0.615194
# [438]	valid_0's rmse: 0.615082
# [439]	valid_0's rmse: 0.614985
# [440]	valid_0's rmse: 0.614925
# [441]	valid_0's rmse: 0.614812
# [442]	valid_0's rmse: 0.614771
# [443]	valid_0's rmse: 0.614697
# [444]	valid_0's rmse: 0.614596
# [445]	valid_0's rmse: 0.614488
# [446]	valid_0's rmse: 0.614418
# [447]	valid_0's rmse: 0.614406
# [448]	valid_0's rmse: 0.614379
# [449]	valid_0's rmse: 0.614278
# [450]	valid_0's rmse: 0.614176
# [451]	valid_0's rmse: 0.614062
# [452]	valid_0's rmse: 0.613918
# [453]	valid_0's rmse: 0.613855
# [454]	valid_0's rmse: 0.613805
# [455]	valid_0's rmse: 0.613725
# [456]	valid_0's rmse: 0.613668
# [457]	valid_0's rmse: 0.613558
# [458]	valid_0's rmse: 0.613406
# [459]	valid_0's rmse: 0.61341
# [460]	valid_0's rmse: 0.613308
# [461]	valid_0's rmse: 0.613213
# [462]	valid_0's rmse: 0.613138
# [463]	valid_0's rmse: 0.61305
# [464]	valid_0's rmse: 0.613007
# [465]	valid_0's rmse: 0.612892
# [466]	valid_0's rmse: 0.612844
# [467]	valid_0's rmse: 0.612726
# [468]	valid_0's rmse: 0.612653
# [469]	valid_0's rmse: 0.612546
# [470]	valid_0's rmse: 0.612492
# [471]	valid_0's rmse: 0.612457
# [472]	valid_0's rmse: 0.612396
# [473]	valid_0's rmse: 0.612332
# [474]	valid_0's rmse: 0.612291
# [475]	valid_0's rmse: 0.612224
# [476]	valid_0's rmse: 0.612121
# [477]	valid_0's rmse: 0.612073
# [478]	valid_0's rmse: 0.612005
# [479]	valid_0's rmse: 0.6119
# [480]	valid_0's rmse: 0.611805
# [481]	valid_0's rmse: 0.611718
# [482]	valid_0's rmse: 0.611677
# [483]	valid_0's rmse: 0.611628
# [484]	valid_0's rmse: 0.611519
# [485]	valid_0's rmse: 0.61145
# [486]	valid_0's rmse: 0.611347
# [487]	valid_0's rmse: 0.611227
# [488]	valid_0's rmse: 0.611203
# [489]	valid_0's rmse: 0.61118
# [490]	valid_0's rmse: 0.611097
# [491]	valid_0's rmse: 0.610989
# [492]	valid_0's rmse: 0.61093
# [493]	valid_0's rmse: 0.610841
# [494]	valid_0's rmse: 0.610813
# [495]	valid_0's rmse: 0.610756
# [496]	valid_0's rmse: 0.610672
# [497]	valid_0's rmse: 0.610586
# [498]	valid_0's rmse: 0.610465
# [499]	valid_0's rmse: 0.61043
# [500]	valid_0's rmse: 0.610325
# [501]	valid_0's rmse: 0.610243
# [502]	valid_0's rmse: 0.61019
# [503]	valid_0's rmse: 0.610117
# [504]	valid_0's rmse: 0.609978
# [505]	valid_0's rmse: 0.609882
# [506]	valid_0's rmse: 0.609848
# [507]	valid_0's rmse: 0.60982
# [508]	valid_0's rmse: 0.609798
# [509]	valid_0's rmse: 0.609682
# [510]	valid_0's rmse: 0.609625
# [511]	valid_0's rmse: 0.6095
# [512]	valid_0's rmse: 0.609426
# [513]	valid_0's rmse: 0.609395
# [514]	valid_0's rmse: 0.60931
# [515]	valid_0's rmse: 0.609278
# [516]	valid_0's rmse: 0.609208
# [517]	valid_0's rmse: 0.609184
# [518]	valid_0's rmse: 0.60913
# [519]	valid_0's rmse: 0.609027
# [520]	valid_0's rmse: 0.608975
# [521]	valid_0's rmse: 0.608848
# [522]	valid_0's rmse: 0.608764
# [523]	valid_0's rmse: 0.608696
# [524]	valid_0's rmse: 0.60859
# [525]	valid_0's rmse: 0.608584
# [526]	valid_0's rmse: 0.608515
# [527]	valid_0's rmse: 0.608507
# [528]	valid_0's rmse: 0.608444
# [529]	valid_0's rmse: 0.60834
# [530]	valid_0's rmse: 0.608315
# [531]	valid_0's rmse: 0.608216
# [532]	valid_0's rmse: 0.60811
# [533]	valid_0's rmse: 0.608029
# [534]	valid_0's rmse: 0.607955
# [535]	valid_0's rmse: 0.60785
# [536]	valid_0's rmse: 0.607775
# [537]	valid_0's rmse: 0.607733
# [538]	valid_0's rmse: 0.607691
# [539]	valid_0's rmse: 0.607699
# [540]	valid_0's rmse: 0.607727
# [541]	valid_0's rmse: 0.607674
# [542]	valid_0's rmse: 0.607609
# [543]	valid_0's rmse: 0.60755
# [544]	valid_0's rmse: 0.607556
# [545]	valid_0's rmse: 0.607525
# [546]	valid_0's rmse: 0.607438
# [547]	valid_0's rmse: 0.607346
# [548]	valid_0's rmse: 0.607297
# [549]	valid_0's rmse: 0.607249
# [550]	valid_0's rmse: 0.607176
# [551]	valid_0's rmse: 0.607122
# [552]	valid_0's rmse: 0.607083
# [553]	valid_0's rmse: 0.606998
# [554]	valid_0's rmse: 0.606958
# [555]	valid_0's rmse: 0.606905
# [556]	valid_0's rmse: 0.606902
# [557]	valid_0's rmse: 0.606923
# [558]	valid_0's rmse: 0.606841
# [559]	valid_0's rmse: 0.606719
# [560]	valid_0's rmse: 0.606651
# [561]	valid_0's rmse: 0.606687
# [562]	valid_0's rmse: 0.606581
# [563]	valid_0's rmse: 0.606521
# [564]	valid_0's rmse: 0.606507
# [565]	valid_0's rmse: 0.606503
# [566]	valid_0's rmse: 0.606442
# [567]	valid_0's rmse: 0.606394
# [568]	valid_0's rmse: 0.606324
# [569]	valid_0's rmse: 0.60629
# [570]	valid_0's rmse: 0.606213
# [571]	valid_0's rmse: 0.606106
# [572]	valid_0's rmse: 0.606075
# [573]	valid_0's rmse: 0.605934
# [574]	valid_0's rmse: 0.605796
# [575]	valid_0's rmse: 0.605772
# [576]	valid_0's rmse: 0.605635
# [577]	valid_0's rmse: 0.605513
# [578]	valid_0's rmse: 0.605426
# [579]	valid_0's rmse: 0.605282
# [580]	valid_0's rmse: 0.60525
# [581]	valid_0's rmse: 0.605157
# [582]	valid_0's rmse: 0.605131
# [583]	valid_0's rmse: 0.605085
# [584]	valid_0's rmse: 0.60504
# [585]	valid_0's rmse: 0.604997
# [586]	valid_0's rmse: 0.604951
# [587]	valid_0's rmse: 0.604877
# [588]	valid_0's rmse: 0.604871
# [589]	valid_0's rmse: 0.604827
# [590]	valid_0's rmse: 0.604752
# [591]	valid_0's rmse: 0.604692
# [592]	valid_0's rmse: 0.604626
# [593]	valid_0's rmse: 0.604549
# [594]	valid_0's rmse: 0.604487
# [595]	valid_0's rmse: 0.604466
# [596]	valid_0's rmse: 0.604432
# [597]	valid_0's rmse: 0.604366
# [598]	valid_0's rmse: 0.604337
# [599]	valid_0's rmse: 0.604314
# [600]	valid_0's rmse: 0.604234
# [601]	valid_0's rmse: 0.604216
# [602]	valid_0's rmse: 0.604169
# [603]	valid_0's rmse: 0.604108
# [604]	valid_0's rmse: 0.604078
# [605]	valid_0's rmse: 0.604021
# [606]	valid_0's rmse: 0.604016
# [607]	valid_0's rmse: 0.603992
# [608]	valid_0's rmse: 0.603927
# [609]	valid_0's rmse: 0.603879
# [610]	valid_0's rmse: 0.603858
# [611]	valid_0's rmse: 0.603793
# [612]	valid_0's rmse: 0.603775
# [613]	valid_0's rmse: 0.603724
# [614]	valid_0's rmse: 0.603657
# [615]	valid_0's rmse: 0.603615
# [616]	valid_0's rmse: 0.603565
# [617]	valid_0's rmse: 0.603496
# [618]	valid_0's rmse: 0.603409
# [619]	valid_0's rmse: 0.603332
# [620]	valid_0's rmse: 0.603295
# [621]	valid_0's rmse: 0.603278
# [622]	valid_0's rmse: 0.603225
# [623]	valid_0's rmse: 0.603147
# [624]	valid_0's rmse: 0.603099
# [625]	valid_0's rmse: 0.603053
# [626]	valid_0's rmse: 0.602977
# [627]	valid_0's rmse: 0.60293
# [628]	valid_0's rmse: 0.60292
# [629]	valid_0's rmse: 0.602835
# [630]	valid_0's rmse: 0.602801
# [631]	valid_0's rmse: 0.602706
# [632]	valid_0's rmse: 0.602643
# [633]	valid_0's rmse: 0.602615
# [634]	valid_0's rmse: 0.602619
# [635]	valid_0's rmse: 0.602614
# [636]	valid_0's rmse: 0.602519
# [637]	valid_0's rmse: 0.602465
# [638]	valid_0's rmse: 0.602461
# [639]	valid_0's rmse: 0.602447
# [640]	valid_0's rmse: 0.602377
# [641]	valid_0's rmse: 0.602328
# [642]	valid_0's rmse: 0.602283
# [643]	valid_0's rmse: 0.602189
# [644]	valid_0's rmse: 0.602181
# [645]	valid_0's rmse: 0.602202
# [646]	valid_0's rmse: 0.60218
# [647]	valid_0's rmse: 0.602194
# [648]	valid_0's rmse: 0.602163
# [649]	valid_0's rmse: 0.602137
# [650]	valid_0's rmse: 0.602103
# [651]	valid_0's rmse: 0.602082
# [652]	valid_0's rmse: 0.602036
# [653]	valid_0's rmse: 0.602071
# [654]	valid_0's rmse: 0.602053
# [655]	valid_0's rmse: 0.602033
# [656]	valid_0's rmse: 0.601985
# ...
# [362]	valid_0's rmse: 0.683199
# [363]	valid_0's rmse: 0.683127
# [364]	valid_0's rmse: 0.683027
# [365]	valid_0's rmse: 0.682951
# [366]	valid_0's rmse: 0.682828
# [367]	valid_0's rmse: 0.682737
# [368]	valid_0's rmse: 0.68261
# [369]	valid_0's rmse: 0.682517
# [370]	valid_0's rmse: 0.682433
# [371]	valid_0's rmse: 0.682328
# [372]	valid_0's rmse: 0.682196
# [373]	valid_0's rmse: 0.682081
# [374]	valid_0's rmse: 0.681961
# [375]	valid_0's rmse: 0.681848
# [376]	valid_0's rmse: 0.681722
# [377]	valid_0's rmse: 0.681584
# [378]	valid_0's rmse: 0.681502
# [379]	valid_0's rmse: 0.681388
# [380]	valid_0's rmse: 0.681254
# [381]	valid_0's rmse: 0.681194
# [382]	valid_0's rmse: 0.681065
# [383]	valid_0's rmse: 0.680981
# [384]	valid_0's rmse: 0.680899
# [385]	valid_0's rmse: 0.680792
# [386]	valid_0's rmse: 0.680659
# [387]	valid_0's rmse: 0.680581
# [388]	valid_0's rmse: 0.680521
# [389]	valid_0's rmse: 0.680397
# [390]	valid_0's rmse: 0.680262
# [391]	valid_0's rmse: 0.680157
# [392]	valid_0's rmse: 0.680033
# [393]	valid_0's rmse: 0.679935
# [394]	valid_0's rmse: 0.679851
# [395]	valid_0's rmse: 0.679739
# [396]	valid_0's rmse: 0.679615
# [397]	valid_0's rmse: 0.679485
# [398]	valid_0's rmse: 0.679417
# [399]	valid_0's rmse: 0.679294
# [400]	valid_0's rmse: 0.679174
# [401]	valid_0's rmse: 0.679122
# [402]	valid_0's rmse: 0.679013
# [403]	valid_0's rmse: 0.678893
# [404]	valid_0's rmse: 0.67881
# [405]	valid_0's rmse: 0.678698
# [406]	valid_0's rmse: 0.678586
# [407]	valid_0's rmse: 0.678514
# [408]	valid_0's rmse: 0.678473
# [409]	valid_0's rmse: 0.678345
# [410]	valid_0's rmse: 0.678302
# [411]	valid_0's rmse: 0.678218
# [412]	valid_0's rmse: 0.678119
# [413]	valid_0's rmse: 0.678047
# [414]	valid_0's rmse: 0.678012
# [415]	valid_0's rmse: 0.677902
# [416]	valid_0's rmse: 0.677834
# [417]	valid_0's rmse: 0.677726
# [418]	valid_0's rmse: 0.677695
# [419]	valid_0's rmse: 0.677626
# [420]	valid_0's rmse: 0.677529
# [421]	valid_0's rmse: 0.677536
# [422]	valid_0's rmse: 0.677484
# [423]	valid_0's rmse: 0.67737
# [424]	valid_0's rmse: 0.677311
# [425]	valid_0's rmse: 0.677167
# [426]	valid_0's rmse: 0.67713
# [427]	valid_0's rmse: 0.677054
# [428]	valid_0's rmse: 0.676968
# [429]	valid_0's rmse: 0.676939
# [430]	valid_0's rmse: 0.676929
# [431]	valid_0's rmse: 0.676848
# [432]	valid_0's rmse: 0.676709
# [433]	valid_0's rmse: 0.676667
# [434]	valid_0's rmse: 0.676635
# [435]	valid_0's rmse: 0.676535
# [436]	valid_0's rmse: 0.676513
# [437]	valid_0's rmse: 0.676475
# [438]	valid_0's rmse: 0.676423
# [439]	valid_0's rmse: 0.676375
# [440]	valid_0's rmse: 0.676324
# [441]	valid_0's rmse: 0.676297
# [442]	valid_0's rmse: 0.676188
# [443]	valid_0's rmse: 0.676161
# [444]	valid_0's rmse: 0.676146
# [445]	valid_0's rmse: 0.676091
# [446]	valid_0's rmse: 0.676062
# [447]	valid_0's rmse: 0.675984
# [448]	valid_0's rmse: 0.675924
# [449]	valid_0's rmse: 0.675864
# [450]	valid_0's rmse: 0.675846
# [451]	valid_0's rmse: 0.675797
# [452]	valid_0's rmse: 0.675785
# [453]	valid_0's rmse: 0.675747
# [454]	valid_0's rmse: 0.675698
# [455]	valid_0's rmse: 0.675653
# [456]	valid_0's rmse: 0.675639
# [457]	valid_0's rmse: 0.675591
# [458]	valid_0's rmse: 0.675523
# [459]	valid_0's rmse: 0.675478
# [460]	valid_0's rmse: 0.67541
# [461]	valid_0's rmse: 0.675349
# [462]	valid_0's rmse: 0.675288
# [463]	valid_0's rmse: 0.675303
# [464]	valid_0's rmse: 0.675208
# [465]	valid_0's rmse: 0.675179
# [466]	valid_0's rmse: 0.675215
# [467]	valid_0's rmse: 0.675182
# [468]	valid_0's rmse: 0.675175
# [469]	valid_0's rmse: 0.675182
# [470]	valid_0's rmse: 0.675202
# [471]	valid_0's rmse: 0.675155
# [472]	valid_0's rmse: 0.67509
# [473]	valid_0's rmse: 0.675051
# [474]	valid_0's rmse: 0.674997
# [475]	valid_0's rmse: 0.674968
# [476]	valid_0's rmse: 0.674912
# [477]	valid_0's rmse: 0.674913
# [478]	valid_0's rmse: 0.674879
# [479]	valid_0's rmse: 0.674829
# [480]	valid_0's rmse: 0.674835
# [481]	valid_0's rmse: 0.674833
# [482]	valid_0's rmse: 0.674866
# [483]	valid_0's rmse: 0.674881
# [484]	valid_0's rmse: 0.674822
# [485]	valid_0's rmse: 0.674825
# [486]	valid_0's rmse: 0.674827
# [487]	valid_0's rmse: 0.674721
# [488]	valid_0's rmse: 0.674754
# [489]	valid_0's rmse: 0.674695
# [490]	valid_0's rmse: 0.674661
# [491]	valid_0's rmse: 0.674666
# [492]	valid_0's rmse: 0.674587
# [493]	valid_0's rmse: 0.674555
# [494]	valid_0's rmse: 0.674435
# [495]	valid_0's rmse: 0.674434
# [496]	valid_0's rmse: 0.674397
# [497]	valid_0's rmse: 0.674375
# [498]	valid_0's rmse: 0.674366
# [499]	valid_0's rmse: 0.674302
# [500]	valid_0's rmse: 0.674244
# [501]	valid_0's rmse: 0.674183
# [502]	valid_0's rmse: 0.67411
# [503]	valid_0's rmse: 0.674079
# [504]	valid_0's rmse: 0.674047
# [505]	valid_0's rmse: 0.673951
# [506]	valid_0's rmse: 0.673895
# [507]	valid_0's rmse: 0.673848
# [508]	valid_0's rmse: 0.673795
# [509]	valid_0's rmse: 0.673826
# [510]	valid_0's rmse: 0.673758
# [511]	valid_0's rmse: 0.673625
# [512]	valid_0's rmse: 0.673634
# [513]	valid_0's rmse: 0.673609
# [514]	valid_0's rmse: 0.673636
# [515]	valid_0's rmse: 0.673595
# [516]	valid_0's rmse: 0.673564
# [517]	valid_0's rmse: 0.673521
# [518]	valid_0's rmse: 0.673546
# [519]	valid_0's rmse: 0.673551
# [520]	valid_0's rmse: 0.673416
# [521]	valid_0's rmse: 0.673388
# [522]	valid_0's rmse: 0.67339
# [523]	valid_0's rmse: 0.673312
# [524]	valid_0's rmse: 0.673304
# [525]	valid_0's rmse: 0.673294
# [526]	valid_0's rmse: 0.673311
# [527]	valid_0's rmse: 0.673264
# [528]	valid_0's rmse: 0.67329
# [529]	valid_0's rmse: 0.673245
# [530]	valid_0's rmse: 0.673277
# [531]	valid_0's rmse: 0.67323
# [532]	valid_0's rmse: 0.673186
# [533]	valid_0's rmse: 0.673142
# [534]	valid_0's rmse: 0.673192
# [535]	valid_0's rmse: 0.673152
# [536]	valid_0's rmse: 0.67311
# [537]	valid_0's rmse: 0.673147
# [538]	valid_0's rmse: 0.67312
# [539]	valid_0's rmse: 0.67306
# [540]	valid_0's rmse: 0.673002
# [541]	valid_0's rmse: 0.672955
# [542]	valid_0's rmse: 0.672949
# [543]	valid_0's rmse: 0.672917
# [544]	valid_0's rmse: 0.672886
# [545]	valid_0's rmse: 0.672797
# [546]	valid_0's rmse: 0.672772
# [547]	valid_0's rmse: 0.672738
# [548]	valid_0's rmse: 0.672731
# [549]	valid_0's rmse: 0.67272
# [550]	valid_0's rmse: 0.672652
# [551]	valid_0's rmse: 0.672591
# [552]	valid_0's rmse: 0.67258
# [553]	valid_0's rmse: 0.672556
# [554]	valid_0's rmse: 0.672505
# [555]	valid_0's rmse: 0.672506
# [556]	valid_0's rmse: 0.672488
# [557]	valid_0's rmse: 0.672442
# [558]	valid_0's rmse: 0.672404
# [559]	valid_0's rmse: 0.672349
# [560]	valid_0's rmse: 0.672263
# [561]	valid_0's rmse: 0.672261
# [562]	valid_0's rmse: 0.672176
# [563]	valid_0's rmse: 0.672137
# [564]	valid_0's rmse: 0.67206
# [565]	valid_0's rmse: 0.671974
# [566]	valid_0's rmse: 0.671926
# [567]	valid_0's rmse: 0.671879
# [568]	valid_0's rmse: 0.671841
# [569]	valid_0's rmse: 0.671782
# [570]	valid_0's rmse: 0.671768
# [571]	valid_0's rmse: 0.671726
# [572]	valid_0's rmse: 0.671666
# [573]	valid_0's rmse: 0.671648
# [574]	valid_0's rmse: 0.671634
# [575]	valid_0's rmse: 0.671626
# [576]	valid_0's rmse: 0.671613
# [577]	valid_0's rmse: 0.671676
# [578]	valid_0's rmse: 0.671643
# [579]	valid_0's rmse: 0.671594
# [580]	valid_0's rmse: 0.671582
# [581]	valid_0's rmse: 0.671611
# [582]	valid_0's rmse: 0.671601
# [583]	valid_0's rmse: 0.6716
# [584]	valid_0's rmse: 0.671598
# [585]	valid_0's rmse: 0.671595
# [586]	valid_0's rmse: 0.671591
# [587]	valid_0's rmse: 0.671654
# [588]	valid_0's rmse: 0.67166
# [589]	valid_0's rmse: 0.671649
# [590]	valid_0's rmse: 0.671658
# [591]	valid_0's rmse: 0.671595
# [592]	valid_0's rmse: 0.671608
# [593]	valid_0's rmse: 0.671629
# [594]	valid_0's rmse: 0.671625
# [595]	valid_0's rmse: 0.671624
# [596]	valid_0's rmse: 0.671619
# [597]	valid_0's rmse: 0.671561
# [598]	valid_0's rmse: 0.671507
# [599]	valid_0's rmse: 0.671528
# [600]	valid_0's rmse: 0.671486
# [601]	valid_0's rmse: 0.671441
# [602]	valid_0's rmse: 0.671381
# [603]	valid_0's rmse: 0.671336
# [604]	valid_0's rmse: 0.671323
# [605]	valid_0's rmse: 0.671255
# [606]	valid_0's rmse: 0.671244
# [607]	valid_0's rmse: 0.671251
# [608]	valid_0's rmse: 0.671182
# [609]	valid_0's rmse: 0.67119
# [610]	valid_0's rmse: 0.671137
# [611]	valid_0's rmse: 0.671103
# [612]	valid_0's rmse: 0.671123
# [613]	valid_0's rmse: 0.671066
# [614]	valid_0's rmse: 0.671041
# [615]	valid_0's rmse: 0.670977
# [616]	valid_0's rmse: 0.67095
# [617]	valid_0's rmse: 0.670899
# [618]	valid_0's rmse: 0.670889
# [619]	valid_0's rmse: 0.670922
# [620]	valid_0's rmse: 0.67083
# [621]	valid_0's rmse: 0.670843
# [622]	valid_0's rmse: 0.670791
# [623]	valid_0's rmse: 0.670769
# [624]	valid_0's rmse: 0.670761
# [625]	valid_0's rmse: 0.670716
# [626]	valid_0's rmse: 0.670714
# [627]	valid_0's rmse: 0.6707
# [628]	valid_0's rmse: 0.670687
# [629]	valid_0's rmse: 0.670625
# [630]	valid_0's rmse: 0.67055
# [631]	valid_0's rmse: 0.67054
# [632]	valid_0's rmse: 0.670496
# [633]	valid_0's rmse: 0.670511
# [634]	valid_0's rmse: 0.670526
# [635]	valid_0's rmse: 0.67055
# [636]	valid_0's rmse: 0.670553
# [637]	valid_0's rmse: 0.670566
# [638]	valid_0's rmse: 0.670516
# [639]	valid_0's rmse: 0.670573
# [640]	valid_0's rmse: 0.670566
# [641]	valid_0's rmse: 0.670592
# [642]	valid_0's rmse: 0.670595
# [643]	valid_0's rmse: 0.670653
# [644]	valid_0's rmse: 0.670687
# [645]	valid_0's rmse: 0.670766
# [646]	valid_0's rmse: 0.67076
# [647]	valid_0's rmse: 0.67074
# [648]	valid_0's rmse: 0.67079
# [649]	valid_0's rmse: 0.670758
# [650]	valid_0's rmse: 0.670777
# [651]	valid_0's rmse: 0.670776
# [652]	valid_0's rmse: 0.670793
# [653]	valid_0's rmse: 0.670782
# [654]	valid_0's rmse: 0.670736
# [655]	valid_0's rmse: 0.670765
# [656]	valid_0's rmse: 0.670809
# [657]	valid_0's rmse: 0.67075
# [658]	valid_0's rmse: 0.670772
# [659]	valid_0's rmse: 0.670777
# [660]	valid_0's rmse: 0.670716
# [661]	valid_0's rmse: 0.67073
# [662]	valid_0's rmse: 0.670695
# [663]	valid_0's rmse: 0.670681
# [664]	valid_0's rmse: 0.670717
# [665]	valid_0's rmse: 0.670685
# [666]	valid_0's rmse: 0.670763
# [667]	valid_0's rmse: 0.6707
# [668]	valid_0's rmse: 0.670708
# [669]	valid_0's rmse: 0.670732
# [670]	valid_0's rmse: 0.670747
# [671]	valid_0's rmse: 0.670716
# [672]	valid_0's rmse: 0.670733
# [673]	valid_0's rmse: 0.670721
# [674]	valid_0's rmse: 0.670737
# [675]	valid_0's rmse: 0.670679
# [676]	valid_0's rmse: 0.670679
# [677]	valid_0's rmse: 0.670646
# [678]	valid_0's rmse: 0.670577
# [679]	valid_0's rmse: 0.670525
# [680]	valid_0's rmse: 0.67052
# [681]	valid_0's rmse: 0.670462
# [682]	valid_0's rmse: 0.67044
# [683]	valid_0's rmse: 0.670369
# [684]	valid_0's rmse: 0.670388
# [685]	valid_0's rmse: 0.670385
# [686]	valid_0's rmse: 0.670333
# [687]	valid_0's rmse: 0.670374
# [688]	valid_0's rmse: 0.670383
# [689]	valid_0's rmse: 0.670398
# [690]	valid_0's rmse: 0.670322
# [691]	valid_0's rmse: 0.670264
# [692]	valid_0's rmse: 0.670269
# [693]	valid_0's rmse: 0.670189
# [694]	valid_0's rmse: 0.670147
# [695]	valid_0's rmse: 0.670102
# [696]	valid_0's rmse: 0.670095
# [697]	valid_0's rmse: 0.670057
# [698]	valid_0's rmse: 0.670072
# [699]	valid_0's rmse: 0.670104
# [700]	valid_0's rmse: 0.670051
# [701]	valid_0's rmse: 0.670086
# [702]	valid_0's rmse: 0.670119
# [703]	valid_0's rmse: 0.670114
# [704]	valid_0's rmse: 0.670086
# [705]	valid_0's rmse: 0.670112
# [706]	valid_0's rmse: 0.670093
# [707]	valid_0's rmse: 0.670109
# [708]	valid_0's rmse: 0.670068
# [709]	valid_0's rmse: 0.670071
# [710]	valid_0's rmse: 0.670036
# [711]	valid_0's rmse: 0.670107
# [712]	valid_0's rmse: 0.670107
# [713]	valid_0's rmse: 0.670073
# [714]	valid_0's rmse: 0.670066
# [715]	valid_0's rmse: 0.670094
# [716]	valid_0's rmse: 0.670081
# [717]	valid_0's rmse: 0.670057
# [718]	valid_0's rmse: 0.670091
# [719]	valid_0's rmse: 0.670151
# [720]	valid_0's rmse: 0.670173
# [721]	valid_0's rmse: 0.670192
# [722]	valid_0's rmse: 0.670184
# [723]	valid_0's rmse: 0.670193
# [724]	valid_0's rmse: 0.670198
# [725]	valid_0's rmse: 0.670221
# [726]	valid_0's rmse: 0.67024
# [727]	valid_0's rmse: 0.670305
# [728]	valid_0's rmse: 0.670313
# [729]	valid_0's rmse: 0.670304
# [730]	valid_0's rmse: 0.670294
# [731]	valid_0's rmse: 0.670284
# [732]	valid_0's rmse: 0.670286
# [733]	valid_0's rmse: 0.670323
# [734]	valid_0's rmse: 0.670302
# [735]	valid_0's rmse: 0.670278
# [736]	valid_0's rmse: 0.670281
# [737]	valid_0's rmse: 0.670302
# [738]	valid_0's rmse: 0.670331
# [739]	valid_0's rmse: 0.67036
# [740]	valid_0's rmse: 0.670379
# [741]	valid_0's rmse: 0.670357
# [742]	valid_0's rmse: 0.670371
# [743]	valid_0's rmse: 0.67034
# [744]	valid_0's rmse: 0.670332
# [745]	valid_0's rmse: 0.670338
# [746]	valid_0's rmse: 0.670349
# [747]	valid_0's rmse: 0.670318
# [748]	valid_0's rmse: 0.670276
# [749]	valid_0's rmse: 0.6703
# [750]	valid_0's rmse: 0.67031
# [751]	valid_0's rmse: 0.670286
# [752]	valid_0's rmse: 0.670274
# [753]	valid_0's rmse: 0.670279
# [754]	valid_0's rmse: 0.670303
# [755]	valid_0's rmse: 0.670291
# [756]	valid_0's rmse: 0.67027
# [757]	valid_0's rmse: 0.670223
# [758]	valid_0's rmse: 0.6702
# [759]	valid_0's rmse: 0.670189
# [760]	valid_0's rmse: 0.670234
# [761]	valid_0's rmse: 0.670223
# [762]	valid_0's rmse: 0.670212
# [763]	valid_0's rmse: 0.670229
# [764]	valid_0's rmse: 0.670246
# [765]	valid_0's rmse: 0.670231
# [766]	valid_0's rmse: 0.670171
# [767]	valid_0's rmse: 0.670186
# [768]	valid_0's rmse: 0.670164
# [769]	valid_0's rmse: 0.670153
# [770]	valid_0's rmse: 0.670165
# [771]	valid_0's rmse: 0.670189
# [772]	valid_0's rmse: 0.670166
# [773]	valid_0's rmse: 0.670184
# [774]	valid_0's rmse: 0.670203
# [775]	valid_0's rmse: 0.670187
# [776]	valid_0's rmse: 0.670185
# [777]	valid_0's rmse: 0.670168
# [778]	valid_0's rmse: 0.670218
# [779]	valid_0's rmse: 0.670234
# [780]	valid_0's rmse: 0.670219
# [781]	valid_0's rmse: 0.670221
# [782]	valid_0's rmse: 0.670188
# [783]	valid_0's rmse: 0.670195
# [784]	valid_0's rmse: 0.670183
# [785]	valid_0's rmse: 0.670164
# [786]	valid_0's rmse: 0.670188
# [787]	valid_0's rmse: 0.670207
# [788]	valid_0's rmse: 0.670196
# [789]	valid_0's rmse: 0.670179
# [790]	valid_0's rmse: 0.670152
# [791]	valid_0's rmse: 0.670084
# [792]	valid_0's rmse: 0.670102
# [793]	valid_0's rmse: 0.670082
# [794]	valid_0's rmse: 0.670097
# [795]	valid_0's rmse: 0.670149
# [796]	valid_0's rmse: 0.670139
# [797]	valid_0's rmse: 0.670179
# [798]	valid_0's rmse: 0.670166
# [799]	valid_0's rmse: 0.670172
# [800]	valid_0's rmse: 0.670208
# [801]	valid_0's rmse: 0.67022
# [802]	valid_0's rmse: 0.6703
# [803]	valid_0's rmse: 0.670316
# [804]	valid_0's rmse: 0.6703
# [805]	valid_0's rmse: 0.670277
# [806]	valid_0's rmse: 0.670245
# [807]	valid_0's rmse: 0.670278
# [808]	valid_0's rmse: 0.670278
# [809]	valid_0's rmse: 0.670263
# [810]	valid_0's rmse: 0.670243
# Early stopping, best iteration is:
# [710]	valid_0's rmse: 0.670036
# Average rmse: 0.6154045367357004
# Complete training lgbm RMSE = 0.44739481178873497
# Number of features: 165
# Average rmse: 0.6162859683423461
# Complete training xgb RMSE = 0.4350288405765967
# [('ridge', Pipeline(steps=[('remove_infs',
#                  FunctionTransformer(func=<function ModelTrainer.make_pipeline.<locals>.<lambda> at 0x7d5c75d1a9e0>)),
#                 ('imputer', SimpleImputer()),
#                 ('normalizer',
#                  FunctionTransformer(func=<function ModelTrainer.make_pipeline.<locals>.<lambda> at 0x7d5c75d1aa70>)),
#                 ('scaler', RobustScaler()),
#                 ('model', Ridge(alpha=1, random_state=42))])), ('svr', Pipeline(steps=[('remove_infs',
#                  FunctionTransformer(func=<function ModelTrainer.make_pipeline.<locals>.<lambda> at 0x7d5c75d1b370>)),
#                 ('imputer', SimpleImputer()),
#                 ('normalizer',
#                  FunctionTransformer(func=<function ModelTrainer.make_pipeline.<locals>.<lambda> at 0x7d5c75d1b250>)),
#                 ('scaler', RobustScaler()), ('model', SVR())])), ('catboost', <catboost.core.CatBoostRegressor object at 0x7d5c75e77340>), ('lgbm', LGBMRegressor(force_col_wise=True, learning_rate=0.005, metric='rmse',
#               n_estimators=1024, random_state=42, verbosity=0)), ('xgb', XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_boost_round=1000, num_estimators=1000, ...))]

# %%
def evaluate_models(models, data_X, data_Y):
    # split the full train data (data_X and data_Y) into train and validation sets
    X_train, X_val, y_train, y_val = train_test_split(data_X, data_Y,
                                                      test_size=0.2, random_state=SEED)
    # fit and evaluate the models
    weights = list()
    for name, model in models:
        # fit the model
        model.fit(X_train, y_train)
        # evaluate the model
        y_preds = model.predict(X_val)
        # Calculate the 
        rmse = mean_squared_error(y_true=y_val, y_pred=y_preds, squared=False)
        # store the performance
        weights.append(rmse)
    # report model performance
    print(f"Weight = {weights}")
    return weights

# %%
try:
    weights = evaluate_models(models, data_X, data_Y)
    # Use the weights (scores) as a weighting for the ensemble
    ensemble = VotingRegressor(estimators=models, weights=weights)
    ensemble.fit(data_X, data_Y)
    test_y = ensemble.predict(test_x)
    print(test_y)
except Exception as e: 
    print(e)
# Out:
# Weight = [0.5618777679613814, 0.5787275718598376, 0.5442215367246644, 0.5413674268821377, 0.5367460131530352]
# [1.13043857 0.34337336 0.22957829]

# %%
sub3 = pd.DataFrame({'id': test_ids, 'score': test_y})

# %%
sub3
# Out:
#          id     score
# 0  0000aaaa  1.130439
# 1  2222bbbb  0.343373
# 2  4444cccc  0.229578

# %%
##

# %%
import warnings
warnings.filterwarnings('ignore')
import gc
import ctypes
import os
import itertools
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import random
import pprint
import time
import copy
import lightgbm as lgb
import torch
import polars as pl
import optuna

from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LinearRegression,Lasso, Ridge, ElasticNet
from sklearn.metrics import mean_absolute_error,mean_squared_error,accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import LabelEncoder, PowerTransformer, RobustScaler, FunctionTransformer
from sklearn.model_selection import KFold, StratifiedKFold, GroupKFold, train_test_split
from sklearn.decomposition import TruncatedSVD, PCA
from sklearn.ensemble import GradientBoostingRegressor, HistGradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn import metrics
# %matplotlib inline
from random import choice, choices
from functools import reduce, partial
from tqdm import tqdm
from itertools import cycle
from collections import Counter
from scipy import stats
from scipy.stats import skew, kurtosis
from transformers import BertTokenizer
from collections import Counter, defaultdict
from tqdm.autonotebook import tqdm
from math import sqrt
from sklearn import model_selection

def clean_memory():
    gc.collect()
    ctypes.CDLL("libc.so.6").malloc_trim(0)
    torch.cuda.empty_cache()
clean_memory()

# %%
import pandas as pd

def getEssays(df):
  
    # 'id', 'activity', 'cursor_position', 'text_change' 열만 선택한 DataFrame 복사
    textInputDf = df[['id', 'activity', 'cursor_position', 'text_change']].copy()
    
    # 'activity' 열에서 'Nonproduction'인 행을 제외
    textInputDf = textInputDf[textInputDf.activity != 'Nonproduction']

    # 각 'id'별로 발생한 활동 수를 계산하여 배열로 저장
    valCountsArr = textInputDf['id'].value_counts(sort=False).values

    lastIndex = 0

    # 결과를 저장할 Pandas Series 생성
    essaySeries = pd.Series()

    for index, valCount in enumerate(valCountsArr):

        currTextInput = textInputDf[['activity', 'cursor_position', 'text_change']].iloc[lastIndex : lastIndex + valCount]
        lastIndex += valCount
        essayText = ""

        for Input in currTextInput.values:
            
            # Input[0] = activity
            # Input[2] = cursor_position
            # Input[3] = text_change
            
            if Input[0] == 'Replace':
                # '=>' 문자열을 기준으로 text_change를 분할
                replaceTxt = Input[2].split(' => ')
                
                # DONT TOUCH
                essayText = essayText[:Input[1] - len(replaceTxt[1])] + replaceTxt[1] + essayText[Input[1] - len(replaceTxt[1]) + len(replaceTxt[0]):]
                continue

                
            # If activity = Paste    
            if Input[0] == 'Paste':
                # DONT TOUCH
                essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]
                continue

                
            # If activity = Remove/Cut
            if Input[0] == 'Remove/Cut':
                # DONT TOUCH
                essayText = essayText[:Input[1]] + essayText[Input[1] + len(Input[2]):]
                continue

                
            # If activity = Move...
            if "M" in Input[0]:
                # "Move from to" 텍스트를 제거
                croppedTxt = Input[0][10:]
                
                # ' To '를 기준으로 문자열을 분할
                splitTxt = croppedTxt.split(' To ')
                
                # 문자열을 다시 ', '를 기준으로 분할하여 배열로 저장
                valueArr = [item.split(', ') for item in splitTxt]
                
                # Move from [2, 4] To [5, 7] = (2, 4, 5, 7)
                moveData = (int(valueArr[0][0][1:]), int(valueArr[0][1][:-1]), int(valueArr[1][0][1:]), int(valueArr[1][1][:-1]))

                # 같은 위치로 이동하는 경우 건너뛰기
                if moveData[0] != moveData[2]:
                    # 텍스트를 앞으로 이동시키는 경우 (다른 경우)
                    if moveData[0] < moveData[2]:
                        # DONT TOUCH
                        essayText = essayText[:moveData[0]] + essayText[moveData[1]:moveData[3]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[3]:]
                    else:
                        # DONT TOUCH
                        essayText = essayText[:moveData[2]] + essayText[moveData[0]:moveData[1]] + essayText[moveData[2]:moveData[0]] + essayText[moveData[1]:]
                continue
                         
            # If just input
            # DONT TOUCH
            essayText = essayText[:Input[1] - len(Input[2])] + Input[2] + essayText[Input[1] - len(Input[2]):]

        # 결과 시리즈의 해당 인덱스에 에세이 텍스트를 설정  
        essaySeries[index] = essayText
     
    # 결과 시리즈의 인덱스를 고유한 'id' 값으로 설정
    essaySeries.index =  textInputDf['id'].unique()
    
    return essaySeries

# %%
traindf = pd.read_csv('/kaggle/input/linking-writing-processes-to-writing-quality/train_logs.csv')
train_scores = pd.read_csv('/kaggle/input/linking-writing-processes-to-writing-quality/train_scores.csv')
testdf = pd.read_csv('/kaggle/input/linking-writing-processes-to-writing-quality/test_logs.csv')

# %%
train_essays = getEssays(traindf)
test_essays = getEssays(testdf)

# %%
train_essaysdf = pd.DataFrame({'id': train_essays.index, 'essay': train_essays.values})
test_essaysdf = pd.DataFrame({'id': test_essays.index, 'essay': test_essays.values})

merged_data = train_essaysdf.merge(train_scores, on='id')

# %%
#단어와 단어의 연속된 조합(단어 n-그램)을 추출하고, 이를 기반으로 텍스트 데이터를 벡터 형태로 변환
#X_tokenizer_train과 X_tokenizer_test에는 학습 및 테스트 데이터에 대한 단어 빈도 벡터가 저장
#y는 target value score
count_vectorizer = CountVectorizer(ngram_range=(1, 2))
X_tokenizer_train = count_vectorizer.fit_transform(merged_data['essay'])
X_tokenizer_test = count_vectorizer.transform(test_essaysdf['essay'])
count_vectorizer.get_feature_names_out() #ADDED
y = merged_data['score']

df_train = pd.DataFrame()
df_test = pd.DataFrame()

# 메모리 요구사항 증가 but, 연산 수행시 효과적: dense 행렬 변환
X_tokenizer_train = X_tokenizer_train.todense()
X_tokenizer_test = X_tokenizer_test.todense()

for i in range(X_tokenizer_train.shape[1]) : 
    L = list(X_tokenizer_train[:,i])
    li = [int(x) for x in L ]
    df_train[f'feature {i}'] = li
    
for i in range(X_tokenizer_test.shape[1]) : 
    L = list(X_tokenizer_test[:,i])
    li = [int(x) for x in L ]
    df_test[f'feature {i}'] = li    
    
df_train_index = train_essaysdf['id']
df_test_index = test_essaysdf['id']

# id 열 추가 
df_train.loc[:, 'id'] = df_train_index
df_test.loc[:, 'id'] = df_test_index

# 집계함수 적용 df
train_agg_fe_df = traindf.groupby("id")[['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']].agg(['mean', 'std', 'min', 'max', 'last', 'first', 'sem', 'median', 'sum'])
train_agg_fe_df.columns = ['_'.join(x) for x in train_agg_fe_df.columns]
train_agg_fe_df = train_agg_fe_df.add_prefix("tmp_")
train_agg_fe_df.reset_index(inplace=True)

test_agg_fe_df = testdf.groupby("id")[['down_time', 'up_time', 'action_time', 'cursor_position', 'word_count']].agg(['mean', 'std', 'min', 'max', 'last', 'first', 'sem', 'median', 'sum'])
test_agg_fe_df.columns = ['_'.join(x) for x in test_agg_fe_df.columns]
test_agg_fe_df = test_agg_fe_df.add_prefix("tmp_")
test_agg_fe_df.reset_index(inplace=True)

# %%
from collections import defaultdict

class Preprocessor:
    
    def __init__(self, seed):
        self.seed = seed
        
        self.activities = ['Input', 'Remove/Cut', 'Nonproduction', 'Replace', 'Paste']
        self.events = ['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick', 'ArrowLeft', '.', ',', 
              'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock', "'", 'Delete', 'Unidentified']
        self.text_changes = ['q', ' ', 'NoChange', '.', ',', '\n', "'", '"', '-', '?', ';', '=', '/', '\\', ':']
        self.punctuations = ['"', '.', ',', "'", '-', ';', ':', '?', '!', '<', '>', '/',
                        '@', '#', '$', '%', '^', '&', '*', '(', ')', '_', '+']
        self.gaps = [1, 2, 3, 5, 10, 20, 50, 100]
        
        self.idf = defaultdict(float)
#         self.gaps = [1, 2]
    
    def activity_counts(self, df):
        tmp_df = df.groupby('id').agg({'activity': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['activity'].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.activities:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'activity_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf

            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf

        return ret


    def event_counts(self, df, colname):
        tmp_df = df.groupby('id').agg({colname: list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df[colname].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.events:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'{colname}_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf
            
            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf

        return ret


    def text_change_counts(self, df):
        tmp_df = df.groupby('id').agg({'text_change': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['text_change'].values):
            items = list(Counter(li).items())
            di = dict()
            for k in self.text_changes:
                di[k] = 0
            for item in items:
                k, v = item[0], item[1]
                if k in di:
                    di[k] = v
            ret.append(di)
        ret = pd.DataFrame(ret)
        cols = [f'text_change_{i}_count' for i in range(len(ret.columns))]
        ret.columns = cols

        cnts = ret.sum(1)

        for col in cols:
            if col in self.idf.keys():
                idf = self.idf[col]
            else:
                idf = df.shape[0] / (ret[col].sum() + 1)
                idf = np.log(idf)
                self.idf[col] = idf
            
            ret[col] = 1 + np.log(ret[col] / cnts)
            ret[col] *= idf
            
        return ret

    def match_punctuations(self, df):
        tmp_df = df.groupby('id').agg({'down_event': list}).reset_index()
        ret = list()
        for li in tqdm(tmp_df['down_event'].values):
            cnt = 0
            items = list(Counter(li).items())
            for item in items:
                k, v = item[0], item[1]
                if k in self.punctuations:
                    cnt += v
            ret.append(cnt)
        ret = pd.DataFrame({'punct_cnt': ret})
        return ret


    def get_input_words(self, df):
        tmp_df = df[(~df['text_change'].str.contains('=>'))&(df['text_change'] != 'NoChange')].reset_index(drop=True)
        tmp_df = tmp_df.groupby('id').agg({'text_change': list}).reset_index()
        tmp_df['text_change'] = tmp_df['text_change'].apply(lambda x: ''.join(x))
        tmp_df['text_change'] = tmp_df['text_change'].apply(lambda x: re.findall(r'q+', x))
        tmp_df['input_word_count'] = tmp_df['text_change'].apply(len)
        tmp_df['input_word_length_mean'] = tmp_df['text_change'].apply(lambda x: np.mean([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df['input_word_length_max'] = tmp_df['text_change'].apply(lambda x: np.max([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df['input_word_length_std'] = tmp_df['text_change'].apply(lambda x: np.std([len(i) for i in x] if len(x) > 0 else 0))
        tmp_df.drop(['text_change'], axis=1, inplace=True)
        return tmp_df
    
    def make_feats(self, df):
        
        print("Starting to engineer features")
        
        # initialize features dataframe
        feats = pd.DataFrame({'id': df['id'].unique().tolist()})
        
        # get shifted features
        # time shift
        print("Engineering time data")
        for gap in self.gaps:
            print(f"> for gap {gap}")
            df[f'up_time_shift{gap}'] = df.groupby('id')['up_time'].shift(gap)
            df[f'action_time_gap{gap}'] = df['down_time'] - df[f'up_time_shift{gap}']
        df.drop(columns=[f'up_time_shift{gap}' for gap in self.gaps], inplace=True)

        # cursor position shift
        print("Engineering cursor position data")
        for gap in self.gaps:
            print(f"> for gap {gap}")
            df[f'cursor_position_shift{gap}'] = df.groupby('id')['cursor_position'].shift(gap)
            df[f'cursor_position_change{gap}'] = df['cursor_position'] - df[f'cursor_position_shift{gap}']
            df[f'cursor_position_abs_change{gap}'] = np.abs(df[f'cursor_position_change{gap}'])
        df.drop(columns=[f'cursor_position_shift{gap}' for gap in self.gaps], inplace=True)

        # word count shift
        print("Engineering word count data")
        for gap in self.gaps:
            print(f"> for gap {gap}")
            df[f'word_count_shift{gap}'] = df.groupby('id')['word_count'].shift(gap)
            df[f'word_count_change{gap}'] = df['word_count'] - df[f'word_count_shift{gap}']
            df[f'word_count_abs_change{gap}'] = np.abs(df[f'word_count_change{gap}'])
        df.drop(columns=[f'word_count_shift{gap}' for gap in self.gaps], inplace=True)
        
        # get aggregate statistical features
        print("Engineering statistical summaries for features")
        # [(feature name, [ stat summaries to add ])]
        feats_stat = [
            ('event_id', ['max']),
            ('up_time', ['max']),
            ('action_time', ['max', 'min', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew']),
            ('activity', ['nunique']),
            ('down_event', ['nunique']),
            ('up_event', ['nunique']),
            ('text_change', ['nunique']),
            ('cursor_position', ['nunique', 'max', 'quantile', 'sem', 'mean']),
            ('word_count', ['nunique', 'max', 'quantile', 'sem', 'mean'])]
        for gap in self.gaps:
            feats_stat.extend([
                (f'action_time_gap{gap}', ['max', 'min', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew']),
                (f'cursor_position_change{gap}', ['max', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew']),
                (f'word_count_change{gap}', ['max', 'mean', 'std', 'quantile', 'sem', 'sum', 'skew'])
            ])
        
        pbar = tqdm(feats_stat)
        for item in pbar:
            colname, methods = item[0], item[1]
            for method in methods:
                pbar.set_postfix()
                if isinstance(method, str):
                    method_name = method
                else:
                    method_name = method.__name__
                    
                pbar.set_postfix(column=colname, method=method_name)
                tmp_df = df.groupby(['id']).agg({colname: method}).reset_index().rename(columns={colname: f'{colname}_{method_name}'})
                feats = feats.merge(tmp_df, on='id', how='left')

        # counts
        print("Engineering activity counts data")
        tmp_df = self.activity_counts(df)
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering event counts data")
        tmp_df = self.event_counts(df, 'down_event')
        feats = pd.concat([feats, tmp_df], axis=1)
        tmp_df = self.event_counts(df, 'up_event')
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering text change counts data")
        tmp_df = self.text_change_counts(df)
        feats = pd.concat([feats, tmp_df], axis=1)
        
        print("Engineering punctuation counts data")
        tmp_df = self.match_punctuations(df)
        feats = pd.concat([feats, tmp_df], axis=1)

        # input words
        print("Engineering input words data")
        tmp_df = self.get_input_words(df)
        feats = pd.merge(feats, tmp_df, on='id', how='left')

        # compare feats
        print("Engineering ratios data")
        feats['word_time_ratio'] = feats['word_count_max'] / feats['up_time_max']
        feats['word_event_ratio'] = feats['word_count_max'] / feats['event_id_max']
        feats['event_time_ratio'] = feats['event_id_max']  / feats['up_time_max']
        feats['idle_time_ratio'] = feats['action_time_gap1_sum'] / feats['up_time_max']
        
        print("Done!")
        return feats

# %%
# 위 클래스 이용, train,test data -> feature engineering.
preprocessor = Preprocessor(seed=42)

print("Engineering features for training data")

other_train_feats = preprocessor.make_feats(traindf)

print()
print("-"*25)
print("Engineering features for test data")
print("-"*25)
other_test_feats = preprocessor.make_feats(testdf)

df_train_all = pd.DataFrame()
df_test_all = pd.DataFrame()

df_train_all = df_train.merge(train_agg_fe_df,on='id')
df_test_all = df_test.merge(test_agg_fe_df,on='id')

# 1,3 사분위 수 계산
def q1(x):
    return x.quantile(0.25)
def q3(x):
    return x.quantile(0.75)

AGGREGATIONS = ['count', 'mean', 'std', 'min', 'max', 'first', 'last', 'sem', q1, 'median', q3, 'skew', 'sum']

def split_essays_into_sentences(df):
    essay_df = df
    essay_df['id'] = essay_df.index
    essay_df['sent'] = essay_df['essay'].apply(lambda x: re.split('\\.|\\?|\\!',str(x)))
    essay_df = essay_df.explode('sent')
    essay_df['sent'] = essay_df['sent'].apply(lambda x: x.replace('\n','').strip())
    # Number of characters in sentences
    essay_df['sent_len'] = essay_df['sent'].apply(lambda x: len(x))
    # Number of words in sentences
    essay_df['sent_word_count'] = essay_df['sent'].apply(lambda x: len(x.split(' ')))
    essay_df = essay_df[essay_df.columns.tolist()].reset_index(drop=True)
    return essay_df

def compute_sentence_aggregations(df):
    sent_agg_df = pd.concat(
        [df[['id','sent_len']].groupby(['id']).agg(AGGREGATIONS), df[['id','sent_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1
    )
    sent_agg_df.columns = ['_'.join(x) for x in sent_agg_df.columns]
    sent_agg_df['id'] = sent_agg_df.index
    sent_agg_df = sent_agg_df.reset_index(drop=True)
    sent_agg_df.drop(columns=["sent_word_count_count"], inplace=True)
    sent_agg_df = sent_agg_df.rename(columns={"sent_len_count":"sent_count"})
    return sent_agg_df

def split_essays_into_paragraphs(df):
    essay_df = df
    essay_df['id'] = essay_df.index
    essay_df['paragraph'] = essay_df['essay'].apply(lambda x: str(x).split('\n'))
    essay_df = essay_df.explode('paragraph')
    # Number of characters in paragraphs
    essay_df['paragraph_len'] = essay_df['paragraph'].apply(lambda x: len(x)) 
    # Number of words in paragraphs
    essay_df['paragraph_word_count'] = essay_df['paragraph'].apply(lambda x: len(x.split(' ')))
    essay_df = essay_df[essay_df.paragraph_len!=0].reset_index(drop=True)
    return essay_df

def compute_paragraph_aggregations(df):
    paragraph_agg_df = pd.concat(
        [df[['id','paragraph_len']].groupby(['id']).agg(AGGREGATIONS), df[['id','paragraph_word_count']].groupby(['id']).agg(AGGREGATIONS)], axis=1
    ) 
    paragraph_agg_df.columns = ['_'.join(x) for x in paragraph_agg_df.columns]
    paragraph_agg_df['id'] = paragraph_agg_df.index
    paragraph_agg_df = paragraph_agg_df.reset_index(drop=True)
    paragraph_agg_df.drop(columns=["paragraph_word_count_count"], inplace=True)
    paragraph_agg_df = paragraph_agg_df.rename(columns={"paragraph_len_count":"paragraph_count"})
    return paragraph_agg_df


train_sent_df = split_essays_into_sentences(train_essaysdf)
train_sent_agg_df = compute_sentence_aggregations(train_sent_df)

train_paragraph_df = split_essays_into_paragraphs(train_essaysdf)
train_paragraph_agg_df = compute_paragraph_aggregations(train_paragraph_df)

test_sent_agg_df = compute_sentence_aggregations(split_essays_into_sentences(test_essaysdf))
test_paragraph_agg_df = compute_paragraph_aggregations(split_essays_into_paragraphs(test_essaysdf))

train_paragraph_agg_df.loc[:, 'id'] = df_train_index
train_sent_agg_df.loc[:, 'id'] = df_train_index

test_paragraph_agg_df.loc[:, 'id'] = df_test_index
test_sent_agg_df.loc[:, 'id'] = df_test_index


new_train_feats = pd.DataFrame()
new_test_feats = pd.DataFrame()

new_train_feats = train_paragraph_agg_df.merge(df_train_all,on='id')
new_train_feats = new_train_feats.merge(train_sent_agg_df,on='id')

new_test_feats = test_paragraph_agg_df.merge(df_test_all,on='id')
new_test_feats = new_test_feats.merge(test_sent_agg_df,on='id')

train_feats = pd.DataFrame()
test_feats = pd.DataFrame()

train_feats = new_train_feats.merge(other_train_feats,on='id')
test_feats = new_test_feats.merge(other_test_feats,on='id')

data = []

for logs in [traindf, testdf]:
    logs['up_time_lagged'] = logs.groupby('id')['up_time'].shift(1).fillna(logs['down_time'])
    logs['time_diff'] = abs(logs['down_time'] - logs['up_time_lagged']) / 1000

    group = logs.groupby('id')['time_diff']
    largest_lantency = group.max()
    smallest_lantency = group.min()
    median_lantency = group.median()
    initial_pause = logs.groupby('id')['down_time'].first() / 1000
    pauses_half_sec = group.apply(lambda x: ((x > 0.5) & (x < 1)).sum())
    pauses_1_sec = group.apply(lambda x: ((x > 1) & (x < 1.5)).sum())
    pauses_1_half_sec = group.apply(lambda x: ((x > 1.5) & (x < 2)).sum())
    pauses_2_sec = group.apply(lambda x: ((x > 2) & (x < 3)).sum())
    pauses_3_sec = group.apply(lambda x: (x > 3).sum())

    data.append(pd.DataFrame({
        'id': logs['id'].unique(),
        'largest_lantency': largest_lantency,
        'smallest_lantency': smallest_lantency,
        'median_lantency': median_lantency,
        'initial_pause': initial_pause,
        'pauses_half_sec': pauses_half_sec,
        'pauses_1_sec': pauses_1_sec,
        'pauses_1_half_sec': pauses_1_half_sec,
        'pauses_2_sec': pauses_2_sec,
        'pauses_3_sec': pauses_3_sec,
    }).reset_index(drop=True))

train_eD592674, test_eD592674 = data

train_feats = train_feats.merge(train_eD592674, on='id', how='left')
test_feats = test_feats.merge(test_eD592674, on='id', how='left')
train_feats = train_feats.merge(train_scores, on='id', how='left')

# train_feats 데이터프레임의 'score' 열을 정수형 레이블로 변환 ex) 3.5 -> 6(0.5 단위 씩)
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

train_feats['score_class'] = le.fit_transform(train_feats['score'])

activities = ['Input', 'Remove/Cut', 'Nonproduction', 'Replace', 'Paste']
events = ['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick', 'ArrowLeft',  'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock', 'Delete', 'Unidentified']
text_changes = ['q', 'NoChange']

for i in activities:
    print(i)
    new_df = traindf[traindf['activity'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'activity_{i}_{a}' for a in ['mean','median']]
    train_feats = train_feats.merge(new_df,on=['id'],how='left')

for i in events:
    print(i)
    new_df = traindf[traindf['down_event'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'down_event_{i}_{a}' for a in ['mean','median']]
    train_feats = train_feats.merge(new_df,on=['id'],how='left')
    new_df = traindf[traindf['up_event'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'up_event_{i}_{a}' for a in ['mean','median']]
    train_feats = train_feats.merge(new_df,on=['id'],how='left')

for i in text_changes:
    print(i)
    new_df = traindf[traindf['text_change'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'text_change_{i}_{a}' for a in ['mean','median']]
    train_feats = train_feats.merge(new_df,on=['id'],how='left')

for i in activities:
    print(i)
    new_df = testdf[testdf['activity'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'activity_{i}_{a}' for a in ['mean','median']]
    test_feats = test_feats.merge(new_df,on=['id'],how='left')

for i in events:
    print(i)
    new_df = testdf[testdf['down_event'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'down_event_{i}_{a}' for a in ['mean','median']]
    test_feats = test_feats.merge(new_df,on=['id'],how='left')
    new_df = testdf[testdf['up_event'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'up_event_{i}_{a}' for a in ['mean','median']]
    test_feats = test_feats.merge(new_df,on=['id'],how='left')

for i in text_changes:
    print(i)
    new_df = testdf[testdf['text_change'] == i]
    new_df = new_df.groupby(['id'])['time_diff'].agg(['mean','median']).reset_index()
    new_df.columns = ['id'] + [f'text_change_{i}_{a}' for a in ['mean','median']]
    test_feats = test_feats.merge(new_df,on=['id'],how='left')

for i in train_feats.columns:
    if i not in test_feats.columns:
        test_feats[i] = 0
        
target_col = ['score']

drop_cols = ['id', 'score_class']
train_cols = list()

train_cols = [col for col in train_feats.columns if col not in target_col + drop_cols]

nan_cols = train_feats.columns[train_feats.isna().any()].tolist()

# 결측치 최빈값으로 처리 
for col in nan_cols:
    mode_value_train = train_feats[col].mode()[0] #최빈값 여러 개 일 경우 첫 번째꺼 선택 
    train_feats[col].fillna(0, inplace=True)
    
for col in test_feats.columns[test_feats.isna().any()].tolist():
    # Find the most frequent value in the training set for the current feature
    most_frequent_value_train = train_feats[col].mode()[0]
    
    # Fill missing values in the test set with the most frequent value from the training set
    test_feats[col].fillna(0, inplace=True)

train_feats.shape, test_feats.shape
# Out:
# Engineering features for training data
# Starting to engineer features
# Engineering time data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering cursor position data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering word count data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering statistical summaries for features
#   0%|          | 0/33 [00:00<?, ?it/s]
# Engineering activity counts data
#   0%|          | 0/2471 [00:00<?, ?it/s]
# Engineering event counts data
#   0%|          | 0/2471 [00:00<?, ?it/s]
#   0%|          | 0/2471 [00:00<?, ?it/s]
# Engineering text change counts data
#   0%|          | 0/2471 [00:00<?, ?it/s]
# Engineering punctuation counts data
#   0%|          | 0/2471 [00:00<?, ?it/s]
# Engineering input words data
# Engineering ratios data
# Done!
#
# -------------------------
# Engineering features for test data
# -------------------------
# Starting to engineer features
# Engineering time data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering cursor position data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering word count data
# > for gap 1
# > for gap 2
# > for gap 3
# > for gap 5
# > for gap 10
# > for gap 20
# > for gap 50
# > for gap 100
# Engineering statistical summaries for features
#   0%|          | 0/33 [00:00<?, ?it/s]
# Engineering activity counts data
#   0%|          | 0/3 [00:00<?, ?it/s]
# Engineering event counts data
#   0%|          | 0/3 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Engineering text change counts data
#   0%|          | 0/3 [00:00<?, ?it/s]
# Engineering punctuation counts data
#   0%|          | 0/3 [00:00<?, ?it/s]
# Engineering input words data
# Engineering ratios data
# Done!
# Input
# Remove/Cut
# Nonproduction
# Replace
# Paste
# q
# Space
# Backspace
# Shift
# ArrowRight
# Leftclick
# ArrowLeft
# ArrowDown
# ArrowUp
# Enter
# CapsLock
# Delete
# Unidentified
# q
# NoChange
# Input
# Remove/Cut
# Nonproduction
# Replace
# Paste
# q
# Space
# Backspace
# Shift
# ArrowRight
# Leftclick
# ArrowLeft
# ArrowDown
# ArrowUp
# Enter
# CapsLock
# Delete
# Unidentified
# q
# NoChange
# ((2471, 725), (3, 725))

# %%
models_dict = {}
scores = []

models = []
test_predict_list = []
best_params = {'boosting_type': 'gbdt', 
               'metric': 'rmse',
               'reg_alpha': 0.003188447814669599, 
               'reg_lambda': 0.0010228604507564066, 
               'colsample_bytree': 0.5420247656839267, 
               'subsample': 0.9778252382803456, 
               'feature_fraction': 0.8,
               'bagging_freq': 1,
               'bagging_fraction': 0.75,
               'learning_rate': 0.01716485155812008, 
               'num_leaves': 19, 
               'min_child_samples': 46,
               'verbosity': -1,
               'random_state': 42,
               'n_estimators': 500,
               'device_type': 'cpu'}

for i in range(1): 
    kf = model_selection.KFold(n_splits=10, random_state=42 + i, shuffle=True)

    oof_valid_preds = np.zeros(train_feats.shape[0], )

    X_test = test_feats[train_cols]


    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_feats)):

        print("==-"* 50)
        print("Fold : ", fold)

        X_train, y_train = train_feats.iloc[train_idx][train_cols], train_feats.iloc[train_idx][target_col]
        X_valid, y_valid = train_feats.iloc[valid_idx][train_cols], train_feats.iloc[valid_idx][target_col]

        print("Trian :", X_train.shape, y_train.shape)
        print("Valid :", X_valid.shape, y_valid.shape)

        params = {
            "objective": "regression",
            "metric": "rmse",
            'random_state': 42,
            "n_estimators" : 12001,
            "verbosity": -1,
            "device_type": "cpu",
            **best_params
        }

        model = lgb.LGBMRegressor(**params)

        early_stopping_callback = lgb.early_stopping(200, first_metric_only=True, verbose=False)
        verbose_callback = lgb.callback.record_evaluation({})

        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],  
                  callbacks=[early_stopping_callback, verbose_callback],
        )
        models.append(model)

        valid_predict = model.predict(X_valid)
        oof_valid_preds[valid_idx] = valid_predict

        test_predict = model.predict(X_test)
        test_predict_list.append(test_predict)

        score = metrics.mean_squared_error(y_valid, valid_predict, squared=False)
        print("Fold RMSE Score : ", score)

        models_dict[f'{fold}_{i}'] = model


    oof_score = metrics.mean_squared_error(train_feats[target_col], oof_valid_preds, squared=False)
    scores.append(oof_score)
    print("OOF RMSE Score : ", oof_score)
# Out:
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  0
# Trian : (2223, 722) (2223, 1)
# Valid : (248, 722) (248, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.00909
# [2]	valid_0's rmse: 0.999003
# [3]	valid_0's rmse: 0.989599
# [4]	valid_0's rmse: 0.980598
# [5]	valid_0's rmse: 0.970613
# [6]	valid_0's rmse: 0.962115
# [7]	valid_0's rmse: 0.952944
# [8]	valid_0's rmse: 0.944107
# [9]	valid_0's rmse: 0.93578
# [10]	valid_0's rmse: 0.927389
# [11]	valid_0's rmse: 0.919344
# [12]	valid_0's rmse: 0.911336
# [13]	valid_0's rmse: 0.903048
# [14]	valid_0's rmse: 0.895367
# [15]	valid_0's rmse: 0.888157
# [16]	valid_0's rmse: 0.881305
# [17]	valid_0's rmse: 0.874578
# [18]	valid_0's rmse: 0.867399
# [19]	valid_0's rmse: 0.860764
# [20]	valid_0's rmse: 0.853305
# [21]	valid_0's rmse: 0.847057
# [22]	valid_0's rmse: 0.840782
# [23]	valid_0's rmse: 0.834395
# [24]	valid_0's rmse: 0.828359
# [25]	valid_0's rmse: 0.822193
# [26]	valid_0's rmse: 0.81676
# [27]	valid_0's rmse: 0.811531
# [28]	valid_0's rmse: 0.806509
# [29]	valid_0's rmse: 0.800967
# [30]	valid_0's rmse: 0.795999
# [31]	valid_0's rmse: 0.79083
# [32]	valid_0's rmse: 0.785889
# [33]	valid_0's rmse: 0.780943
# [34]	valid_0's rmse: 0.776255
# [35]	valid_0's rmse: 0.77192
# [36]	valid_0's rmse: 0.767794
# [37]	valid_0's rmse: 0.763132
# [38]	valid_0's rmse: 0.75929
# [39]	valid_0's rmse: 0.754756
# [40]	valid_0's rmse: 0.75065
# [41]	valid_0's rmse: 0.746581
# [42]	valid_0's rmse: 0.742718
# [43]	valid_0's rmse: 0.738855
# [44]	valid_0's rmse: 0.734742
# [45]	valid_0's rmse: 0.731045
# [46]	valid_0's rmse: 0.72725
# [47]	valid_0's rmse: 0.723403
# [48]	valid_0's rmse: 0.720182
# [49]	valid_0's rmse: 0.716847
# [50]	valid_0's rmse: 0.713509
# [51]	valid_0's rmse: 0.710657
# [52]	valid_0's rmse: 0.707552
# [53]	valid_0's rmse: 0.704269
# [54]	valid_0's rmse: 0.701314
# [55]	valid_0's rmse: 0.698381
# [56]	valid_0's rmse: 0.695702
# [57]	valid_0's rmse: 0.693417
# [58]	valid_0's rmse: 0.690813
# [59]	valid_0's rmse: 0.688589
# [60]	valid_0's rmse: 0.686668
# [61]	valid_0's rmse: 0.68446
# [62]	valid_0's rmse: 0.682253
# [63]	valid_0's rmse: 0.68033
# [64]	valid_0's rmse: 0.678279
# [65]	valid_0's rmse: 0.676073
# [66]	valid_0's rmse: 0.673938
# [67]	valid_0's rmse: 0.672147
# [68]	valid_0's rmse: 0.670041
# [69]	valid_0's rmse: 0.668164
# [70]	valid_0's rmse: 0.665748
# [71]	valid_0's rmse: 0.664284
# [72]	valid_0's rmse: 0.66262
# [73]	valid_0's rmse: 0.660797
# [74]	valid_0's rmse: 0.659247
# [75]	valid_0's rmse: 0.657415
# [76]	valid_0's rmse: 0.655371
# [77]	valid_0's rmse: 0.653678
# [78]	valid_0's rmse: 0.652304
# [79]	valid_0's rmse: 0.650997
# [80]	valid_0's rmse: 0.649536
# [81]	valid_0's rmse: 0.648229
# [82]	valid_0's rmse: 0.646627
# [83]	valid_0's rmse: 0.644753
# [84]	valid_0's rmse: 0.643316
# [85]	valid_0's rmse: 0.641856
# [86]	valid_0's rmse: 0.640739
# [87]	valid_0's rmse: 0.63963
# [88]	valid_0's rmse: 0.637785
# [89]	valid_0's rmse: 0.636288
# [90]	valid_0's rmse: 0.635403
# [91]	valid_0's rmse: 0.633888
# [92]	valid_0's rmse: 0.632706
# [93]	valid_0's rmse: 0.631433
# [94]	valid_0's rmse: 0.629998
# [95]	valid_0's rmse: 0.628532
# [96]	valid_0's rmse: 0.627283
# [97]	valid_0's rmse: 0.626114
# [98]	valid_0's rmse: 0.62475
# [99]	valid_0's rmse: 0.623714
# [100]	valid_0's rmse: 0.622908
# [101]	valid_0's rmse: 0.621877
# [102]	valid_0's rmse: 0.621072
# [103]	valid_0's rmse: 0.620308
# [104]	valid_0's rmse: 0.619554
# [105]	valid_0's rmse: 0.618654
# [106]	valid_0's rmse: 0.617623
# [107]	valid_0's rmse: 0.617163
# [108]	valid_0's rmse: 0.616477
# [109]	valid_0's rmse: 0.615594
# [110]	valid_0's rmse: 0.614645
# [111]	valid_0's rmse: 0.614029
# [112]	valid_0's rmse: 0.61344
# [113]	valid_0's rmse: 0.61276
# [114]	valid_0's rmse: 0.611884
# [115]	valid_0's rmse: 0.610896
# [116]	valid_0's rmse: 0.610397
# [117]	valid_0's rmse: 0.610034
# [118]	valid_0's rmse: 0.608863
# [119]	valid_0's rmse: 0.607907
# [120]	valid_0's rmse: 0.607484
# [121]	valid_0's rmse: 0.607165
# [122]	valid_0's rmse: 0.60656
# [123]	valid_0's rmse: 0.606049
# [124]	valid_0's rmse: 0.60523
# [125]	valid_0's rmse: 0.604403
# [126]	valid_0's rmse: 0.603562
# [127]	valid_0's rmse: 0.603033
# [128]	valid_0's rmse: 0.602335
# [129]	valid_0's rmse: 0.60208
# [130]	valid_0's rmse: 0.601553
# [131]	valid_0's rmse: 0.60135
# [132]	valid_0's rmse: 0.600866
# [133]	valid_0's rmse: 0.600189
# [134]	valid_0's rmse: 0.599842
# [135]	valid_0's rmse: 0.599444
# [136]	valid_0's rmse: 0.598654
# [137]	valid_0's rmse: 0.598175
# [138]	valid_0's rmse: 0.597932
# [139]	valid_0's rmse: 0.597505
# [140]	valid_0's rmse: 0.597578
# [141]	valid_0's rmse: 0.597398
# [142]	valid_0's rmse: 0.597153
# [143]	valid_0's rmse: 0.596772
# [144]	valid_0's rmse: 0.59654
# [145]	valid_0's rmse: 0.596339
# [146]	valid_0's rmse: 0.596105
# [147]	valid_0's rmse: 0.595961
# [148]	valid_0's rmse: 0.595562
# [149]	valid_0's rmse: 0.59482
# [150]	valid_0's rmse: 0.594301
# [151]	valid_0's rmse: 0.593897
# [152]	valid_0's rmse: 0.593395
# [153]	valid_0's rmse: 0.593181
# [154]	valid_0's rmse: 0.592525
# [155]	valid_0's rmse: 0.592472
# [156]	valid_0's rmse: 0.592169
# [157]	valid_0's rmse: 0.592083
# [158]	valid_0's rmse: 0.591998
# [159]	valid_0's rmse: 0.591947
# [160]	valid_0's rmse: 0.591933
# [161]	valid_0's rmse: 0.591862
# [162]	valid_0's rmse: 0.591537
# [163]	valid_0's rmse: 0.591442
# [164]	valid_0's rmse: 0.591026
# [165]	valid_0's rmse: 0.590912
# [166]	valid_0's rmse: 0.590293
# [167]	valid_0's rmse: 0.590068
# [168]	valid_0's rmse: 0.589608
# [169]	valid_0's rmse: 0.589321
# [170]	valid_0's rmse: 0.588911
# [171]	valid_0's rmse: 0.588904
# [172]	valid_0's rmse: 0.588839
# [173]	valid_0's rmse: 0.588728
# [174]	valid_0's rmse: 0.588643
# [175]	valid_0's rmse: 0.588273
# [176]	valid_0's rmse: 0.588234
# [177]	valid_0's rmse: 0.587753
# [178]	valid_0's rmse: 0.587659
# [179]	valid_0's rmse: 0.58791
# [180]	valid_0's rmse: 0.587683
# [181]	valid_0's rmse: 0.587496
# [182]	valid_0's rmse: 0.587222
# [183]	valid_0's rmse: 0.587028
# [184]	valid_0's rmse: 0.586552
# [185]	valid_0's rmse: 0.586434
# [186]	valid_0's rmse: 0.58628
# [187]	valid_0's rmse: 0.585843
# [188]	valid_0's rmse: 0.585449
# [189]	valid_0's rmse: 0.58541
# [190]	valid_0's rmse: 0.585092
# [191]	valid_0's rmse: 0.584918
# [192]	valid_0's rmse: 0.584485
# [193]	valid_0's rmse: 0.584792
# [194]	valid_0's rmse: 0.584835
# [195]	valid_0's rmse: 0.584439
# [196]	valid_0's rmse: 0.584354
# [197]	valid_0's rmse: 0.584174
# [198]	valid_0's rmse: 0.584356
# [199]	valid_0's rmse: 0.584286
# [200]	valid_0's rmse: 0.584049
# [201]	valid_0's rmse: 0.583634
# [202]	valid_0's rmse: 0.583137
# [203]	valid_0's rmse: 0.583202
# [204]	valid_0's rmse: 0.583343
# [205]	valid_0's rmse: 0.583089
# [206]	valid_0's rmse: 0.582718
# [207]	valid_0's rmse: 0.582467
# [208]	valid_0's rmse: 0.582188
# [209]	valid_0's rmse: 0.581953
# [210]	valid_0's rmse: 0.58201
# [211]	valid_0's rmse: 0.581924
# [212]	valid_0's rmse: 0.58196
# [213]	valid_0's rmse: 0.581786
# [214]	valid_0's rmse: 0.581801
# [215]	valid_0's rmse: 0.581965
# [216]	valid_0's rmse: 0.58172
# [217]	valid_0's rmse: 0.581647
# [218]	valid_0's rmse: 0.581751
# [219]	valid_0's rmse: 0.581738
# [220]	valid_0's rmse: 0.581701
# [221]	valid_0's rmse: 0.581633
# [222]	valid_0's rmse: 0.58174
# [223]	valid_0's rmse: 0.581731
# [224]	valid_0's rmse: 0.581523
# [225]	valid_0's rmse: 0.581669
# [226]	valid_0's rmse: 0.581688
# [227]	valid_0's rmse: 0.581516
# [228]	valid_0's rmse: 0.581195
# [229]	valid_0's rmse: 0.580965
# [230]	valid_0's rmse: 0.580948
# [231]	valid_0's rmse: 0.580923
# [232]	valid_0's rmse: 0.580736
# [233]	valid_0's rmse: 0.580485
# [234]	valid_0's rmse: 0.58038
# [235]	valid_0's rmse: 0.580119
# [236]	valid_0's rmse: 0.5802
# [237]	valid_0's rmse: 0.580576
# [238]	valid_0's rmse: 0.580515
# [239]	valid_0's rmse: 0.580634
# [240]	valid_0's rmse: 0.580684
# [241]	valid_0's rmse: 0.580372
# [242]	valid_0's rmse: 0.580456
# [243]	valid_0's rmse: 0.58051
# [244]	valid_0's rmse: 0.58034
# [245]	valid_0's rmse: 0.580647
# [246]	valid_0's rmse: 0.580756
# [247]	valid_0's rmse: 0.58078
# [248]	valid_0's rmse: 0.580683
# [249]	valid_0's rmse: 0.580815
# [250]	valid_0's rmse: 0.580654
# [251]	valid_0's rmse: 0.580482
# [252]	valid_0's rmse: 0.58044
# [253]	valid_0's rmse: 0.580375
# [254]	valid_0's rmse: 0.580379
# [255]	valid_0's rmse: 0.580379
# [256]	valid_0's rmse: 0.580591
# [257]	valid_0's rmse: 0.5807
# [258]	valid_0's rmse: 0.580657
# [259]	valid_0's rmse: 0.580143
# [260]	valid_0's rmse: 0.580132
# [261]	valid_0's rmse: 0.580013
# [262]	valid_0's rmse: 0.579787
# [263]	valid_0's rmse: 0.579862
# [264]	valid_0's rmse: 0.579707
# [265]	valid_0's rmse: 0.579614
# [266]	valid_0's rmse: 0.580075
# [267]	valid_0's rmse: 0.580109
# [268]	valid_0's rmse: 0.580013
# [269]	valid_0's rmse: 0.579841
# [270]	valid_0's rmse: 0.579901
# [271]	valid_0's rmse: 0.579878
# [272]	valid_0's rmse: 0.57965
# [273]	valid_0's rmse: 0.579476
# [274]	valid_0's rmse: 0.579352
# [275]	valid_0's rmse: 0.579386
# [276]	valid_0's rmse: 0.579303
# [277]	valid_0's rmse: 0.578969
# [278]	valid_0's rmse: 0.579078
# [279]	valid_0's rmse: 0.579075
# [280]	valid_0's rmse: 0.579071
# [281]	valid_0's rmse: 0.579114
# [282]	valid_0's rmse: 0.578777
# [283]	valid_0's rmse: 0.578891
# [284]	valid_0's rmse: 0.578852
# [285]	valid_0's rmse: 0.578864
# [286]	valid_0's rmse: 0.578859
# [287]	valid_0's rmse: 0.578935
# [288]	valid_0's rmse: 0.579023
# [289]	valid_0's rmse: 0.578918
# [290]	valid_0's rmse: 0.578895
# [291]	valid_0's rmse: 0.578836
# [292]	valid_0's rmse: 0.578878
# [293]	valid_0's rmse: 0.578874
# [294]	valid_0's rmse: 0.578927
# [295]	valid_0's rmse: 0.578879
# [296]	valid_0's rmse: 0.579052
# [297]	valid_0's rmse: 0.579143
# [298]	valid_0's rmse: 0.579033
# [299]	valid_0's rmse: 0.578707
# [300]	valid_0's rmse: 0.579002
# [301]	valid_0's rmse: 0.578776
# [302]	valid_0's rmse: 0.579107
# [303]	valid_0's rmse: 0.57881
# [304]	valid_0's rmse: 0.578811
# [305]	valid_0's rmse: 0.578853
# [306]	valid_0's rmse: 0.57903
# [307]	valid_0's rmse: 0.579113
# [308]	valid_0's rmse: 0.579077
# [309]	valid_0's rmse: 0.579079
# [310]	valid_0's rmse: 0.579104
# [311]	valid_0's rmse: 0.579057
# [312]	valid_0's rmse: 0.579166
# [313]	valid_0's rmse: 0.579264
# [314]	valid_0's rmse: 0.579107
# [315]	valid_0's rmse: 0.578927
# [316]	valid_0's rmse: 0.579404
# [317]	valid_0's rmse: 0.579434
# [318]	valid_0's rmse: 0.57969
# [319]	valid_0's rmse: 0.579824
# [320]	valid_0's rmse: 0.579689
# [321]	valid_0's rmse: 0.579488
# [322]	valid_0's rmse: 0.579528
# [323]	valid_0's rmse: 0.579402
# [324]	valid_0's rmse: 0.579332
# [325]	valid_0's rmse: 0.579576
# [326]	valid_0's rmse: 0.579539
# [327]	valid_0's rmse: 0.579535
# [328]	valid_0's rmse: 0.579442
# [329]	valid_0's rmse: 0.579356
# [330]	valid_0's rmse: 0.579217
# [331]	valid_0's rmse: 0.579365
# [332]	valid_0's rmse: 0.579467
# [333]	valid_0's rmse: 0.579406
# [334]	valid_0's rmse: 0.579342
# [335]	valid_0's rmse: 0.579381
# [336]	valid_0's rmse: 0.579264
# [337]	valid_0's rmse: 0.579329
# [338]	valid_0's rmse: 0.579104
# [339]	valid_0's rmse: 0.57915
# [340]	valid_0's rmse: 0.578927
# [341]	valid_0's rmse: 0.578988
# [342]	valid_0's rmse: 0.578995
# [343]	valid_0's rmse: 0.578996
# [344]	valid_0's rmse: 0.57883
# [345]	valid_0's rmse: 0.578916
# [346]	valid_0's rmse: 0.579071
# [347]	valid_0's rmse: 0.579104
# [348]	valid_0's rmse: 0.578916
# [349]	valid_0's rmse: 0.578999
# [350]	valid_0's rmse: 0.57888
# [351]	valid_0's rmse: 0.57873
# [352]	valid_0's rmse: 0.578645
# [353]	valid_0's rmse: 0.578617
# [354]	valid_0's rmse: 0.578674
# [355]	valid_0's rmse: 0.578519
# [356]	valid_0's rmse: 0.578773
# [357]	valid_0's rmse: 0.578705
# [358]	valid_0's rmse: 0.578437
# [359]	valid_0's rmse: 0.578498
# [360]	valid_0's rmse: 0.578404
# [361]	valid_0's rmse: 0.578293
# [362]	valid_0's rmse: 0.578348
# [363]	valid_0's rmse: 0.578406
# [364]	valid_0's rmse: 0.578414
# [365]	valid_0's rmse: 0.578287
# [366]	valid_0's rmse: 0.578402
# [367]	valid_0's rmse: 0.578369
# [368]	valid_0's rmse: 0.578129
# [369]	valid_0's rmse: 0.578272
# [370]	valid_0's rmse: 0.578217
# [371]	valid_0's rmse: 0.578257
# [372]	valid_0's rmse: 0.578197
# [373]	valid_0's rmse: 0.578256
# [374]	valid_0's rmse: 0.578181
# [375]	valid_0's rmse: 0.57806
# [376]	valid_0's rmse: 0.578405
# [377]	valid_0's rmse: 0.578572
# [378]	valid_0's rmse: 0.578568
# [379]	valid_0's rmse: 0.578751
# [380]	valid_0's rmse: 0.578818
# [381]	valid_0's rmse: 0.579014
# [382]	valid_0's rmse: 0.579077
# [383]	valid_0's rmse: 0.578889
# [384]	valid_0's rmse: 0.578691
# [385]	valid_0's rmse: 0.578735
# [386]	valid_0's rmse: 0.578876
# [387]	valid_0's rmse: 0.578963
# [388]	valid_0's rmse: 0.57913
# [389]	valid_0's rmse: 0.578932
# [390]	valid_0's rmse: 0.578893
# [391]	valid_0's rmse: 0.578983
# [392]	valid_0's rmse: 0.5791
# [393]	valid_0's rmse: 0.579237
# [394]	valid_0's rmse: 0.57894
# [395]	valid_0's rmse: 0.578988
# [396]	valid_0's rmse: 0.579011
# [397]	valid_0's rmse: 0.578958
# [398]	valid_0's rmse: 0.579024
# [399]	valid_0's rmse: 0.578952
# [400]	valid_0's rmse: 0.579199
# [401]	valid_0's rmse: 0.579267
# [402]	valid_0's rmse: 0.579272
# [403]	valid_0's rmse: 0.579337
# [404]	valid_0's rmse: 0.579367
# [405]	valid_0's rmse: 0.579371
# [406]	valid_0's rmse: 0.57935
# [407]	valid_0's rmse: 0.579635
# [408]	valid_0's rmse: 0.579692
# [409]	valid_0's rmse: 0.579898
# [410]	valid_0's rmse: 0.579755
# [411]	valid_0's rmse: 0.579804
# [412]	valid_0's rmse: 0.579761
# [413]	valid_0's rmse: 0.57977
# [414]	valid_0's rmse: 0.579961
# [415]	valid_0's rmse: 0.579922
# [416]	valid_0's rmse: 0.579852
# [417]	valid_0's rmse: 0.579872
# [418]	valid_0's rmse: 0.579647
# [419]	valid_0's rmse: 0.579588
# [420]	valid_0's rmse: 0.579754
# [421]	valid_0's rmse: 0.579701
# [422]	valid_0's rmse: 0.579771
# [423]	valid_0's rmse: 0.579645
# [424]	valid_0's rmse: 0.579717
# [425]	valid_0's rmse: 0.579795
# [426]	valid_0's rmse: 0.579913
# [427]	valid_0's rmse: 0.580167
# [428]	valid_0's rmse: 0.580243
# [429]	valid_0's rmse: 0.580276
# [430]	valid_0's rmse: 0.580207
# [431]	valid_0's rmse: 0.580322
# [432]	valid_0's rmse: 0.580395
# [433]	valid_0's rmse: 0.580508
# [434]	valid_0's rmse: 0.580494
# [435]	valid_0's rmse: 0.580139
# [436]	valid_0's rmse: 0.580054
# [437]	valid_0's rmse: 0.580208
# [438]	valid_0's rmse: 0.580317
# [439]	valid_0's rmse: 0.580134
# [440]	valid_0's rmse: 0.580312
# [441]	valid_0's rmse: 0.580352
# [442]	valid_0's rmse: 0.5802
# [443]	valid_0's rmse: 0.580266
# [444]	valid_0's rmse: 0.580287
# [445]	valid_0's rmse: 0.580278
# [446]	valid_0's rmse: 0.58037
# [447]	valid_0's rmse: 0.580335
# [448]	valid_0's rmse: 0.580213
# [449]	valid_0's rmse: 0.58035
# [450]	valid_0's rmse: 0.580562
# [451]	valid_0's rmse: 0.580604
# [452]	valid_0's rmse: 0.580716
# [453]	valid_0's rmse: 0.580578
# [454]	valid_0's rmse: 0.580757
# [455]	valid_0's rmse: 0.580507
# [456]	valid_0's rmse: 0.580684
# [457]	valid_0's rmse: 0.580942
# [458]	valid_0's rmse: 0.580944
# [459]	valid_0's rmse: 0.580945
# [460]	valid_0's rmse: 0.580814
# [461]	valid_0's rmse: 0.580964
# [462]	valid_0's rmse: 0.580806
# [463]	valid_0's rmse: 0.580715
# [464]	valid_0's rmse: 0.580727
# [465]	valid_0's rmse: 0.580684
# [466]	valid_0's rmse: 0.580592
# [467]	valid_0's rmse: 0.58073
# [468]	valid_0's rmse: 0.580688
# [469]	valid_0's rmse: 0.580713
# [470]	valid_0's rmse: 0.580904
# [471]	valid_0's rmse: 0.580792
# [472]	valid_0's rmse: 0.580845
# [473]	valid_0's rmse: 0.580718
# [474]	valid_0's rmse: 0.580609
# [475]	valid_0's rmse: 0.580627
# [476]	valid_0's rmse: 0.580585
# [477]	valid_0's rmse: 0.580362
# [478]	valid_0's rmse: 0.580221
# [479]	valid_0's rmse: 0.580209
# [480]	valid_0's rmse: 0.580223
# [481]	valid_0's rmse: 0.580227
# [482]	valid_0's rmse: 0.580386
# [483]	valid_0's rmse: 0.580297
# [484]	valid_0's rmse: 0.580289
# [485]	valid_0's rmse: 0.580324
# [486]	valid_0's rmse: 0.580335
# [487]	valid_0's rmse: 0.580249
# [488]	valid_0's rmse: 0.580214
# [489]	valid_0's rmse: 0.580238
# [490]	valid_0's rmse: 0.580451
# [491]	valid_0's rmse: 0.58064
# [492]	valid_0's rmse: 0.580663
# [493]	valid_0's rmse: 0.580612
# [494]	valid_0's rmse: 0.58047
# [495]	valid_0's rmse: 0.580514
# [496]	valid_0's rmse: 0.580452
# [497]	valid_0's rmse: 0.580381
# [498]	valid_0's rmse: 0.580412
# [499]	valid_0's rmse: 0.580294
# [500]	valid_0's rmse: 0.580308
# Fold RMSE Score :  0.5780599214224069
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  1
# Trian : (2224, 722) (2224, 1)
# Valid : (247, 722) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 0.944748
# [2]	valid_0's rmse: 0.934054
# [3]	valid_0's rmse: 0.924513
# [4]	valid_0's rmse: 0.915392
# [5]	valid_0's rmse: 0.905953
# [6]	valid_0's rmse: 0.895863
# [7]	valid_0's rmse: 0.886851
# [8]	valid_0's rmse: 0.877825
# [9]	valid_0's rmse: 0.869054
# [10]	valid_0's rmse: 0.859964
# [11]	valid_0's rmse: 0.851215
# [12]	valid_0's rmse: 0.842833
# [13]	valid_0's rmse: 0.83451
# [14]	valid_0's rmse: 0.826905
# [15]	valid_0's rmse: 0.819306
# [16]	valid_0's rmse: 0.81198
# [17]	valid_0's rmse: 0.804345
# [18]	valid_0's rmse: 0.797685
# [19]	valid_0's rmse: 0.791329
# [20]	valid_0's rmse: 0.784475
# [21]	valid_0's rmse: 0.777797
# [22]	valid_0's rmse: 0.771083
# [23]	valid_0's rmse: 0.764664
# [24]	valid_0's rmse: 0.75853
# [25]	valid_0's rmse: 0.752483
# [26]	valid_0's rmse: 0.746894
# [27]	valid_0's rmse: 0.741253
# [28]	valid_0's rmse: 0.735812
# [29]	valid_0's rmse: 0.729854
# [30]	valid_0's rmse: 0.724138
# [31]	valid_0's rmse: 0.718851
# [32]	valid_0's rmse: 0.713521
# [33]	valid_0's rmse: 0.708826
# [34]	valid_0's rmse: 0.703761
# [35]	valid_0's rmse: 0.699087
# [36]	valid_0's rmse: 0.69423
# [37]	valid_0's rmse: 0.689831
# [38]	valid_0's rmse: 0.68535
# [39]	valid_0's rmse: 0.68142
# [40]	valid_0's rmse: 0.677299
# [41]	valid_0's rmse: 0.673659
# [42]	valid_0's rmse: 0.670454
# [43]	valid_0's rmse: 0.666582
# [44]	valid_0's rmse: 0.662678
# [45]	valid_0's rmse: 0.659182
# [46]	valid_0's rmse: 0.655538
# [47]	valid_0's rmse: 0.651336
# [48]	valid_0's rmse: 0.648564
# [49]	valid_0's rmse: 0.64537
# [50]	valid_0's rmse: 0.641719
# [51]	valid_0's rmse: 0.638912
# [52]	valid_0's rmse: 0.636035
# [53]	valid_0's rmse: 0.633265
# [54]	valid_0's rmse: 0.630258
# [55]	valid_0's rmse: 0.627653
# [56]	valid_0's rmse: 0.624819
# [57]	valid_0's rmse: 0.622014
# [58]	valid_0's rmse: 0.619217
# [59]	valid_0's rmse: 0.61661
# [60]	valid_0's rmse: 0.614087
# [61]	valid_0's rmse: 0.611765
# [62]	valid_0's rmse: 0.609017
# [63]	valid_0's rmse: 0.606342
# [64]	valid_0's rmse: 0.603969
# [65]	valid_0's rmse: 0.601595
# [66]	valid_0's rmse: 0.599478
# [67]	valid_0's rmse: 0.597321
# [68]	valid_0's rmse: 0.595037
# [69]	valid_0's rmse: 0.59317
# [70]	valid_0's rmse: 0.591452
# [71]	valid_0's rmse: 0.589525
# [72]	valid_0's rmse: 0.587552
# [73]	valid_0's rmse: 0.585824
# [74]	valid_0's rmse: 0.584139
# [75]	valid_0's rmse: 0.582868
# [76]	valid_0's rmse: 0.581139
# [77]	valid_0's rmse: 0.57983
# [78]	valid_0's rmse: 0.578452
# [79]	valid_0's rmse: 0.576593
# [80]	valid_0's rmse: 0.575018
# [81]	valid_0's rmse: 0.573664
# [82]	valid_0's rmse: 0.572236
# [83]	valid_0's rmse: 0.570907
# [84]	valid_0's rmse: 0.569876
# [85]	valid_0's rmse: 0.568933
# [86]	valid_0's rmse: 0.567601
# [87]	valid_0's rmse: 0.566546
# [88]	valid_0's rmse: 0.565192
# [89]	valid_0's rmse: 0.564059
# [90]	valid_0's rmse: 0.562902
# [91]	valid_0's rmse: 0.561467
# [92]	valid_0's rmse: 0.560511
# [93]	valid_0's rmse: 0.559818
# [94]	valid_0's rmse: 0.55922
# [95]	valid_0's rmse: 0.558101
# [96]	valid_0's rmse: 0.557066
# [97]	valid_0's rmse: 0.556725
# [98]	valid_0's rmse: 0.555418
# [99]	valid_0's rmse: 0.554433
# [100]	valid_0's rmse: 0.55422
# [101]	valid_0's rmse: 0.553774
# [102]	valid_0's rmse: 0.553262
# [103]	valid_0's rmse: 0.552298
# [104]	valid_0's rmse: 0.551766
# [105]	valid_0's rmse: 0.550909
# [106]	valid_0's rmse: 0.550286
# [107]	valid_0's rmse: 0.549856
# [108]	valid_0's rmse: 0.549043
# [109]	valid_0's rmse: 0.548887
# [110]	valid_0's rmse: 0.547757
# [111]	valid_0's rmse: 0.546867
# [112]	valid_0's rmse: 0.545922
# [113]	valid_0's rmse: 0.545391
# [114]	valid_0's rmse: 0.544403
# [115]	valid_0's rmse: 0.543687
# [116]	valid_0's rmse: 0.542915
# [117]	valid_0's rmse: 0.542807
# [118]	valid_0's rmse: 0.542033
# [119]	valid_0's rmse: 0.541079
# [120]	valid_0's rmse: 0.540465
# [121]	valid_0's rmse: 0.539899
# [122]	valid_0's rmse: 0.539463
# [123]	valid_0's rmse: 0.5386
# [124]	valid_0's rmse: 0.537915
# [125]	valid_0's rmse: 0.537629
# [126]	valid_0's rmse: 0.536966
# [127]	valid_0's rmse: 0.536373
# [128]	valid_0's rmse: 0.536046
# [129]	valid_0's rmse: 0.53597
# [130]	valid_0's rmse: 0.535546
# [131]	valid_0's rmse: 0.535373
# [132]	valid_0's rmse: 0.534916
# [133]	valid_0's rmse: 0.534374
# [134]	valid_0's rmse: 0.534182
# [135]	valid_0's rmse: 0.533726
# [136]	valid_0's rmse: 0.533449
# [137]	valid_0's rmse: 0.533231
# [138]	valid_0's rmse: 0.533109
# [139]	valid_0's rmse: 0.532744
# [140]	valid_0's rmse: 0.53239
# [141]	valid_0's rmse: 0.531994
# [142]	valid_0's rmse: 0.531411
# [143]	valid_0's rmse: 0.530899
# [144]	valid_0's rmse: 0.53014
# [145]	valid_0's rmse: 0.530044
# [146]	valid_0's rmse: 0.529592
# [147]	valid_0's rmse: 0.529371
# [148]	valid_0's rmse: 0.529137
# [149]	valid_0's rmse: 0.528569
# [150]	valid_0's rmse: 0.528541
# [151]	valid_0's rmse: 0.528006
# [152]	valid_0's rmse: 0.527723
# [153]	valid_0's rmse: 0.5275
# [154]	valid_0's rmse: 0.526994
# [155]	valid_0's rmse: 0.526781
# [156]	valid_0's rmse: 0.526542
# [157]	valid_0's rmse: 0.526673
# [158]	valid_0's rmse: 0.526554
# [159]	valid_0's rmse: 0.526845
# [160]	valid_0's rmse: 0.52699
# [161]	valid_0's rmse: 0.52678
# [162]	valid_0's rmse: 0.526433
# [163]	valid_0's rmse: 0.526661
# [164]	valid_0's rmse: 0.526632
# [165]	valid_0's rmse: 0.526313
# [166]	valid_0's rmse: 0.526297
# [167]	valid_0's rmse: 0.52614
# [168]	valid_0's rmse: 0.526205
# [169]	valid_0's rmse: 0.525704
# [170]	valid_0's rmse: 0.525254
# [171]	valid_0's rmse: 0.525308
# [172]	valid_0's rmse: 0.525144
# [173]	valid_0's rmse: 0.524884
# [174]	valid_0's rmse: 0.524783
# [175]	valid_0's rmse: 0.524438
# [176]	valid_0's rmse: 0.52433
# [177]	valid_0's rmse: 0.524251
# [178]	valid_0's rmse: 0.523842
# [179]	valid_0's rmse: 0.524268
# [180]	valid_0's rmse: 0.52423
# [181]	valid_0's rmse: 0.523994
# [182]	valid_0's rmse: 0.523724
# [183]	valid_0's rmse: 0.523281
# [184]	valid_0's rmse: 0.523034
# [185]	valid_0's rmse: 0.522882
# [186]	valid_0's rmse: 0.522535
# [187]	valid_0's rmse: 0.522452
# [188]	valid_0's rmse: 0.522541
# [189]	valid_0's rmse: 0.522123
# [190]	valid_0's rmse: 0.522017
# [191]	valid_0's rmse: 0.522128
# [192]	valid_0's rmse: 0.521663
# [193]	valid_0's rmse: 0.52133
# [194]	valid_0's rmse: 0.520967
# [195]	valid_0's rmse: 0.520995
# [196]	valid_0's rmse: 0.521008
# [197]	valid_0's rmse: 0.520959
# [198]	valid_0's rmse: 0.521112
# [199]	valid_0's rmse: 0.520932
# [200]	valid_0's rmse: 0.520733
# [201]	valid_0's rmse: 0.520666
# [202]	valid_0's rmse: 0.520759
# [203]	valid_0's rmse: 0.520874
# [204]	valid_0's rmse: 0.520549
# [205]	valid_0's rmse: 0.520893
# [206]	valid_0's rmse: 0.520634
# [207]	valid_0's rmse: 0.520717
# [208]	valid_0's rmse: 0.520502
# [209]	valid_0's rmse: 0.520456
# [210]	valid_0's rmse: 0.520485
# [211]	valid_0's rmse: 0.520187
# [212]	valid_0's rmse: 0.520244
# [213]	valid_0's rmse: 0.520198
# [214]	valid_0's rmse: 0.520328
# [215]	valid_0's rmse: 0.519995
# [216]	valid_0's rmse: 0.51938
# [217]	valid_0's rmse: 0.519095
# [218]	valid_0's rmse: 0.51925
# [219]	valid_0's rmse: 0.518893
# [220]	valid_0's rmse: 0.518605
# [221]	valid_0's rmse: 0.518404
# [222]	valid_0's rmse: 0.518526
# [223]	valid_0's rmse: 0.518587
# [224]	valid_0's rmse: 0.51881
# [225]	valid_0's rmse: 0.518752
# [226]	valid_0's rmse: 0.518592
# [227]	valid_0's rmse: 0.518505
# [228]	valid_0's rmse: 0.518521
# [229]	valid_0's rmse: 0.518612
# [230]	valid_0's rmse: 0.518543
# [231]	valid_0's rmse: 0.518446
# [232]	valid_0's rmse: 0.518334
# [233]	valid_0's rmse: 0.518357
# [234]	valid_0's rmse: 0.518079
# [235]	valid_0's rmse: 0.517749
# [236]	valid_0's rmse: 0.517725
# [237]	valid_0's rmse: 0.517536
# [238]	valid_0's rmse: 0.517651
# [239]	valid_0's rmse: 0.517598
# [240]	valid_0's rmse: 0.517452
# [241]	valid_0's rmse: 0.517312
# [242]	valid_0's rmse: 0.517255
# [243]	valid_0's rmse: 0.517208
# [244]	valid_0's rmse: 0.517149
# [245]	valid_0's rmse: 0.517034
# [246]	valid_0's rmse: 0.517127
# [247]	valid_0's rmse: 0.516814
# [248]	valid_0's rmse: 0.517086
# [249]	valid_0's rmse: 0.517137
# [250]	valid_0's rmse: 0.516865
# [251]	valid_0's rmse: 0.516762
# [252]	valid_0's rmse: 0.51695
# [253]	valid_0's rmse: 0.516989
# [254]	valid_0's rmse: 0.516757
# [255]	valid_0's rmse: 0.517005
# [256]	valid_0's rmse: 0.517062
# [257]	valid_0's rmse: 0.516957
# [258]	valid_0's rmse: 0.516828
# [259]	valid_0's rmse: 0.51691
# [260]	valid_0's rmse: 0.517001
# [261]	valid_0's rmse: 0.517036
# [262]	valid_0's rmse: 0.517014
# [263]	valid_0's rmse: 0.516738
# [264]	valid_0's rmse: 0.516597
# [265]	valid_0's rmse: 0.516393
# [266]	valid_0's rmse: 0.516379
# [267]	valid_0's rmse: 0.516512
# [268]	valid_0's rmse: 0.516605
# [269]	valid_0's rmse: 0.516723
# [270]	valid_0's rmse: 0.516393
# [271]	valid_0's rmse: 0.516353
# [272]	valid_0's rmse: 0.516198
# [273]	valid_0's rmse: 0.516228
# [274]	valid_0's rmse: 0.516124
# [275]	valid_0's rmse: 0.516065
# [276]	valid_0's rmse: 0.515936
# [277]	valid_0's rmse: 0.516317
# [278]	valid_0's rmse: 0.516632
# [279]	valid_0's rmse: 0.516724
# [280]	valid_0's rmse: 0.516732
# [281]	valid_0's rmse: 0.516891
# [282]	valid_0's rmse: 0.516743
# [283]	valid_0's rmse: 0.516799
# [284]	valid_0's rmse: 0.516805
# [285]	valid_0's rmse: 0.516897
# [286]	valid_0's rmse: 0.517139
# [287]	valid_0's rmse: 0.51705
# [288]	valid_0's rmse: 0.517018
# [289]	valid_0's rmse: 0.517143
# [290]	valid_0's rmse: 0.517279
# [291]	valid_0's rmse: 0.517259
# [292]	valid_0's rmse: 0.517117
# [293]	valid_0's rmse: 0.517231
# [294]	valid_0's rmse: 0.517313
# [295]	valid_0's rmse: 0.517262
# [296]	valid_0's rmse: 0.517106
# [297]	valid_0's rmse: 0.517214
# [298]	valid_0's rmse: 0.51725
# [299]	valid_0's rmse: 0.517376
# [300]	valid_0's rmse: 0.51752
# [301]	valid_0's rmse: 0.517504
# [302]	valid_0's rmse: 0.517708
# [303]	valid_0's rmse: 0.517614
# [304]	valid_0's rmse: 0.51753
# [305]	valid_0's rmse: 0.517593
# [306]	valid_0's rmse: 0.51774
# [307]	valid_0's rmse: 0.517714
# [308]	valid_0's rmse: 0.5176
# [309]	valid_0's rmse: 0.517429
# [310]	valid_0's rmse: 0.517675
# [311]	valid_0's rmse: 0.517633
# [312]	valid_0's rmse: 0.517563
# [313]	valid_0's rmse: 0.51756
# [314]	valid_0's rmse: 0.51745
# [315]	valid_0's rmse: 0.517634
# [316]	valid_0's rmse: 0.517511
# [317]	valid_0's rmse: 0.517622
# [318]	valid_0's rmse: 0.517502
# [319]	valid_0's rmse: 0.517218
# [320]	valid_0's rmse: 0.517107
# [321]	valid_0's rmse: 0.517134
# [322]	valid_0's rmse: 0.516907
# [323]	valid_0's rmse: 0.516825
# [324]	valid_0's rmse: 0.516709
# [325]	valid_0's rmse: 0.517001
# [326]	valid_0's rmse: 0.517018
# [327]	valid_0's rmse: 0.516982
# [328]	valid_0's rmse: 0.517075
# [329]	valid_0's rmse: 0.516889
# [330]	valid_0's rmse: 0.516735
# [331]	valid_0's rmse: 0.516824
# [332]	valid_0's rmse: 0.516694
# [333]	valid_0's rmse: 0.516469
# [334]	valid_0's rmse: 0.51646
# [335]	valid_0's rmse: 0.516594
# [336]	valid_0's rmse: 0.516646
# [337]	valid_0's rmse: 0.516864
# [338]	valid_0's rmse: 0.516731
# [339]	valid_0's rmse: 0.516562
# [340]	valid_0's rmse: 0.516506
# [341]	valid_0's rmse: 0.51668
# [342]	valid_0's rmse: 0.516878
# [343]	valid_0's rmse: 0.51698
# [344]	valid_0's rmse: 0.517037
# [345]	valid_0's rmse: 0.516997
# [346]	valid_0's rmse: 0.517147
# [347]	valid_0's rmse: 0.516925
# [348]	valid_0's rmse: 0.517287
# [349]	valid_0's rmse: 0.517151
# [350]	valid_0's rmse: 0.517169
# [351]	valid_0's rmse: 0.517276
# [352]	valid_0's rmse: 0.517282
# [353]	valid_0's rmse: 0.517304
# [354]	valid_0's rmse: 0.517261
# [355]	valid_0's rmse: 0.517067
# [356]	valid_0's rmse: 0.51718
# [357]	valid_0's rmse: 0.517284
# [358]	valid_0's rmse: 0.517368
# [359]	valid_0's rmse: 0.517242
# [360]	valid_0's rmse: 0.517096
# [361]	valid_0's rmse: 0.517153
# [362]	valid_0's rmse: 0.517011
# [363]	valid_0's rmse: 0.517125
# [364]	valid_0's rmse: 0.516919
# [365]	valid_0's rmse: 0.516867
# [366]	valid_0's rmse: 0.516872
# [367]	valid_0's rmse: 0.517036
# [368]	valid_0's rmse: 0.516896
# [369]	valid_0's rmse: 0.51677
# [370]	valid_0's rmse: 0.51683
# [371]	valid_0's rmse: 0.516744
# [372]	valid_0's rmse: 0.516532
# [373]	valid_0's rmse: 0.516602
# [374]	valid_0's rmse: 0.516435
# [375]	valid_0's rmse: 0.516642
# [376]	valid_0's rmse: 0.516658
# [377]	valid_0's rmse: 0.516661
# [378]	valid_0's rmse: 0.516807
# [379]	valid_0's rmse: 0.516777
# [380]	valid_0's rmse: 0.516891
# [381]	valid_0's rmse: 0.516729
# [382]	valid_0's rmse: 0.516658
# [383]	valid_0's rmse: 0.51676
# [384]	valid_0's rmse: 0.516706
# [385]	valid_0's rmse: 0.516746
# [386]	valid_0's rmse: 0.516829
# [387]	valid_0's rmse: 0.517051
# [388]	valid_0's rmse: 0.517137
# [389]	valid_0's rmse: 0.517062
# [390]	valid_0's rmse: 0.517024
# [391]	valid_0's rmse: 0.517092
# [392]	valid_0's rmse: 0.517033
# [393]	valid_0's rmse: 0.517362
# [394]	valid_0's rmse: 0.517296
# [395]	valid_0's rmse: 0.51713
# [396]	valid_0's rmse: 0.516939
# [397]	valid_0's rmse: 0.516914
# [398]	valid_0's rmse: 0.516876
# [399]	valid_0's rmse: 0.516535
# [400]	valid_0's rmse: 0.51656
# [401]	valid_0's rmse: 0.516723
# [402]	valid_0's rmse: 0.516699
# [403]	valid_0's rmse: 0.516571
# [404]	valid_0's rmse: 0.516556
# [405]	valid_0's rmse: 0.516664
# [406]	valid_0's rmse: 0.516834
# [407]	valid_0's rmse: 0.516753
# [408]	valid_0's rmse: 0.516689
# [409]	valid_0's rmse: 0.516672
# [410]	valid_0's rmse: 0.516533
# [411]	valid_0's rmse: 0.516589
# [412]	valid_0's rmse: 0.516864
# [413]	valid_0's rmse: 0.516889
# [414]	valid_0's rmse: 0.516983
# [415]	valid_0's rmse: 0.516833
# [416]	valid_0's rmse: 0.51692
# [417]	valid_0's rmse: 0.516969
# [418]	valid_0's rmse: 0.517255
# [419]	valid_0's rmse: 0.517187
# [420]	valid_0's rmse: 0.517243
# [421]	valid_0's rmse: 0.517045
# [422]	valid_0's rmse: 0.516935
# [423]	valid_0's rmse: 0.517008
# [424]	valid_0's rmse: 0.516885
# [425]	valid_0's rmse: 0.516937
# [426]	valid_0's rmse: 0.5172
# [427]	valid_0's rmse: 0.517454
# [428]	valid_0's rmse: 0.517622
# [429]	valid_0's rmse: 0.517764
# [430]	valid_0's rmse: 0.517929
# [431]	valid_0's rmse: 0.518028
# [432]	valid_0's rmse: 0.518036
# [433]	valid_0's rmse: 0.518143
# [434]	valid_0's rmse: 0.517974
# [435]	valid_0's rmse: 0.51795
# [436]	valid_0's rmse: 0.518012
# [437]	valid_0's rmse: 0.517811
# [438]	valid_0's rmse: 0.517786
# [439]	valid_0's rmse: 0.517649
# [440]	valid_0's rmse: 0.517882
# [441]	valid_0's rmse: 0.517729
# [442]	valid_0's rmse: 0.517697
# [443]	valid_0's rmse: 0.517923
# [444]	valid_0's rmse: 0.518052
# [445]	valid_0's rmse: 0.518071
# [446]	valid_0's rmse: 0.518293
# [447]	valid_0's rmse: 0.518357
# [448]	valid_0's rmse: 0.518598
# [449]	valid_0's rmse: 0.51823
# [450]	valid_0's rmse: 0.518245
# [451]	valid_0's rmse: 0.518203
# [452]	valid_0's rmse: 0.518345
# [453]	valid_0's rmse: 0.518439
# [454]	valid_0's rmse: 0.51837
# [455]	valid_0's rmse: 0.518256
# [456]	valid_0's rmse: 0.518381
# [457]	valid_0's rmse: 0.51825
# [458]	valid_0's rmse: 0.518421
# [459]	valid_0's rmse: 0.518379
# [460]	valid_0's rmse: 0.518229
# [461]	valid_0's rmse: 0.518192
# [462]	valid_0's rmse: 0.518231
# [463]	valid_0's rmse: 0.518351
# [464]	valid_0's rmse: 0.518294
# [465]	valid_0's rmse: 0.518165
# [466]	valid_0's rmse: 0.51829
# [467]	valid_0's rmse: 0.518396
# [468]	valid_0's rmse: 0.518311
# [469]	valid_0's rmse: 0.518683
# [470]	valid_0's rmse: 0.518641
# [471]	valid_0's rmse: 0.518562
# [472]	valid_0's rmse: 0.518353
# [473]	valid_0's rmse: 0.518294
# [474]	valid_0's rmse: 0.518209
# [475]	valid_0's rmse: 0.518077
# [476]	valid_0's rmse: 0.518123
# Fold RMSE Score :  0.5159360141965132
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  2
# Trian : (2224, 722) (2224, 1)
# Valid : (247, 722) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.03053
# [2]	valid_0's rmse: 1.02067
# [3]	valid_0's rmse: 1.01101
# [4]	valid_0's rmse: 1.00204
# [5]	valid_0's rmse: 0.992636
# [6]	valid_0's rmse: 0.984135
# [7]	valid_0's rmse: 0.976102
# [8]	valid_0's rmse: 0.967525
# [9]	valid_0's rmse: 0.959797
# [10]	valid_0's rmse: 0.951309
# [11]	valid_0's rmse: 0.944218
# [12]	valid_0's rmse: 0.936417
# [13]	valid_0's rmse: 0.92889
# [14]	valid_0's rmse: 0.922087
# [15]	valid_0's rmse: 0.915414
# [16]	valid_0's rmse: 0.908523
# [17]	valid_0's rmse: 0.901793
# [18]	valid_0's rmse: 0.895028
# [19]	valid_0's rmse: 0.888705
# [20]	valid_0's rmse: 0.882648
# [21]	valid_0's rmse: 0.876743
# [22]	valid_0's rmse: 0.870886
# [23]	valid_0's rmse: 0.865327
# [24]	valid_0's rmse: 0.859489
# [25]	valid_0's rmse: 0.853799
# [26]	valid_0's rmse: 0.848668
# [27]	valid_0's rmse: 0.844141
# [28]	valid_0's rmse: 0.839849
# [29]	valid_0's rmse: 0.834657
# [30]	valid_0's rmse: 0.829996
# [31]	valid_0's rmse: 0.825942
# [32]	valid_0's rmse: 0.821688
# [33]	valid_0's rmse: 0.817388
# [34]	valid_0's rmse: 0.813394
# [35]	valid_0's rmse: 0.808912
# [36]	valid_0's rmse: 0.804901
# [37]	valid_0's rmse: 0.800981
# [38]	valid_0's rmse: 0.797173
# [39]	valid_0's rmse: 0.793545
# [40]	valid_0's rmse: 0.789445
# [41]	valid_0's rmse: 0.785682
# [42]	valid_0's rmse: 0.782476
# [43]	valid_0's rmse: 0.779849
# [44]	valid_0's rmse: 0.776685
# [45]	valid_0's rmse: 0.773634
# [46]	valid_0's rmse: 0.77094
# [47]	valid_0's rmse: 0.767937
# [48]	valid_0's rmse: 0.765219
# [49]	valid_0's rmse: 0.76251
# [50]	valid_0's rmse: 0.759986
# [51]	valid_0's rmse: 0.757513
# [52]	valid_0's rmse: 0.75462
# [53]	valid_0's rmse: 0.752326
# [54]	valid_0's rmse: 0.75028
# [55]	valid_0's rmse: 0.7481
# [56]	valid_0's rmse: 0.746065
# [57]	valid_0's rmse: 0.743852
# [58]	valid_0's rmse: 0.742318
# [59]	valid_0's rmse: 0.740209
# [60]	valid_0's rmse: 0.738885
# [61]	valid_0's rmse: 0.737029
# [62]	valid_0's rmse: 0.735133
# [63]	valid_0's rmse: 0.733319
# [64]	valid_0's rmse: 0.731641
# [65]	valid_0's rmse: 0.73014
# [66]	valid_0's rmse: 0.728846
# [67]	valid_0's rmse: 0.727409
# [68]	valid_0's rmse: 0.726159
# [69]	valid_0's rmse: 0.724535
# [70]	valid_0's rmse: 0.722794
# [71]	valid_0's rmse: 0.721275
# [72]	valid_0's rmse: 0.719651
# [73]	valid_0's rmse: 0.718326
# [74]	valid_0's rmse: 0.717145
# [75]	valid_0's rmse: 0.715911
# [76]	valid_0's rmse: 0.714503
# [77]	valid_0's rmse: 0.713807
# [78]	valid_0's rmse: 0.712787
# [79]	valid_0's rmse: 0.711504
# [80]	valid_0's rmse: 0.710399
# [81]	valid_0's rmse: 0.709505
# [82]	valid_0's rmse: 0.709071
# [83]	valid_0's rmse: 0.707685
# [84]	valid_0's rmse: 0.706472
# [85]	valid_0's rmse: 0.705379
# [86]	valid_0's rmse: 0.704277
# [87]	valid_0's rmse: 0.703334
# [88]	valid_0's rmse: 0.702535
# [89]	valid_0's rmse: 0.701415
# [90]	valid_0's rmse: 0.700087
# [91]	valid_0's rmse: 0.699232
# [92]	valid_0's rmse: 0.698352
# [93]	valid_0's rmse: 0.697639
# [94]	valid_0's rmse: 0.697218
# [95]	valid_0's rmse: 0.696321
# [96]	valid_0's rmse: 0.695611
# [97]	valid_0's rmse: 0.694662
# [98]	valid_0's rmse: 0.694406
# [99]	valid_0's rmse: 0.693565
# [100]	valid_0's rmse: 0.693016
# [101]	valid_0's rmse: 0.691878
# [102]	valid_0's rmse: 0.69126
# [103]	valid_0's rmse: 0.69051
# [104]	valid_0's rmse: 0.690339
# [105]	valid_0's rmse: 0.689989
# [106]	valid_0's rmse: 0.689307
# [107]	valid_0's rmse: 0.688643
# [108]	valid_0's rmse: 0.68833
# [109]	valid_0's rmse: 0.687799
# [110]	valid_0's rmse: 0.686966
# [111]	valid_0's rmse: 0.686525
# [112]	valid_0's rmse: 0.6859
# [113]	valid_0's rmse: 0.685268
# [114]	valid_0's rmse: 0.684877
# [115]	valid_0's rmse: 0.684269
# [116]	valid_0's rmse: 0.684073
# [117]	valid_0's rmse: 0.683714
# [118]	valid_0's rmse: 0.683632
# [119]	valid_0's rmse: 0.683427
# [120]	valid_0's rmse: 0.683172
# [121]	valid_0's rmse: 0.683044
# [122]	valid_0's rmse: 0.682635
# [123]	valid_0's rmse: 0.68212
# [124]	valid_0's rmse: 0.681657
# [125]	valid_0's rmse: 0.681217
# [126]	valid_0's rmse: 0.681074
# [127]	valid_0's rmse: 0.680934
# [128]	valid_0's rmse: 0.680577
# [129]	valid_0's rmse: 0.680034
# [130]	valid_0's rmse: 0.679518
# [131]	valid_0's rmse: 0.67934
# [132]	valid_0's rmse: 0.679058
# [133]	valid_0's rmse: 0.678692
# [134]	valid_0's rmse: 0.678651
# [135]	valid_0's rmse: 0.678589
# [136]	valid_0's rmse: 0.67854
# [137]	valid_0's rmse: 0.678197
# [138]	valid_0's rmse: 0.677849
# [139]	valid_0's rmse: 0.678147
# [140]	valid_0's rmse: 0.678034
# [141]	valid_0's rmse: 0.67779
# [142]	valid_0's rmse: 0.677694
# [143]	valid_0's rmse: 0.67753
# [144]	valid_0's rmse: 0.677297
# [145]	valid_0's rmse: 0.677313
# [146]	valid_0's rmse: 0.677271
# [147]	valid_0's rmse: 0.677175
# [148]	valid_0's rmse: 0.677107
# [149]	valid_0's rmse: 0.677177
# [150]	valid_0's rmse: 0.676874
# [151]	valid_0's rmse: 0.676464
# [152]	valid_0's rmse: 0.676337
# [153]	valid_0's rmse: 0.676232
# [154]	valid_0's rmse: 0.676116
# [155]	valid_0's rmse: 0.676256
# [156]	valid_0's rmse: 0.675956
# [157]	valid_0's rmse: 0.675771
# [158]	valid_0's rmse: 0.675522
# [159]	valid_0's rmse: 0.675805
# [160]	valid_0's rmse: 0.675917
# [161]	valid_0's rmse: 0.675678
# [162]	valid_0's rmse: 0.675436
# [163]	valid_0's rmse: 0.675339
# [164]	valid_0's rmse: 0.6752
# [165]	valid_0's rmse: 0.67511
# [166]	valid_0's rmse: 0.675222
# [167]	valid_0's rmse: 0.675199
# [168]	valid_0's rmse: 0.67518
# [169]	valid_0's rmse: 0.675052
# [170]	valid_0's rmse: 0.675002
# [171]	valid_0's rmse: 0.674717
# [172]	valid_0's rmse: 0.674603
# [173]	valid_0's rmse: 0.674746
# [174]	valid_0's rmse: 0.674729
# [175]	valid_0's rmse: 0.674802
# [176]	valid_0's rmse: 0.674601
# [177]	valid_0's rmse: 0.674579
# [178]	valid_0's rmse: 0.674526
# [179]	valid_0's rmse: 0.67449
# [180]	valid_0's rmse: 0.674333
# [181]	valid_0's rmse: 0.674359
# [182]	valid_0's rmse: 0.67421
# [183]	valid_0's rmse: 0.674546
# [184]	valid_0's rmse: 0.67434
# [185]	valid_0's rmse: 0.674416
# [186]	valid_0's rmse: 0.67443
# [187]	valid_0's rmse: 0.674291
# [188]	valid_0's rmse: 0.674376
# [189]	valid_0's rmse: 0.67426
# [190]	valid_0's rmse: 0.674286
# [191]	valid_0's rmse: 0.674177
# [192]	valid_0's rmse: 0.67414
# [193]	valid_0's rmse: 0.674092
# [194]	valid_0's rmse: 0.674156
# [195]	valid_0's rmse: 0.673993
# [196]	valid_0's rmse: 0.673918
# [197]	valid_0's rmse: 0.674015
# [198]	valid_0's rmse: 0.67419
# [199]	valid_0's rmse: 0.674121
# [200]	valid_0's rmse: 0.674214
# [201]	valid_0's rmse: 0.674274
# [202]	valid_0's rmse: 0.674498
# [203]	valid_0's rmse: 0.674372
# [204]	valid_0's rmse: 0.674494
# [205]	valid_0's rmse: 0.674563
# [206]	valid_0's rmse: 0.674399
# [207]	valid_0's rmse: 0.674564
# [208]	valid_0's rmse: 0.674429
# [209]	valid_0's rmse: 0.674541
# [210]	valid_0's rmse: 0.674311
# [211]	valid_0's rmse: 0.67446
# [212]	valid_0's rmse: 0.674237
# [213]	valid_0's rmse: 0.674472
# [214]	valid_0's rmse: 0.67436
# [215]	valid_0's rmse: 0.674223
# [216]	valid_0's rmse: 0.674095
# [217]	valid_0's rmse: 0.674024
# [218]	valid_0's rmse: 0.67388
# [219]	valid_0's rmse: 0.673946
# [220]	valid_0's rmse: 0.674118
# [221]	valid_0's rmse: 0.674158
# [222]	valid_0's rmse: 0.674051
# [223]	valid_0's rmse: 0.674013
# [224]	valid_0's rmse: 0.674232
# [225]	valid_0's rmse: 0.67437
# [226]	valid_0's rmse: 0.674285
# [227]	valid_0's rmse: 0.674257
# [228]	valid_0's rmse: 0.674532
# [229]	valid_0's rmse: 0.674497
# [230]	valid_0's rmse: 0.674256
# [231]	valid_0's rmse: 0.674332
# [232]	valid_0's rmse: 0.674341
# [233]	valid_0's rmse: 0.674434
# [234]	valid_0's rmse: 0.674245
# [235]	valid_0's rmse: 0.673995
# [236]	valid_0's rmse: 0.673986
# [237]	valid_0's rmse: 0.673817
# [238]	valid_0's rmse: 0.673711
# [239]	valid_0's rmse: 0.673576
# [240]	valid_0's rmse: 0.673578
# [241]	valid_0's rmse: 0.673705
# [242]	valid_0's rmse: 0.673687
# [243]	valid_0's rmse: 0.673636
# [244]	valid_0's rmse: 0.673754
# [245]	valid_0's rmse: 0.673699
# [246]	valid_0's rmse: 0.67373
# [247]	valid_0's rmse: 0.673518
# [248]	valid_0's rmse: 0.673545
# [249]	valid_0's rmse: 0.673213
# [250]	valid_0's rmse: 0.673104
# [251]	valid_0's rmse: 0.673282
# [252]	valid_0's rmse: 0.673346
# [253]	valid_0's rmse: 0.673236
# [254]	valid_0's rmse: 0.673163
# [255]	valid_0's rmse: 0.673374
# [256]	valid_0's rmse: 0.673383
# [257]	valid_0's rmse: 0.673421
# [258]	valid_0's rmse: 0.673645
# [259]	valid_0's rmse: 0.673289
# [260]	valid_0's rmse: 0.673111
# [261]	valid_0's rmse: 0.673181
# [262]	valid_0's rmse: 0.673459
# [263]	valid_0's rmse: 0.673255
# [264]	valid_0's rmse: 0.673345
# [265]	valid_0's rmse: 0.673555
# [266]	valid_0's rmse: 0.673302
# [267]	valid_0's rmse: 0.673568
# [268]	valid_0's rmse: 0.673555
# [269]	valid_0's rmse: 0.673512
# [270]	valid_0's rmse: 0.673433
# [271]	valid_0's rmse: 0.673406
# [272]	valid_0's rmse: 0.673481
# [273]	valid_0's rmse: 0.673604
# [274]	valid_0's rmse: 0.67354
# [275]	valid_0's rmse: 0.673601
# [276]	valid_0's rmse: 0.673677
# [277]	valid_0's rmse: 0.67339
# [278]	valid_0's rmse: 0.673357
# [279]	valid_0's rmse: 0.673531
# [280]	valid_0's rmse: 0.673632
# [281]	valid_0's rmse: 0.673638
# [282]	valid_0's rmse: 0.673657
# [283]	valid_0's rmse: 0.67388
# [284]	valid_0's rmse: 0.673698
# [285]	valid_0's rmse: 0.673637
# [286]	valid_0's rmse: 0.673669
# [287]	valid_0's rmse: 0.673475
# [288]	valid_0's rmse: 0.673386
# [289]	valid_0's rmse: 0.673657
# [290]	valid_0's rmse: 0.673731
# [291]	valid_0's rmse: 0.673688
# [292]	valid_0's rmse: 0.673413
# [293]	valid_0's rmse: 0.673647
# [294]	valid_0's rmse: 0.673852
# [295]	valid_0's rmse: 0.673658
# [296]	valid_0's rmse: 0.673882
# [297]	valid_0's rmse: 0.673911
# [298]	valid_0's rmse: 0.67394
# [299]	valid_0's rmse: 0.674201
# [300]	valid_0's rmse: 0.67413
# [301]	valid_0's rmse: 0.674093
# [302]	valid_0's rmse: 0.673635
# [303]	valid_0's rmse: 0.673623
# [304]	valid_0's rmse: 0.673553
# [305]	valid_0's rmse: 0.673742
# [306]	valid_0's rmse: 0.673646
# [307]	valid_0's rmse: 0.673541
# [308]	valid_0's rmse: 0.673422
# [309]	valid_0's rmse: 0.673408
# [310]	valid_0's rmse: 0.673305
# [311]	valid_0's rmse: 0.673262
# [312]	valid_0's rmse: 0.673122
# [313]	valid_0's rmse: 0.673377
# [314]	valid_0's rmse: 0.673394
# [315]	valid_0's rmse: 0.673273
# [316]	valid_0's rmse: 0.673326
# [317]	valid_0's rmse: 0.673403
# [318]	valid_0's rmse: 0.673373
# [319]	valid_0's rmse: 0.67342
# [320]	valid_0's rmse: 0.673562
# [321]	valid_0's rmse: 0.673571
# [322]	valid_0's rmse: 0.673625
# [323]	valid_0's rmse: 0.673669
# [324]	valid_0's rmse: 0.673708
# [325]	valid_0's rmse: 0.673833
# [326]	valid_0's rmse: 0.6741
# [327]	valid_0's rmse: 0.674047
# [328]	valid_0's rmse: 0.674049
# [329]	valid_0's rmse: 0.674189
# [330]	valid_0's rmse: 0.674271
# [331]	valid_0's rmse: 0.674501
# [332]	valid_0's rmse: 0.674506
# [333]	valid_0's rmse: 0.674244
# [334]	valid_0's rmse: 0.674296
# [335]	valid_0's rmse: 0.674259
# [336]	valid_0's rmse: 0.674243
# [337]	valid_0's rmse: 0.674394
# [338]	valid_0's rmse: 0.674226
# [339]	valid_0's rmse: 0.674119
# [340]	valid_0's rmse: 0.674038
# [341]	valid_0's rmse: 0.674025
# [342]	valid_0's rmse: 0.673839
# [343]	valid_0's rmse: 0.673706
# [344]	valid_0's rmse: 0.673635
# [345]	valid_0's rmse: 0.673729
# [346]	valid_0's rmse: 0.673746
# [347]	valid_0's rmse: 0.673706
# [348]	valid_0's rmse: 0.673928
# [349]	valid_0's rmse: 0.674054
# [350]	valid_0's rmse: 0.674163
# [351]	valid_0's rmse: 0.674172
# [352]	valid_0's rmse: 0.674355
# [353]	valid_0's rmse: 0.674326
# [354]	valid_0's rmse: 0.674315
# [355]	valid_0's rmse: 0.674308
# [356]	valid_0's rmse: 0.674359
# [357]	valid_0's rmse: 0.674446
# [358]	valid_0's rmse: 0.67465
# [359]	valid_0's rmse: 0.67483
# [360]	valid_0's rmse: 0.674776
# [361]	valid_0's rmse: 0.674838
# [362]	valid_0's rmse: 0.674879
# [363]	valid_0's rmse: 0.674739
# [364]	valid_0's rmse: 0.674647
# [365]	valid_0's rmse: 0.674559
# [366]	valid_0's rmse: 0.674607
# [367]	valid_0's rmse: 0.67469
# [368]	valid_0's rmse: 0.674605
# [369]	valid_0's rmse: 0.674647
# [370]	valid_0's rmse: 0.674684
# [371]	valid_0's rmse: 0.674654
# [372]	valid_0's rmse: 0.674839
# [373]	valid_0's rmse: 0.674863
# [374]	valid_0's rmse: 0.674679
# [375]	valid_0's rmse: 0.674558
# [376]	valid_0's rmse: 0.674614
# [377]	valid_0's rmse: 0.674457
# [378]	valid_0's rmse: 0.674523
# [379]	valid_0's rmse: 0.674526
# [380]	valid_0's rmse: 0.674658
# [381]	valid_0's rmse: 0.674799
# [382]	valid_0's rmse: 0.674838
# [383]	valid_0's rmse: 0.675027
# [384]	valid_0's rmse: 0.675026
# [385]	valid_0's rmse: 0.675044
# [386]	valid_0's rmse: 0.675092
# [387]	valid_0's rmse: 0.67526
# [388]	valid_0's rmse: 0.675114
# [389]	valid_0's rmse: 0.675253
# [390]	valid_0's rmse: 0.675493
# [391]	valid_0's rmse: 0.675518
# [392]	valid_0's rmse: 0.675297
# [393]	valid_0's rmse: 0.675029
# [394]	valid_0's rmse: 0.67519
# [395]	valid_0's rmse: 0.675434
# [396]	valid_0's rmse: 0.675617
# [397]	valid_0's rmse: 0.675633
# [398]	valid_0's rmse: 0.675793
# [399]	valid_0's rmse: 0.675745
# [400]	valid_0's rmse: 0.675686
# [401]	valid_0's rmse: 0.675778
# [402]	valid_0's rmse: 0.675771
# [403]	valid_0's rmse: 0.675804
# [404]	valid_0's rmse: 0.675706
# [405]	valid_0's rmse: 0.675805
# [406]	valid_0's rmse: 0.67593
# [407]	valid_0's rmse: 0.675874
# [408]	valid_0's rmse: 0.675883
# [409]	valid_0's rmse: 0.676055
# [410]	valid_0's rmse: 0.676154
# [411]	valid_0's rmse: 0.676328
# [412]	valid_0's rmse: 0.676409
# [413]	valid_0's rmse: 0.676449
# [414]	valid_0's rmse: 0.676671
# [415]	valid_0's rmse: 0.67673
# [416]	valid_0's rmse: 0.676753
# [417]	valid_0's rmse: 0.676738
# [418]	valid_0's rmse: 0.676944
# [419]	valid_0's rmse: 0.677077
# [420]	valid_0's rmse: 0.677128
# [421]	valid_0's rmse: 0.677362
# [422]	valid_0's rmse: 0.677443
# [423]	valid_0's rmse: 0.677379
# [424]	valid_0's rmse: 0.677141
# [425]	valid_0's rmse: 0.677054
# [426]	valid_0's rmse: 0.676963
# [427]	valid_0's rmse: 0.677094
# [428]	valid_0's rmse: 0.677028
# [429]	valid_0's rmse: 0.677227
# [430]	valid_0's rmse: 0.677164
# [431]	valid_0's rmse: 0.677063
# [432]	valid_0's rmse: 0.677081
# [433]	valid_0's rmse: 0.676859
# [434]	valid_0's rmse: 0.676698
# [435]	valid_0's rmse: 0.676914
# [436]	valid_0's rmse: 0.676732
# [437]	valid_0's rmse: 0.676791
# [438]	valid_0's rmse: 0.676855
# [439]	valid_0's rmse: 0.676782
# [440]	valid_0's rmse: 0.676901
# [441]	valid_0's rmse: 0.676797
# [442]	valid_0's rmse: 0.676815
# [443]	valid_0's rmse: 0.676889
# [444]	valid_0's rmse: 0.676966
# [445]	valid_0's rmse: 0.677112
# [446]	valid_0's rmse: 0.677137
# [447]	valid_0's rmse: 0.677077
# [448]	valid_0's rmse: 0.676875
# [449]	valid_0's rmse: 0.676947
# [450]	valid_0's rmse: 0.67694
# Fold RMSE Score :  0.673103638666674
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  3
# Trian : (2224, 722) (2224, 1)
# Valid : (247, 722) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.07594
# [2]	valid_0's rmse: 1.06531
# [3]	valid_0's rmse: 1.05533
# [4]	valid_0's rmse: 1.04577
# [5]	valid_0's rmse: 1.03603
# [6]	valid_0's rmse: 1.02619
# [7]	valid_0's rmse: 1.01744
# [8]	valid_0's rmse: 1.00877
# [9]	valid_0's rmse: 1.00003
# [10]	valid_0's rmse: 0.991645
# [11]	valid_0's rmse: 0.983211
# [12]	valid_0's rmse: 0.975341
# [13]	valid_0's rmse: 0.967153
# [14]	valid_0's rmse: 0.959356
# [15]	valid_0's rmse: 0.951661
# [16]	valid_0's rmse: 0.944738
# [17]	valid_0's rmse: 0.937291
# [18]	valid_0's rmse: 0.929765
# [19]	valid_0's rmse: 0.923502
# [20]	valid_0's rmse: 0.916742
# [21]	valid_0's rmse: 0.910077
# [22]	valid_0's rmse: 0.903208
# [23]	valid_0's rmse: 0.896552
# [24]	valid_0's rmse: 0.890177
# [25]	valid_0's rmse: 0.884186
# [26]	valid_0's rmse: 0.877986
# [27]	valid_0's rmse: 0.872321
# [28]	valid_0's rmse: 0.866947
# [29]	valid_0's rmse: 0.861337
# [30]	valid_0's rmse: 0.855891
# [31]	valid_0's rmse: 0.850611
# [32]	valid_0's rmse: 0.845597
# [33]	valid_0's rmse: 0.841218
# [34]	valid_0's rmse: 0.836527
# [35]	valid_0's rmse: 0.831981
# [36]	valid_0's rmse: 0.827576
# [37]	valid_0's rmse: 0.823172
# [38]	valid_0's rmse: 0.818796
# [39]	valid_0's rmse: 0.814634
# [40]	valid_0's rmse: 0.810785
# [41]	valid_0's rmse: 0.806395
# [42]	valid_0's rmse: 0.802096
# [43]	valid_0's rmse: 0.798438
# [44]	valid_0's rmse: 0.794794
# [45]	valid_0's rmse: 0.79151
# [46]	valid_0's rmse: 0.787719
# [47]	valid_0's rmse: 0.783946
# [48]	valid_0's rmse: 0.78081
# [49]	valid_0's rmse: 0.777548
# [50]	valid_0's rmse: 0.77441
# [51]	valid_0's rmse: 0.771124
# [52]	valid_0's rmse: 0.767965
# [53]	valid_0's rmse: 0.764895
# [54]	valid_0's rmse: 0.761479
# [55]	valid_0's rmse: 0.758101
# [56]	valid_0's rmse: 0.754981
# [57]	valid_0's rmse: 0.752444
# [58]	valid_0's rmse: 0.749594
# [59]	valid_0's rmse: 0.747281
# ...
# [437]	valid_0's rmse: 0.63532
# [438]	valid_0's rmse: 0.635436
# [439]	valid_0's rmse: 0.635164
# [440]	valid_0's rmse: 0.635142
# [441]	valid_0's rmse: 0.635409
# [442]	valid_0's rmse: 0.635351
# [443]	valid_0's rmse: 0.635378
# [444]	valid_0's rmse: 0.635593
# [445]	valid_0's rmse: 0.635623
# [446]	valid_0's rmse: 0.635567
# [447]	valid_0's rmse: 0.635507
# [448]	valid_0's rmse: 0.635628
# [449]	valid_0's rmse: 0.635541
# [450]	valid_0's rmse: 0.63552
# [451]	valid_0's rmse: 0.635598
# [452]	valid_0's rmse: 0.63547
# [453]	valid_0's rmse: 0.63528
# [454]	valid_0's rmse: 0.635221
# [455]	valid_0's rmse: 0.635123
# [456]	valid_0's rmse: 0.635199
# [457]	valid_0's rmse: 0.634993
# [458]	valid_0's rmse: 0.635079
# [459]	valid_0's rmse: 0.635163
# [460]	valid_0's rmse: 0.635158
# [461]	valid_0's rmse: 0.635097
# [462]	valid_0's rmse: 0.634838
# [463]	valid_0's rmse: 0.634813
# [464]	valid_0's rmse: 0.634693
# [465]	valid_0's rmse: 0.63467
# [466]	valid_0's rmse: 0.634575
# [467]	valid_0's rmse: 0.634739
# [468]	valid_0's rmse: 0.634756
# [469]	valid_0's rmse: 0.634685
# [470]	valid_0's rmse: 0.634692
# [471]	valid_0's rmse: 0.634842
# [472]	valid_0's rmse: 0.634905
# [473]	valid_0's rmse: 0.634956
# [474]	valid_0's rmse: 0.634871
# [475]	valid_0's rmse: 0.634963
# [476]	valid_0's rmse: 0.634972
# [477]	valid_0's rmse: 0.635036
# [478]	valid_0's rmse: 0.635114
# [479]	valid_0's rmse: 0.635174
# [480]	valid_0's rmse: 0.634964
# [481]	valid_0's rmse: 0.634902
# [482]	valid_0's rmse: 0.634767
# [483]	valid_0's rmse: 0.634828
# [484]	valid_0's rmse: 0.634903
# [485]	valid_0's rmse: 0.635054
# [486]	valid_0's rmse: 0.634959
# [487]	valid_0's rmse: 0.63489
# [488]	valid_0's rmse: 0.634655
# [489]	valid_0's rmse: 0.63462
# [490]	valid_0's rmse: 0.634653
# [491]	valid_0's rmse: 0.634293
# [492]	valid_0's rmse: 0.634395
# [493]	valid_0's rmse: 0.6346
# [494]	valid_0's rmse: 0.6346
# [495]	valid_0's rmse: 0.634647
# [496]	valid_0's rmse: 0.634597
# [497]	valid_0's rmse: 0.634559
# [498]	valid_0's rmse: 0.634595
# [499]	valid_0's rmse: 0.634564
# [500]	valid_0's rmse: 0.634674
# Fold RMSE Score :  0.6342930428246635
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  9
# Trian : (2224, 722) (2224, 1)
# Valid : (247, 722) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 0.957071
# [2]	valid_0's rmse: 0.94704
# [3]	valid_0's rmse: 0.937088
# [4]	valid_0's rmse: 0.927209
# [5]	valid_0's rmse: 0.917848
# [6]	valid_0's rmse: 0.908422
# [7]	valid_0's rmse: 0.900354
# [8]	valid_0's rmse: 0.891958
# [9]	valid_0's rmse: 0.883345
# [10]	valid_0's rmse: 0.874988
# [11]	valid_0's rmse: 0.867067
# [12]	valid_0's rmse: 0.858865
# [13]	valid_0's rmse: 0.850775
# [14]	valid_0's rmse: 0.842544
# [15]	valid_0's rmse: 0.834904
# [16]	valid_0's rmse: 0.827576
# [17]	valid_0's rmse: 0.820666
# [18]	valid_0's rmse: 0.813487
# [19]	valid_0's rmse: 0.806877
# [20]	valid_0's rmse: 0.800204
# [21]	valid_0's rmse: 0.793778
# [22]	valid_0's rmse: 0.787448
# [23]	valid_0's rmse: 0.781271
# [24]	valid_0's rmse: 0.775141
# [25]	valid_0's rmse: 0.769773
# [26]	valid_0's rmse: 0.763888
# [27]	valid_0's rmse: 0.758932
# [28]	valid_0's rmse: 0.753417
# [29]	valid_0's rmse: 0.748182
# [30]	valid_0's rmse: 0.743067
# [31]	valid_0's rmse: 0.738389
# [32]	valid_0's rmse: 0.733381
# [33]	valid_0's rmse: 0.728862
# [34]	valid_0's rmse: 0.724427
# [35]	valid_0's rmse: 0.719862
# [36]	valid_0's rmse: 0.715165
# [37]	valid_0's rmse: 0.710888
# [38]	valid_0's rmse: 0.706959
# [39]	valid_0's rmse: 0.703091
# [40]	valid_0's rmse: 0.698993
# [41]	valid_0's rmse: 0.695506
# [42]	valid_0's rmse: 0.692108
# [43]	valid_0's rmse: 0.6883
# [44]	valid_0's rmse: 0.684791
# [45]	valid_0's rmse: 0.68145
# [46]	valid_0's rmse: 0.677822
# [47]	valid_0's rmse: 0.6747
# [48]	valid_0's rmse: 0.671834
# [49]	valid_0's rmse: 0.66903
# [50]	valid_0's rmse: 0.665459
# [51]	valid_0's rmse: 0.662235
# [52]	valid_0's rmse: 0.659406
# [53]	valid_0's rmse: 0.656786
# [54]	valid_0's rmse: 0.654069
# [55]	valid_0's rmse: 0.651276
# [56]	valid_0's rmse: 0.648739
# [57]	valid_0's rmse: 0.646512
# [58]	valid_0's rmse: 0.644098
# [59]	valid_0's rmse: 0.641802
# [60]	valid_0's rmse: 0.639688
# [61]	valid_0's rmse: 0.637232
# [62]	valid_0's rmse: 0.635381
# [63]	valid_0's rmse: 0.633599
# [64]	valid_0's rmse: 0.63137
# [65]	valid_0's rmse: 0.629273
# [66]	valid_0's rmse: 0.62694
# [67]	valid_0's rmse: 0.625286
# [68]	valid_0's rmse: 0.623459
# [69]	valid_0's rmse: 0.621419
# [70]	valid_0's rmse: 0.619275
# [71]	valid_0's rmse: 0.617574
# [72]	valid_0's rmse: 0.615855
# [73]	valid_0's rmse: 0.614132
# [74]	valid_0's rmse: 0.612734
# [75]	valid_0's rmse: 0.611258
# [76]	valid_0's rmse: 0.609885
# [77]	valid_0's rmse: 0.608152
# [78]	valid_0's rmse: 0.606774
# [79]	valid_0's rmse: 0.605436
# [80]	valid_0's rmse: 0.604019
# [81]	valid_0's rmse: 0.602415
# [82]	valid_0's rmse: 0.601019
# [83]	valid_0's rmse: 0.599822
# [84]	valid_0's rmse: 0.598849
# [85]	valid_0's rmse: 0.597852
# [86]	valid_0's rmse: 0.59679
# [87]	valid_0's rmse: 0.595723
# [88]	valid_0's rmse: 0.594703
# [89]	valid_0's rmse: 0.593678
# [90]	valid_0's rmse: 0.592912
# [91]	valid_0's rmse: 0.591815
# [92]	valid_0's rmse: 0.590625
# [93]	valid_0's rmse: 0.589762
# [94]	valid_0's rmse: 0.589053
# [95]	valid_0's rmse: 0.588501
# [96]	valid_0's rmse: 0.58766
# [97]	valid_0's rmse: 0.586747
# [98]	valid_0's rmse: 0.586266
# [99]	valid_0's rmse: 0.585649
# [100]	valid_0's rmse: 0.584784
# [101]	valid_0's rmse: 0.584105
# [102]	valid_0's rmse: 0.583724
# [103]	valid_0's rmse: 0.582971
# [104]	valid_0's rmse: 0.581969
# [105]	valid_0's rmse: 0.581431
# [106]	valid_0's rmse: 0.580661
# [107]	valid_0's rmse: 0.579845
# [108]	valid_0's rmse: 0.579111
# [109]	valid_0's rmse: 0.578848
# [110]	valid_0's rmse: 0.578414
# [111]	valid_0's rmse: 0.578008
# [112]	valid_0's rmse: 0.577596
# [113]	valid_0's rmse: 0.576881
# [114]	valid_0's rmse: 0.576762
# [115]	valid_0's rmse: 0.576336
# [116]	valid_0's rmse: 0.57592
# [117]	valid_0's rmse: 0.575355
# [118]	valid_0's rmse: 0.575166
# [119]	valid_0's rmse: 0.574665
# [120]	valid_0's rmse: 0.574144
# [121]	valid_0's rmse: 0.573778
# [122]	valid_0's rmse: 0.573366
# [123]	valid_0's rmse: 0.572905
# [124]	valid_0's rmse: 0.572598
# [125]	valid_0's rmse: 0.572181
# [126]	valid_0's rmse: 0.571933
# [127]	valid_0's rmse: 0.571672
# [128]	valid_0's rmse: 0.571581
# [129]	valid_0's rmse: 0.571484
# [130]	valid_0's rmse: 0.570917
# [131]	valid_0's rmse: 0.570461
# [132]	valid_0's rmse: 0.56997
# [133]	valid_0's rmse: 0.56969
# [134]	valid_0's rmse: 0.569394
# [135]	valid_0's rmse: 0.568961
# [136]	valid_0's rmse: 0.568701
# [137]	valid_0's rmse: 0.568193
# [138]	valid_0's rmse: 0.567742
# [139]	valid_0's rmse: 0.567293
# [140]	valid_0's rmse: 0.567184
# [141]	valid_0's rmse: 0.566946
# [142]	valid_0's rmse: 0.566732
# [143]	valid_0's rmse: 0.566585
# [144]	valid_0's rmse: 0.566446
# [145]	valid_0's rmse: 0.566156
# [146]	valid_0's rmse: 0.56621
# [147]	valid_0's rmse: 0.566046
# [148]	valid_0's rmse: 0.565981
# [149]	valid_0's rmse: 0.565672
# [150]	valid_0's rmse: 0.56566
# [151]	valid_0's rmse: 0.565442
# [152]	valid_0's rmse: 0.565224
# [153]	valid_0's rmse: 0.565119
# [154]	valid_0's rmse: 0.565011
# [155]	valid_0's rmse: 0.564886
# [156]	valid_0's rmse: 0.564404
# [157]	valid_0's rmse: 0.564331
# [158]	valid_0's rmse: 0.564302
# [159]	valid_0's rmse: 0.564107
# [160]	valid_0's rmse: 0.564354
# [161]	valid_0's rmse: 0.564126
# [162]	valid_0's rmse: 0.564139
# [163]	valid_0's rmse: 0.564005
# [164]	valid_0's rmse: 0.563722
# [165]	valid_0's rmse: 0.563495
# [166]	valid_0's rmse: 0.563493
# [167]	valid_0's rmse: 0.563527
# [168]	valid_0's rmse: 0.563459
# [169]	valid_0's rmse: 0.563336
# [170]	valid_0's rmse: 0.563395
# [171]	valid_0's rmse: 0.563148
# [172]	valid_0's rmse: 0.562809
# [173]	valid_0's rmse: 0.562543
# [174]	valid_0's rmse: 0.562462
# [175]	valid_0's rmse: 0.562342
# [176]	valid_0's rmse: 0.562509
# [177]	valid_0's rmse: 0.562659
# [178]	valid_0's rmse: 0.562517
# [179]	valid_0's rmse: 0.56236
# [180]	valid_0's rmse: 0.562144
# [181]	valid_0's rmse: 0.561992
# [182]	valid_0's rmse: 0.562046
# [183]	valid_0's rmse: 0.562022
# [184]	valid_0's rmse: 0.562284
# [185]	valid_0's rmse: 0.561896
# [186]	valid_0's rmse: 0.561849
# [187]	valid_0's rmse: 0.561536
# [188]	valid_0's rmse: 0.561468
# [189]	valid_0's rmse: 0.560985
# [190]	valid_0's rmse: 0.560969
# [191]	valid_0's rmse: 0.560434
# [192]	valid_0's rmse: 0.560202
# [193]	valid_0's rmse: 0.560296
# [194]	valid_0's rmse: 0.560453
# [195]	valid_0's rmse: 0.560542
# [196]	valid_0's rmse: 0.560911
# [197]	valid_0's rmse: 0.56102
# [198]	valid_0's rmse: 0.56112
# [199]	valid_0's rmse: 0.56086
# [200]	valid_0's rmse: 0.560955
# [201]	valid_0's rmse: 0.561103
# [202]	valid_0's rmse: 0.561206
# [203]	valid_0's rmse: 0.561258
# [204]	valid_0's rmse: 0.561189
# [205]	valid_0's rmse: 0.561087
# [206]	valid_0's rmse: 0.561112
# [207]	valid_0's rmse: 0.560952
# [208]	valid_0's rmse: 0.561021
# [209]	valid_0's rmse: 0.56077
# [210]	valid_0's rmse: 0.560499
# [211]	valid_0's rmse: 0.560281
# [212]	valid_0's rmse: 0.560323
# [213]	valid_0's rmse: 0.560346
# [214]	valid_0's rmse: 0.560371
# [215]	valid_0's rmse: 0.560415
# [216]	valid_0's rmse: 0.560315
# [217]	valid_0's rmse: 0.560271
# [218]	valid_0's rmse: 0.560146
# [219]	valid_0's rmse: 0.559773
# [220]	valid_0's rmse: 0.559853
# [221]	valid_0's rmse: 0.559589
# [222]	valid_0's rmse: 0.559656
# [223]	valid_0's rmse: 0.559696
# [224]	valid_0's rmse: 0.559778
# [225]	valid_0's rmse: 0.559855
# [226]	valid_0's rmse: 0.559542
# [227]	valid_0's rmse: 0.559323
# [228]	valid_0's rmse: 0.559326
# [229]	valid_0's rmse: 0.559489
# [230]	valid_0's rmse: 0.559256
# [231]	valid_0's rmse: 0.559201
# [232]	valid_0's rmse: 0.559104
# [233]	valid_0's rmse: 0.559113
# [234]	valid_0's rmse: 0.558921
# [235]	valid_0's rmse: 0.559018
# [236]	valid_0's rmse: 0.559325
# [237]	valid_0's rmse: 0.559246
# [238]	valid_0's rmse: 0.559208
# [239]	valid_0's rmse: 0.55943
# [240]	valid_0's rmse: 0.559223
# [241]	valid_0's rmse: 0.559174
# [242]	valid_0's rmse: 0.559236
# [243]	valid_0's rmse: 0.559461
# [244]	valid_0's rmse: 0.559509
# [245]	valid_0's rmse: 0.559416
# [246]	valid_0's rmse: 0.559518
# [247]	valid_0's rmse: 0.55928
# [248]	valid_0's rmse: 0.559328
# [249]	valid_0's rmse: 0.558944
# [250]	valid_0's rmse: 0.559148
# [251]	valid_0's rmse: 0.559133
# [252]	valid_0's rmse: 0.559347
# [253]	valid_0's rmse: 0.559373
# [254]	valid_0's rmse: 0.55936
# [255]	valid_0's rmse: 0.559427
# [256]	valid_0's rmse: 0.559622
# [257]	valid_0's rmse: 0.559687
# [258]	valid_0's rmse: 0.559862
# [259]	valid_0's rmse: 0.559824
# [260]	valid_0's rmse: 0.560051
# [261]	valid_0's rmse: 0.560159
# [262]	valid_0's rmse: 0.560164
# [263]	valid_0's rmse: 0.560161
# [264]	valid_0's rmse: 0.56039
# [265]	valid_0's rmse: 0.560441
# [266]	valid_0's rmse: 0.560374
# [267]	valid_0's rmse: 0.560498
# [268]	valid_0's rmse: 0.560641
# [269]	valid_0's rmse: 0.560567
# [270]	valid_0's rmse: 0.560707
# [271]	valid_0's rmse: 0.56046
# [272]	valid_0's rmse: 0.560566
# [273]	valid_0's rmse: 0.56054
# [274]	valid_0's rmse: 0.560439
# [275]	valid_0's rmse: 0.560465
# [276]	valid_0's rmse: 0.56049
# [277]	valid_0's rmse: 0.560477
# [278]	valid_0's rmse: 0.560706
# [279]	valid_0's rmse: 0.560881
# [280]	valid_0's rmse: 0.560818
# [281]	valid_0's rmse: 0.560945
# [282]	valid_0's rmse: 0.560784
# [283]	valid_0's rmse: 0.560826
# [284]	valid_0's rmse: 0.560554
# [285]	valid_0's rmse: 0.56066
# [286]	valid_0's rmse: 0.560421
# [287]	valid_0's rmse: 0.560391
# [288]	valid_0's rmse: 0.560351
# [289]	valid_0's rmse: 0.560645
# [290]	valid_0's rmse: 0.560762
# [291]	valid_0's rmse: 0.560966
# [292]	valid_0's rmse: 0.561024
# [293]	valid_0's rmse: 0.561215
# [294]	valid_0's rmse: 0.561119
# [295]	valid_0's rmse: 0.56125
# [296]	valid_0's rmse: 0.561404
# [297]	valid_0's rmse: 0.561221
# [298]	valid_0's rmse: 0.56144
# [299]	valid_0's rmse: 0.561429
# [300]	valid_0's rmse: 0.561588
# [301]	valid_0's rmse: 0.5616
# [302]	valid_0's rmse: 0.561433
# [303]	valid_0's rmse: 0.561688
# [304]	valid_0's rmse: 0.561446
# [305]	valid_0's rmse: 0.561565
# [306]	valid_0's rmse: 0.561422
# [307]	valid_0's rmse: 0.561381
# [308]	valid_0's rmse: 0.561347
# [309]	valid_0's rmse: 0.56129
# [310]	valid_0's rmse: 0.561178
# [311]	valid_0's rmse: 0.561332
# [312]	valid_0's rmse: 0.561476
# [313]	valid_0's rmse: 0.561328
# [314]	valid_0's rmse: 0.5614
# [315]	valid_0's rmse: 0.561214
# [316]	valid_0's rmse: 0.561257
# [317]	valid_0's rmse: 0.561055
# [318]	valid_0's rmse: 0.561155
# [319]	valid_0's rmse: 0.56117
# [320]	valid_0's rmse: 0.561397
# [321]	valid_0's rmse: 0.561313
# [322]	valid_0's rmse: 0.561524
# [323]	valid_0's rmse: 0.561561
# [324]	valid_0's rmse: 0.561727
# [325]	valid_0's rmse: 0.561582
# [326]	valid_0's rmse: 0.561317
# [327]	valid_0's rmse: 0.561246
# [328]	valid_0's rmse: 0.561332
# [329]	valid_0's rmse: 0.561539
# [330]	valid_0's rmse: 0.561302
# [331]	valid_0's rmse: 0.561288
# [332]	valid_0's rmse: 0.561306
# [333]	valid_0's rmse: 0.561542
# [334]	valid_0's rmse: 0.561608
# [335]	valid_0's rmse: 0.561754
# [336]	valid_0's rmse: 0.562002
# [337]	valid_0's rmse: 0.561914
# [338]	valid_0's rmse: 0.562017
# [339]	valid_0's rmse: 0.562079
# [340]	valid_0's rmse: 0.562096
# [341]	valid_0's rmse: 0.562144
# [342]	valid_0's rmse: 0.562226
# [343]	valid_0's rmse: 0.562432
# [344]	valid_0's rmse: 0.562427
# [345]	valid_0's rmse: 0.562164
# [346]	valid_0's rmse: 0.562372
# [347]	valid_0's rmse: 0.562143
# [348]	valid_0's rmse: 0.562148
# [349]	valid_0's rmse: 0.562232
# [350]	valid_0's rmse: 0.5624
# [351]	valid_0's rmse: 0.5625
# [352]	valid_0's rmse: 0.562434
# [353]	valid_0's rmse: 0.562373
# [354]	valid_0's rmse: 0.562333
# [355]	valid_0's rmse: 0.56236
# [356]	valid_0's rmse: 0.56252
# [357]	valid_0's rmse: 0.562553
# [358]	valid_0's rmse: 0.56272
# [359]	valid_0's rmse: 0.562595
# [360]	valid_0's rmse: 0.56252
# [361]	valid_0's rmse: 0.562642
# [362]	valid_0's rmse: 0.562718
# [363]	valid_0's rmse: 0.562914
# [364]	valid_0's rmse: 0.562764
# [365]	valid_0's rmse: 0.562793
# [366]	valid_0's rmse: 0.562766
# [367]	valid_0's rmse: 0.562837
# [368]	valid_0's rmse: 0.562765
# [369]	valid_0's rmse: 0.563041
# [370]	valid_0's rmse: 0.562933
# [371]	valid_0's rmse: 0.563058
# [372]	valid_0's rmse: 0.563136
# [373]	valid_0's rmse: 0.563278
# [374]	valid_0's rmse: 0.563252
# [375]	valid_0's rmse: 0.563243
# [376]	valid_0's rmse: 0.563267
# [377]	valid_0's rmse: 0.563368
# [378]	valid_0's rmse: 0.563098
# [379]	valid_0's rmse: 0.563235
# [380]	valid_0's rmse: 0.563331
# [381]	valid_0's rmse: 0.563535
# [382]	valid_0's rmse: 0.563666
# [383]	valid_0's rmse: 0.563644
# [384]	valid_0's rmse: 0.563762
# [385]	valid_0's rmse: 0.563679
# [386]	valid_0's rmse: 0.563739
# [387]	valid_0's rmse: 0.563706
# [388]	valid_0's rmse: 0.56331
# [389]	valid_0's rmse: 0.563143
# [390]	valid_0's rmse: 0.562933
# [391]	valid_0's rmse: 0.562846
# [392]	valid_0's rmse: 0.563027
# [393]	valid_0's rmse: 0.56296
# [394]	valid_0's rmse: 0.563235
# [395]	valid_0's rmse: 0.563074
# [396]	valid_0's rmse: 0.562979
# [397]	valid_0's rmse: 0.563052
# [398]	valid_0's rmse: 0.563009
# [399]	valid_0's rmse: 0.563008
# [400]	valid_0's rmse: 0.563227
# [401]	valid_0's rmse: 0.563212
# [402]	valid_0's rmse: 0.563167
# [403]	valid_0's rmse: 0.563214
# [404]	valid_0's rmse: 0.563047
# [405]	valid_0's rmse: 0.562938
# [406]	valid_0's rmse: 0.562633
# [407]	valid_0's rmse: 0.562634
# [408]	valid_0's rmse: 0.562566
# [409]	valid_0's rmse: 0.562579
# [410]	valid_0's rmse: 0.562499
# [411]	valid_0's rmse: 0.562408
# [412]	valid_0's rmse: 0.562457
# [413]	valid_0's rmse: 0.562285
# [414]	valid_0's rmse: 0.562418
# [415]	valid_0's rmse: 0.562439
# [416]	valid_0's rmse: 0.562361
# [417]	valid_0's rmse: 0.562584
# [418]	valid_0's rmse: 0.562403
# [419]	valid_0's rmse: 0.562602
# [420]	valid_0's rmse: 0.562684
# [421]	valid_0's rmse: 0.56249
# [422]	valid_0's rmse: 0.562539
# [423]	valid_0's rmse: 0.562595
# [424]	valid_0's rmse: 0.562665
# [425]	valid_0's rmse: 0.562749
# [426]	valid_0's rmse: 0.562623
# [427]	valid_0's rmse: 0.562573
# [428]	valid_0's rmse: 0.562587
# [429]	valid_0's rmse: 0.562479
# [430]	valid_0's rmse: 0.562545
# [431]	valid_0's rmse: 0.562305
# [432]	valid_0's rmse: 0.562336
# [433]	valid_0's rmse: 0.562499
# [434]	valid_0's rmse: 0.562497
# Fold RMSE Score :  0.5589213621903013
# OOF RMSE Score :  0.6061917777736919

# %%
importances = np.array([0]* len(train_cols))
for i in range(5):
    importances += models[i].feature_importances_ 
    
import math
new_cols = np.array(train_cols)[np.argsort(importances)[::-1]][:550]

models_dict = {}
scores = []

models = []
test_predict_list = []
best_params = {'boosting_type': 'gbdt', 
               'metric': 'rmse',
               'reg_alpha': 0.003188447814669599, 
               'reg_lambda': 0.0010228604507564066, 
               'colsample_bytree': 0.5420247656839267, 
               'subsample': 0.9778252382803456, 
               'feature_fraction': 0.8,
               'bagging_freq': 1,
               'bagging_fraction': 0.75,
               'learning_rate': 0.01716485155812008, 
               'num_leaves': 19, 
               'min_child_samples': 46,
               'verbosity': -1,
               'random_state': 42,
               'n_estimators': 500,
               'device_type': 'cpu'}

for i in range(5): 
    kf = model_selection.KFold(n_splits=10, random_state=42 + i, shuffle=True)

    oof_valid_preds = np.zeros(train_feats.shape[0], )

    X_test = test_feats[new_cols]


    for fold, (train_idx, valid_idx) in enumerate(kf.split(train_feats)):

        print("==-"* 50)
        print("Fold : ", fold)

        X_train, y_train = train_feats.iloc[train_idx][new_cols], train_feats.iloc[train_idx][target_col]
        X_valid, y_valid = train_feats.iloc[valid_idx][new_cols], train_feats.iloc[valid_idx][target_col]

        print("Trian :", X_train.shape, y_train.shape)
        print("Valid :", X_valid.shape, y_valid.shape)

        params = {
            "objective": "regression",
            "metric": "rmse",
            'random_state': 42,
            "n_estimators" : 12001,
            "verbosity": -1,
            "device_type": "cpu",
            **best_params
        }

        model = lgb.LGBMRegressor(**params)

        early_stopping_callback = lgb.early_stopping(200, first_metric_only=True, verbose=False)
        verbose_callback = lgb.callback.record_evaluation({})

        model.fit(X_train, y_train, eval_set=[(X_valid, y_valid)],  
                  callbacks=[early_stopping_callback, verbose_callback],
        )
        models.append(model)

        valid_predict = model.predict(X_valid)
        oof_valid_preds[valid_idx] = valid_predict

        test_predict = model.predict(X_test)
        test_predict_list.append(test_predict)

        score = metrics.mean_squared_error(y_valid, valid_predict, squared=False)
        print("Fold RMSE Score : ", score)

        models_dict[f'{fold}_{i}'] = model


    oof_score = metrics.mean_squared_error(train_feats[target_col], oof_valid_preds, squared=False)
    scores.append(oof_score)
    print("OOF RMSE Score : ", oof_score)
    
test_feats['score'] = np.mean(test_predict_list, axis=0)
publiclgbm_pred = test_feats[['id', 'score']]
sub2 = publiclgbm_pred.copy()
# Out:
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  0
# Trian : (2223, 550) (2223, 1)
# Valid : (248, 550) (248, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.00924
# [2]	valid_0's rmse: 0.999041
# [3]	valid_0's rmse: 0.989123
# [4]	valid_0's rmse: 0.979909
# [5]	valid_0's rmse: 0.970245
# [6]	valid_0's rmse: 0.96201
# [7]	valid_0's rmse: 0.953515
# [8]	valid_0's rmse: 0.944912
# [9]	valid_0's rmse: 0.936749
# [10]	valid_0's rmse: 0.928864
# [11]	valid_0's rmse: 0.921245
# [12]	valid_0's rmse: 0.913122
# [13]	valid_0's rmse: 0.904978
# [14]	valid_0's rmse: 0.89723
# [15]	valid_0's rmse: 0.889919
# [16]	valid_0's rmse: 0.883108
# [17]	valid_0's rmse: 0.875937
# [18]	valid_0's rmse: 0.86865
# [19]	valid_0's rmse: 0.862907
# [20]	valid_0's rmse: 0.856233
# [21]	valid_0's rmse: 0.849763
# [22]	valid_0's rmse: 0.843443
# [23]	valid_0's rmse: 0.837033
# [24]	valid_0's rmse: 0.830701
# [25]	valid_0's rmse: 0.824989
# [26]	valid_0's rmse: 0.819046
# [27]	valid_0's rmse: 0.813564
# [28]	valid_0's rmse: 0.807902
# [29]	valid_0's rmse: 0.802139
# [30]	valid_0's rmse: 0.79753
# [31]	valid_0's rmse: 0.792267
# [32]	valid_0's rmse: 0.787116
# [33]	valid_0's rmse: 0.782453
# [34]	valid_0's rmse: 0.777473
# [35]	valid_0's rmse: 0.772411
# [36]	valid_0's rmse: 0.768087
# [37]	valid_0's rmse: 0.763923
# [38]	valid_0's rmse: 0.759673
# [39]	valid_0's rmse: 0.75516
# [40]	valid_0's rmse: 0.750704
# [41]	valid_0's rmse: 0.746012
# [42]	valid_0's rmse: 0.742133
# [43]	valid_0's rmse: 0.738457
# [44]	valid_0's rmse: 0.734389
# [45]	valid_0's rmse: 0.73098
# [46]	valid_0's rmse: 0.727495
# [47]	valid_0's rmse: 0.723307
# [48]	valid_0's rmse: 0.72016
# [49]	valid_0's rmse: 0.716817
# [50]	valid_0's rmse: 0.713581
# [51]	valid_0's rmse: 0.710556
# [52]	valid_0's rmse: 0.707776
# [53]	valid_0's rmse: 0.704554
# [54]	valid_0's rmse: 0.701441
# [55]	valid_0's rmse: 0.698677
# [56]	valid_0's rmse: 0.695745
# [57]	valid_0's rmse: 0.692722
# [58]	valid_0's rmse: 0.689732
# [59]	valid_0's rmse: 0.687342
# [60]	valid_0's rmse: 0.685277
# [61]	valid_0's rmse: 0.682878
# [62]	valid_0's rmse: 0.680497
# [63]	valid_0's rmse: 0.678631
# [64]	valid_0's rmse: 0.676448
# [65]	valid_0's rmse: 0.674242
# [66]	valid_0's rmse: 0.671781
# [67]	valid_0's rmse: 0.669995
# [68]	valid_0's rmse: 0.667662
# [69]	valid_0's rmse: 0.665833
# [70]	valid_0's rmse: 0.663739
# [71]	valid_0's rmse: 0.661846
# [72]	valid_0's rmse: 0.660251
# [73]	valid_0's rmse: 0.658647
# [74]	valid_0's rmse: 0.657363
# [75]	valid_0's rmse: 0.655602
# [76]	valid_0's rmse: 0.653939
# [77]	valid_0's rmse: 0.652623
# [78]	valid_0's rmse: 0.650913
# [79]	valid_0's rmse: 0.649781
# [80]	valid_0's rmse: 0.648093
# [81]	valid_0's rmse: 0.646516
# [82]	valid_0's rmse: 0.645112
# [83]	valid_0's rmse: 0.643721
# [84]	valid_0's rmse: 0.642319
# [85]	valid_0's rmse: 0.640823
# [86]	valid_0's rmse: 0.639849
# [87]	valid_0's rmse: 0.638726
# [88]	valid_0's rmse: 0.637868
# [89]	valid_0's rmse: 0.636483
# [90]	valid_0's rmse: 0.635375
# [91]	valid_0's rmse: 0.634224
# [92]	valid_0's rmse: 0.633515
# [93]	valid_0's rmse: 0.632376
# [94]	valid_0's rmse: 0.631005
# [95]	valid_0's rmse: 0.629681
# [96]	valid_0's rmse: 0.62849
# [97]	valid_0's rmse: 0.627458
# [98]	valid_0's rmse: 0.626281
# [99]	valid_0's rmse: 0.625268
# [100]	valid_0's rmse: 0.624798
# [101]	valid_0's rmse: 0.623845
# [102]	valid_0's rmse: 0.623088
# [103]	valid_0's rmse: 0.622341
# [104]	valid_0's rmse: 0.621453
# [105]	valid_0's rmse: 0.62064
# [106]	valid_0's rmse: 0.619426
# [107]	valid_0's rmse: 0.618779
# [108]	valid_0's rmse: 0.618111
# [109]	valid_0's rmse: 0.617499
# [110]	valid_0's rmse: 0.617078
# [111]	valid_0's rmse: 0.616161
# [112]	valid_0's rmse: 0.61557
# [113]	valid_0's rmse: 0.615196
# [114]	valid_0's rmse: 0.614679
# [115]	valid_0's rmse: 0.613868
# [116]	valid_0's rmse: 0.613561
# [117]	valid_0's rmse: 0.613252
# [118]	valid_0's rmse: 0.612702
# [119]	valid_0's rmse: 0.6122
# [120]	valid_0's rmse: 0.611511
# [121]	valid_0's rmse: 0.610522
# [122]	valid_0's rmse: 0.61009
# [123]	valid_0's rmse: 0.609245
# [124]	valid_0's rmse: 0.608125
# [125]	valid_0's rmse: 0.607637
# [126]	valid_0's rmse: 0.607207
# [127]	valid_0's rmse: 0.606813
# [128]	valid_0's rmse: 0.606081
# [129]	valid_0's rmse: 0.605819
# [130]	valid_0's rmse: 0.605574
# [131]	valid_0's rmse: 0.605227
# [132]	valid_0's rmse: 0.604731
# [133]	valid_0's rmse: 0.604013
# [134]	valid_0's rmse: 0.60321
# [135]	valid_0's rmse: 0.602757
# [136]	valid_0's rmse: 0.602163
# [137]	valid_0's rmse: 0.601424
# [138]	valid_0's rmse: 0.600784
# [139]	valid_0's rmse: 0.600107
# [140]	valid_0's rmse: 0.599727
# [141]	valid_0's rmse: 0.599039
# [142]	valid_0's rmse: 0.598456
# [143]	valid_0's rmse: 0.598306
# [144]	valid_0's rmse: 0.597881
# [145]	valid_0's rmse: 0.597831
# [146]	valid_0's rmse: 0.597377
# [147]	valid_0's rmse: 0.597333
# [148]	valid_0's rmse: 0.596965
# [149]	valid_0's rmse: 0.596308
# [150]	valid_0's rmse: 0.596085
# [151]	valid_0's rmse: 0.596036
# [152]	valid_0's rmse: 0.595897
# [153]	valid_0's rmse: 0.595881
# [154]	valid_0's rmse: 0.595344
# [155]	valid_0's rmse: 0.595045
# [156]	valid_0's rmse: 0.594757
# [157]	valid_0's rmse: 0.594609
# [158]	valid_0's rmse: 0.594024
# [159]	valid_0's rmse: 0.593845
# [160]	valid_0's rmse: 0.593697
# [161]	valid_0's rmse: 0.593899
# [162]	valid_0's rmse: 0.593837
# [163]	valid_0's rmse: 0.593814
# [164]	valid_0's rmse: 0.593444
# [165]	valid_0's rmse: 0.593382
# [166]	valid_0's rmse: 0.593264
# [167]	valid_0's rmse: 0.592891
# [168]	valid_0's rmse: 0.59286
# [169]	valid_0's rmse: 0.592754
# [170]	valid_0's rmse: 0.592481
# [171]	valid_0's rmse: 0.592463
# [172]	valid_0's rmse: 0.592477
# [173]	valid_0's rmse: 0.592513
# [174]	valid_0's rmse: 0.592696
# [175]	valid_0's rmse: 0.592617
# [176]	valid_0's rmse: 0.592741
# [177]	valid_0's rmse: 0.592546
# [178]	valid_0's rmse: 0.592359
# [179]	valid_0's rmse: 0.592407
# [180]	valid_0's rmse: 0.592098
# [181]	valid_0's rmse: 0.591822
# [182]	valid_0's rmse: 0.591503
# [183]	valid_0's rmse: 0.591183
# [184]	valid_0's rmse: 0.591298
# [185]	valid_0's rmse: 0.591224
# [186]	valid_0's rmse: 0.591083
# [187]	valid_0's rmse: 0.591071
# [188]	valid_0's rmse: 0.591193
# [189]	valid_0's rmse: 0.591102
# [190]	valid_0's rmse: 0.590851
# [191]	valid_0's rmse: 0.590973
# [192]	valid_0's rmse: 0.590553
# [193]	valid_0's rmse: 0.590394
# [194]	valid_0's rmse: 0.590454
# [195]	valid_0's rmse: 0.590354
# [196]	valid_0's rmse: 0.59035
# [197]	valid_0's rmse: 0.59033
# [198]	valid_0's rmse: 0.589986
# [199]	valid_0's rmse: 0.59017
# [200]	valid_0's rmse: 0.590005
# [201]	valid_0's rmse: 0.58968
# [202]	valid_0's rmse: 0.58962
# [203]	valid_0's rmse: 0.589301
# [204]	valid_0's rmse: 0.589087
# [205]	valid_0's rmse: 0.589132
# [206]	valid_0's rmse: 0.58894
# [207]	valid_0's rmse: 0.588615
# [208]	valid_0's rmse: 0.588338
# [209]	valid_0's rmse: 0.58836
# [210]	valid_0's rmse: 0.588206
# [211]	valid_0's rmse: 0.588201
# [212]	valid_0's rmse: 0.588227
# [213]	valid_0's rmse: 0.588054
# [214]	valid_0's rmse: 0.587979
# [215]	valid_0's rmse: 0.58822
# [216]	valid_0's rmse: 0.588078
# [217]	valid_0's rmse: 0.588044
# [218]	valid_0's rmse: 0.587916
# [219]	valid_0's rmse: 0.587907
# [220]	valid_0's rmse: 0.58769
# [221]	valid_0's rmse: 0.58776
# [222]	valid_0's rmse: 0.587703
# [223]	valid_0's rmse: 0.587663
# [224]	valid_0's rmse: 0.587668
# [225]	valid_0's rmse: 0.587424
# [226]	valid_0's rmse: 0.587344
# [227]	valid_0's rmse: 0.58731
# [228]	valid_0's rmse: 0.587261
# [229]	valid_0's rmse: 0.587203
# [230]	valid_0's rmse: 0.587382
# [231]	valid_0's rmse: 0.587607
# [232]	valid_0's rmse: 0.587551
# [233]	valid_0's rmse: 0.587327
# [234]	valid_0's rmse: 0.587319
# [235]	valid_0's rmse: 0.587088
# [236]	valid_0's rmse: 0.587088
# [237]	valid_0's rmse: 0.58721
# [238]	valid_0's rmse: 0.587223
# [239]	valid_0's rmse: 0.587488
# [240]	valid_0's rmse: 0.58767
# [241]	valid_0's rmse: 0.587655
# [242]	valid_0's rmse: 0.58762
# [243]	valid_0's rmse: 0.587625
# [244]	valid_0's rmse: 0.58729
# [245]	valid_0's rmse: 0.587293
# [246]	valid_0's rmse: 0.587098
# [247]	valid_0's rmse: 0.586763
# [248]	valid_0's rmse: 0.586743
# [249]	valid_0's rmse: 0.586722
# [250]	valid_0's rmse: 0.586632
# [251]	valid_0's rmse: 0.586708
# [252]	valid_0's rmse: 0.58694
# [253]	valid_0's rmse: 0.5868
# [254]	valid_0's rmse: 0.587077
# [255]	valid_0's rmse: 0.587042
# [256]	valid_0's rmse: 0.58679
# [257]	valid_0's rmse: 0.58686
# [258]	valid_0's rmse: 0.586874
# [259]	valid_0's rmse: 0.586674
# [260]	valid_0's rmse: 0.586569
# [261]	valid_0's rmse: 0.58653
# [262]	valid_0's rmse: 0.586469
# [263]	valid_0's rmse: 0.58616
# [264]	valid_0's rmse: 0.586362
# [265]	valid_0's rmse: 0.586449
# [266]	valid_0's rmse: 0.586403
# [267]	valid_0's rmse: 0.586338
# [268]	valid_0's rmse: 0.586299
# [269]	valid_0's rmse: 0.586242
# [270]	valid_0's rmse: 0.586204
# [271]	valid_0's rmse: 0.586285
# [272]	valid_0's rmse: 0.586362
# [273]	valid_0's rmse: 0.586212
# [274]	valid_0's rmse: 0.586246
# [275]	valid_0's rmse: 0.586267
# [276]	valid_0's rmse: 0.586349
# [277]	valid_0's rmse: 0.586296
# [278]	valid_0's rmse: 0.586391
# [279]	valid_0's rmse: 0.586311
# [280]	valid_0's rmse: 0.586456
# [281]	valid_0's rmse: 0.586513
# [282]	valid_0's rmse: 0.586387
# [283]	valid_0's rmse: 0.586453
# [284]	valid_0's rmse: 0.586368
# [285]	valid_0's rmse: 0.586235
# [286]	valid_0's rmse: 0.586272
# [287]	valid_0's rmse: 0.58627
# [288]	valid_0's rmse: 0.586153
# [289]	valid_0's rmse: 0.586032
# [290]	valid_0's rmse: 0.585802
# [291]	valid_0's rmse: 0.585735
# [292]	valid_0's rmse: 0.58546
# [293]	valid_0's rmse: 0.585539
# [294]	valid_0's rmse: 0.585489
# [295]	valid_0's rmse: 0.585361
# [296]	valid_0's rmse: 0.585387
# [297]	valid_0's rmse: 0.585367
# [298]	valid_0's rmse: 0.585402
# [299]	valid_0's rmse: 0.585353
# [300]	valid_0's rmse: 0.58531
# [301]	valid_0's rmse: 0.585222
# [302]	valid_0's rmse: 0.585302
# [303]	valid_0's rmse: 0.585196
# [304]	valid_0's rmse: 0.585224
# [305]	valid_0's rmse: 0.585262
# [306]	valid_0's rmse: 0.585362
# [307]	valid_0's rmse: 0.585498
# [308]	valid_0's rmse: 0.585418
# [309]	valid_0's rmse: 0.585574
# [310]	valid_0's rmse: 0.585715
# [311]	valid_0's rmse: 0.585822
# [312]	valid_0's rmse: 0.585704
# [313]	valid_0's rmse: 0.585763
# [314]	valid_0's rmse: 0.585727
# [315]	valid_0's rmse: 0.585357
# [316]	valid_0's rmse: 0.585432
# [317]	valid_0's rmse: 0.585485
# [318]	valid_0's rmse: 0.585576
# [319]	valid_0's rmse: 0.58558
# [320]	valid_0's rmse: 0.585576
# [321]	valid_0's rmse: 0.585547
# [322]	valid_0's rmse: 0.585736
# [323]	valid_0's rmse: 0.585713
# [324]	valid_0's rmse: 0.585947
# [325]	valid_0's rmse: 0.5861
# [326]	valid_0's rmse: 0.586106
# [327]	valid_0's rmse: 0.586076
# [328]	valid_0's rmse: 0.585944
# [329]	valid_0's rmse: 0.586011
# [330]	valid_0's rmse: 0.586221
# [331]	valid_0's rmse: 0.586196
# [332]	valid_0's rmse: 0.586264
# [333]	valid_0's rmse: 0.586366
# [334]	valid_0's rmse: 0.586278
# [335]	valid_0's rmse: 0.586403
# [336]	valid_0's rmse: 0.586327
# [337]	valid_0's rmse: 0.586031
# [338]	valid_0's rmse: 0.585836
# [339]	valid_0's rmse: 0.585765
# [340]	valid_0's rmse: 0.585803
# [341]	valid_0's rmse: 0.585747
# [342]	valid_0's rmse: 0.585943
# [343]	valid_0's rmse: 0.586158
# [344]	valid_0's rmse: 0.585959
# [345]	valid_0's rmse: 0.586011
# [346]	valid_0's rmse: 0.585976
# [347]	valid_0's rmse: 0.586309
# [348]	valid_0's rmse: 0.586134
# [349]	valid_0's rmse: 0.586106
# [350]	valid_0's rmse: 0.586332
# [351]	valid_0's rmse: 0.586334
# [352]	valid_0's rmse: 0.586414
# [353]	valid_0's rmse: 0.586576
# [354]	valid_0's rmse: 0.58652
# [355]	valid_0's rmse: 0.586286
# [356]	valid_0's rmse: 0.58622
# [357]	valid_0's rmse: 0.586172
# [358]	valid_0's rmse: 0.586131
# [359]	valid_0's rmse: 0.586227
# [360]	valid_0's rmse: 0.586295
# [361]	valid_0's rmse: 0.586249
# [362]	valid_0's rmse: 0.586299
# [363]	valid_0's rmse: 0.586236
# [364]	valid_0's rmse: 0.58631
# [365]	valid_0's rmse: 0.586211
# [366]	valid_0's rmse: 0.586247
# [367]	valid_0's rmse: 0.586406
# [368]	valid_0's rmse: 0.586512
# [369]	valid_0's rmse: 0.586741
# [370]	valid_0's rmse: 0.586885
# [371]	valid_0's rmse: 0.587115
# [372]	valid_0's rmse: 0.587237
# [373]	valid_0's rmse: 0.58724
# [374]	valid_0's rmse: 0.587009
# [375]	valid_0's rmse: 0.586998
# [376]	valid_0's rmse: 0.586823
# [377]	valid_0's rmse: 0.586804
# [378]	valid_0's rmse: 0.586829
# [379]	valid_0's rmse: 0.58703
# [380]	valid_0's rmse: 0.587051
# [381]	valid_0's rmse: 0.587
# [382]	valid_0's rmse: 0.587012
# [383]	valid_0's rmse: 0.586768
# [384]	valid_0's rmse: 0.586665
# [385]	valid_0's rmse: 0.586492
# [386]	valid_0's rmse: 0.58639
# [387]	valid_0's rmse: 0.586362
# [388]	valid_0's rmse: 0.586316
# [389]	valid_0's rmse: 0.586324
# [390]	valid_0's rmse: 0.586295
# [391]	valid_0's rmse: 0.586476
# [392]	valid_0's rmse: 0.586356
# [393]	valid_0's rmse: 0.586379
# [394]	valid_0's rmse: 0.586586
# [395]	valid_0's rmse: 0.586709
# [396]	valid_0's rmse: 0.586845
# [397]	valid_0's rmse: 0.586724
# [398]	valid_0's rmse: 0.586968
# [399]	valid_0's rmse: 0.586908
# [400]	valid_0's rmse: 0.586792
# [401]	valid_0's rmse: 0.586998
# [402]	valid_0's rmse: 0.586957
# [403]	valid_0's rmse: 0.586714
# [404]	valid_0's rmse: 0.58677
# [405]	valid_0's rmse: 0.586793
# [406]	valid_0's rmse: 0.586711
# [407]	valid_0's rmse: 0.586718
# [408]	valid_0's rmse: 0.586627
# [409]	valid_0's rmse: 0.586725
# [410]	valid_0's rmse: 0.58665
# [411]	valid_0's rmse: 0.586584
# [412]	valid_0's rmse: 0.586712
# [413]	valid_0's rmse: 0.586716
# [414]	valid_0's rmse: 0.586991
# [415]	valid_0's rmse: 0.587025
# [416]	valid_0's rmse: 0.587227
# [417]	valid_0's rmse: 0.587187
# [418]	valid_0's rmse: 0.587331
# [419]	valid_0's rmse: 0.587105
# [420]	valid_0's rmse: 0.58721
# [421]	valid_0's rmse: 0.587116
# [422]	valid_0's rmse: 0.586971
# [423]	valid_0's rmse: 0.586837
# [424]	valid_0's rmse: 0.586811
# [425]	valid_0's rmse: 0.586811
# [426]	valid_0's rmse: 0.586807
# [427]	valid_0's rmse: 0.586818
# [428]	valid_0's rmse: 0.586721
# [429]	valid_0's rmse: 0.586881
# [430]	valid_0's rmse: 0.586872
# [431]	valid_0's rmse: 0.587009
# [432]	valid_0's rmse: 0.58715
# [433]	valid_0's rmse: 0.587104
# [434]	valid_0's rmse: 0.586973
# [435]	valid_0's rmse: 0.586771
# [436]	valid_0's rmse: 0.586774
# [437]	valid_0's rmse: 0.586731
# [438]	valid_0's rmse: 0.58658
# [439]	valid_0's rmse: 0.586599
# [440]	valid_0's rmse: 0.5865
# [441]	valid_0's rmse: 0.586584
# [442]	valid_0's rmse: 0.586622
# [443]	valid_0's rmse: 0.586529
# [444]	valid_0's rmse: 0.586709
# [445]	valid_0's rmse: 0.586752
# [446]	valid_0's rmse: 0.586855
# [447]	valid_0's rmse: 0.586706
# [448]	valid_0's rmse: 0.586714
# [449]	valid_0's rmse: 0.586632
# [450]	valid_0's rmse: 0.586626
# [451]	valid_0's rmse: 0.586711
# [452]	valid_0's rmse: 0.586864
# [453]	valid_0's rmse: 0.586915
# [454]	valid_0's rmse: 0.586844
# [455]	valid_0's rmse: 0.586862
# [456]	valid_0's rmse: 0.586951
# [457]	valid_0's rmse: 0.58692
# [458]	valid_0's rmse: 0.586977
# [459]	valid_0's rmse: 0.586909
# [460]	valid_0's rmse: 0.586882
# [461]	valid_0's rmse: 0.586844
# [462]	valid_0's rmse: 0.587004
# [463]	valid_0's rmse: 0.586894
# [464]	valid_0's rmse: 0.586883
# [465]	valid_0's rmse: 0.586866
# [466]	valid_0's rmse: 0.586807
# [467]	valid_0's rmse: 0.58686
# [468]	valid_0's rmse: 0.586912
# [469]	valid_0's rmse: 0.586939
# [470]	valid_0's rmse: 0.587035
# [471]	valid_0's rmse: 0.587047
# [472]	valid_0's rmse: 0.58694
# [473]	valid_0's rmse: 0.586951
# [474]	valid_0's rmse: 0.586852
# [475]	valid_0's rmse: 0.586964
# [476]	valid_0's rmse: 0.58684
# [477]	valid_0's rmse: 0.58673
# [478]	valid_0's rmse: 0.586533
# [479]	valid_0's rmse: 0.586555
# [480]	valid_0's rmse: 0.58652
# [481]	valid_0's rmse: 0.58666
# [482]	valid_0's rmse: 0.586394
# [483]	valid_0's rmse: 0.586202
# [484]	valid_0's rmse: 0.586173
# [485]	valid_0's rmse: 0.586091
# [486]	valid_0's rmse: 0.586041
# [487]	valid_0's rmse: 0.58617
# [488]	valid_0's rmse: 0.586183
# [489]	valid_0's rmse: 0.586347
# [490]	valid_0's rmse: 0.586585
# [491]	valid_0's rmse: 0.586715
# [492]	valid_0's rmse: 0.586626
# [493]	valid_0's rmse: 0.58659
# [494]	valid_0's rmse: 0.586681
# [495]	valid_0's rmse: 0.58663
# [496]	valid_0's rmse: 0.586668
# [497]	valid_0's rmse: 0.586572
# [498]	valid_0's rmse: 0.586499
# [499]	valid_0's rmse: 0.586524
# [500]	valid_0's rmse: 0.586596
# Fold RMSE Score :  0.5851960087683472
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  1
# Trian : (2224, 550) (2224, 1)
# Valid : (247, 550) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 0.94482
# [2]	valid_0's rmse: 0.935168
# [3]	valid_0's rmse: 0.925436
# [4]	valid_0's rmse: 0.916001
# [5]	valid_0's rmse: 0.906423
# [6]	valid_0's rmse: 0.896587
# [7]	valid_0's rmse: 0.887859
# [8]	valid_0's rmse: 0.878832
# [9]	valid_0's rmse: 0.870332
# [10]	valid_0's rmse: 0.861813
# [11]	valid_0's rmse: 0.853492
# [12]	valid_0's rmse: 0.845324
# [13]	valid_0's rmse: 0.837076
# [14]	valid_0's rmse: 0.829845
# [15]	valid_0's rmse: 0.821926
# [16]	valid_0's rmse: 0.81458
# [17]	valid_0's rmse: 0.807187
# [18]	valid_0's rmse: 0.80021
# [19]	valid_0's rmse: 0.793121
# [20]	valid_0's rmse: 0.785971
# [21]	valid_0's rmse: 0.779731
# [22]	valid_0's rmse: 0.772875
# [23]	valid_0's rmse: 0.766731
# [24]	valid_0's rmse: 0.760971
# [25]	valid_0's rmse: 0.755128
# [26]	valid_0's rmse: 0.749508
# [27]	valid_0's rmse: 0.743853
# [28]	valid_0's rmse: 0.738141
# [29]	valid_0's rmse: 0.731917
# [30]	valid_0's rmse: 0.726364
# [31]	valid_0's rmse: 0.721279
# [32]	valid_0's rmse: 0.715462
# [33]	valid_0's rmse: 0.710385
# [34]	valid_0's rmse: 0.705532
# [35]	valid_0's rmse: 0.701051
# [36]	valid_0's rmse: 0.695789
# [37]	valid_0's rmse: 0.691593
# [38]	valid_0's rmse: 0.68723
# [39]	valid_0's rmse: 0.683231
# [40]	valid_0's rmse: 0.679516
# [41]	valid_0's rmse: 0.675486
# [42]	valid_0's rmse: 0.672063
# [43]	valid_0's rmse: 0.668234
# [44]	valid_0's rmse: 0.66462
# [45]	valid_0's rmse: 0.661227
# [46]	valid_0's rmse: 0.657644
# [47]	valid_0's rmse: 0.65356
# [48]	valid_0's rmse: 0.65054
# [49]	valid_0's rmse: 0.64721
# [50]	valid_0's rmse: 0.644109
# [51]	valid_0's rmse: 0.641072
# [52]	valid_0's rmse: 0.637784
# [53]	valid_0's rmse: 0.635179
# [54]	valid_0's rmse: 0.632418
# [55]	valid_0's rmse: 0.629908
# [56]	valid_0's rmse: 0.627193
# [57]	valid_0's rmse: 0.624316
# [58]	valid_0's rmse: 0.62211
# [59]	valid_0's rmse: 0.619481
# [60]	valid_0's rmse: 0.617296
# [61]	valid_0's rmse: 0.615201
# [62]	valid_0's rmse: 0.612623
# [63]	valid_0's rmse: 0.610366
# [64]	valid_0's rmse: 0.607772
# [65]	valid_0's rmse: 0.605278
# [66]	valid_0's rmse: 0.603453
# [67]	valid_0's rmse: 0.601504
# [68]	valid_0's rmse: 0.598935
# [69]	valid_0's rmse: 0.59727
# [70]	valid_0's rmse: 0.595462
# [71]	valid_0's rmse: 0.593729
# [72]	valid_0's rmse: 0.591934
# [73]	valid_0's rmse: 0.589997
# [74]	valid_0's rmse: 0.58822
# [75]	valid_0's rmse: 0.586734
# [76]	valid_0's rmse: 0.585419
# [77]	valid_0's rmse: 0.583691
# [78]	valid_0's rmse: 0.58249
# [79]	valid_0's rmse: 0.580852
# [80]	valid_0's rmse: 0.579578
# [81]	valid_0's rmse: 0.578374
# [82]	valid_0's rmse: 0.577022
# [83]	valid_0's rmse: 0.575844
# [84]	valid_0's rmse: 0.574773
# [85]	valid_0's rmse: 0.573633
# [86]	valid_0's rmse: 0.572431
# [87]	valid_0's rmse: 0.570904
# [88]	valid_0's rmse: 0.570169
# [89]	valid_0's rmse: 0.569364
# [90]	valid_0's rmse: 0.568311
# [91]	valid_0's rmse: 0.566991
# [92]	valid_0's rmse: 0.565878
# [93]	valid_0's rmse: 0.565317
# [94]	valid_0's rmse: 0.564764
# [95]	valid_0's rmse: 0.56403
# [96]	valid_0's rmse: 0.563224
# [97]	valid_0's rmse: 0.56241
# [98]	valid_0's rmse: 0.561441
# [99]	valid_0's rmse: 0.560675
# [100]	valid_0's rmse: 0.559988
# [101]	valid_0's rmse: 0.559347
# [102]	valid_0's rmse: 0.558746
# [103]	valid_0's rmse: 0.557575
# [104]	valid_0's rmse: 0.556617
# [105]	valid_0's rmse: 0.555824
# [106]	valid_0's rmse: 0.555268
# [107]	valid_0's rmse: 0.554786
# [108]	valid_0's rmse: 0.554014
# [109]	valid_0's rmse: 0.553472
# [110]	valid_0's rmse: 0.55254
# [111]	valid_0's rmse: 0.55173
# [112]	valid_0's rmse: 0.551233
# [113]	valid_0's rmse: 0.550562
# [114]	valid_0's rmse: 0.549571
# [115]	valid_0's rmse: 0.548914
# [116]	valid_0's rmse: 0.548744
# [117]	valid_0's rmse: 0.548537
# [118]	valid_0's rmse: 0.548071
# [119]	valid_0's rmse: 0.547412
# [120]	valid_0's rmse: 0.546837
# [121]	valid_0's rmse: 0.546304
# [122]	valid_0's rmse: 0.545848
# [123]	valid_0's rmse: 0.545212
# [124]	valid_0's rmse: 0.544584
# [125]	valid_0's rmse: 0.544064
# [126]	valid_0's rmse: 0.543405
# [127]	valid_0's rmse: 0.542808
# [128]	valid_0's rmse: 0.542484
# [129]	valid_0's rmse: 0.541885
# [130]	valid_0's rmse: 0.54187
# [131]	valid_0's rmse: 0.541688
# [132]	valid_0's rmse: 0.541234
# [133]	valid_0's rmse: 0.540804
# [134]	valid_0's rmse: 0.540025
# [135]	valid_0's rmse: 0.539571
# [136]	valid_0's rmse: 0.539022
# [137]	valid_0's rmse: 0.538748
# [138]	valid_0's rmse: 0.538626
# [139]	valid_0's rmse: 0.538271
# [140]	valid_0's rmse: 0.538225
# [141]	valid_0's rmse: 0.537988
# [142]	valid_0's rmse: 0.537697
# [143]	valid_0's rmse: 0.537521
# [144]	valid_0's rmse: 0.537064
# [145]	valid_0's rmse: 0.536784
# [146]	valid_0's rmse: 0.536323
# [147]	valid_0's rmse: 0.535722
# [148]	valid_0's rmse: 0.535275
# [149]	valid_0's rmse: 0.535138
# [150]	valid_0's rmse: 0.534942
# [151]	valid_0's rmse: 0.534499
# [152]	valid_0's rmse: 0.534229
# [153]	valid_0's rmse: 0.533978
# [154]	valid_0's rmse: 0.53341
# [155]	valid_0's rmse: 0.53309
# [156]	valid_0's rmse: 0.532946
# [157]	valid_0's rmse: 0.532567
# [158]	valid_0's rmse: 0.532349
# [159]	valid_0's rmse: 0.532309
# [160]	valid_0's rmse: 0.532135
# [161]	valid_0's rmse: 0.53162
# [162]	valid_0's rmse: 0.531241
# [163]	valid_0's rmse: 0.531632
# [164]	valid_0's rmse: 0.531481
# [165]	valid_0's rmse: 0.531264
# [166]	valid_0's rmse: 0.530966
# [167]	valid_0's rmse: 0.530923
# [168]	valid_0's rmse: 0.530936
# [169]	valid_0's rmse: 0.530649
# [170]	valid_0's rmse: 0.530334
# [171]	valid_0's rmse: 0.530139
# [172]	valid_0's rmse: 0.529789
# [173]	valid_0's rmse: 0.529478
# [174]	valid_0's rmse: 0.529258
# [175]	valid_0's rmse: 0.528902
# [176]	valid_0's rmse: 0.528851
# [177]	valid_0's rmse: 0.528648
# [178]	valid_0's rmse: 0.528217
# [179]	valid_0's rmse: 0.528182
# [180]	valid_0's rmse: 0.527805
# [181]	valid_0's rmse: 0.527709
# [182]	valid_0's rmse: 0.527191
# [183]	valid_0's rmse: 0.526809
# [184]	valid_0's rmse: 0.526654
# [185]	valid_0's rmse: 0.526642
# [186]	valid_0's rmse: 0.526504
# [187]	valid_0's rmse: 0.526497
# [188]	valid_0's rmse: 0.525956
# [189]	valid_0's rmse: 0.526352
# [190]	valid_0's rmse: 0.526487
# [191]	valid_0's rmse: 0.526518
# [192]	valid_0's rmse: 0.526109
# [193]	valid_0's rmse: 0.526008
# [194]	valid_0's rmse: 0.525708
# [195]	valid_0's rmse: 0.525766
# [196]	valid_0's rmse: 0.525838
# [197]	valid_0's rmse: 0.525915
# [198]	valid_0's rmse: 0.526178
# [199]	valid_0's rmse: 0.526033
# [200]	valid_0's rmse: 0.525792
# [201]	valid_0's rmse: 0.525531
# [202]	valid_0's rmse: 0.525249
# [203]	valid_0's rmse: 0.525244
# [204]	valid_0's rmse: 0.525095
# [205]	valid_0's rmse: 0.525061
# [206]	valid_0's rmse: 0.525272
# [207]	valid_0's rmse: 0.525027
# [208]	valid_0's rmse: 0.524885
# [209]	valid_0's rmse: 0.524942
# [210]	valid_0's rmse: 0.524843
# [211]	valid_0's rmse: 0.524806
# [212]	valid_0's rmse: 0.524757
# [213]	valid_0's rmse: 0.524642
# [214]	valid_0's rmse: 0.524404
# [215]	valid_0's rmse: 0.523991
# [216]	valid_0's rmse: 0.523836
# [217]	valid_0's rmse: 0.523759
# [218]	valid_0's rmse: 0.523745
# [219]	valid_0's rmse: 0.523433
# [220]	valid_0's rmse: 0.52352
# [221]	valid_0's rmse: 0.523524
# [222]	valid_0's rmse: 0.523569
# [223]	valid_0's rmse: 0.523594
# [224]	valid_0's rmse: 0.523755
# [225]	valid_0's rmse: 0.523491
# [226]	valid_0's rmse: 0.523471
# [227]	valid_0's rmse: 0.523525
# [228]	valid_0's rmse: 0.523383
# [229]	valid_0's rmse: 0.523134
# [230]	valid_0's rmse: 0.523032
# [231]	valid_0's rmse: 0.522951
# [232]	valid_0's rmse: 0.522754
# [233]	valid_0's rmse: 0.52281
# [234]	valid_0's rmse: 0.522491
# [235]	valid_0's rmse: 0.522178
# [236]	valid_0's rmse: 0.522211
# [237]	valid_0's rmse: 0.522131
# [238]	valid_0's rmse: 0.52218
# [239]	valid_0's rmse: 0.522076
# [240]	valid_0's rmse: 0.522024
# [241]	valid_0's rmse: 0.522075
# [242]	valid_0's rmse: 0.521835
# [243]	valid_0's rmse: 0.521905
# [244]	valid_0's rmse: 0.522246
# [245]	valid_0's rmse: 0.522255
# [246]	valid_0's rmse: 0.522012
# [247]	valid_0's rmse: 0.521962
# [248]	valid_0's rmse: 0.521943
# [249]	valid_0's rmse: 0.521884
# [250]	valid_0's rmse: 0.521941
# [251]	valid_0's rmse: 0.521863
# [252]	valid_0's rmse: 0.522022
# [253]	valid_0's rmse: 0.521838
# [254]	valid_0's rmse: 0.52167
# [255]	valid_0's rmse: 0.521773
# [256]	valid_0's rmse: 0.521722
# [257]	valid_0's rmse: 0.521279
# [258]	valid_0's rmse: 0.521695
# [259]	valid_0's rmse: 0.521657
# [260]	valid_0's rmse: 0.521416
# [261]	valid_0's rmse: 0.521491
# [262]	valid_0's rmse: 0.521472
# [263]	valid_0's rmse: 0.521508
# [264]	valid_0's rmse: 0.521657
# [265]	valid_0's rmse: 0.521201
# [266]	valid_0's rmse: 0.521313
# [267]	valid_0's rmse: 0.52115
# [268]	valid_0's rmse: 0.521154
# [269]	valid_0's rmse: 0.520954
# [270]	valid_0's rmse: 0.520762
# [271]	valid_0's rmse: 0.520744
# [272]	valid_0's rmse: 0.520774
# [273]	valid_0's rmse: 0.520745
# [274]	valid_0's rmse: 0.520758
# [275]	valid_0's rmse: 0.520524
# [276]	valid_0's rmse: 0.520364
# [277]	valid_0's rmse: 0.520279
# [278]	valid_0's rmse: 0.520386
# [279]	valid_0's rmse: 0.520258
# [280]	valid_0's rmse: 0.520113
# [281]	valid_0's rmse: 0.520098
# [282]	valid_0's rmse: 0.520082
# [283]	valid_0's rmse: 0.519863
# [284]	valid_0's rmse: 0.520034
# [285]	valid_0's rmse: 0.520211
# [286]	valid_0's rmse: 0.520323
# [287]	valid_0's rmse: 0.520255
# [288]	valid_0's rmse: 0.520125
# [289]	valid_0's rmse: 0.520468
# [290]	valid_0's rmse: 0.520354
# [291]	valid_0's rmse: 0.520166
# [292]	valid_0's rmse: 0.52015
# [293]	valid_0's rmse: 0.520147
# [294]	valid_0's rmse: 0.52038
# [295]	valid_0's rmse: 0.520265
# [296]	valid_0's rmse: 0.520098
# [297]	valid_0's rmse: 0.520042
# [298]	valid_0's rmse: 0.520151
# [299]	valid_0's rmse: 0.519934
# [300]	valid_0's rmse: 0.51995
# [301]	valid_0's rmse: 0.520106
# [302]	valid_0's rmse: 0.520248
# [303]	valid_0's rmse: 0.520095
# [304]	valid_0's rmse: 0.520274
# [305]	valid_0's rmse: 0.520185
# [306]	valid_0's rmse: 0.520154
# [307]	valid_0's rmse: 0.520104
# [308]	valid_0's rmse: 0.519983
# [309]	valid_0's rmse: 0.51988
# [310]	valid_0's rmse: 0.519852
# [311]	valid_0's rmse: 0.520016
# [312]	valid_0's rmse: 0.520138
# [313]	valid_0's rmse: 0.520024
# [314]	valid_0's rmse: 0.519952
# [315]	valid_0's rmse: 0.519899
# [316]	valid_0's rmse: 0.520028
# [317]	valid_0's rmse: 0.519998
# [318]	valid_0's rmse: 0.519889
# [319]	valid_0's rmse: 0.520159
# [320]	valid_0's rmse: 0.520367
# [321]	valid_0's rmse: 0.520352
# [322]	valid_0's rmse: 0.520639
# [323]	valid_0's rmse: 0.520603
# [324]	valid_0's rmse: 0.520494
# [325]	valid_0's rmse: 0.520618
# [326]	valid_0's rmse: 0.52062
# [327]	valid_0's rmse: 0.520625
# [328]	valid_0's rmse: 0.520471
# [329]	valid_0's rmse: 0.520577
# [330]	valid_0's rmse: 0.520443
# [331]	valid_0's rmse: 0.520581
# [332]	valid_0's rmse: 0.52079
# [333]	valid_0's rmse: 0.520643
# [334]	valid_0's rmse: 0.520913
# [335]	valid_0's rmse: 0.520934
# [336]	valid_0's rmse: 0.521146
# [337]	valid_0's rmse: 0.520789
# [338]	valid_0's rmse: 0.520638
# [339]	valid_0's rmse: 0.520417
# [340]	valid_0's rmse: 0.520541
# [341]	valid_0's rmse: 0.520628
# [342]	valid_0's rmse: 0.520673
# [343]	valid_0's rmse: 0.520633
# [344]	valid_0's rmse: 0.520817
# [345]	valid_0's rmse: 0.5207
# [346]	valid_0's rmse: 0.520633
# [347]	valid_0's rmse: 0.520787
# [348]	valid_0's rmse: 0.520933
# [349]	valid_0's rmse: 0.52084
# [350]	valid_0's rmse: 0.520898
# [351]	valid_0's rmse: 0.520918
# [352]	valid_0's rmse: 0.52093
# [353]	valid_0's rmse: 0.521063
# [354]	valid_0's rmse: 0.521342
# [355]	valid_0's rmse: 0.521164
# [356]	valid_0's rmse: 0.520936
# [357]	valid_0's rmse: 0.521084
# [358]	valid_0's rmse: 0.521075
# [359]	valid_0's rmse: 0.521102
# [360]	valid_0's rmse: 0.520849
# [361]	valid_0's rmse: 0.521032
# [362]	valid_0's rmse: 0.521045
# [363]	valid_0's rmse: 0.521231
# [364]	valid_0's rmse: 0.521256
# [365]	valid_0's rmse: 0.521164
# [366]	valid_0's rmse: 0.521077
# [367]	valid_0's rmse: 0.521071
# [368]	valid_0's rmse: 0.521015
# [369]	valid_0's rmse: 0.521239
# [370]	valid_0's rmse: 0.521259
# [371]	valid_0's rmse: 0.521254
# [372]	valid_0's rmse: 0.521144
# [373]	valid_0's rmse: 0.521475
# [374]	valid_0's rmse: 0.521332
# [375]	valid_0's rmse: 0.521319
# [376]	valid_0's rmse: 0.521441
# [377]	valid_0's rmse: 0.521292
# [378]	valid_0's rmse: 0.52111
# [379]	valid_0's rmse: 0.520786
# [380]	valid_0's rmse: 0.520837
# [381]	valid_0's rmse: 0.520995
# [382]	valid_0's rmse: 0.520689
# [383]	valid_0's rmse: 0.52092
# [384]	valid_0's rmse: 0.520879
# [385]	valid_0's rmse: 0.520807
# [386]	valid_0's rmse: 0.520929
# [387]	valid_0's rmse: 0.521163
# [388]	valid_0's rmse: 0.521097
# [389]	valid_0's rmse: 0.521291
# [390]	valid_0's rmse: 0.521271
# [391]	valid_0's rmse: 0.521358
# [392]	valid_0's rmse: 0.521216
# [393]	valid_0's rmse: 0.521035
# [394]	valid_0's rmse: 0.521061
# [395]	valid_0's rmse: 0.520893
# [396]	valid_0's rmse: 0.520579
# [397]	valid_0's rmse: 0.5206
# [398]	valid_0's rmse: 0.520599
# [399]	valid_0's rmse: 0.520557
# [400]	valid_0's rmse: 0.520564
# [401]	valid_0's rmse: 0.520741
# [402]	valid_0's rmse: 0.520678
# [403]	valid_0's rmse: 0.520575
# [404]	valid_0's rmse: 0.520598
# [405]	valid_0's rmse: 0.520472
# [406]	valid_0's rmse: 0.520851
# [407]	valid_0's rmse: 0.520839
# [408]	valid_0's rmse: 0.520732
# [409]	valid_0's rmse: 0.520672
# [410]	valid_0's rmse: 0.520495
# [411]	valid_0's rmse: 0.520587
# [412]	valid_0's rmse: 0.520607
# [413]	valid_0's rmse: 0.520513
# [414]	valid_0's rmse: 0.520489
# [415]	valid_0's rmse: 0.520661
# [416]	valid_0's rmse: 0.520556
# [417]	valid_0's rmse: 0.520549
# [418]	valid_0's rmse: 0.520623
# [419]	valid_0's rmse: 0.520719
# [420]	valid_0's rmse: 0.520714
# [421]	valid_0's rmse: 0.520775
# [422]	valid_0's rmse: 0.520736
# [423]	valid_0's rmse: 0.520727
# [424]	valid_0's rmse: 0.520729
# [425]	valid_0's rmse: 0.520668
# [426]	valid_0's rmse: 0.520886
# [427]	valid_0's rmse: 0.520789
# [428]	valid_0's rmse: 0.520851
# [429]	valid_0's rmse: 0.520868
# [430]	valid_0's rmse: 0.520832
# [431]	valid_0's rmse: 0.520791
# [432]	valid_0's rmse: 0.520821
# [433]	valid_0's rmse: 0.520976
# [434]	valid_0's rmse: 0.521001
# [435]	valid_0's rmse: 0.520973
# [436]	valid_0's rmse: 0.521017
# [437]	valid_0's rmse: 0.521127
# [438]	valid_0's rmse: 0.521123
# [439]	valid_0's rmse: 0.521077
# [440]	valid_0's rmse: 0.521406
# [441]	valid_0's rmse: 0.5214
# [442]	valid_0's rmse: 0.521553
# [443]	valid_0's rmse: 0.521805
# [444]	valid_0's rmse: 0.521877
# [445]	valid_0's rmse: 0.521919
# [446]	valid_0's rmse: 0.521774
# [447]	valid_0's rmse: 0.5217
# [448]	valid_0's rmse: 0.521878
# [449]	valid_0's rmse: 0.521834
# [450]	valid_0's rmse: 0.522028
# [451]	valid_0's rmse: 0.522092
# [452]	valid_0's rmse: 0.52202
# [453]	valid_0's rmse: 0.522178
# [454]	valid_0's rmse: 0.522217
# [455]	valid_0's rmse: 0.522053
# [456]	valid_0's rmse: 0.522032
# [457]	valid_0's rmse: 0.521983
# [458]	valid_0's rmse: 0.522054
# [459]	valid_0's rmse: 0.522117
# [460]	valid_0's rmse: 0.522302
# [461]	valid_0's rmse: 0.522065
# [462]	valid_0's rmse: 0.522092
# [463]	valid_0's rmse: 0.522006
# [464]	valid_0's rmse: 0.52201
# [465]	valid_0's rmse: 0.521934
# [466]	valid_0's rmse: 0.52209
# [467]	valid_0's rmse: 0.52213
# [468]	valid_0's rmse: 0.522299
# [469]	valid_0's rmse: 0.5224
# [470]	valid_0's rmse: 0.522472
# [471]	valid_0's rmse: 0.522332
# [472]	valid_0's rmse: 0.522181
# [473]	valid_0's rmse: 0.5219
# [474]	valid_0's rmse: 0.522052
# [475]	valid_0's rmse: 0.522151
# [476]	valid_0's rmse: 0.522185
# [477]	valid_0's rmse: 0.522267
# [478]	valid_0's rmse: 0.522334
# [479]	valid_0's rmse: 0.522324
# [480]	valid_0's rmse: 0.522434
# [481]	valid_0's rmse: 0.522518
# [482]	valid_0's rmse: 0.522675
# [483]	valid_0's rmse: 0.522674
# [484]	valid_0's rmse: 0.522752
# [485]	valid_0's rmse: 0.522714
# [486]	valid_0's rmse: 0.522726
# [487]	valid_0's rmse: 0.522631
# [488]	valid_0's rmse: 0.522625
# [489]	valid_0's rmse: 0.522627
# [490]	valid_0's rmse: 0.52261
# [491]	valid_0's rmse: 0.522649
# [492]	valid_0's rmse: 0.52275
# [493]	valid_0's rmse: 0.522728
# [494]	valid_0's rmse: 0.522596
# [495]	valid_0's rmse: 0.522479
# [496]	valid_0's rmse: 0.522556
# [497]	valid_0's rmse: 0.52244
# [498]	valid_0's rmse: 0.522435
# [499]	valid_0's rmse: 0.522589
# [500]	valid_0's rmse: 0.52282
# Fold RMSE Score :  0.5198524352712088
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  2
# Trian : (2224, 550) (2224, 1)
# Valid : (247, 550) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.0306
# [2]	valid_0's rmse: 1.02015
# [3]	valid_0's rmse: 1.01077
# [4]	valid_0's rmse: 1.00186
# [5]	valid_0's rmse: 0.992669
# [6]	valid_0's rmse: 0.98359
# [7]	valid_0's rmse: 0.976123
# [8]	valid_0's rmse: 0.967589
# [9]	valid_0's rmse: 0.959924
# [10]	valid_0's rmse: 0.951602
# [11]	valid_0's rmse: 0.944216
# [12]	valid_0's rmse: 0.935991
# [13]	valid_0's rmse: 0.928212
# [14]	valid_0's rmse: 0.921128
# [15]	valid_0's rmse: 0.914117
# [16]	valid_0's rmse: 0.907249
# [17]	valid_0's rmse: 0.900978
# [18]	valid_0's rmse: 0.894581
# [19]	valid_0's rmse: 0.887934
# [20]	valid_0's rmse: 0.881613
# [21]	valid_0's rmse: 0.87561
# [22]	valid_0's rmse: 0.869329
# [23]	valid_0's rmse: 0.863788
# [24]	valid_0's rmse: 0.85791
# [25]	valid_0's rmse: 0.852224
# [26]	valid_0's rmse: 0.847205
# [27]	valid_0's rmse: 0.842259
# [28]	valid_0's rmse: 0.837623
# [29]	valid_0's rmse: 0.832723
# [30]	valid_0's rmse: 0.828309
# [31]	valid_0's rmse: 0.823964
# [32]	valid_0's rmse: 0.819466
# [33]	valid_0's rmse: 0.815362
# [34]	valid_0's rmse: 0.811327
# [35]	valid_0's rmse: 0.80721
# [36]	valid_0's rmse: 0.802795
# [37]	valid_0's rmse: 0.798937
# [38]	valid_0's rmse: 0.795053
# [39]	valid_0's rmse: 0.791327
# [40]	valid_0's rmse: 0.787171
# [41]	valid_0's rmse: 0.783981
# [42]	valid_0's rmse: 0.781011
# [43]	valid_0's rmse: 0.778157
# [44]	valid_0's rmse: 0.775468
# [45]	valid_0's rmse: 0.772487
# [46]	valid_0's rmse: 0.769938
# [47]	valid_0's rmse: 0.767107
# [48]	valid_0's rmse: 0.764267
# [49]	valid_0's rmse: 0.761269
# [50]	valid_0's rmse: 0.758768
# [51]	valid_0's rmse: 0.756223
# [52]	valid_0's rmse: 0.753456
# [53]	valid_0's rmse: 0.750959
# [54]	valid_0's rmse: 0.748493
# [55]	valid_0's rmse: 0.746122
# [56]	valid_0's rmse: 0.744282
# [57]	valid_0's rmse: 0.742531
# [58]	valid_0's rmse: 0.740712
# [59]	valid_0's rmse: 0.738674
# [60]	valid_0's rmse: 0.736669
# [61]	valid_0's rmse: 0.734648
# [62]	valid_0's rmse: 0.733046
# [63]	valid_0's rmse: 0.731345
# [64]	valid_0's rmse: 0.730069
# [65]	valid_0's rmse: 0.728558
# [66]	valid_0's rmse: 0.72721
# [67]	valid_0's rmse: 0.726001
# [68]	valid_0's rmse: 0.724567
# [69]	valid_0's rmse: 0.723392
# [70]	valid_0's rmse: 0.721917
# [71]	valid_0's rmse: 0.720455
# [72]	valid_0's rmse: 0.718541
# [73]	valid_0's rmse: 0.717565
# [74]	valid_0's rmse: 0.716365
# [75]	valid_0's rmse: 0.715138
# [76]	valid_0's rmse: 0.713951
# [77]	valid_0's rmse: 0.713094
# [78]	valid_0's rmse: 0.71206
# [79]	valid_0's rmse: 0.711183
# [80]	valid_0's rmse: 0.710163
# [81]	valid_0's rmse: 0.709407
# [82]	valid_0's rmse: 0.708551
# [83]	valid_0's rmse: 0.707337
# [84]	valid_0's rmse: 0.706457
# [85]	valid_0's rmse: 0.705448
# [86]	valid_0's rmse: 0.704105
# [87]	valid_0's rmse: 0.702892
# [88]	valid_0's rmse: 0.701595
# [89]	valid_0's rmse: 0.70063
# [90]	valid_0's rmse: 0.699918
# [91]	valid_0's rmse: 0.699375
# [92]	valid_0's rmse: 0.698849
# [93]	valid_0's rmse: 0.69846
# [94]	valid_0's rmse: 0.697872
# [95]	valid_0's rmse: 0.69709
# [96]	valid_0's rmse: 0.696067
# [97]	valid_0's rmse: 0.695519
# [98]	valid_0's rmse: 0.694832
# [99]	valid_0's rmse: 0.694222
# [100]	valid_0's rmse: 0.693689
# [101]	valid_0's rmse: 0.693222
# [102]	valid_0's rmse: 0.692843
# [103]	valid_0's rmse: 0.692019
# [104]	valid_0's rmse: 0.692145
# [105]	valid_0's rmse: 0.691722
# [106]	valid_0's rmse: 0.690853
# [107]	valid_0's rmse: 0.690553
# [108]	valid_0's rmse: 0.690296
# [109]	valid_0's rmse: 0.690044
# [110]	valid_0's rmse: 0.689804
# [111]	valid_0's rmse: 0.689248
# [112]	valid_0's rmse: 0.688762
# [113]	valid_0's rmse: 0.688577
# [114]	valid_0's rmse: 0.688284
# [115]	valid_0's rmse: 0.687924
# [116]	valid_0's rmse: 0.687628
# [117]	valid_0's rmse: 0.687357
# [118]	valid_0's rmse: 0.687167
# [119]	valid_0's rmse: 0.686766
# [120]	valid_0's rmse: 0.686439
# [121]	valid_0's rmse: 0.686095
# [122]	valid_0's rmse: 0.685396
# [123]	valid_0's rmse: 0.684691
# [124]	valid_0's rmse: 0.684284
# [125]	valid_0's rmse: 0.683824
# [126]	valid_0's rmse: 0.683608
# [127]	valid_0's rmse: 0.683209
# [128]	valid_0's rmse: 0.683106
# [129]	valid_0's rmse: 0.682781
# [130]	valid_0's rmse: 0.682388
# [131]	valid_0's rmse: 0.682099
# [132]	valid_0's rmse: 0.681784
# [133]	valid_0's rmse: 0.681534
# [134]	valid_0's rmse: 0.681432
# [135]	valid_0's rmse: 0.681656
# [136]	valid_0's rmse: 0.681436
# [137]	valid_0's rmse: 0.681222
# [138]	valid_0's rmse: 0.680989
# [139]	valid_0's rmse: 0.68064
# [140]	valid_0's rmse: 0.6805
# [141]	valid_0's rmse: 0.680095
# [142]	valid_0's rmse: 0.679787
# [143]	valid_0's rmse: 0.679714
# [144]	valid_0's rmse: 0.679711
# [145]	valid_0's rmse: 0.679606
# [146]	valid_0's rmse: 0.679315
# [147]	valid_0's rmse: 0.67926
# [148]	valid_0's rmse: 0.679068
# [149]	valid_0's rmse: 0.679018
# [150]	valid_0's rmse: 0.678882
# [151]	valid_0's rmse: 0.678501
# [152]	valid_0's rmse: 0.678815
# [153]	valid_0's rmse: 0.678659
# [154]	valid_0's rmse: 0.678349
# [155]	valid_0's rmse: 0.677988
# [156]	valid_0's rmse: 0.677621
# [157]	valid_0's rmse: 0.677273
# [158]	valid_0's rmse: 0.677027
# [159]	valid_0's rmse: 0.676936
# [160]	valid_0's rmse: 0.676649
# [161]	valid_0's rmse: 0.676718
# [162]	valid_0's rmse: 0.676596
# [163]	valid_0's rmse: 0.676759
# [164]	valid_0's rmse: 0.676715
# [165]	valid_0's rmse: 0.676449
# [166]	valid_0's rmse: 0.676465
# [167]	valid_0's rmse: 0.676611
# [168]	valid_0's rmse: 0.676832
# [169]	valid_0's rmse: 0.676909
# [170]	valid_0's rmse: 0.676788
# [171]	valid_0's rmse: 0.676721
# [172]	valid_0's rmse: 0.676595
# [173]	valid_0's rmse: 0.676689
# [174]	valid_0's rmse: 0.676626
# [175]	valid_0's rmse: 0.676624
# [176]	valid_0's rmse: 0.67662
# [177]	valid_0's rmse: 0.676662
# [178]	valid_0's rmse: 0.67651
# [179]	valid_0's rmse: 0.676197
# [180]	valid_0's rmse: 0.676135
# [181]	valid_0's rmse: 0.676337
# [182]	valid_0's rmse: 0.676397
# [183]	valid_0's rmse: 0.676779
# [184]	valid_0's rmse: 0.676794
# [185]	valid_0's rmse: 0.676832
# [186]	valid_0's rmse: 0.67642
# [187]	valid_0's rmse: 0.676276
# [188]	valid_0's rmse: 0.676441
# [189]	valid_0's rmse: 0.676531
# [190]	valid_0's rmse: 0.676466
# [191]	valid_0's rmse: 0.676485
# [192]	valid_0's rmse: 0.676268
# [193]	valid_0's rmse: 0.676171
# [194]	valid_0's rmse: 0.676309
# [195]	valid_0's rmse: 0.67622
# [196]	valid_0's rmse: 0.67617
# [197]	valid_0's rmse: 0.676079
# [198]	valid_0's rmse: 0.676325
# [199]	valid_0's rmse: 0.676407
# [200]	valid_0's rmse: 0.676641
# [201]	valid_0's rmse: 0.676729
# [202]	valid_0's rmse: 0.676859
# [203]	valid_0's rmse: 0.676885
# [204]	valid_0's rmse: 0.676868
# [205]	valid_0's rmse: 0.677036
# [206]	valid_0's rmse: 0.676929
# [207]	valid_0's rmse: 0.676913
# [208]	valid_0's rmse: 0.676985
# [209]	valid_0's rmse: 0.677175
# [210]	valid_0's rmse: 0.677113
# [211]	valid_0's rmse: 0.677387
# [212]	valid_0's rmse: 0.677407
# [213]	valid_0's rmse: 0.677349
# [214]	valid_0's rmse: 0.67721
# [215]	valid_0's rmse: 0.677411
# [216]	valid_0's rmse: 0.677218
# [217]	valid_0's rmse: 0.677318
# [218]	valid_0's rmse: 0.67736
# [219]	valid_0's rmse: 0.677421
# [220]	valid_0's rmse: 0.677466
# [221]	valid_0's rmse: 0.677386
# [222]	valid_0's rmse: 0.67731
# [223]	valid_0's rmse: 0.677444
# [224]	valid_0's rmse: 0.677501
# [225]	valid_0's rmse: 0.677608
# [226]	valid_0's rmse: 0.67797
# [227]	valid_0's rmse: 0.677946
# [228]	valid_0's rmse: 0.677755
# [229]	valid_0's rmse: 0.677929
# [230]	valid_0's rmse: 0.678132
# [231]	valid_0's rmse: 0.678003
# [232]	valid_0's rmse: 0.677984
# [233]	valid_0's rmse: 0.677935
# [234]	valid_0's rmse: 0.67747
# [235]	valid_0's rmse: 0.677372
# [236]	valid_0's rmse: 0.677348
# [237]	valid_0's rmse: 0.677423
# [238]	valid_0's rmse: 0.677422
# [239]	valid_0's rmse: 0.677308
# [240]	valid_0's rmse: 0.677433
# [241]	valid_0's rmse: 0.677492
# [242]	valid_0's rmse: 0.677584
# [243]	valid_0's rmse: 0.677409
# [244]	valid_0's rmse: 0.677563
# [245]	valid_0's rmse: 0.67765
# [246]	valid_0's rmse: 0.677509
# [247]	valid_0's rmse: 0.677364
# [248]	valid_0's rmse: 0.677286
# [249]	valid_0's rmse: 0.677055
# [250]	valid_0's rmse: 0.676884
# [251]	valid_0's rmse: 0.67673
# [252]	valid_0's rmse: 0.676558
# [253]	valid_0's rmse: 0.676629
# [254]	valid_0's rmse: 0.676407
# [255]	valid_0's rmse: 0.676287
# [256]	valid_0's rmse: 0.676118
# [257]	valid_0's rmse: 0.676017
# [258]	valid_0's rmse: 0.676036
# [259]	valid_0's rmse: 0.676182
# [260]	valid_0's rmse: 0.676184
# [261]	valid_0's rmse: 0.676566
# [262]	valid_0's rmse: 0.676643
# [263]	valid_0's rmse: 0.67662
# [264]	valid_0's rmse: 0.676813
# [265]	valid_0's rmse: 0.676886
# [266]	valid_0's rmse: 0.676932
# [267]	valid_0's rmse: 0.676901
# [268]	valid_0's rmse: 0.676839
# [269]	valid_0's rmse: 0.676838
# [270]	valid_0's rmse: 0.676632
# [271]	valid_0's rmse: 0.676479
# [272]	valid_0's rmse: 0.676545
# [273]	valid_0's rmse: 0.676602
# [274]	valid_0's rmse: 0.67614
# [275]	valid_0's rmse: 0.676015
# [276]	valid_0's rmse: 0.675969
# [277]	valid_0's rmse: 0.675783
# [278]	valid_0's rmse: 0.675857
# [279]	valid_0's rmse: 0.675804
# [280]	valid_0's rmse: 0.675934
# [281]	valid_0's rmse: 0.676003
# [282]	valid_0's rmse: 0.675948
# [283]	valid_0's rmse: 0.676155
# [284]	valid_0's rmse: 0.675784
# [285]	valid_0's rmse: 0.675594
# [286]	valid_0's rmse: 0.675466
# [287]	valid_0's rmse: 0.675238
# [288]	valid_0's rmse: 0.675381
# [289]	valid_0's rmse: 0.675325
# [290]	valid_0's rmse: 0.675188
# [291]	valid_0's rmse: 0.67515
# [292]	valid_0's rmse: 0.674989
# [293]	valid_0's rmse: 0.674927
# [294]	valid_0's rmse: 0.675165
# [295]	valid_0's rmse: 0.675111
# [296]	valid_0's rmse: 0.675178
# [297]	valid_0's rmse: 0.674982
# [298]	valid_0's rmse: 0.675058
# [299]	valid_0's rmse: 0.675105
# [300]	valid_0's rmse: 0.675179
# [301]	valid_0's rmse: 0.675205
# [302]	valid_0's rmse: 0.675051
# [303]	valid_0's rmse: 0.675073
# [304]	valid_0's rmse: 0.675089
# [305]	valid_0's rmse: 0.675012
# [306]	valid_0's rmse: 0.674971
# [307]	valid_0's rmse: 0.674944
# [308]	valid_0's rmse: 0.674744
# [309]	valid_0's rmse: 0.67467
# [310]	valid_0's rmse: 0.674669
# [311]	valid_0's rmse: 0.674716
# [312]	valid_0's rmse: 0.674778
# [313]	valid_0's rmse: 0.674739
# [314]	valid_0's rmse: 0.674765
# [315]	valid_0's rmse: 0.674604
# [316]	valid_0's rmse: 0.674634
# [317]	valid_0's rmse: 0.674641
# [318]	valid_0's rmse: 0.674677
# [319]	valid_0's rmse: 0.674746
# [320]	valid_0's rmse: 0.674609
# [321]	valid_0's rmse: 0.674533
# [322]	valid_0's rmse: 0.674534
# [323]	valid_0's rmse: 0.674542
# [324]	valid_0's rmse: 0.674573
# [325]	valid_0's rmse: 0.674572
# [326]	valid_0's rmse: 0.674537
# [327]	valid_0's rmse: 0.674407
# [328]	valid_0's rmse: 0.674387
# [329]	valid_0's rmse: 0.67434
# [330]	valid_0's rmse: 0.674552
# [331]	valid_0's rmse: 0.674686
# [332]	valid_0's rmse: 0.674737
# [333]	valid_0's rmse: 0.674759
# [334]	valid_0's rmse: 0.674617
# [335]	valid_0's rmse: 0.674615
# [336]	valid_0's rmse: 0.674367
# [337]	valid_0's rmse: 0.674353
# [338]	valid_0's rmse: 0.674166
# [339]	valid_0's rmse: 0.674291
# [340]	valid_0's rmse: 0.674272
# [341]	valid_0's rmse: 0.674128
# [342]	valid_0's rmse: 0.674067
# [343]	valid_0's rmse: 0.674209
# [344]	valid_0's rmse: 0.674153
# [345]	valid_0's rmse: 0.674141
# [346]	valid_0's rmse: 0.674271
# [347]	valid_0's rmse: 0.674294
# [348]	valid_0's rmse: 0.674524
# [349]	valid_0's rmse: 0.674502
# [350]	valid_0's rmse: 0.674283
# [351]	valid_0's rmse: 0.674306
# [352]	valid_0's rmse: 0.674266
# [353]	valid_0's rmse: 0.674375
# [354]	valid_0's rmse: 0.674548
# [355]	valid_0's rmse: 0.674444
# [356]	valid_0's rmse: 0.674323
# [357]	valid_0's rmse: 0.674326
# [358]	valid_0's rmse: 0.674443
# [359]	valid_0's rmse: 0.674467
# [360]	valid_0's rmse: 0.674646
# [361]	valid_0's rmse: 0.674744
# [362]	valid_0's rmse: 0.674939
# [363]	valid_0's rmse: 0.674855
# [364]	valid_0's rmse: 0.67469
# [365]	valid_0's rmse: 0.674576
# [366]	valid_0's rmse: 0.674506
# [367]	valid_0's rmse: 0.67458
# [368]	valid_0's rmse: 0.674497
# [369]	valid_0's rmse: 0.67455
# [370]	valid_0's rmse: 0.674592
# [371]	valid_0's rmse: 0.67454
# [372]	valid_0's rmse: 0.674773
# [373]	valid_0's rmse: 0.674665
# [374]	valid_0's rmse: 0.674572
# [375]	valid_0's rmse: 0.674572
# [376]	valid_0's rmse: 0.674592
# [377]	valid_0's rmse: 0.674704
# [378]	valid_0's rmse: 0.674884
# [379]	valid_0's rmse: 0.675077
# [380]	valid_0's rmse: 0.674811
# [381]	valid_0's rmse: 0.674931
# [382]	valid_0's rmse: 0.675224
# [383]	valid_0's rmse: 0.675241
# [384]	valid_0's rmse: 0.675231
# [385]	valid_0's rmse: 0.67533
# [386]	valid_0's rmse: 0.675383
# [387]	valid_0's rmse: 0.675513
# [388]	valid_0's rmse: 0.67546
# [389]	valid_0's rmse: 0.675657
# [390]	valid_0's rmse: 0.675689
# [391]	valid_0's rmse: 0.675593
# [392]	valid_0's rmse: 0.675524
# [393]	valid_0's rmse: 0.675473
# [394]	valid_0's rmse: 0.675473
# [395]	valid_0's rmse: 0.675653
# [396]	valid_0's rmse: 0.67589
# [397]	valid_0's rmse: 0.675897
# [398]	valid_0's rmse: 0.675945
# [399]	valid_0's rmse: 0.675891
# [400]	valid_0's rmse: 0.676044
# [401]	valid_0's rmse: 0.676163
# [402]	valid_0's rmse: 0.67617
# [403]	valid_0's rmse: 0.676257
# [404]	valid_0's rmse: 0.676187
# [405]	valid_0's rmse: 0.67618
# [406]	valid_0's rmse: 0.676016
# [407]	valid_0's rmse: 0.67576
# [408]	valid_0's rmse: 0.675863
# [409]	valid_0's rmse: 0.675909
# [410]	valid_0's rmse: 0.675954
# [411]	valid_0's rmse: 0.676242
# [412]	valid_0's rmse: 0.676112
# [413]	valid_0's rmse: 0.676213
# [414]	valid_0's rmse: 0.676209
# [415]	valid_0's rmse: 0.67639
# [416]	valid_0's rmse: 0.676547
# [417]	valid_0's rmse: 0.676382
# [418]	valid_0's rmse: 0.676589
# [419]	valid_0's rmse: 0.676488
# [420]	valid_0's rmse: 0.676718
# [421]	valid_0's rmse: 0.676527
# [422]	valid_0's rmse: 0.676544
# [423]	valid_0's rmse: 0.676289
# [424]	valid_0's rmse: 0.676181
# [425]	valid_0's rmse: 0.676387
# [426]	valid_0's rmse: 0.676254
# [427]	valid_0's rmse: 0.676241
# [428]	valid_0's rmse: 0.676212
# [429]	valid_0's rmse: 0.6764
# [430]	valid_0's rmse: 0.676163
# [431]	valid_0's rmse: 0.676201
# [432]	valid_0's rmse: 0.676324
# [433]	valid_0's rmse: 0.676085
# [434]	valid_0's rmse: 0.676106
# [435]	valid_0's rmse: 0.676186
# [436]	valid_0's rmse: 0.676261
# [437]	valid_0's rmse: 0.676097
# [438]	valid_0's rmse: 0.676106
# [439]	valid_0's rmse: 0.676024
# [440]	valid_0's rmse: 0.675826
# [441]	valid_0's rmse: 0.676097
# [442]	valid_0's rmse: 0.676203
# [443]	valid_0's rmse: 0.676247
# [444]	valid_0's rmse: 0.676212
# [445]	valid_0's rmse: 0.676118
# [446]	valid_0's rmse: 0.676023
# [447]	valid_0's rmse: 0.676232
# [448]	valid_0's rmse: 0.676268
# [449]	valid_0's rmse: 0.676282
# [450]	valid_0's rmse: 0.676194
# [451]	valid_0's rmse: 0.676199
# [452]	valid_0's rmse: 0.676288
# [453]	valid_0's rmse: 0.676087
# [454]	valid_0's rmse: 0.676194
# [455]	valid_0's rmse: 0.676163
# [456]	valid_0's rmse: 0.676316
# [457]	valid_0's rmse: 0.676368
# [458]	valid_0's rmse: 0.676169
# [459]	valid_0's rmse: 0.676155
# [460]	valid_0's rmse: 0.676129
# [461]	valid_0's rmse: 0.676012
# [462]	valid_0's rmse: 0.676251
# [463]	valid_0's rmse: 0.676356
# [464]	valid_0's rmse: 0.676407
# [465]	valid_0's rmse: 0.676384
# [466]	valid_0's rmse: 0.676278
# [467]	valid_0's rmse: 0.676243
# [468]	valid_0's rmse: 0.676277
# [469]	valid_0's rmse: 0.676084
# [470]	valid_0's rmse: 0.676018
# [471]	valid_0's rmse: 0.676179
# [472]	valid_0's rmse: 0.676213
# [473]	valid_0's rmse: 0.676574
# [474]	valid_0's rmse: 0.676551
# [475]	valid_0's rmse: 0.676384
# [476]	valid_0's rmse: 0.676372
# [477]	valid_0's rmse: 0.676238
# [478]	valid_0's rmse: 0.676304
# [479]	valid_0's rmse: 0.676465
# [480]	valid_0's rmse: 0.676648
# [481]	valid_0's rmse: 0.676871
# [482]	valid_0's rmse: 0.676937
# [483]	valid_0's rmse: 0.676922
# [484]	valid_0's rmse: 0.677069
# [485]	valid_0's rmse: 0.676909
# [486]	valid_0's rmse: 0.677111
# [487]	valid_0's rmse: 0.677174
# [488]	valid_0's rmse: 0.677209
# [489]	valid_0's rmse: 0.677302
# [490]	valid_0's rmse: 0.677219
# [491]	valid_0's rmse: 0.677257
# [492]	valid_0's rmse: 0.677214
# [493]	valid_0's rmse: 0.677336
# [494]	valid_0's rmse: 0.677165
# [495]	valid_0's rmse: 0.677188
# [496]	valid_0's rmse: 0.677303
# [497]	valid_0's rmse: 0.677228
# [498]	valid_0's rmse: 0.677353
# [499]	valid_0's rmse: 0.677372
# [500]	valid_0's rmse: 0.677439
# Fold RMSE Score :  0.6740674882752484
# ...
# ==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-==-
# Fold :  9
# Trian : (2224, 550) (2224, 1)
# Valid : (247, 550) (247, 1)
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=0.5420247656839267 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_fraction is set=0.75, subsample=0.9778252382803456 will be ignored. Current value: bagging_fraction=0.75
# [1]	valid_0's rmse: 1.07567
# [2]	valid_0's rmse: 1.06636
# [3]	valid_0's rmse: 1.05564
# [4]	valid_0's rmse: 1.04575
# [5]	valid_0's rmse: 1.03701
# [6]	valid_0's rmse: 1.02848
# [7]	valid_0's rmse: 1.02014
# [8]	valid_0's rmse: 1.012
# [9]	valid_0's rmse: 1.00404
# [10]	valid_0's rmse: 0.995549
# [11]	valid_0's rmse: 0.986748
# [12]	valid_0's rmse: 0.978749
# [13]	valid_0's rmse: 0.970726
# [14]	valid_0's rmse: 0.962264
# [15]	valid_0's rmse: 0.954489
# [16]	valid_0's rmse: 0.94692
# [17]	valid_0's rmse: 0.939361
# [18]	valid_0's rmse: 0.93244
# [19]	valid_0's rmse: 0.926082
# [20]	valid_0's rmse: 0.919591
# [21]	valid_0's rmse: 0.912536
# [22]	valid_0's rmse: 0.906086
# [23]	valid_0's rmse: 0.89971
# [24]	valid_0's rmse: 0.893557
# [25]	valid_0's rmse: 0.886978
# [26]	valid_0's rmse: 0.881243
# [27]	valid_0's rmse: 0.875815
# [28]	valid_0's rmse: 0.870554
# [29]	valid_0's rmse: 0.864632
# [30]	valid_0's rmse: 0.858829
# [31]	valid_0's rmse: 0.852787
# [32]	valid_0's rmse: 0.848028
# [33]	valid_0's rmse: 0.843138
# [34]	valid_0's rmse: 0.838255
# [35]	valid_0's rmse: 0.833093
# [36]	valid_0's rmse: 0.828081
# [37]	valid_0's rmse: 0.823414
# [38]	valid_0's rmse: 0.818839
# [39]	valid_0's rmse: 0.814698
# [40]	valid_0's rmse: 0.810374
# [41]	valid_0's rmse: 0.806156
# [42]	valid_0's rmse: 0.801979
# [43]	valid_0's rmse: 0.797994
# [44]	valid_0's rmse: 0.794031
# [45]	valid_0's rmse: 0.790386
# [46]	valid_0's rmse: 0.787146
# [47]	valid_0's rmse: 0.783605
# [48]	valid_0's rmse: 0.780093
# [49]	valid_0's rmse: 0.776589
# [50]	valid_0's rmse: 0.773509
# [51]	valid_0's rmse: 0.770187
# [52]	valid_0's rmse: 0.766362
# [53]	valid_0's rmse: 0.763393
# [54]	valid_0's rmse: 0.760791
# [55]	valid_0's rmse: 0.757518
# [56]	valid_0's rmse: 0.754642
# [57]	valid_0's rmse: 0.751559
# [58]	valid_0's rmse: 0.748833
# [59]	valid_0's rmse: 0.745753
# [60]	valid_0's rmse: 0.742912
# [61]	valid_0's rmse: 0.740385
# [62]	valid_0's rmse: 0.737977
# [63]	valid_0's rmse: 0.735708
# [64]	valid_0's rmse: 0.733269
# [65]	valid_0's rmse: 0.730757
# [66]	valid_0's rmse: 0.728129
# [67]	valid_0's rmse: 0.726032
# [68]	valid_0's rmse: 0.723945
# [69]	valid_0's rmse: 0.721555
# [70]	valid_0's rmse: 0.719071
# [71]	valid_0's rmse: 0.716878
# [72]	valid_0's rmse: 0.714811
# [73]	valid_0's rmse: 0.712683
# [74]	valid_0's rmse: 0.71073
# [75]	valid_0's rmse: 0.708506
# [76]	valid_0's rmse: 0.706541
# [77]	valid_0's rmse: 0.704562
# [78]	valid_0's rmse: 0.703008
# [79]	valid_0's rmse: 0.701223
# [80]	valid_0's rmse: 0.699357
# [81]	valid_0's rmse: 0.697641
# [82]	valid_0's rmse: 0.696419
# [83]	valid_0's rmse: 0.694746
# [84]	valid_0's rmse: 0.693391
# [85]	valid_0's rmse: 0.691748
# [86]	valid_0's rmse: 0.690322
# [87]	valid_0's rmse: 0.688608
# [88]	valid_0's rmse: 0.687231
# [89]	valid_0's rmse: 0.685743
# [90]	valid_0's rmse: 0.684518
# [91]	valid_0's rmse: 0.682686
# [92]	valid_0's rmse: 0.681607
# [93]	valid_0's rmse: 0.680314
# [94]	valid_0's rmse: 0.679041
# [95]	valid_0's rmse: 0.677788
# [96]	valid_0's rmse: 0.676628
# [97]	valid_0's rmse: 0.675005
# [98]	valid_0's rmse: 0.673719
# [99]	valid_0's rmse: 0.671878
# [100]	valid_0's rmse: 0.670825
# [101]	valid_0's rmse: 0.669644
# [102]	valid_0's rmse: 0.668716
# [103]	valid_0's rmse: 0.667779
# [104]	valid_0's rmse: 0.667066
# [105]	valid_0's rmse: 0.665917
# [106]	valid_0's rmse: 0.664969
# [107]	valid_0's rmse: 0.664104
# [108]	valid_0's rmse: 0.663182
# [109]	valid_0's rmse: 0.662708
# [110]	valid_0's rmse: 0.661845
# [111]	valid_0's rmse: 0.660736
# [112]	valid_0's rmse: 0.6599
# [113]	valid_0's rmse: 0.658811
# [114]	valid_0's rmse: 0.65797
# [115]	valid_0's rmse: 0.656853
# [116]	valid_0's rmse: 0.656031
# [117]	valid_0's rmse: 0.65502
# [118]	valid_0's rmse: 0.654078
# [119]	valid_0's rmse: 0.653108
# [120]	valid_0's rmse: 0.652206
# [121]	valid_0's rmse: 0.651673
# [122]	valid_0's rmse: 0.650823
# [123]	valid_0's rmse: 0.650024
# [124]	valid_0's rmse: 0.649534
# [125]	valid_0's rmse: 0.648881
# [126]	valid_0's rmse: 0.648269
# [127]	valid_0's rmse: 0.647619
# [128]	valid_0's rmse: 0.647131
# [129]	valid_0's rmse: 0.6465
# [130]	valid_0's rmse: 0.645534
# [131]	valid_0's rmse: 0.644918
# [132]	valid_0's rmse: 0.644361
# [133]	valid_0's rmse: 0.643887
# [134]	valid_0's rmse: 0.643291
# [135]	valid_0's rmse: 0.642759
# [136]	valid_0's rmse: 0.642382
# [137]	valid_0's rmse: 0.641903
# [138]	valid_0's rmse: 0.641728
# [139]	valid_0's rmse: 0.641052
# [140]	valid_0's rmse: 0.640802
# [141]	valid_0's rmse: 0.640447
# [142]	valid_0's rmse: 0.640012
# [143]	valid_0's rmse: 0.639127
# [144]	valid_0's rmse: 0.638221
# [145]	valid_0's rmse: 0.638072
# [146]	valid_0's rmse: 0.637813
# [147]	valid_0's rmse: 0.637444
# [148]	valid_0's rmse: 0.637048
# [149]	valid_0's rmse: 0.636609
# [150]	valid_0's rmse: 0.635828
# [151]	valid_0's rmse: 0.63552
# [152]	valid_0's rmse: 0.63477
# [153]	valid_0's rmse: 0.63458
# [154]	valid_0's rmse: 0.634362
# [155]	valid_0's rmse: 0.634211
# [156]	valid_0's rmse: 0.633823
# [157]	valid_0's rmse: 0.63351
# [158]	valid_0's rmse: 0.632974
# [159]	valid_0's rmse: 0.632731
# [160]	valid_0's rmse: 0.63212
# [161]	valid_0's rmse: 0.632175
# [162]	valid_0's rmse: 0.631908
# [163]	valid_0's rmse: 0.631609
# [164]	valid_0's rmse: 0.631456
# [165]	valid_0's rmse: 0.63111
# [166]	valid_0's rmse: 0.630934
# [167]	valid_0's rmse: 0.630625
# [168]	valid_0's rmse: 0.630209
# [169]	valid_0's rmse: 0.629718
# [170]	valid_0's rmse: 0.629466
# [171]	valid_0's rmse: 0.629327
# [172]	valid_0's rmse: 0.629201
# [173]	valid_0's rmse: 0.629007
# [174]	valid_0's rmse: 0.628884
# [175]	valid_0's rmse: 0.628665
# [176]	valid_0's rmse: 0.62828
# [177]	valid_0's rmse: 0.628057
# [178]	valid_0's rmse: 0.627958
# [179]	valid_0's rmse: 0.627492
# [180]	valid_0's rmse: 0.627208
# [181]	valid_0's rmse: 0.626709
# [182]	valid_0's rmse: 0.626432
# [183]	valid_0's rmse: 0.626107
# [184]	valid_0's rmse: 0.625862
# [185]	valid_0's rmse: 0.625935
# [186]	valid_0's rmse: 0.62589
# [187]	valid_0's rmse: 0.625551
# [188]	valid_0's rmse: 0.625262
# [189]	valid_0's rmse: 0.624748
# [190]	valid_0's rmse: 0.624663
# [191]	valid_0's rmse: 0.624179
# [192]	valid_0's rmse: 0.623988
# [193]	valid_0's rmse: 0.623897
# [194]	valid_0's rmse: 0.624001
# [195]	valid_0's rmse: 0.624029
# [196]	valid_0's rmse: 0.623696
# [197]	valid_0's rmse: 0.623555
# [198]	valid_0's rmse: 0.623336
# [199]	valid_0's rmse: 0.62329
# [200]	valid_0's rmse: 0.623313
# [201]	valid_0's rmse: 0.623126
# [202]	valid_0's rmse: 0.622964
# [203]	valid_0's rmse: 0.62312
# [204]	valid_0's rmse: 0.622983
# [205]	valid_0's rmse: 0.622942
# [206]	valid_0's rmse: 0.622853
# [207]	valid_0's rmse: 0.622814
# [208]	valid_0's rmse: 0.622699
# [209]	valid_0's rmse: 0.622373
# [210]	valid_0's rmse: 0.622323
# [211]	valid_0's rmse: 0.622073
# [212]	valid_0's rmse: 0.621875
# [213]	valid_0's rmse: 0.622
# [214]	valid_0's rmse: 0.621756
# [215]	valid_0's rmse: 0.621473
# [216]	valid_0's rmse: 0.621629
# [217]	valid_0's rmse: 0.621289
# [218]	valid_0's rmse: 0.621088
# [219]	valid_0's rmse: 0.62135
# [220]	valid_0's rmse: 0.621014
# [221]	valid_0's rmse: 0.620885
# [222]	valid_0's rmse: 0.620733
# [223]	valid_0's rmse: 0.620714
# [224]	valid_0's rmse: 0.620681
# [225]	valid_0's rmse: 0.620599
# [226]	valid_0's rmse: 0.620191
# [227]	valid_0's rmse: 0.619911
# [228]	valid_0's rmse: 0.619681
# [229]	valid_0's rmse: 0.619507
# [230]	valid_0's rmse: 0.619603
# [231]	valid_0's rmse: 0.61977
# [232]	valid_0's rmse: 0.619759
# [233]	valid_0's rmse: 0.619805
# [234]	valid_0's rmse: 0.620044
# [235]	valid_0's rmse: 0.6201
# [236]	valid_0's rmse: 0.619853
# [237]	valid_0's rmse: 0.619597
# [238]	valid_0's rmse: 0.619517
# [239]	valid_0's rmse: 0.619383
# [240]	valid_0's rmse: 0.619107
# [241]	valid_0's rmse: 0.618872
# [242]	valid_0's rmse: 0.618666
# [243]	valid_0's rmse: 0.618491
# [244]	valid_0's rmse: 0.618462
# [245]	valid_0's rmse: 0.61854
# [246]	valid_0's rmse: 0.618399
# [247]	valid_0's rmse: 0.61847
# [248]	valid_0's rmse: 0.618245
# [249]	valid_0's rmse: 0.618187
# [250]	valid_0's rmse: 0.618235
# [251]	valid_0's rmse: 0.618151
# [252]	valid_0's rmse: 0.617801
# [253]	valid_0's rmse: 0.617943
# [254]	valid_0's rmse: 0.617413
# [255]	valid_0's rmse: 0.61774
# [256]	valid_0's rmse: 0.617625
# [257]	valid_0's rmse: 0.617305
# [258]	valid_0's rmse: 0.617317
# [259]	valid_0's rmse: 0.617405
# [260]	valid_0's rmse: 0.617253
# [261]	valid_0's rmse: 0.617024
# [262]	valid_0's rmse: 0.617258
# [263]	valid_0's rmse: 0.616939
# [264]	valid_0's rmse: 0.616617
# [265]	valid_0's rmse: 0.616854
# [266]	valid_0's rmse: 0.616762
# [267]	valid_0's rmse: 0.616656
# [268]	valid_0's rmse: 0.616466
# [269]	valid_0's rmse: 0.61647
# [270]	valid_0's rmse: 0.616397
# [271]	valid_0's rmse: 0.61631
# [272]	valid_0's rmse: 0.616488
# [273]	valid_0's rmse: 0.616359
# [274]	valid_0's rmse: 0.616379
# [275]	valid_0's rmse: 0.616698
# [276]	valid_0's rmse: 0.616415
# [277]	valid_0's rmse: 0.61655
# [278]	valid_0's rmse: 0.616562
# [279]	valid_0's rmse: 0.616636
# [280]	valid_0's rmse: 0.616554
# [281]	valid_0's rmse: 0.616362
# [282]	valid_0's rmse: 0.616187
# [283]	valid_0's rmse: 0.615913
# [284]	valid_0's rmse: 0.615802
# [285]	valid_0's rmse: 0.615987
# [286]	valid_0's rmse: 0.615909
# [287]	valid_0's rmse: 0.615815
# [288]	valid_0's rmse: 0.615652
# [289]	valid_0's rmse: 0.615524
# [290]	valid_0's rmse: 0.615105
# [291]	valid_0's rmse: 0.614805
# [292]	valid_0's rmse: 0.614869
# [293]	valid_0's rmse: 0.614927
# [294]	valid_0's rmse: 0.615058
# [295]	valid_0's rmse: 0.615122
# [296]	valid_0's rmse: 0.614891
# [297]	valid_0's rmse: 0.614794
# [298]	valid_0's rmse: 0.61505
# [299]	valid_0's rmse: 0.615139
# [300]	valid_0's rmse: 0.615173
# [301]	valid_0's rmse: 0.615
# [302]	valid_0's rmse: 0.61481
# [303]	valid_0's rmse: 0.614726
# [304]	valid_0's rmse: 0.614722
# [305]	valid_0's rmse: 0.614621
# [306]	valid_0's rmse: 0.61463
# [307]	valid_0's rmse: 0.61488
# [308]	valid_0's rmse: 0.614848
# [309]	valid_0's rmse: 0.614877
# [310]	valid_0's rmse: 0.614836
# [311]	valid_0's rmse: 0.614919
# [312]	valid_0's rmse: 0.61516
# [313]	valid_0's rmse: 0.615042
# [314]	valid_0's rmse: 0.615054
# [315]	valid_0's rmse: 0.615106
# [316]	valid_0's rmse: 0.614958
# [317]	valid_0's rmse: 0.615025
# [318]	valid_0's rmse: 0.615126
# [319]	valid_0's rmse: 0.614896
# [320]	valid_0's rmse: 0.614549
# [321]	valid_0's rmse: 0.614862
# [322]	valid_0's rmse: 0.614876
# [323]	valid_0's rmse: 0.61505
# [324]	valid_0's rmse: 0.615137
# [325]	valid_0's rmse: 0.6148
# [326]	valid_0's rmse: 0.614749
# [327]	valid_0's rmse: 0.614798
# [328]	valid_0's rmse: 0.615058
# [329]	valid_0's rmse: 0.61511
# [330]	valid_0's rmse: 0.615216
# [331]	valid_0's rmse: 0.615091
# [332]	valid_0's rmse: 0.615086
# [333]	valid_0's rmse: 0.614896
# [334]	valid_0's rmse: 0.614934
# [335]	valid_0's rmse: 0.614902
# [336]	valid_0's rmse: 0.614853
# [337]	valid_0's rmse: 0.614935
# [338]	valid_0's rmse: 0.614866
# [339]	valid_0's rmse: 0.614894
# [340]	valid_0's rmse: 0.614792
# [341]	valid_0's rmse: 0.614781
# [342]	valid_0's rmse: 0.614473
# [343]	valid_0's rmse: 0.614542
# [344]	valid_0's rmse: 0.614448
# [345]	valid_0's rmse: 0.614376
# [346]	valid_0's rmse: 0.61432
# [347]	valid_0's rmse: 0.614
# [348]	valid_0's rmse: 0.613733
# [349]	valid_0's rmse: 0.613806
# [350]	valid_0's rmse: 0.613925
# [351]	valid_0's rmse: 0.613945
# [352]	valid_0's rmse: 0.61363
# [353]	valid_0's rmse: 0.613498
# [354]	valid_0's rmse: 0.61368
# [355]	valid_0's rmse: 0.613685
# [356]	valid_0's rmse: 0.613634
# [357]	valid_0's rmse: 0.613837
# [358]	valid_0's rmse: 0.614027
# [359]	valid_0's rmse: 0.614062
# [360]	valid_0's rmse: 0.614376
# [361]	valid_0's rmse: 0.614289
# [362]	valid_0's rmse: 0.614281
# [363]	valid_0's rmse: 0.614263
# [364]	valid_0's rmse: 0.61421
# [365]	valid_0's rmse: 0.614207
# [366]	valid_0's rmse: 0.614286
# [367]	valid_0's rmse: 0.614142
# [368]	valid_0's rmse: 0.614121
# [369]	valid_0's rmse: 0.614154
# [370]	valid_0's rmse: 0.614289
# [371]	valid_0's rmse: 0.614241
# [372]	valid_0's rmse: 0.614173
# [373]	valid_0's rmse: 0.614077
# [374]	valid_0's rmse: 0.614055
# [375]	valid_0's rmse: 0.614023
# [376]	valid_0's rmse: 0.614062
# [377]	valid_0's rmse: 0.613986
# [378]	valid_0's rmse: 0.613842
# [379]	valid_0's rmse: 0.614081
# [380]	valid_0's rmse: 0.614134
# [381]	valid_0's rmse: 0.614077
# [382]	valid_0's rmse: 0.614311
# [383]	valid_0's rmse: 0.614337
# [384]	valid_0's rmse: 0.614331
# [385]	valid_0's rmse: 0.614171
# [386]	valid_0's rmse: 0.614309
# [387]	valid_0's rmse: 0.614397
# [388]	valid_0's rmse: 0.614517
# [389]	valid_0's rmse: 0.614552
# [390]	valid_0's rmse: 0.61462
# [391]	valid_0's rmse: 0.614717
# [392]	valid_0's rmse: 0.614813
# [393]	valid_0's rmse: 0.614493
# [394]	valid_0's rmse: 0.614468
# [395]	valid_0's rmse: 0.614601
# [396]	valid_0's rmse: 0.614597
# [397]	valid_0's rmse: 0.614784
# [398]	valid_0's rmse: 0.615035
# [399]	valid_0's rmse: 0.61499
# [400]	valid_0's rmse: 0.615108
# [401]	valid_0's rmse: 0.61499
# [402]	valid_0's rmse: 0.615048
# [403]	valid_0's rmse: 0.615122
# [404]	valid_0's rmse: 0.615143
# [405]	valid_0's rmse: 0.615068
# [406]	valid_0's rmse: 0.61505
# [407]	valid_0's rmse: 0.614836
# [408]	valid_0's rmse: 0.614769
# [409]	valid_0's rmse: 0.614889
# [410]	valid_0's rmse: 0.614769
# [411]	valid_0's rmse: 0.614829
# [412]	valid_0's rmse: 0.614571
# [413]	valid_0's rmse: 0.614471
# [414]	valid_0's rmse: 0.614329
# [415]	valid_0's rmse: 0.614166
# [416]	valid_0's rmse: 0.614199
# [417]	valid_0's rmse: 0.61406
# [418]	valid_0's rmse: 0.61399
# [419]	valid_0's rmse: 0.614009
# [420]	valid_0's rmse: 0.613966
# [421]	valid_0's rmse: 0.613843
# [422]	valid_0's rmse: 0.61369
# [423]	valid_0's rmse: 0.613546
# [424]	valid_0's rmse: 0.613642
# [425]	valid_0's rmse: 0.613613
# [426]	valid_0's rmse: 0.613751
# [427]	valid_0's rmse: 0.614034
# [428]	valid_0's rmse: 0.614171
# [429]	valid_0's rmse: 0.614051
# [430]	valid_0's rmse: 0.61422
# [431]	valid_0's rmse: 0.614145
# [432]	valid_0's rmse: 0.614152
# [433]	valid_0's rmse: 0.614152
# [434]	valid_0's rmse: 0.614295
# [435]	valid_0's rmse: 0.614477
# [436]	valid_0's rmse: 0.614735
# [437]	valid_0's rmse: 0.614749
# [438]	valid_0's rmse: 0.614687
# [439]	valid_0's rmse: 0.614776
# [440]	valid_0's rmse: 0.614769
# [441]	valid_0's rmse: 0.614903
# [442]	valid_0's rmse: 0.615132
# [443]	valid_0's rmse: 0.61502
# [444]	valid_0's rmse: 0.61487
# [445]	valid_0's rmse: 0.615039
# [446]	valid_0's rmse: 0.615038
# [447]	valid_0's rmse: 0.615242
# [448]	valid_0's rmse: 0.615404
# [449]	valid_0's rmse: 0.615412
# [450]	valid_0's rmse: 0.61546
# [451]	valid_0's rmse: 0.615462
# [452]	valid_0's rmse: 0.615557
# [453]	valid_0's rmse: 0.615498
# [454]	valid_0's rmse: 0.615501
# [455]	valid_0's rmse: 0.615576
# [456]	valid_0's rmse: 0.61561
# [457]	valid_0's rmse: 0.61561
# [458]	valid_0's rmse: 0.615332
# [459]	valid_0's rmse: 0.615222
# [460]	valid_0's rmse: 0.615368
# [461]	valid_0's rmse: 0.615241
# [462]	valid_0's rmse: 0.615259
# [463]	valid_0's rmse: 0.61527
# [464]	valid_0's rmse: 0.615304
# [465]	valid_0's rmse: 0.615439
# [466]	valid_0's rmse: 0.6157
# [467]	valid_0's rmse: 0.615829
# [468]	valid_0's rmse: 0.61596
# [469]	valid_0's rmse: 0.615753
# [470]	valid_0's rmse: 0.615722
# [471]	valid_0's rmse: 0.615686
# [472]	valid_0's rmse: 0.615718
# [473]	valid_0's rmse: 0.615702
# [474]	valid_0's rmse: 0.61578
# [475]	valid_0's rmse: 0.615879
# [476]	valid_0's rmse: 0.616017
# [477]	valid_0's rmse: 0.616087
# [478]	valid_0's rmse: 0.615925
# [479]	valid_0's rmse: 0.615832
# [480]	valid_0's rmse: 0.615947
# [481]	valid_0's rmse: 0.61587
# [482]	valid_0's rmse: 0.615898
# [483]	valid_0's rmse: 0.616158
# [484]	valid_0's rmse: 0.616015
# [485]	valid_0's rmse: 0.616214
# [486]	valid_0's rmse: 0.616227
# [487]	valid_0's rmse: 0.616287
# [488]	valid_0's rmse: 0.616453
# [489]	valid_0's rmse: 0.61667
# [490]	valid_0's rmse: 0.616671
# [491]	valid_0's rmse: 0.616871
# [492]	valid_0's rmse: 0.616901
# [493]	valid_0's rmse: 0.616824
# [494]	valid_0's rmse: 0.616909
# [495]	valid_0's rmse: 0.616972
# [496]	valid_0's rmse: 0.617026
# [497]	valid_0's rmse: 0.616965
# [498]	valid_0's rmse: 0.616952
# [499]	valid_0's rmse: 0.616712
# [500]	valid_0's rmse: 0.61686
# Fold RMSE Score :  0.6134983737292414
# OOF RMSE Score :  0.6077963781408956

# %% [markdown]
# # Submission

# %%
clean_memory()

# %%
sub1.rename(columns={'score': 'score_1'}, inplace=True)
sub2.rename(columns={'score': 'score_2'}, inplace=True)
sub3.rename(columns={'score': 'score_3'}, inplace=True)

submission = pd.merge(sub1, sub2, on='id')
submission = pd.merge(submission, sub3, on='id')

submission['score'] = (submission['score_1']*0.1 +  #LGBM + NN (Weighted search for "print(W)")
                       submission['score_2']*0.3 +  #LGBM Public
                       submission['score_3']*0.6)   #Fusion

submission_final = submission[['id', 'score']]

# %%
submission_final.to_csv('submission.csv', index=False)

# %%
submission_final
# Out:
#          id     score
# 0  0000aaaa  1.319241
# 1  2222bbbb  0.762568
# 2  4444cccc  0.692047
